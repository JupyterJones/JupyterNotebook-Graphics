# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
count=1
search = raw_input("Title :")
# ONLY the DATA table can use MATCH
for row in c.execute('SELECT rowid,* FROM ipynb WHERE ipynb MATCH ?',(search,)):
    if search in row[1] or search in row[3]:
        print row[0],row[1],row[3],"\n----------------------"
        count=count+1
        if count>20:break
c.close()
conn.close()
# Out:
# Title :Graphic
# 373 Desktop_JupyterNotebook-Graphics_TitleandSigntitlenpost.py152695701516152695701516_TitleandSigntitlenpost.py152695701516152695701516.ipynb Titleand Signtitlenpost.py152695701516152695701516 Date :Sat Sep  8 11:10:12 2018
# ----------------------
# 557 Desktop_JupyterNotebook-Graphics_WordcloudImageGeneratorforgithub152584611653152584611653_WordcloudImageGeneratorforgithub152584611653152584611653.ipynb Wordcloud Image Generatorforgithub152584611653152584611653 Date :Sat Sep  8 08:11:32 2018
# ----------------------
# 577 Desktop_JupyterNotebook-Graphics_ImageEffectsBotCopy1150331676885150331676885_ImageEffectsBotCopy1150331676885150331676885.ipynb Image Effects Bot Copy1150331676885150331676885 Date :Sat Sep  8 08:11:32 2018
# ----------------------
# 729 Desktop_JupyterNotebook-Graphics_creating-saving-using_npy-filters-checkpoint_creating-saving-using_npy-filters-checkpoint.ipynb creating saving using npy filters checkpoint Date :Fri Sep  7 10:53:11 2018
# ----------------------
# 787 Desktop_JupyterNotebook-Graphics_jupyter-to-database-FTS4151799372055151799372055_jupyter-to-database-FTS4151799372055151799372055.ipynb jupyter to database FTS4151799372055151799372055 Date :Sat Sep  8 11:44:28 2018
# ----------------------
# 1311 Desktop_JupyterNotebook-Graphics_FirstCellManualPost_Screen_capture_Python_and_OS150535313078150535313078_FirstCellManualPost_Screen_capture_Python_and_OS150535313078150535313078.ipynb First Cell Manual Post Screen capture Python and OS150535313078150535313078 Date :Sat Sep  8 08:20:32 2018
# ----------------------

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
count=1
search = raw_input("Title :")
# ONLY the DATA table can use MATCH
for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE description MATCH ?',(search,)):
    print row[0],row[1],row[3],"\n----------------------"
    count=count+1
    if count>13:break
c.close()
conn.close()
# Out:
# Title :Mosaic
# 513 _home_conda_Desktop_NoteBooks_GRAPHICS_725_Mosaic_Maker151218772313151218772313_725_Mosaic_Maker151218772313151218772313.ipynb 725 Mosaic Maker151218772313151218772313 Date :Mon Jul 23 12:30:57 2018
# ----------------------
# 514 Index 725 Mosaic Maker151218772313151218772313 Date :Mon Jul 23 12:30:57 2018
# ----------------------

# %% [markdown]
# # View the Notebook file ODD NUMBERS ARE NOTEBOOKS
# ## Even numbers descriptions

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ROWID :")
for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE rowid = ?',(search,)):
    print row[2]
c.close()
conn.close()

# %% [markdown]
# # Create a Jupyter Notebook from the Database

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"

conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ID :")
#filename = search+"DB.ipynb"
#f= open(filename,"w");f.close()
SEARCH = int(search)+1
for row in c.execute('SELECT content FROM ipynb WHERE rowid == ?', (SEARCH,)):
        filename = row[0]
print filename        
with open(filename, 'w') as outfile:
    for row in c.execute('SELECT content FROM ipynb WHERE rowid == ?', (search,)):
        row0 = row[0]
        #row0 =str(row0,"\n")
        outfile.write(row0)
        #print row0
print filename        
conn.close()
outfile.close()


  # 427
# Out:
# ID :513
# _home_conda_Desktop_NoteBooks_GRAPHICS_725_Mosaic_Maker151218772313151218772313_725_Mosaic_Maker151218772313151218772313.ipynb
# _home_conda_Desktop_NoteBooks_GRAPHICS_725_Mosaic_Maker151218772313151218772313_725_Mosaic_Maker151218772313151218772313.ipynb
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cd6a53fa0aee> in <module>()
#      24 print filename
#      25 conn.close()
# ---> 26 f.close()
#      27
#      28
#
# NameError: name 'f' is not defined

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ROWID :")
for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE rowid = ?',(search,)):
    print row[2]
c.close()
conn.close()

# %%
import os
import os.path
title = "sept8_IPNB.list"
f= open(title,"w");f.close()
count=0
for dirpath, dirnames, filenames in os.walk("/home/"):
    filenames = [f for f in filenames if not f[0] == '.']
    dirnames[:] = [d for d in dirnames if not d[0] == '.']
    for filename in [f for f in filenames if f.endswith(".ipynb")]:
        count=count+1
        Path = os.path.join(dirpath, filename)
        with open(title, 'a') as outfile:
            path = Path+"\n"
            outfile.write(path)

# %%
import sqlite3
import re
import sys
import time
import os
database = "sept8_IPNB.list.db"
#database = "junk2.db"
conn = sqlite3.connect(database)
conn.text_factory = lambda x: unicode(x, "utf-8", "ignore")
c = conn.cursor()
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS4(file, content, description);
""")
conn.commit()
conn.close()
conn = sqlite3.connect(database)
c = conn.cursor()
count=1
titlelist = "sept8_IPNB.list"
titles = open(titlelist,"r")
for title in titles.readlines():
    title = title.replace("\n", "")
    dt=time.ctime(os.path.getctime(title))
    dt=str(dt)
    filename = os.path.basename(title)
    # Use for debug print filename,":"
    description = filename
    description = description.replace("-", " ")
    description = description.replace("_", " ")
    description = description.replace(".ipynb", " ")
    description = re.sub("([a-z])([A-Z])","\g<1> \g<2>",description)
    
    
    dt=time.ctime(os.path.getctime(title))
    dt=str(dt)
    #dt = dt.replace(" ","")
    description = description+"Date :"+dt
    suf = title.replace("/home/jack/","")
    suf = suf.replace(".ipynb","_")
    suf = suf.replace("/","_")
    filename = suf+filename
    with open(title, "rb") as input_file:
                ablob = input_file.read()
                content  = sqlite3.Binary(ablob)
                c.execute("INSERT INTO ipynb (file, content, description) VALUES(?, ?, ?)", 
                      (filename, content, description))
                
                conn.commit()
    line = file
    #line ="Good-mouse-sizing-and-cropping.ipynb"
    index = "Index"
    c.execute("INSERT INTO ipynb VALUES (?,?,?)", (index, filename, description)) 
    conn.commit()
    count=count+1
    print count,filename, description

c.close()
conn.close()
# Out:
# 2 Untitled_Untitled.ipynb Untitled Date :Fri Apr 28 06:44:57 2017
# 3 JuliaIntroGood_JuliaIntroGood.ipynb Julia Intro Good Date :Sun Nov 19 16:38:08 2017
# 4 Untitled1_Untitled1.ipynb Untitled1 Date :Sat May  6 22:26:17 2017
# 5 Untitled3_Untitled3.ipynb Untitled3 Date :Sun Jun 11 10:30:25 2017
# 6 Untitled2_Untitled2.ipynb Untitled2 Date :Sun Jun 11 09:41:56 2017
# 7 PycharmProjects_webcam_webcam_webcam.ipynb webcam Date :Mon Jun 26 12:26:40 2017
# 8 Desktop_jack_watch_top_10_python_idioms_top_10_python_idioms.ipynb top 10 python idioms Date :Thu Apr  6 09:29:53 2017
# 9 Desktop_jack_watch_gmail_gmail.ipynb gmail Date :Sat Apr  8 13:33:50 2017
# 10 Desktop_jack_watch_FACESANDFRIENDS_FACESANDFRIENDS.ipynb FACESANDFRIENDS Date :Sat Apr  8 15:08:52 2017
# 11 Desktop_jack_watch_IndeedJobs_IndeedJobs.ipynb Indeed Jobs Date :Sat Apr  8 14:27:06 2017
# 12 Desktop_jack_watch_IPythonMagic_IPythonMagic.ipynb IPython Magic Date :Tue Apr  4 11:26:15 2017
# 13 Desktop_jack_watch_Intro_Intro.ipynb Intro Date :Tue Apr  4 11:27:33 2017
# 14 Desktop_jack_watch_bollinger_bollinger.ipynb bollinger Date :Fri Apr  7 13:12:43 2017
# 15 Desktop_jack_watch_Untitled_Untitled.ipynb Untitled Date :Tue Apr  4 17:33:58 2017
# 16 Desktop_jack_watch_plot_iris_dataset_plot_iris_dataset.ipynb plot iris dataset Date :Sun Apr  9 14:25:10 2017
# 17 Desktop_jack_watch_Matplotlib_Matplotlib.ipynb Matplotlib Date :Tue Apr  4 13:09:30 2017
# 18 Desktop_jack_watch_index_index.ipynb index Date :Thu Apr  6 12:39:47 2017
# 19 Desktop_jack_watch_ThreeBodyProblem_ThreeBodyProblem.ipynb Three Body Problem Date :Sun Nov 19 17:17:22 2017
# 20 Desktop_jack_watch_twitterbak_twitterbak.ipynb twitterbak Date :Sun Nov 19 17:17:22 2017
# 21 Desktop_jack_watch_sqlite_sqlite.ipynb sqlite Date :Sat Apr  8 14:14:16 2017
# 22 Desktop_jack_watch_My_SQLite_My_SQLite.ipynb My SQLite Date :Tue Apr  4 18:13:52 2017
# 23 Desktop_jack_watch_Index(1)_Index(1).ipynb Index(1) Date :Sun Nov 19 17:17:22 2017
# 24 Desktop_jack_watch_AnimationEmbedding_AnimationEmbedding.ipynb Animation Embedding Date :Thu Apr  6 09:31:56 2017
# 25 Desktop_jack_watch_Chapter9LoadingdatafromSQLdatabases_Chapter9LoadingdatafromSQLdatabases.ipynb Chapter9Loadingdatafrom SQLdatabases Date :Sun Nov 19 17:17:22 2017
# 26 Desktop_jack_watch_XKCD_plots_XKCD_plots.ipynb XKCD plots Date :Thu Apr  6 09:20:46 2017
# 27 Desktop_jack_watch_ImageDownloads_ImageDownloads.ipynb Image Downloads Date :Thu Apr  6 09:29:24 2017
# 28 Desktop_jack_watch_tweepy_tutorial_tweepy_tutorial.ipynb tweepy tutorial Date :Sat Apr  8 13:50:26 2017
# 29 Desktop_jack_watch_SciPy_SciPy.ipynb Sci Py Date :Thu Apr  6 15:39:05 2017
# 30 Desktop_jack_watch_MathTeachersTalk2014_MathTeachersTalk2014.ipynb Math Teachers Talk2014 Date :Sat Apr  8 16:29:21 2017
# 31 Desktop_jack_watch_lorenz_lorenz.ipynb lorenz Date :Fri Apr  7 13:12:05 2017
# 32 Desktop_jack_watch_twitter_twitter.ipynb twitter Date :Wed Apr  5 18:04:36 2017
# 33 Desktop_jack_watch_08afile_io_08afile_io.ipynb 08afile io Date :Sun Nov 19 17:17:22 2017
# 34 Desktop_jack_watch_Untitled1_Untitled1.ipynb Untitled1 Date :Tue Apr  4 17:43:35 2017
# 35 Desktop_jack_watch_SineAndSquareWaves_SineAndSquareWaves.ipynb Sine And Square Waves Date :Sat Apr  8 16:26:42 2017
# 36 Desktop_jack_watch_Untitled3_Untitled3.ipynb Untitled3 Date :Sat Apr  8 17:01:41 2017
# 37 Desktop_jack_watch_tutorial_tutorial.ipynb tutorial Date :Thu Apr  6 09:26:22 2017
# 38 Desktop_jack_watch_Untitled4_Untitled4.ipynb Untitled4 Date :Sat Apr  8 17:03:54 2017
# 39 Desktop_jack_watch_IP6NLTKTokenizing_IP6NLTKTokenizing.ipynb IP6NLTKTokenizing Date :Sun Nov 19 17:17:22 2017
# 40 Desktop_jack_watch_mario_mario.ipynb mario Date :Thu Apr  6 11:17:24 2017
# 41 Desktop_jack_watch_xkcd1313part2_xkcd1313part2.ipynb xkcd1313part2 Date :Sun Nov 19 17:17:22 2017
# 42 Desktop_jack_watch_BASIC_image_processing_BASIC_image_processing.ipynb BASIC image processing Date :Thu Apr  6 09:22:52 2017
# 43 Desktop_jack_watch_plot_multioutput_face_completion_plot_multioutput_face_completion.ipynb plot multioutput face completion Date :Sun Apr  9 14:29:24 2017
# 44 Desktop_jack_watch_the_cosmic_spectrum_and_the_color_of_the_universe_the_cosmic_spectrum_and_the_color_of_the_universe.ipynb the cosmic spectrum and the color of the universe Date :Thu Apr  6 09:28:59 2017
# 45 Desktop_jack_watch_FractalCircles_FractalCircles.ipynb Fractal Circles Date :Sun Nov 19 17:17:22 2017
# 46 Desktop_jack_watch_Untitled2_Untitled2.ipynb Untitled2 Date :Tue Apr  4 18:11:35 2017
# 47 Desktop_jack_watch_Birthday_Birthday.ipynb Birthday Date :Sat Apr  8 16:25:51 2017
# 48 Desktop_jack_watch_CapturingOutput_CapturingOutput.ipynb Capturing Output Date :Sun Nov 19 17:17:22 2017
# 49 Desktop_jack_watch_Comparison_Comparison.ipynb Comparison Date :Thu Apr  6 09:31:23 2017
# 50 Desktop_jack_watch_03._OpenCV_03._OpenCV.ipynb 03. Open CV Date :Thu Apr  6 11:35:12 2017
# 51 Desktop_jack_watch_LearningComputingwithRobots_LearningComputingwithRobots.ipynb Learning Computingwith Robots Date :Sun Nov 19 17:17:22 2017
# 52 Desktop_jack_watch_texas_texas.ipynb texas Date :Fri Apr  7 13:13:33 2017
# 53 Desktop_jack_watch_Intro_Python_NLP_Intro_Python_NLP.ipynb Intro Python NLP Date :Mon Apr  3 17:28:26 2017
# 54 Desktop_jack_watch_Pendulum_Pendulum.ipynb Pendulum Date :Thu Apr  6 09:37:35 2017
# 55 Desktop_jack_watch_IntrotoScikitLearn_IntrotoScikitLearn.ipynb Introto Scikit Learn Date :Sun Nov 19 17:17:22 2017
# 56 Desktop_jack_watch_FunctionalGeometry_FunctionalGeometry.ipynb Functional Geometry Date :Sun Nov 19 17:17:22 2017
# 57 Desktop_jack_watch_mining_website_mining_website.ipynb mining website Date :Tue Apr  4 17:28:30 2017
# 58 Desktop_jack_watch_NLTK_NLTK.ipynb NLTK Date :Tue Apr  4 15:52:02 2017
# 59 Desktop_jack_watch_Python-Lectures_06_06.ipynb 06 Date :Tue Apr  4 17:40:10 2017
# 60 Desktop_jack_watch_Python-Lectures_00_00.ipynb 00 Date :Tue Apr  4 17:40:10 2017
# 61 Desktop_jack_watch_Python-Lectures_05_05.ipynb 05 Date :Tue Apr  4 17:40:10 2017
# 62 Desktop_jack_watch_Python-Lectures_07_07.ipynb 07 Date :Tue Apr  4 17:40:10 2017
# 63 Desktop_jack_watch_Python-Lectures_01_01.ipynb 01 Date :Tue Apr  4 17:40:10 2017
# 64 Desktop_jack_watch_Python-Lectures_03_03.ipynb 03 Date :Tue Apr  4 17:40:10 2017
# 65 Desktop_jack_watch_Python-Lectures_04_04.ipynb 04 Date :Tue Apr  4 17:40:10 2017
# 66 Desktop_jack_watch_Python-Lectures_02_02.ipynb 02 Date :Tue Apr  4 18:23:08 2017
# 67 Desktop_jack_watch_nltk_nltksession4_nltksession4.ipynb nltksession4 Date :Sun Nov 19 17:17:22 2017
# 68 Desktop_jack_watch_nltk_nltksession1_nltksession1.ipynb nltksession1 Date :Sun Nov 19 17:17:22 2017
# 69 Desktop_jack_watch_nltk_nltksession3_nltksession3.ipynb nltksession3 Date :Sun Nov 19 17:17:22 2017
# 70 Desktop_jack_watch_nltk_nltksession2_nltksession2.ipynb nltksession2 Date :Sun Nov 19 17:17:22 2017
# 71 Desktop_jack_watch_nltk_resources_completed-notebooks_nltksession2complete_nltksession2complete.ipynb nltksession2complete Date :Sun Nov 19 17:17:22 2017
# 72 Desktop_jack_watch_nltk_resources_completed-notebooks_nltksession1complete_nltksession1complete.ipynb nltksession1complete Date :Sun Nov 19 17:17:22 2017
# 73 Desktop_jack_watch_nltk_resources_completed-notebooks_resbazday1complete_resbazday1complete.ipynb resbazday1complete Date :Sun Nov 19 17:17:22 2017
# 74 Desktop_jack_watch_nltk_resources_completed-notebooks_resbazday2complete_resbazday2complete.ipynb resbazday2complete Date :Sun Nov 19 17:17:22 2017
# 75 Desktop_jack_watch_nltk_resources_completed-notebooks_nltksession4complete_nltksession4complete.ipynb nltksession4complete Date :Sun Nov 19 17:17:22 2017
# 76 Desktop_jack_watch_nltk_resources_completed-notebooks_nltksession3complete_nltksession3complete.ipynb nltksession3complete Date :Sun Nov 19 17:17:22 2017
# 77 Desktop_jack_watch_jupyter_examples-master_SVGonjupyter_SVGonjupyter.ipynb SVGonjupyter Date :Sun Nov 19 17:17:23 2017
# 78 Desktop_jack_watch_jupyter_examples-master_Theano_Theano.ipynb Theano Date :Thu Apr  6 11:34:41 2017
# 79 Desktop_jack_watch_jupyter_examples-master_chainer_chainer.ipynb chainer Date :Thu Apr  6 14:44:42 2017
# 80 Desktop_jack_watch_jupyter_examples-master_tensorflow_tensorflow.ipynb tensorflow Date :Thu Apr  6 11:34:41 2017
# 81 Desktop_jack_watch_jupyter_examples-master_networkx_networkx.ipynb networkx Date :Thu Apr  6 11:34:41 2017
# 82 Desktop_jack_watch_jupyter_examples-master_chainer_mnist_1.13_chainer_mnist_1.13.ipynb chainer mnist 1.13 Date :Thu Apr  6 11:34:41 2017
# 83 Desktop_jack_watch_jupyter_examples-master_opencv_opencv.ipynb opencv Date :Thu Apr  6 11:34:41 2017
# 84 Desktop_jack_watch_jupyter_examples-master_sympy_sympy.ipynb sympy Date :Thu Apr  6 11:34:41 2017
# 85 Desktop_jack_watch_jupyter_examples-master_bokeh_bokeh.ipynb bokeh Date :Thu Apr  6 14:27:16 2017
# 86 Desktop_jack_watch_jupyter_examples-master_seaborn_seaborn.ipynb seaborn Date :Thu Apr  6 11:34:41 2017
# 87 Desktop_jack_watch_jupyter_examples-master_lightning_lightning.ipynb lightning Date :Thu Apr  6 14:39:03 2017
# 88 Desktop_jack_watch_jupyter_examples-master_slide_slide.ipynb slide Date :Thu Apr  6 15:22:29 2017
# 89 Desktop_jack_watch_jupyter_examples-master_chainer_mnist_chainer_mnist.ipynb chainer mnist Date :Thu Apr  6 11:34:41 2017
# 90 Desktop_jack_watch_jupyter_examples-master_ipywidgets_ipywidgets.ipynb ipywidgets Date :Thu Apr  6 15:10:32 2017
# 91 Desktop_jack_watch_jupyter_examples-master_Keras_mnist_Keras_mnist.ipynb Keras mnist Date :Thu Apr  6 11:34:41 2017
# 92 Desktop_jack_watch_nltk-_nltk_test_twitter_twitter.ipynb twitter Date :Tue Apr  4 07:52:12 2017
# 93 Desktop_jack_watch_python-lessons_dictionaries_dictionaries.ipynb dictionaries Date :Fri Apr  7 08:25:51 2017
# 94 Desktop_jack_watch_python-lessons_var_string_num_var_string_num.ipynb var string num Date :Fri Apr  7 08:24:18 2017
# 95 Desktop_jack_watch_python-lessons_while_input_while_input.ipynb while input Date :Fri Apr  7 08:25:18 2017
# 96 Desktop_jack_watch_python-lessons_Untitled_Untitled.ipynb Untitled Date :Sat Apr  8 16:02:34 2017
# 97 Desktop_jack_watch_python-lessons_lists_tuples_lists_tuples.ipynb lists tuples Date :Fri Apr  7 08:23:55 2017
# 98 Desktop_jack_watch_python-lessons_classes_classes.ipynb classes Date :Fri Sep  1 07:55:06 2017
# 99 Desktop_jack_watch_python-lessons_introducing_functions_introducing_functions.ipynb introducing functions Date :Fri Apr  7 08:23:13 2017
# 100 Desktop_jack_watch_python-lessons_if_statements_if_statements.ipynb if statements Date :Fri Apr  7 08:23:13 2017
# 101 Desktop_jack_watch_python-lessons_hello_world_hello_world.ipynb hello world Date :Fri Apr  7 08:24:40 2017
# 102 Desktop_jack_watch_python-lessons_Working_Py2.7_MySQL_Working_Py2.7_MySQL.ipynb Working Py2.7 My SQL Date :Sat Apr  8 14:29:11 2017
# 103 Desktop_jack_watch_python-lessons_terminal_apps_terminal_apps.ipynb terminal apps Date :Fri Apr  7 08:25:36 2017
# 104 Desktop_jack_watch_python-lessons_more_functions_more_functions.ipynb more functions Date :Fri Apr  7 08:23:13 2017
# 105 Desktop_altair_NewNotebook_NewNotebook.ipynb New Notebook Date :Wed Aug  9 07:47:50 2017
# 106 Desktop_altair_altair_altair_notebooks_04BarCharts_04BarCharts.ipynb 04Bar Charts Date :Sun Nov 19 17:17:24 2017
# 107 Desktop_altair_altair_altair_notebooks_10Heatmaps_10Heatmaps.ipynb 10Heatmaps Date :Sun Nov 19 17:17:24 2017
# 108 Desktop_altair_altair_altair_notebooks_03ScatterCharts_03ScatterCharts.ipynb 03Scatter Charts Date :Sun Nov 19 17:17:24 2017
# 109 Desktop_altair_altair_altair_notebooks_05LineCharts_05LineCharts.ipynb 05Line Charts Date :Sun Nov 19 17:17:24 2017
# 110 Desktop_altair_altair_altair_notebooks_12Measles_12Measles.ipynb 12Measles Date :Sun Nov 19 17:17:24 2017
# 111 Desktop_altair_altair_altair_notebooks_06AreaCharts_06AreaCharts.ipynb 06Area Charts Date :Sun Nov 19 17:17:24 2017
# 112 Desktop_altair_altair_altair_notebooks_API_API.ipynb API Date :Wed Aug  9 07:31:41 2017
# 113 Desktop_altair_altair_altair_notebooks_07LayeredCharts_07LayeredCharts.ipynb 07Layered Charts Date :Sun Nov 19 17:17:24 2017
# 114 Desktop_altair_altair_altair_notebooks_02Introduction_02Introduction.ipynb 02Introduction Date :Sun Nov 19 17:17:24 2017
# 115 Desktop_altair_altair_altair_notebooks_08GroupedRegressionCharts_08GroupedRegressionCharts.ipynb 08Grouped Regression Charts Date :Sun Nov 19 17:17:24 2017
# 116 Desktop_altair_altair_altair_notebooks_01Index_01Index.ipynb 01Index Date :Sun Nov 19 17:17:24 2017
# 117 Desktop_altair_altair_altair_notebooks_09CarsDataset_09CarsDataset.ipynb 09Cars Dataset Date :Sun Nov 19 17:17:24 2017
# 118 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_binned_scatter_binned.ipynb scatter binned Date :Wed Aug  9 07:31:41 2017
# 119 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_bar_histogram_trellis_bar_histogram.ipynb trellis bar histogram Date :Wed Aug  9 07:31:41 2017
# 120 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_area_binned_stacked_area_binned.ipynb stacked area binned Date :Wed Aug  9 07:31:41 2017
# 121 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_h_stacked_bar_h.ipynb stacked bar h Date :Wed Aug  9 07:31:41 2017
# 122 Desktop_altair_altair_altair_notebooks_auto_examples_point_filled_point_filled.ipynb point filled Date :Wed Aug  9 07:31:41 2017
# 123 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_scatter_binned_row_trellis_scatter_binned_row.ipynb trellis scatter binned row Date :Wed Aug  9 07:31:41 2017
# 124 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_row_column_trellis_row_column.ipynb trellis row column Date :Wed Aug  9 07:31:41 2017
# 125 Desktop_altair_altair_altair_notebooks_auto_examples_line_slope_line_slope.ipynb line slope Date :Wed Aug  9 07:31:41 2017
# 126 Desktop_altair_altair_altair_notebooks_auto_examples_bar_aggregate_bar_aggregate.ipynb bar aggregate Date :Wed Aug  9 07:31:41 2017
# 127 Desktop_altair_altair_altair_notebooks_auto_examples_box_plot_box_plot.ipynb box plot Date :Wed Aug  9 07:31:41 2017
# 128 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_1d_stacked_bar_1d.ipynb stacked bar 1d Date :Wed Aug  9 07:31:41 2017
# 129 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_v_stacked_bar_v.ipynb stacked bar v Date :Wed Aug  9 07:31:41 2017
# 130 Desktop_altair_altair_altair_notebooks_auto_examples_point_dot_timeunit_color_point_dot_timeunit_color.ipynb point dot timeunit color Date :Wed Aug  9 07:31:41 2017
# 131 Desktop_altair_altair_altair_notebooks_auto_examples_bar_1d_bar_1d.ipynb bar 1d Date :Wed Aug  9 07:31:41 2017
# 132 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_order_scatter_color_order.ipynb scatter color order Date :Wed Aug  9 07:31:41 2017
# 133 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_ordinal_custom_scatter_color_ordinal_custom.ipynb scatter color ordinal custom Date :Wed Aug  9 07:31:41 2017
# 134 Desktop_altair_altair_altair_notebooks_auto_examples_github_punchcard_github_punchcard.ipynb github punchcard Date :Wed Aug  9 07:31:41 2017
# 135 Desktop_altair_altair_altair_notebooks_auto_examples_point_1d_point_1d.ipynb point 1d Date :Wed Aug  9 07:31:41 2017
# 136 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_binned_size_scatter_binned_size.ipynb scatter binned size Date :Wed Aug  9 07:31:41 2017
# 137 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_size_stacked_bar_size.ipynb stacked bar size Date :Wed Aug  9 07:31:41 2017
# 138 Desktop_altair_altair_altair_notebooks_auto_examples_bar_size_fit_bar_size_fit.ipynb bar size fit Date :Wed Aug  9 07:31:41 2017
# 139 Desktop_altair_altair_altair_notebooks_auto_examples_tick_dot_thickness_tick_dot_thickness.ipynb tick dot thickness Date :Wed Aug  9 07:31:41 2017
# 140 Desktop_altair_altair_altair_notebooks_auto_examples_text_scatter_colored_text_scatter_colored.ipynb text scatter colored Date :Wed Aug  9 07:31:41 2017
# 141 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_stacked_bar_trellis_stacked_bar.ipynb trellis stacked bar Date :Wed Aug  9 07:31:41 2017
# 142 Desktop_altair_altair_altair_notebooks_auto_examples_area_vertical_area_vertical.ipynb area vertical Date :Wed Aug  9 07:31:41 2017
# 143 Desktop_altair_altair_altair_notebooks_auto_examples_tick_strip_tick_strip.ipynb tick strip Date :Wed Aug  9 07:31:41 2017
# 144 Desktop_altair_altair_altair_notebooks_auto_examples_line_month_line_month.ipynb line month Date :Wed Aug  9 07:31:41 2017
# 145 Desktop_altair_altair_altair_notebooks_auto_examples_layer_histogram_layer_histogram.ipynb layer histogram Date :Wed Aug  9 07:31:41 2017
# 146 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_bubble_scatter_bubble.ipynb scatter bubble Date :Wed Aug  9 07:31:41 2017
# 147 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_area_ordinal_stacked_area_ordinal.ipynb stacked area ordinal Date :Wed Aug  9 07:31:41 2017
# 148 Desktop_altair_altair_altair_notebooks_auto_examples_layer_line_color_rule_layer_line_color_rule.ipynb layer line color rule Date :Wed Aug  9 07:31:41 2017
# 149 Desktop_altair_altair_altair_notebooks_auto_examples_bar_layered_transparent_bar_layered_transparent.ipynb bar layered transparent Date :Wed Aug  9 07:31:41 2017
# 150 Desktop_altair_altair_altair_notebooks_auto_examples_bar_yearmonth_bar_yearmonth.ipynb bar yearmonth Date :Wed Aug  9 07:31:41 2017
# 151 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_area_stream_stacked_area_stream.ipynb stacked area stream Date :Wed Aug  9 07:31:41 2017
# 152 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_area_stacked_area.ipynb stacked area Date :Wed Aug  9 07:31:41 2017
# 153 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_ordinal_scatter_color_ordinal.ipynb scatter color ordinal Date :Wed Aug  9 07:31:41 2017
# 154 Desktop_altair_altair_altair_notebooks_auto_examples_line_step_line_step.ipynb line step Date :Wed Aug  9 07:31:41 2017
# 155 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_h_order_stacked_bar_h_order.ipynb stacked bar h order Date :Wed Aug  9 07:31:41 2017
# 156 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_area_normalize_stacked_area_normalize.ipynb stacked area normalize Date :Wed Aug  9 07:31:41 2017
# 157 Desktop_altair_altair_altair_notebooks_auto_examples_line_color_line_color.ipynb line color Date :Wed Aug  9 07:31:41 2017
# 158 Desktop_altair_altair_altair_notebooks_auto_examples_line_quarter_legend_line_quarter_legend.ipynb line quarter legend Date :Wed Aug  9 07:31:41 2017
# 159 Desktop_altair_altair_altair_notebooks_auto_examples_overlay_line_short_overlay_line_short.ipynb overlay line short Date :Wed Aug  9 07:31:41 2017
# 160 Desktop_altair_altair_altair_notebooks_auto_examples_overlay_area_short_overlay_area_short.ipynb overlay area short Date :Wed Aug  9 07:31:41 2017
# 161 Desktop_altair_altair_altair_notebooks_auto_examples_tick_dot_tick_dot.ipynb tick dot Date :Wed Aug  9 07:31:41 2017
# 162 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_barley_trellis_barley.ipynb trellis barley Date :Wed Aug  9 07:31:41 2017
# 163 Desktop_altair_altair_altair_notebooks_auto_examples_bar_size_default_bar_size_default.ipynb bar size default Date :Wed Aug  9 07:31:41 2017
# 164 Desktop_altair_altair_altair_notebooks_auto_examples_bar_grouped_horizontal_bar_grouped_horizontal.ipynb bar grouped horizontal Date :Wed Aug  9 07:31:41 2017
# 165 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_shape_custom_scatter_shape_custom.ipynb scatter shape custom Date :Wed Aug  9 07:31:41 2017
# 166 Desktop_altair_altair_altair_notebooks_auto_examples_line_monotone_line_monotone.ipynb line monotone Date :Wed Aug  9 07:31:41 2017
# 167 Desktop_altair_altair_altair_notebooks_auto_examples_errorbar_aggregate_errorbar_aggregate.ipynb errorbar aggregate Date :Wed Aug  9 07:31:41 2017
# 168 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_normalize_stacked_bar_normalize.ipynb stacked bar normalize Date :Wed Aug  9 07:31:41 2017
# 169 Desktop_altair_altair_altair_notebooks_auto_examples_histogram_histogram.ipynb histogram Date :Wed Aug  9 07:31:41 2017
# 170 Desktop_altair_altair_altair_notebooks_auto_examples_bar_size_explicit_bar_size_explicit.ipynb bar size explicit Date :Wed Aug  9 07:31:41 2017
# 171 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_population_stacked_bar_population.ipynb stacked bar population Date :Wed Aug  9 07:31:41 2017
# 172 Desktop_altair_altair_altair_notebooks_auto_examples_Index_Index.ipynb Index Date :Wed Aug  9 07:31:41 2017
# 173 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_shape_constant_scatter_color_shape_constant.ipynb scatter color shape constant Date :Wed Aug  9 07:31:41 2017
# 174 Desktop_altair_altair_altair_notebooks_auto_examples_bar_aggregate_vertical_bar_aggregate_vertical.ipynb bar aggregate vertical Date :Wed Aug  9 07:31:41 2017
# 175 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_bar_trellis_bar.ipynb trellis bar Date :Wed Aug  9 07:31:41 2017
# 176 Desktop_altair_altair_altair_notebooks_auto_examples_line_quarter_line_quarter.ipynb line quarter Date :Wed Aug  9 07:31:41 2017
# 177 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_colored_with_shape_scatter_colored_with_shape.ipynb scatter colored with shape Date :Wed Aug  9 07:31:41 2017
# 178 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_weather_stacked_bar_weather.ipynb stacked bar weather Date :Wed Aug  9 07:31:41 2017
# 179 Desktop_altair_altair_altair_notebooks_auto_examples_bar_1d_bandsize_config_bar_1d_bandsize_config.ipynb bar 1d bandsize config Date :Wed Aug  9 07:31:41 2017
# 180 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_aggregate_detail_scatter_aggregate_detail.ipynb scatter aggregate detail Date :Wed Aug  9 07:31:41 2017
# 181 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_scatter_color.ipynb scatter color Date :Wed Aug  9 07:31:41 2017
# 182 Desktop_altair_altair_altair_notebooks_auto_examples_bar_grouped_bar_grouped.ipynb bar grouped Date :Wed Aug  9 07:31:41 2017
# 183 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_opacity_scatter_opacity.ipynb scatter opacity Date :Wed Aug  9 07:31:41 2017
# 184 Desktop_altair_altair_altair_notebooks_auto_examples_square_square.ipynb square Date :Wed Aug  9 07:31:41 2017
# 185 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_anscombe_trellis_anscombe.ipynb trellis anscombe Date :Wed Aug  9 07:31:41 2017
# 186 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_custom_scatter_color_custom.ipynb scatter color custom Date :Wed Aug  9 07:31:41 2017
# 187 Desktop_altair_altair_altair_notebooks_auto_examples_overlay_area_full_overlay_area_full.ipynb overlay area full Date :Wed Aug  9 07:31:41 2017
# 188 Desktop_altair_altair_altair_notebooks_auto_examples_trellis_scatter_trellis_scatter.ipynb trellis scatter Date :Wed Aug  9 07:31:41 2017
# 189 Desktop_altair_altair_altair_notebooks_auto_examples_overlay_line_full_overlay_line_full.ipynb overlay line full Date :Wed Aug  9 07:31:41 2017
# 190 Desktop_altair_altair_altair_notebooks_auto_examples_errorbar_horizontal_aggregate_errorbar_horizontal_aggregate.ipynb errorbar horizontal aggregate Date :Wed Aug  9 07:31:41 2017
# 191 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_scatter.ipynb scatter Date :Wed Aug  9 07:31:41 2017
# 192 Desktop_altair_altair_altair_notebooks_auto_examples_line_detail_line_detail.ipynb line detail Date :Wed Aug  9 07:31:41 2017
# 193 Desktop_altair_altair_altair_notebooks_auto_examples_text_table_heatmap_text_table_heatmap.ipynb text table heatmap Date :Wed Aug  9 07:31:41 2017
# 194 Desktop_altair_altair_altair_notebooks_auto_examples_circle_circle.ipynb circle Date :Wed Aug  9 07:31:41 2017
# 195 Desktop_altair_altair_altair_notebooks_auto_examples_bar_aggregate_size_bar_aggregate_size.ipynb bar aggregate size Date :Wed Aug  9 07:31:41 2017
# 196 Desktop_altair_altair_altair_notebooks_auto_examples_area_area.ipynb area Date :Wed Aug  9 07:31:41 2017
# 197 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_color_quantitative_scatter_color_quantitative.ipynb scatter color quantitative Date :Wed Aug  9 07:31:41 2017
# 198 Desktop_altair_altair_altair_notebooks_auto_examples_line_line.ipynb line Date :Wed Aug  9 07:31:41 2017
# 199 Desktop_altair_altair_altair_notebooks_auto_examples_bubble_health_income_bubble_health_income.ipynb bubble health income Date :Wed Aug  9 07:31:41 2017
# 200 Desktop_altair_altair_altair_notebooks_auto_examples_bar_size_explicit_bad_bar_size_explicit_bad.ipynb bar size explicit bad Date :Wed Aug  9 07:31:41 2017
# 201 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_connected_scatter_connected.ipynb scatter connected Date :Wed Aug  9 07:31:41 2017
# 202 Desktop_altair_altair_altair_notebooks_auto_examples_scatter_binned_color_scatter_binned_color.ipynb scatter binned color Date :Wed Aug  9 07:31:41 2017
# 203 Desktop_altair_altair_altair_notebooks_auto_examples_stacked_bar_sum_opacity_stacked_bar_sum_opacity.ipynb stacked bar sum opacity Date :Wed Aug  9 07:31:41 2017
# 204 Desktop_altair_schemapi_JSONSchemaNotes_JSONSchemaNotes.ipynb JSONSchema Notes Date :Wed Aug  9 07:39:55 2017
# 205 Desktop_altair_altair_widgets_examples_Iris_Iris.ipynb Iris Date :Wed Aug  9 07:41:30 2017
# 206 Desktop_altair_altair_widgets_altair_widgets_tests_test_widget_basic_test_widget_basic.ipynb test widget basic Date :Wed Aug  9 07:41:30 2017
# 207 Desktop_Phoenix_lessons_WIX_STUFF_WIX_STUFF.ipynb WIX STUFF Date :Thu Aug  3 11:57:30 2017
# 208 Desktop_SuperTwitterBot_TwitterBot_TwitterBot.ipynb Twitter Bot Date :Mon Aug 14 18:05:27 2017
# 209 Desktop_IPyLua_Filters_With_cv2.trackbars_Filters_With_cv2.trackbars.ipynb Filters With cv2.trackbars Date :Mon Jul 31 19:52:09 2017
# 210 Desktop_IPyLua_luademo_luademo.ipynb luademo Date :Sun Nov 19 17:17:35 2017
# 211 Desktop_surrealisme_facedetection_facedetection.ipynb facedetection Date :Sun Nov 19 17:17:38 2017
# 212 Desktop_surrealisme_Untitled_Untitled.ipynb Untitled Date :Thu Jun 15 17:05:17 2017
# 213 Desktop_surrealisme_plot_blob_plot_blob.ipynb plot blob Date :Thu Jun 15 16:10:55 2017
# 214 Desktop_surrealisme_Untitled1_Untitled1.ipynb Untitled1 Date :Wed Jun 14 23:49:35 2017
# 215 Desktop_Books_Epiphanies_Epiphanies.ipynb Epiphanies Date :Thu Aug  3 12:13:32 2017
# 216 Desktop_Books_numerical-python-book-code_ch14codelisting_ch14codelisting.ipynb ch14codelisting Date :Sun Nov 19 17:17:40 2017
# 217 Desktop_Books_numerical-python-book-code_ch06codelisting_ch06codelisting.ipynb ch06codelisting Date :Sun Nov 19 17:17:40 2017
# 218 Desktop_Books_numerical-python-book-code_ch05codelisting_ch05codelisting.ipynb ch05codelisting Date :Sun Nov 19 17:17:40 2017
# 219 Desktop_Books_numerical-python-book-code_ch17codelisting_ch17codelisting.ipynb ch17codelisting Date :Sun Nov 19 17:17:40 2017
# 220 Desktop_Books_numerical-python-book-code_ch19codelisting_ch19codelisting.ipynb ch19codelisting Date :Sun Nov 19 17:17:40 2017
# 221 Desktop_Books_numerical-python-book-code_ch09codelisting_ch09codelisting.ipynb ch09codelisting Date :Sun Nov 19 17:17:40 2017
# 222 Desktop_Books_numerical-python-book-code_ch11codelisting_ch11codelisting.ipynb ch11codelisting Date :Sun Nov 19 17:17:40 2017
# 223 Desktop_Books_numerical-python-book-code_ch08figures_ch08figures.ipynb ch08figures Date :Sun Nov 19 17:17:40 2017
# 224 Desktop_Books_numerical-python-book-code_ch03codelisting_ch03codelisting.ipynb ch03codelisting Date :Sun Nov 19 17:17:40 2017
# 225 Desktop_Books_numerical-python-book-code_ch15codelisting_ch15codelisting.ipynb ch15codelisting Date :Sun Nov 19 17:17:40 2017
# 226 Desktop_Books_numerical-python-book-code_ch18codelisting_ch18codelisting.ipynb ch18codelisting Date :Sun Nov 19 17:17:40 2017
# 227 Desktop_Books_numerical-python-book-code_ch02figures_ch02figures.ipynb ch02figures Date :Sun Nov 19 17:17:40 2017
# 228 Desktop_Books_numerical-python-book-code_ch07codelisting_ch07codelisting.ipynb ch07codelisting Date :Sun Nov 19 17:17:40 2017
# 229 Desktop_Books_numerical-python-book-code_ch10codelisting_ch10codelisting.ipynb ch10codelisting Date :Sun Nov 19 17:17:40 2017
# 230 Desktop_Books_numerical-python-book-code_ch04figures_ch04figures.ipynb ch04figures Date :Sun Nov 19 17:17:40 2017
# 231 Desktop_Books_numerical-python-book-code_ch16codelisting_ch16codelisting.ipynb ch16codelisting Date :Sun Nov 19 17:17:40 2017
# 232 Desktop_Books_numerical-python-book-code_ch08codelisting_ch08codelisting.ipynb ch08codelisting Date :Sun Nov 19 17:17:40 2017
# 233 Desktop_Books_numerical-python-book-code_ch01codelisting_ch01codelisting.ipynb ch01codelisting Date :Sun Nov 19 17:17:40 2017
# 234 Desktop_Books_numerical-python-book-code_ch02codelisting_ch02codelisting.ipynb ch02codelisting Date :Sun Nov 19 17:17:40 2017
# 235 Desktop_Books_numerical-python-book-code_ch12codelisting_ch12codelisting.ipynb ch12codelisting Date :Sun Nov 19 17:17:40 2017
# 236 Desktop_Books_numerical-python-book-code_ch01Markdown_ch01Markdown.ipynb ch01Markdown Date :Sun Nov 19 17:17:40 2017
# 237 Desktop_Books_numerical-python-book-code_ch13codelisting_ch13codelisting.ipynb ch13codelisting Date :Sun Nov 19 17:17:40 2017
# 238 Desktop_Books_numerical-python-book-code_ch04codelisting_ch04codelisting.ipynb ch04codelisting Date :Sun Nov 19 17:17:40 2017
# 239 Desktop_Books_python_epiphanies_crap_crap.ipynb crap Date :Thu Aug  3 12:48:20 2017
# 240 Desktop_Books_pydata-book_ch06_ch06.ipynb ch06 Date :Wed Aug  2 10:40:15 2017
# 241 Desktop_Books_pydata-book_ch04_ch04.ipynb ch04 Date :Wed Aug  2 10:40:15 2017
# 242 Desktop_Books_pydata-book_ch10_ch10.ipynb ch10 Date :Wed Aug  2 10:40:17 2017
# 243 Desktop_Books_pydata-book_appendix_python_appendix_python.ipynb appendix python Date :Wed Aug  2 10:40:15 2017
# 244 Desktop_Books_pydata-book_ch09_ch09.ipynb ch09 Date :Wed Aug  2 10:40:15 2017
# 245 Desktop_Books_pydata-book_ch05_ch05.ipynb ch05 Date :Wed Aug  2 10:40:15 2017
# 246 Desktop_Books_pydata-book_ch12_ch12.ipynb ch12 Date :Wed Aug  2 10:40:18 2017
# 247 Desktop_Books_pydata-book_ch11_ch11.ipynb ch11 Date :Wed Aug  2 10:40:17 2017
# 248 Desktop_Books_pydata-book_fec_study_fec_study.ipynb fec study Date :Wed Aug  2 10:40:18 2017
# 249 Desktop_Books_pydata-book_ch07_ch07.ipynb ch07 Date :Wed Aug  2 10:40:15 2017
# 250 Desktop_Books_pydata-book_ch08_ch08.ipynb ch08 Date :Wed Aug  2 10:40:15 2017
# 251 Desktop_Books_pydata-book_ch02_ch02.ipynb ch02 Date :Wed Aug  2 10:40:15 2017
# 252 Desktop_Books_Automate-The-Boring-Stuff-With-Python_BoringStuff_BoringStuff.ipynb Boring Stuff Date :Sun Nov 19 17:17:40 2017
# 253 Desktop_Books_Automate-The-Boring-Stuff-With-Python_CLIPIT_MODULE_CLIPIT_MODULE.ipynb CLIPIT MODULE Date :Thu Aug  3 21:18:02 2017
# 254 Desktop_imagebot_ARGVS_and___main___ARGVS_and___main__.ipynb ARGVS and   main   Date :Thu Sep  7 06:08:34 2017
# 255 Desktop_imagebot_ImageEffectsBotbak_ImageEffectsBotbak.ipynb Image Effects Botbak Date :Sun Nov 19 17:17:40 2017
# 256 Desktop_imagebot_randpalettepost_randpalettepost.ipynb randpalettepost Date :Sun Nov 19 17:17:40 2017
# 257 Desktop_imagebot_Catastrophe_Hurricane_Catastrophe_Hurricane.ipynb Catastrophe Hurricane Date :Fri Sep 15 18:27:20 2017
# 258 Desktop_imagebot_pygame_pygame.ipynb pygame Date :Sun Sep  3 08:31:03 2017
# 259 Desktop_imagebot_BLENDERS_BLENDERS.ipynb BLENDERS Date :Mon Sep 11 10:14:41 2017
# 260 Desktop_imagebot_Bible_Search_in_SQL_Bible_Search_in_SQL.ipynb Bible Search in SQL Date :Fri Sep 15 11:16:46 2017
# 261 Desktop_imagebot_Bible_Search_Bible_Search.ipynb Bible Search Date :Sun Sep 17 11:15:00 2017
# 262 Desktop_imagebot_RorschachImageMaker_RorschachImageMaker.ipynb Rorschach Image Maker Date :Sun Nov 19 17:17:40 2017
# 263 Desktop_imagebot_TitleandSigntitlenpost.py_TitleandSigntitlenpost.py.ipynb Titleand Signtitlenpost.py Date :Sun Nov 19 17:17:40 2017
# 264 Desktop_imagebot_PILONLY_PILONLY.ipynb PILONLY Date :Sun Nov 19 17:17:40 2017
# 265 Desktop_imagebot_ImageBot_Triangles_ImageBot_Triangles.ipynb Image Bot Triangles Date :Mon Aug 21 19:55:29 2017
# 266 Desktop_imagebot_FirstCellManualPost_Screen_capture_Python_and_OS_FirstCellManualPost_Screen_capture_Python_and_OS.ipynb First Cell Manual Post Screen capture Python and OS Date :Sun Nov 19 17:17:40 2017
# 267 Desktop_imagebot_MEAN_Graphics_MEAN_Graphics.ipynb MEAN Graphics Date :Sat Aug 26 13:14:48 2017
# 268 Desktop_imagebot_ImageEffectsBotCopy1_ImageEffectsBotCopy1.ipynb Image Effects Bot Copy1 Date :Sun Nov 19 17:17:40 2017
# 269 Desktop_imagebot_WordcloudImageGeneratorforgithub_WordcloudImageGeneratorforgithub.ipynb Wordcloud Image Generatorforgithub Date :Sun Nov 19 17:17:40 2017
# 270 Desktop_imagebot_ImageMaker_ImageMaker.ipynb Image Maker Date :Sun Nov 19 17:17:40 2017
# 271 Desktop_imagebot_CatastrophesCopy1_CatastrophesCopy1.ipynb Catastrophes Copy1 Date :Sun Nov 19 17:17:40 2017
# 272 Desktop_imagebot_FTS3_Database_FTS3_Database.ipynb FTS3 Database Date :Thu Sep 14 19:11:15 2017
# 273 Desktop_imagebot_colorific_colorific.ipynb colorific Date :Tue Aug 22 10:27:08 2017
# 274 Desktop_imagebot_GOSimpleExample_GOSimpleExample.ipynb GOSimple Example Date :Sun Nov 19 17:17:40 2017
# 275 Desktop_imagebot_Working_with_Tweets_and_Text_Results_Working_with_Tweets_and_Text_Results.ipynb Working with Tweets and Text Results Date :Fri Sep 15 18:15:50 2017
# 276 Desktop_imagebot_GenIm.pynotebook_GenIm.pynotebook.ipynb Gen Im.pynotebook Date :Sun Nov 19 17:17:40 2017
# 277 Desktop_imagebot_WorkBook_WorkBook.ipynb Work Book Date :Fri Sep  8 18:19:18 2017
# 278 Desktop_imagebot_MeanshiftImageSegmentation_MeanshiftImageSegmentation.ipynb Meanshift Image Segmentation Date :Sun Nov 19 17:17:40 2017
# 279 Desktop_imagebot_Palett_Swap_ARRAY_STUFF_Palett_Swap_ARRAY_STUFF.ipynb Palett Swap ARRAY STUFF Date :Tue Sep 12 08:54:49 2017
# 280 Desktop_imagebot_Text_Generation_Text_Generation.ipynb Text Generation Date :Wed Sep 27 10:03:32 2017
# 281 Desktop_imagebot_MeanshiftIn2D_MeanshiftIn2D.ipynb Meanshift In2D Date :Sun Nov 19 17:17:40 2017
# 282 Desktop_imagebot_NewNotebook_NewNotebook.ipynb New Notebook Date :Sat Sep 16 11:41:42 2017
# 283 Desktop_imagebot_ImageBot1.py_ImageBot1.py.ipynb Image Bot1.py Date :Wed Sep 27 09:34:44 2017
# 284 Desktop_imagebot_TwitterWordcloudImageGenerator_TwitterWordcloudImageGenerator.ipynb Twitter Wordcloud Image Generator Date :Sun Nov 19 17:17:40 2017
# 285 Desktop_imagebot_imfractal_imfractal.ipynb imfractal Date :Sat Sep  2 08:44:10 2017
# 286 Desktop_imagebot_MaskGenerator_MaskGenerator.ipynb Mask Generator Date :Fri Sep  8 16:54:24 2017
# 287 Desktop_imagebot_Twitterimageandcommentmanualupload_Twitterimageandcommentmanualupload.ipynb Twitterimageandcommentmanualupload Date :Sun Nov 19 17:17:40 2017
# 288 Desktop_imagebot_DreamandPosttoTwitter_DreamandPosttoTwitter.ipynb Dreamand Postto Twitter Date :Sun Nov 19 17:17:40 2017
# 289 Desktop_imagebot_INDEX_INDEX.ipynb INDEX Date :Fri Sep 15 17:45:50 2017
# 290 Desktop_imagebot_MaskGeneratorCopy1_MaskGeneratorCopy1.ipynb Mask Generator Copy1 Date :Sun Nov 19 17:17:40 2017
# 291 Desktop_imagebot_TwitterBot_TwitterBot.ipynb Twitter Bot Date :Wed Sep 27 09:34:33 2017
# 292 Desktop_imagebot_AAAAAAAMyManRaynewexperimentsCopy1_AAAAAAAMyManRaynewexperimentsCopy1.ipynb AAAAAAAMy Man Raynewexperiments Copy1 Date :Sun Nov 19 17:17:40 2017
# 293 Desktop_imagebot_Crawler_Crawler.ipynb Crawler Date :Fri Aug 25 10:39:14 2017
# 294 Desktop_imagebot_InkBlotGeneratorOpenCV_InkBlotGeneratorOpenCV.ipynb Ink Blot Generator Open CV Date :Sun Nov 19 17:17:40 2017
# 295 Desktop_imagebot_TXT_and_CSV_TXT_and_CSV.ipynb TXT and CSV Date :Wed Sep 13 07:07:03 2017
# 296 Desktop_imagebot_!!!ASuperGoodmousesizingandcropping_!!!ASuperGoodmousesizingandcropping.ipynb !!!ASuper Goodmousesizingandcropping Date :Sun Nov 19 17:17:40 2017
# 297 Desktop_imagebot_Utilities_Utilities.ipynb Utilities Date :Thu Sep  7 12:44:44 2017
# 298 Desktop_imagebot_ImWork_module_ImWork_module.ipynb Im Work module Date :Sun Nov 19 17:17:40 2017
# 299 Desktop_imagebot_misc_twitter_stuff_misc_twitter_stuff.ipynb misc twitter stuff Date :Wed Sep 27 10:02:39 2017
# 300 Desktop_imagebot_PatternRecognition_PatternRecognition.ipynb Pattern Recognition Date :Sun Nov 19 17:17:40 2017
# 301 Desktop_imagebot_ALLWORKNGSQLITE_and_MYSQL_ALLWORKNGSQLITE_and_MYSQL.ipynb ALLWORKNGSQLITE and MYSQL Date :Sun Nov 19 17:17:40 2017
# 302 Desktop_imagebot_Post_in_Order_Post_in_Order.ipynb Post in Order Date :Thu Sep 14 09:33:29 2017
# 303 Desktop_imagebot_bak_ImageEffectsBotbak_ImageEffectsBotbak.ipynb Image Effects Botbak Date :Sun Nov 19 17:17:40 2017
# 304 Desktop_imagebot_bak_BLENDERS_BLENDERS.ipynb BLENDERS Date :Mon Aug 21 10:22:44 2017
# 305 Desktop_imagebot_bak_TitleandSigntitlenpost.py_TitleandSigntitlenpost.py.ipynb Titleand Signtitlenpost.py Date :Sun Nov 19 17:17:40 2017
# 306 Desktop_imagebot_bak_ImageBot_Triangles_ImageBot_Triangles.ipynb Image Bot Triangles Date :Mon Aug 21 10:22:45 2017
# 307 Desktop_imagebot_bak_ImageEffectsBotCopy1_ImageEffectsBotCopy1.ipynb Image Effects Bot Copy1 Date :Sun Nov 19 17:17:40 2017
# 308 Desktop_imagebot_bak_WordcloudImageGeneratorforgithub_WordcloudImageGeneratorforgithub.ipynb Wordcloud Image Generatorforgithub Date :Sun Nov 19 17:17:40 2017
# 309 Desktop_imagebot_bak_ImageMaker_ImageMaker.ipynb Image Maker Date :Sun Nov 19 17:17:40 2017
# 310 Desktop_imagebot_bak_TwitterWordcloudImageGenerator_TwitterWordcloudImageGenerator.ipynb Twitter Wordcloud Image Generator Date :Sun Nov 19 17:17:40 2017
# 311 Desktop_imagebot_bak_MaskGenerator_MaskGenerator.ipynb Mask Generator Date :Mon Aug 21 10:22:45 2017
# 312 Desktop_imagebot_bak_Twitterimageandcommentmanualupload_Twitterimageandcommentmanualupload.ipynb Twitterimageandcommentmanualupload Date :Sun Nov 19 17:17:40 2017
# 313 Desktop_imagebot_bak_DreamandPosttoTwitter_DreamandPosttoTwitter.ipynb Dreamand Postto Twitter Date :Sun Nov 19 17:17:40 2017
# 314 Desktop_imagebot_bak_INDEX_INDEX.ipynb INDEX Date :Mon Aug 21 10:22:45 2017
# 315 Desktop_imagebot_bak_MaskGeneratorCopy1_MaskGeneratorCopy1.ipynb Mask Generator Copy1 Date :Sun Nov 19 17:17:40 2017
# 316 Desktop_imagebot_bak_TwitterBot_TwitterBot.ipynb Twitter Bot Date :Mon Aug 21 10:22:45 2017
# 317 Desktop_deep-dream-generator_lorenzsystemattractoranimateEXP_lorenzsystemattractoranimateEXP.ipynb lorenzsystemattractoranimate EXP Date :Sun Nov 19 17:17:43 2017
# 318 Desktop_deep-dream-generator_notebooks_top_10_python_idioms_top_10_python_idioms.ipynb top 10 python idioms Date :Sat Jun 10 10:47:01 2017
# 319 Desktop_deep-dream-generator_notebooks_vidextensions_vidextensions.ipynb vidextensions Date :Sun Nov 19 17:17:44 2017
# 320 Desktop_deep-dream-generator_notebooks_TensorFlow_Irisworkingcheckpoint_TensorFlow_Irisworkingcheckpoint.ipynb Tensor Flow Irisworkingcheckpoint Date :Sun Nov 19 17:17:44 2017
# 321 Desktop_deep-dream-generator_notebooks_basic3dsurface_basic3dsurface.ipynb basic3dsurface Date :Sun Nov 19 17:17:44 2017
# 322 Desktop_deep-dream-generator_notebooks_Untitled0_Untitled0.ipynb Untitled0 Date :Wed Jun 21 14:48:27 2017
# 323 Desktop_deep-dream-generator_notebooks_gmail_gmail.ipynb gmail Date :Sat Jun 10 10:47:01 2017
# 324 Desktop_deep-dream-generator_notebooks_TFdreams_TFdreams.ipynb TFdreams Date :Sun Nov 19 17:17:44 2017
# 325 Desktop_deep-dream-generator_notebooks_FACESANDFRIENDS_FACESANDFRIENDS.ipynb FACESANDFRIENDS Date :Sat Jun 10 10:47:01 2017
# 326 Desktop_deep-dream-generator_notebooks_SVGonjupyter_SVGonjupyter.ipynb SVGonjupyter Date :Sun Nov 19 17:17:44 2017
# 327 Desktop_deep-dream-generator_notebooks_py_exp_comp_wm1_py_exp_comp_wm1.ipynb py exp comp wm1 Date :Sun Jun 18 11:34:36 2017
# 328 Desktop_deep-dream-generator_notebooks_Tensorflow2FullyConnected_Tensorflow2FullyConnected.ipynb Tensorflow2Fully Connected Date :Sun Nov 19 17:17:44 2017
# 329 Desktop_deep-dream-generator_notebooks_pygame_pygame.ipynb pygame Date :Thu Jun 29 16:19:45 2017
# 330 Desktop_deep-dream-generator_notebooks_lorenzsystemattractoranimateEXP_lorenzsystemattractoranimateEXP.ipynb lorenzsystemattractoranimate EXP Date :Sun Nov 19 17:17:44 2017
# 331 Desktop_deep-dream-generator_notebooks_IndeedJobs_IndeedJobs.ipynb Indeed Jobs Date :Sat Jun 10 10:47:01 2017
# 332 Desktop_deep-dream-generator_notebooks_basic3dsurface(1)_basic3dsurface(1).ipynb basic3dsurface(1) Date :Sun Nov 19 17:17:44 2017
# 333 Desktop_deep-dream-generator_notebooks_dreamdeeper6experiments_dreamdeeper6experiments.ipynb dreamdeeper6experiments Date :Sun Nov 19 17:17:44 2017
# 334 Desktop_deep-dream-generator_notebooks_dictionaries_dictionaries.ipynb dictionaries Date :Sat Jun 10 10:47:01 2017
# 335 Desktop_deep-dream-generator_notebooks_xxexperimentsAPR22_xxexperimentsAPR22.ipynb xxexperiments APR22 Date :Sun Nov 19 17:17:44 2017
# 336 Desktop_deep-dream-generator_notebooks_tensordream003checkpoint_tensordream003checkpoint.ipynb tensordream003checkpoint Date :Sun Nov 19 17:17:44 2017
# 337 Desktop_deep-dream-generator_notebooks_SQLqueriesontheNAecologyandclimatedatabase_SQLqueriesontheNAecologyandclimatedatabase.ipynb SQLqueriesonthe NAecologyandclimatedatabase Date :Sun Nov 19 17:17:44 2017
# 338 Desktop_deep-dream-generator_notebooks_dream8conv3fc_DSN_dream8conv3fc_DSN.ipynb dream8conv3fc DSN Date :Sun Nov 19 17:17:44 2017
# 339 Desktop_deep-dream-generator_notebooks_dreamPlaces205CNN_dreamPlaces205CNN.ipynb dream Places205CNN Date :Sun Nov 19 17:17:44 2017
# 340 Desktop_deep-dream-generator_notebooks_IPythonMagic_IPythonMagic.ipynb IPython Magic Date :Sat Jun 10 10:47:01 2017
# 341 Desktop_deep-dream-generator_notebooks_!AMyManRayrun_all_!AMyManRayrun_all.ipynb !AMy Man Rayrun all Date :Sun Nov 19 17:17:44 2017
# 342 Desktop_deep-dream-generator_notebooks_Untitled6_Untitled6.ipynb Untitled6 Date :Sat Jun 10 16:45:15 2017
# 343 Desktop_deep-dream-generator_notebooks_plotly_plotly.ipynb plotly Date :Sat Jun 10 10:47:01 2017
# 344 Desktop_deep-dream-generator_notebooks_Theano_Theano.ipynb Theano Date :Sat Jun 10 10:47:01 2017
# 345 Desktop_deep-dream-generator_notebooks_PyMC_PyMC.ipynb Py MC Date :Sun Jun 18 11:34:38 2017
# 346 Desktop_deep-dream-generator_notebooks_Lecture1JaynesCummingmodel_Lecture1JaynesCummingmodel.ipynb Lecture1Jaynes Cummingmodel Date :Sun Nov 19 17:17:44 2017
# 347 Desktop_deep-dream-generator_notebooks_py_exploratory_comp_7_sol_py_exploratory_comp_7_sol.ipynb py exploratory comp 7 sol Date :Sun Jun 18 11:34:37 2017
# 348 Desktop_deep-dream-generator_notebooks_test4_test4.ipynb test4 Date :Sun Jun 18 11:34:39 2017
# 349 Desktop_deep-dream-generator_notebooks_A__matplotlibinformation_A__matplotlibinformation.ipynb A  matplotlibinformation Date :Sun Nov 19 17:17:44 2017
# 350 Desktop_deep-dream-generator_notebooks_parsingstuffnearjunkcheckpoint_parsingstuffnearjunkcheckpoint.ipynb parsingstuffnearjunkcheckpoint Date :Sun Nov 19 17:17:44 2017
# 351 Desktop_deep-dream-generator_notebooks_!AMyManRay_!AMyManRay.ipynb !AMy Man Ray Date :Sun Nov 19 17:17:44 2017
# 352 Desktop_deep-dream-generator_notebooks_Collision_Collision.ipynb Collision Date :Sat Jun 10 10:47:01 2017
# 353 Desktop_deep-dream-generator_notebooks_Intro_Intro.ipynb Intro Date :Sun Jun 18 11:34:33 2017
# 354 Desktop_deep-dream-generator_notebooks_chainer_chainer.ipynb chainer Date :Sat Jun 10 10:47:01 2017
# 355 Desktop_deep-dream-generator_notebooks_AGoodstufnltksession1complete_AGoodstufnltksession1complete.ipynb AGoodstufnltksession1complete Date :Sun Nov 19 17:17:44 2017
# 356 Desktop_deep-dream-generator_notebooks_NetworkX_NetworkX.ipynb Network X Date :Sun Jun 18 11:34:35 2017
# 357 Desktop_deep-dream-generator_notebooks_04Animations_04Animations.ipynb 04Animations Date :Sun Nov 19 17:17:44 2017
# 358 Desktop_deep-dream-generator_notebooks_table_of_contents_ipython_table_of_contents_ipython.ipynb table of contents ipython Date :Sat Jun 10 10:47:01 2017
# 359 Desktop_deep-dream-generator_notebooks_var_string_num_var_string_num.ipynb var string num Date :Sat Jun 10 10:47:01 2017
# 360 Desktop_deep-dream-generator_notebooks_mandelbrotcheckpoint_mandelbrotcheckpoint.ipynb mandelbrotcheckpoint Date :Sun Nov 19 17:17:44 2017
# 361 Desktop_deep-dream-generator_notebooks_Unicode_Unicode.ipynb Unicode Date :Sun Jun 18 11:34:39 2017
# 362 Desktop_deep-dream-generator_notebooks_dream_dream.ipynb dream Date :Sat Jun 10 10:47:01 2017
# 363 Desktop_deep-dream-generator_notebooks_deepdreamcheckpoint_deepdreamcheckpoint.ipynb deepdreamcheckpoint Date :Sun Nov 19 17:17:44 2017
# 364 Desktop_deep-dream-generator_notebooks_mosaic_mosaic.ipynb mosaic Date :Mon Jul 17 07:11:56 2017
# 365 Desktop_deep-dream-generator_notebooks_TensorFlowdream_TensorFlowdream.ipynb Tensor Flowdream Date :Sun Nov 19 17:17:44 2017
# 366 Desktop_deep-dream-generator_notebooks_resources_resources.ipynb resources Date :Sun Jun 18 11:34:38 2017
# 367 Desktop_deep-dream-generator_notebooks_cexperiments_cexperiments.ipynb cexperiments Date :Sun Nov 19 17:17:44 2017
# 368 Desktop_deep-dream-generator_notebooks_pascalmultilabelwithdatalayer_pascalmultilabelwithdatalayer.ipynb pascalmultilabelwithdatalayer Date :Sun Nov 19 17:17:44 2017
# 369 Desktop_deep-dream-generator_notebooks_py_exploratory_comp_10_sol_py_exploratory_comp_10_sol.ipynb py exploratory comp 10 sol Date :Sun Jun 18 11:34:38 2017
# 370 Desktop_deep-dream-generator_notebooks_deepdream_deepdream.ipynb deepdream Date :Wed Aug 16 10:37:51 2017
# 371 Desktop_deep-dream-generator_notebooks_vidstuffCopy1_vidstuffCopy1.ipynb vidstuff Copy1 Date :Sun Nov 19 17:17:44 2017
# 372 Desktop_deep-dream-generator_notebooks_trainer_tutorial_trainer_tutorial.ipynb trainer tutorial Date :Sat Jun 10 10:47:01 2017
# 373 Desktop_deep-dream-generator_notebooks_py_exploratory_comp_1_py_exploratory_comp_1.ipynb py exploratory comp 1 Date :Sun Jun 18 11:34:37 2017
# 374 Desktop_deep-dream-generator_notebooks_AA_FractalCircles_AA_FractalCircles.ipynb AA Fractal Circles Date :Sun Nov 19 17:17:44 2017
# 375 Desktop_deep-dream-generator_notebooks_Tensorflow6LSTM_Tensorflow6LSTM.ipynb Tensorflow6LSTM Date :Sun Nov 19 17:17:44 2017
# 376 Desktop_deep-dream-generator_notebooks_py_exp_comp_wm2_solcheckpoint_py_exp_comp_wm2_solcheckpoint.ipynb py exp comp wm2 solcheckpoint Date :Sun Nov 19 17:17:44 2017
# 377 Desktop_deep-dream-generator_notebooks_!!Creatingamodule_Gtool_!!Creatingamodule_Gtool.ipynb !!Creatingamodule Gtool Date :Sun Nov 19 17:17:44 2017
# 378 Desktop_deep-dream-generator_notebooks_A_dreamblendingimagesuse_A_dreamblendingimagesuse.ipynb A dreamblendingimagesuse Date :Sun Nov 19 17:17:44 2017
# 379 Desktop_deep-dream-generator_notebooks_3d_scatter_3d_scatter.ipynb 3d scatter Date :Sat Jun 10 10:47:01 2017
# 380 Desktop_deep-dream-generator_notebooks_while_input_while_input.ipynb while input Date :Sat Jun 10 10:47:01 2017
# 381 Desktop_deep-dream-generator_notebooks_Untitled_Untitled.ipynb Untitled Date :Fri Jun 16 11:12:27 2017
# 382 Desktop_deep-dream-generator_notebooks_Factorials_Factorials.ipynb Factorials Date :Sun Jun 18 11:34:32 2017
# 383 Desktop_deep-dream-generator_notebooks_prompt_numbers_prompt_numbers.ipynb prompt numbers Date :Sun Jun 18 11:34:35 2017
# 384 Desktop_deep-dream-generator_notebooks_document_clustering_document_clustering.ipynb document clustering Date :Wed Aug 16 17:59:54 2017
# 385 Desktop_deep-dream-generator_notebooks_py_exp_comp_adv4_py_exp_comp_adv4.ipynb py exp comp adv4 Date :Sun Jun 18 11:34:36 2017
# 386 Desktop_deep-dream-generator_notebooks_experimentsAPR29_experimentsAPR29.ipynb experiments APR29 Date :Sun Nov 19 17:17:44 2017
# 387 Desktop_deep-dream-generator_notebooks_batcountryJ_batcountryJ.ipynb batcountry J Date :Sun Nov 19 17:17:44 2017
# 388 Desktop_deep-dream-generator_notebooks_bneedsworkinteractive_text_analyzer_bneedsworkinteractive_text_analyzer.ipynb bneedsworkinteractive text analyzer Date :Sun Nov 19 17:17:44 2017
# 389 Desktop_deep-dream-generator_notebooks_newtensor_newtensor.ipynb newtensor Date :Sat Jun 10 10:47:01 2017
# 390 Desktop_deep-dream-generator_notebooks_ABokehJS_ABokehJS.ipynb ABokeh JS Date :Sun Nov 19 17:17:44 2017
# 391 Desktop_deep-dream-generator_notebooks_plot_iris_dataset_plot_iris_dataset.ipynb plot iris dataset Date :Sat Jun 10 10:47:01 2017
# 392 Desktop_deep-dream-generator_notebooks_Matplotlib_Matplotlib.ipynb Matplotlib Date :Sun Jun 18 11:34:34 2017
# 393 Desktop_deep-dream-generator_notebooks_nbagg_uat_nbagg_uat.ipynb nbagg uat Date :Sun Jun 18 11:34:34 2017
# 394 Desktop_deep-dream-generator_notebooks_test4docinfo_test4docinfo.ipynb test4docinfo Date :Sun Jun 18 11:34:39 2017
# ...
# 2037 python3-starter_notebooks_lists_tuples_lists_tuples.ipynb lists tuples Date :Wed Mar 15 11:48:08 2017
# 2038 python3-starter_notebooks_classes_classes.ipynb classes Date :Wed Mar 15 11:48:08 2017
# 2039 python3-starter_notebooks_SciPy_SciPy.ipynb Sci Py Date :Wed Mar 15 15:24:46 2017
# 2040 python3-starter_notebooks_Spark-ML-Lab4-CriteoPrediction_Spark-ML-Lab4-CriteoPrediction.ipynb Spark ML Lab4 Criteo Prediction Date :Wed Mar 15 11:48:08 2017
# 2041 python3-starter_notebooks_notebook3_with_errors_notebook3_with_errors.ipynb notebook3 with errors Date :Wed Mar 15 11:48:08 2017
# 2042 python3-starter_notebooks_if_statements_if_statements.ipynb if statements Date :Fri Apr  7 08:48:38 2017
# 2043 python3-starter_notebooks_hello_world_hello_world.ipynb hello world Date :Wed Mar 15 11:48:08 2017
# 2044 python3-starter_notebooks_Spark-ML-Lab5-NeuroPCA_Spark-ML-Lab5-NeuroPCA.ipynb Spark ML Lab5 Neuro PCA Date :Wed Mar 15 11:48:08 2017
# 2045 python3-starter_notebooks_Untitled1_Untitled1.ipynb Untitled1 Date :Wed Mar 15 11:48:08 2017
# 2046 python3-starter_notebooks_Spark-ML-Lab3-LinearRegression_Spark-ML-Lab3-LinearRegression.ipynb Spark ML Lab3 Linear Regression Date :Wed Mar 15 11:48:08 2017
# 2047 python3-starter_notebooks_terminal_apps_terminal_apps.ipynb terminal apps Date :Wed Mar 15 11:48:08 2017
# 2048 python3-starter_notebooks_00-classification_00-classification.ipynb 00 classification Date :Wed Mar 15 11:48:08 2017
# 2049 python3-starter_notebooks_Spark-Lab3-EntityResolution_Spark-Lab3-EntityResolution.ipynb Spark Lab3 Entity Resolution Date :Wed Mar 15 11:48:08 2017
# 2050 python3-starter_notebooks_Spark-Lab0-Tutorial_Spark-Lab0-Tutorial.ipynb Spark Lab0 Tutorial Date :Wed Mar 15 11:48:08 2017
# 2051 python3-starter_notebooks_Spark-Lab2-ApacheLog_Spark-Lab2-ApacheLog.ipynb Spark Lab2 Apache Log Date :Wed Mar 15 11:48:08 2017
# 2052 python3-starter_notebooks_Untitled2_Untitled2.ipynb Untitled2 Date :Fri Apr  7 08:32:48 2017
# 2053 python3-starter_notebooks_bat-country_bat-country.ipynb bat country Date :Wed Mar 15 11:48:08 2017
# 2054 python3-starter_notebooks_brewing-logreg_brewing-logreg.ipynb brewing logreg Date :Wed Mar 15 11:48:08 2017
# 2055 python3-starter_notebooks_01-learning-lenet_01-learning-lenet.ipynb 01 learning lenet Date :Wed Mar 15 11:48:08 2017
# 2056 python3-starter_notebooks_NLTK_NLTK.ipynb NLTK Date :Wed Mar 15 11:48:08 2017
# 2057 python3-starter_notebooks_FractalRendering_PythagorasTree_Tree_Tree.ipynb Tree Date :Wed Mar 15 12:29:03 2017
# 2058 python3-starter_notebooks_FractalRendering_KochSnowflake_Snowflake_Snowflake.ipynb Snowflake Date :Wed Mar 15 12:26:20 2017
# 2059 python3-starter_notebooks_FractalRendering_BarnsleyFern_Fern_Fern.ipynb Fern Date :Wed Mar 15 12:05:01 2017
# 2060 python3-starter_ipython-notebooks-master_notebooks_language_IPythonMagic_IPythonMagic.ipynb IPython Magic Date :Wed Mar  8 12:02:56 2017
# 2061 python3-starter_ipython-notebooks-master_notebooks_language_Intro_Intro.ipynb Intro Date :Wed Mar  8 12:02:56 2017
# 2062 python3-starter_ipython-notebooks-master_notebooks_tensorflow_Tensorflow-2-FullyConnected_Tensorflow-2-FullyConnected.ipynb Tensorflow 2 Fully Connected Date :Wed Mar  8 12:02:56 2017
# 2063 python3-starter_ipython-notebooks-master_notebooks_tensorflow_Tensorflow-3-Regularization_Tensorflow-3-Regularization.ipynb Tensorflow 3 Regularization Date :Wed Mar  8 12:02:56 2017
# 2064 python3-starter_ipython-notebooks-master_notebooks_tensorflow_Tensorflow-6-LSTM_Tensorflow-6-LSTM.ipynb Tensorflow 6 LSTM Date :Wed Mar  8 12:02:56 2017
# 2065 python3-starter_ipython-notebooks-master_notebooks_tensorflow_Tensorflow-4-Convolutions_Tensorflow-4-Convolutions.ipynb Tensorflow 4 Convolutions Date :Wed Mar  8 12:02:56 2017
# 2066 python3-starter_ipython-notebooks-master_notebooks_tensorflow_Tensorflow-5-Word2Vec_Tensorflow-5-Word2Vec.ipynb Tensorflow 5 Word2Vec Date :Wed Mar  8 12:02:56 2017
# 2067 python3-starter_ipython-notebooks-master_notebooks_tensorflow_Tensorflow-1-NotMNIST_Tensorflow-1-NotMNIST.ipynb Tensorflow 1 Not MNIST Date :Wed Mar  8 12:02:56 2017
# 2068 python3-starter_ipython-notebooks-master_notebooks_libraries_PyMC_PyMC.ipynb Py MC Date :Wed Mar  8 12:02:56 2017
# 2069 python3-starter_ipython-notebooks-master_notebooks_libraries_NetworkX_NetworkX.ipynb Network X Date :Wed Mar  8 12:02:56 2017
# 2070 python3-starter_ipython-notebooks-master_notebooks_libraries_Matplotlib_Matplotlib.ipynb Matplotlib Date :Wed Mar  8 12:02:56 2017
# 2071 python3-starter_ipython-notebooks-master_notebooks_libraries_Seaborn_Seaborn.ipynb Seaborn Date :Wed Mar  8 12:02:56 2017
# 2072 python3-starter_ipython-notebooks-master_notebooks_libraries_Scikit-learn_Scikit-learn.ipynb Scikit learn Date :Wed Mar  8 12:02:56 2017
# 2073 python3-starter_ipython-notebooks-master_notebooks_libraries_SciPy_SciPy.ipynb Sci Py Date :Wed Mar  8 12:02:56 2017
# 2074 python3-starter_ipython-notebooks-master_notebooks_libraries_DEAP_DEAP.ipynb DEAP Date :Wed Mar  8 12:02:56 2017
# 2075 python3-starter_ipython-notebooks-master_notebooks_libraries_Statsmodels_Statsmodels.ipynb Statsmodels Date :Wed Mar  8 12:02:56 2017
# 2076 python3-starter_ipython-notebooks-master_notebooks_libraries_Pandas_Pandas.ipynb Pandas Date :Wed Mar  8 12:02:56 2017
# 2077 python3-starter_ipython-notebooks-master_notebooks_libraries_Gensim_Gensim.ipynb Gensim Date :Wed Mar  8 12:02:56 2017
# 2078 python3-starter_ipython-notebooks-master_notebooks_libraries_NumPy_NumPy.ipynb Num Py Date :Wed Mar  8 12:02:56 2017
# 2079 python3-starter_ipython-notebooks-master_notebooks_libraries_NLTK_NLTK.ipynb NLTK Date :Wed Mar  8 12:02:56 2017
# 2080 python3-starter_ipython-notebooks-master_notebooks_misc_CodeOptimization_CodeOptimization.ipynb Code Optimization Date :Wed Mar  8 12:02:56 2017
# 2081 python3-starter_ipython-notebooks-master_notebooks_misc_TimeSeriesStockAnalysis_TimeSeriesStockAnalysis.ipynb Time Series Stock Analysis Date :Wed Mar  8 12:02:56 2017
# 2082 python3-starter_ipython-notebooks-master_notebooks_misc_ProbablisticProgramming_ProbablisticProgramming.ipynb Probablistic Programming Date :Wed Mar  8 12:02:56 2017
# 2083 python3-starter_ipython-notebooks-master_notebooks_misc_LanguageVectors_LanguageVectors.ipynb Language Vectors Date :Wed Mar  8 12:02:56 2017
# 2084 python3-starter_ipython-notebooks-master_notebooks_misc_DynamicProgramming_DynamicProgramming.ipynb Dynamic Programming Date :Wed Mar  8 12:02:56 2017
# 2085 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise8_ML-Exercise8.ipynb ML Exercise8 Date :Wed Mar  8 12:02:56 2017
# 2086 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise3_ML-Exercise3.ipynb ML Exercise3 Date :Wed Mar  8 12:02:56 2017
# 2087 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise7_ML-Exercise7.ipynb ML Exercise7 Date :Wed Mar  8 12:02:56 2017
# 2088 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise2_ML-Exercise2.ipynb ML Exercise2 Date :Wed Mar  8 12:02:56 2017
# 2089 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise6_ML-Exercise6.ipynb ML Exercise6 Date :Wed Mar  8 12:02:56 2017
# 2090 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise4_ML-Exercise4.ipynb ML Exercise4 Date :Wed Mar  8 12:02:56 2017
# 2091 python3-starter_ipython-notebooks-master_notebooks_ml_ML-Exercise1_ML-Exercise1.ipynb ML Exercise1 Date :Wed Mar  8 12:02:56 2017
# 2092 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-Lab4-MachineLearning_Spark-Lab4-MachineLearning.ipynb Spark Lab4 Machine Learning Date :Wed Mar  8 12:02:56 2017
# 2093 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-Lab1-WordCount_Spark-Lab1-WordCount.ipynb Spark Lab1 Word Count Date :Wed Mar  8 12:02:56 2017
# 2094 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-ML-Lab4-CriteoPrediction_Spark-ML-Lab4-CriteoPrediction.ipynb Spark ML Lab4 Criteo Prediction Date :Wed Mar  8 12:02:56 2017
# 2095 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-ML-Lab5-NeuroPCA_Spark-ML-Lab5-NeuroPCA.ipynb Spark ML Lab5 Neuro PCA Date :Wed Mar  8 12:02:56 2017
# 2096 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-ML-Lab3-LinearRegression_Spark-ML-Lab3-LinearRegression.ipynb Spark ML Lab3 Linear Regression Date :Wed Mar  8 12:02:56 2017
# 2097 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-Lab3-EntityResolution_Spark-Lab3-EntityResolution.ipynb Spark Lab3 Entity Resolution Date :Wed Mar  8 12:02:56 2017
# 2098 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-Lab0-Tutorial_Spark-Lab0-Tutorial.ipynb Spark Lab0 Tutorial Date :Wed Mar  8 12:02:56 2017
# 2099 python3-starter_ipython-notebooks-master_notebooks_spark_Spark-Lab2-ApacheLog_Spark-Lab2-ApacheLog.ipynb Spark Lab2 Apache Log Date :Wed Mar  8 12:02:56 2017
# 2100 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook9_discrete_random_variables_py_exploratory_comp_9_sol_py_exploratory_comp_9_sol.ipynb py exploratory comp 9 sol Date :Wed Mar  8 12:02:38 2017
# 2101 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook4_functions_py_exploratory_comp_4_py_exploratory_comp_4.ipynb py exploratory comp 4 Date :Wed Mar  8 12:02:38 2017
# 2102 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook4_functions_py_exploratory_comp_4_sol_py_exploratory_comp_4_sol.ipynb py exploratory comp 4 sol Date :Wed Mar  8 12:02:38 2017
# 2103 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_linearsystems_bouwplaats_q3_notebook2_bouwplaats_q3_notebook2.ipynb bouwplaats q3 notebook2 Date :Wed Mar  8 12:02:38 2017
# 2104 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook3_for_and_if_py_exploratory_comp_3_sol_py_exploratory_comp_3_sol.ipynb py exploratory comp 3 sol Date :Wed Mar  8 12:02:38 2017
# 2105 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook3_for_and_if_py_exploratory_comp_3_py_exploratory_comp_3.ipynb py exploratory comp 3 Date :Wed Mar  8 12:02:38 2017
# 2106 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook2_arrays_py_exploratory_comp_2_py_exploratory_comp_2.ipynb py exploratory comp 2 Date :Wed Mar  8 12:02:38 2017
# 2107 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook2_arrays_py_exploratory_comp_2_sol_py_exploratory_comp_2_sol.ipynb py exploratory comp 2 sol Date :Wed Mar  8 12:02:38 2017
# 2108 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook10_continuous_random_variables_py_exploratory_comp_10_sol_py_exploratory_comp_10_sol.ipynb py exploratory comp 10 sol Date :Wed Mar  8 12:02:38 2017
# 2109 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook1_basics_plotting_py_exploratory_comp_1_py_exploratory_comp_1.ipynb py exploratory comp 1 Date :Wed Mar  8 12:02:38 2017
# 2110 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook1_basics_plotting_py_exploratory_comp_1_sol_py_exploratory_comp_1_sol.ipynb py exploratory comp 1 sol Date :Wed Mar  8 12:02:38 2017
# 2111 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_s4_py_exp_comp_s4_py_exp_comp_s4.ipynb py exp comp s4 Date :Wed Mar  8 12:02:38 2017
# 2112 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_s4_py_exp_comp_s4_sol_py_exp_comp_s4_sol.ipynb py exp comp s4 sol Date :Wed Mar  8 12:02:38 2017
# 2113 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook8_pandas_py_exploratory_comp_8_sol_py_exploratory_comp_8_sol.ipynb py exploratory comp 8 sol Date :Wed Mar  8 12:02:38 2017
# 2114 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_pandas_py_exploratory_comp_5_sol_py_exploratory_comp_5_sol.ipynb py exploratory comp 5 sol Date :Wed Mar  8 12:02:38 2017
# 2115 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_pandas_py_exploratory_comp_5_py_exploratory_comp_5.ipynb py exploratory comp 5 Date :Wed Mar  8 12:02:38 2017
# 2116 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_wm1_py_exp_comp_wm1_py_exp_comp_wm1.ipynb py exp comp wm1 Date :Wed Mar  8 12:02:38 2017
# 2117 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_wm1_py_exp_comp_wm1_sol_py_exp_comp_wm1_sol.ipynb py exp comp wm1 sol Date :Wed Mar  8 12:02:38 2017
# 2118 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_s3_py_exp_comp_s3_sol_py_exp_comp_s3_sol.ipynb py exp comp s3 sol Date :Wed Mar  8 12:02:38 2017
# 2119 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_s3_py_exp_comp_s3_py_exp_comp_s3.ipynb py exp comp s3 Date :Wed Mar  8 12:02:38 2017
# 2120 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_wm2_py_exp_comp_wm2_py_exp_comp_wm2.ipynb py exp comp wm2 Date :Wed Mar  8 12:02:38 2017
# 2121 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_wm2_py_exp_comp_wm2_sol_py_exp_comp_wm2_sol.ipynb py exp comp wm2 sol Date :Wed Mar  8 12:02:38 2017
# 2122 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_wm3_py_exp_comp_wm3_sol_py_exp_comp_wm3_sol.ipynb py exp comp wm3 sol Date :Wed Mar  8 12:02:38 2017
# 2123 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_wm3_py_exp_comp_wm3_py_exp_comp_wm3.ipynb py exp comp wm3 Date :Wed Mar  8 12:02:38 2017
# 2124 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook11_hypothesis_test_py_exploratory_comp_11_sol_py_exploratory_comp_11_sol.ipynb py exploratory comp 11 sol Date :Wed Mar  8 12:02:38 2017
# 2125 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_adv4_py_exp_comp_adv4_py_exp_comp_adv4.ipynb py exp comp adv4 Date :Wed Mar  8 12:02:38 2017
# 2126 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_adv4_py_exp_comp_adv4_sol_py_exp_comp_adv4_sol.ipynb py exp comp adv4 sol Date :Wed Mar  8 12:02:38 2017
# 2127 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook7_bugs_py_exploratory_comp_7_sol_py_exploratory_comp_7_sol.ipynb py exploratory comp 7 sol Date :Wed Mar  8 12:02:38 2017
# 2128 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook7_bugs_py_exploratory_comp_7_py_exploratory_comp_7.ipynb py exploratory comp 7 Date :Wed Mar  8 12:02:38 2017
# 2129 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_adv5_py_exp_comp_adv5_sol_py_exp_comp_adv5_sol.ipynb py exp comp adv5 sol Date :Wed Mar  8 12:02:38 2017
# 2130 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook5_rootfinding_py_exploratory_comp_5_sol_py_exploratory_comp_5_sol.ipynb py exploratory comp 5 sol Date :Wed Mar  8 12:02:38 2017
# 2131 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook5_rootfinding_py_exploratory_comp_5_py_exploratory_comp_5.ipynb py exploratory comp 5 Date :Wed Mar  8 12:02:38 2017
# 2132 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook6_linear_systems_py_exploratory_comp_6_sol_py_exploratory_comp_6_sol.ipynb py exploratory comp 6 sol Date :Wed Mar  8 12:02:38 2017
# 2133 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook6_linear_systems_py_exploratory_comp_6_py_exploratory_comp_6.ipynb py exploratory comp 6 Date :Wed Mar  8 12:02:38 2017
# 2134 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_adv3_py_exp_comp_adv3_sol_py_exp_comp_adv3_sol.ipynb py exp comp adv3 sol Date :Wed Mar  8 12:02:38 2017
# 2135 python3-starter_mbakker7-exploratory_computing_with_python-ca15088_notebook_adv3_py_exp_comp_adv3_py_exp_comp_adv3.ipynb py exp comp adv3 Date :Wed Mar  8 12:02:38 2017
# 2136 python3-starter_SALOME_BINARIES-UB16.04_matplotlib_lib_python2.7_site-packages_matplotlib-1.4.3-py2.7-linux-x86_64.egg_matplotlib_backends_web_backend_nbagg_uat_nbagg_uat.ipynb nbagg uat Date :Sun Apr  9 11:12:34 2017

# %% [markdown]
# # UPDATE A SHORT LIST

# %%
import os
import os.path
title = "JupyterNotebook-Graphics.list"
f= open(title,"w");f.close()
count=0
for dirpath, dirnames, filenames in os.walk("/home/jack/Desktop/JupyterNotebook-Graphics/"):
    filenames = [f for f in filenames if not f[0] == '.']
    dirnames[:] = [d for d in dirnames if not d[0] == '.']
    for filename in [f for f in filenames if f.endswith(".db")]:
        count=count+1
        Path = os.path.join(dirpath, filename)
        with open(title, 'a') as outfile:
            path = Path+"\n"
            outfile.write(path)

# %% [markdown]
# # END UPDATE PROCESSING ------------------

# %%
# !sqlite3 /home/jack/nov19b.db "pragma integrity_check;"
# Out:
# ok

# %%
import sqlite3
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str
c = conn.cursor()
c.execute("SELECT COUNT(*) from ipynb")
(number_of_rows,)=c.fetchone()
print (number_of_rows,)
# Out:
# (1444,)

# %% [markdown]
# # FIND A NOTEBOOK

# %%
# !ls /home/jack/*.db
# Out:
# /home/jack/Default.db	 /home/jack/font.db		/home/jack/pdfsBK.db
# /home/jack/font2.db	 /home/jack/NoteBook_Binary.db	/home/jack/postit.db
# /home/jack/font_all2.db  /home/jack/nov19b.db		/home/jack/snippet.db
# /home/jack/font_all.db	 /home/jack/PDE2db.db

# %%
# !rm /home/jack/Desktop/PROCESSING/Processing/nov19b.db

# %%
file = "/home/jack/Desktop/GRAPHICS/nov19b.db"
import os.path, time
print("last modified: %s" % time.ctime(os.path.getmtime(file)))
print("created: %s" % time.ctime(os.path.getctime(file)))
# Out:
# last modified: Thu Nov 30 12:15:43 2017
# created: Wed Dec 13 14:09:31 2017

# %%
# !ls /home/jack/nov19b.db
# Out:
# /home/jack/nov19b.db

# %%
# !locate nov19b.db
# Out:
# /home/jack/Desktop/GRAPHICS/nov19b.db
# /home/jack/Desktop/PROCESSING/Processing/nov19b.db

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
count=1
search = raw_input("Title :")
# ONLY the DATA table can use MATCH
for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE content MATCH ?',(search,)):
    print row[0],row[1],row[3],"\n----------------------"
    count=count+1
    if count>25:break
c.close()
conn.close()
# Out:
# Title :palette
# 209 Desktop_altair_altair_altair_notebooks_04BarCharts_04BarCharts.ipynb 04Bar Charts Date :Sun Nov 19 17:17:24 2017
# ----------------------
# 411 Desktop_Phoenix_lessons_WIX_STUFF_WIX_STUFF.ipynb WIX STUFF Date :Thu Aug  3 11:57:30 2017
# ----------------------
# 415 Desktop_IPyLua_Filters_With_cv2.trackbars_Filters_With_cv2.trackbars.ipynb Filters With cv2.trackbars Date :Mon Jul 31 19:52:09 2017
# ----------------------
# 467 Desktop_Books_numerical-python-book-code_ch12codelisting_ch12codelisting.ipynb ch12codelisting Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 509 Desktop_imagebot_randpalettepost_randpalettepost.ipynb randpalettepost Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 513 Desktop_imagebot_pygame_pygame.ipynb pygame Date :Sun Sep  3 08:31:03 2017
# ----------------------
# 515 Desktop_imagebot_BLENDERS_BLENDERS.ipynb BLENDERS Date :Mon Sep 11 10:14:41 2017
# ----------------------
# 525 Desktop_imagebot_PILONLY_PILONLY.ipynb PILONLY Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 531 Desktop_imagebot_MEAN_Graphics_MEAN_Graphics.ipynb MEAN Graphics Date :Sat Aug 26 13:14:48 2017
# ----------------------
# 537 Desktop_imagebot_ImageMaker_ImageMaker.ipynb Image Maker Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 543 Desktop_imagebot_colorific_colorific.ipynb colorific Date :Tue Aug 22 10:27:08 2017
# ----------------------
# 555 Desktop_imagebot_Palett_Swap_ARRAY_STUFF_Palett_Swap_ARRAY_STUFF.ipynb Palett Swap ARRAY STUFF Date :Tue Sep 12 08:54:49 2017
# ----------------------
# 557 Desktop_imagebot_Text_Generation_Text_Generation.ipynb Text Generation Date :Wed Sep 27 10:03:32 2017
# ----------------------
# 573 Desktop_imagebot_DreamandPosttoTwitter_DreamandPosttoTwitter.ipynb Dreamand Postto Twitter Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 575 Desktop_imagebot_INDEX_INDEX.ipynb INDEX Date :Fri Sep 15 17:45:50 2017
# ----------------------
# 577 Desktop_imagebot_MaskGeneratorCopy1_MaskGeneratorCopy1.ipynb Mask Generator Copy1 Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 581 Desktop_imagebot_AAAAAAAMyManRaynewexperimentsCopy1_AAAAAAAMyManRaynewexperimentsCopy1.ipynb AAAAAAAMy Man Raynewexperiments Copy1 Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 591 Desktop_imagebot_Utilities_Utilities.ipynb Utilities Date :Thu Sep  7 12:44:44 2017
# ----------------------
# 601 Desktop_imagebot_Post_in_Order_Post_in_Order.ipynb Post in Order Date :Thu Sep 14 09:33:29 2017
# ----------------------
# 605 Desktop_imagebot_bak_BLENDERS_BLENDERS.ipynb BLENDERS Date :Mon Aug 21 10:22:44 2017
# ----------------------
# 615 Desktop_imagebot_bak_ImageMaker_ImageMaker.ipynb Image Maker Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 623 Desktop_imagebot_bak_DreamandPosttoTwitter_DreamandPosttoTwitter.ipynb Dreamand Postto Twitter Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 627 Desktop_imagebot_bak_MaskGeneratorCopy1_MaskGeneratorCopy1.ipynb Mask Generator Copy1 Date :Sun Nov 19 17:17:40 2017
# ----------------------
# 631 Desktop_deep-dream-generator_lorenzsystemattractoranimateEXP_lorenzsystemattractoranimateEXP.ipynb lorenzsystemattractoranimate EXP Date :Sun Nov 19 17:17:43 2017
# ----------------------
# 641 Desktop_deep-dream-generator_notebooks_Untitled0_Untitled0.ipynb Untitled0 Date :Wed Jun 21 14:48:27 2017
# ----------------------

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
count=1
search = raw_input("Title :")
for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE content MATCH ?',(search,)):
    print row[0],row[1],row[3],"\n----------------------"
    count=count+1
    if count>10:break
c.close()
conn.close()
# Out:
# Title :pdf
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-2-a752f964dc93> in <module>()
#      10 count=1
#      11 search = raw_input("Title :")
# ---> 12 for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE content MATCH ?',(search,)):
#      13     print row[0],row[1],row[3],"\n----------------------"
#      14     count=count+1
#
# OperationalError: unable to use function MATCH in the requested context

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
count=1
search = raw_input("ROWID :")
for row in c.execute('SELECT rowid, file, content, description FROM ipynb WHERE rowid = ?',(search,)):
    print row[0],row[1],row[3],"\n----------------------"
    count=count+1
    if count>10:break
c.close()
conn.close()
# Out:
# ROWID :1936
# 1936 Index nteract  Creating Showme A C++ Image Viewer
# Date :Sat Jul 29 09:26:59 2017/home/jack/Desktop/numpy-array-filters/nteract/nteract--Creating-Showme-A_C++_Image-Viewer.ipynbnteract--Creating-Showme-A_C++_Image-Viewer.ipynb
#
# ----------------------

# %% [markdown]
# # Create a Notebook

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"

conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("FileName :")
f= open(search,"w");f.close()
with open(search, 'a') as outfile:
    for row in c.execute('SELECT content FROM ipynb WHERE file MATCH ?', (search,)):
        row0 = row[0]
        #row0 =str(row0,"\n")
        outfile.write(row0)
        print row0
        
conn.close()
f.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-ec6630f67098> in <module>()
#       9 conn.text_factory=str
#      10 c = conn.cursor()
# ---> 11 search = raw_input("FileName :")
#      12 f= open(search,"w");f.close()
#      13 with open('newtest.ipynb', 'a') as outfile:
#
# /home/jack/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /home/jack/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"

conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ROWID :")
f= open(search,"w");f.close()
with open('newtest.ipynb', 'a') as outfile:
    for row in c.execute('SELECT content FROM ipynb WHERE rowid = ?', (search,)):
        row0 = row[0]
        #row0 =str(row0,"\n")
        outfile.write(row0)
        
conn.close()
f.close()
# Out:
# ROWID :65

# %%
1753

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
f= open('.ipynb',"w")
f.close()
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ROWID :")
with open('.ipynb', 'a') as outfile:
        for row in c.execute('SELECT content FROM ipynb WHERE rowid = ?', (search,)):
            #for row in c.execute('SELECT * FROM ipynb WHERE rowid = 100 LIMIT 10 OFFSET 0'):
            row0 = row[0]
            #row0 =str(row0,"\n")
            outfile.write(row0)

conn.close()
f.close()
# Out:
# ROWID :1783

# %% [markdown]
# # Print a Span of ROWID rowids

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
#database = "junk.db"
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
start =raw_input("ROWID-Start :")
end =raw_input("ROWID-End :")
#for row in c.execute('SELECT rowid, * FROM ipynb WHERE rowid = ?', (search,)):
#for row in c.execute('SELECT rowid, * FROM ipynb WHERE rowid > 40 and rowid < 100'):    
for row in c.execute('SELECT rowid, * FROM ipynb WHERE rowid > ? and rowid < ?',(start, end)):    
     
        print row[0],row[1],"\n\n",row[3]
conn.close()
f.close()

# %%
import sqlite3
import sys
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory = str
c = conn.cursor()
count=0;req=200
id1 = raw_input("Starting ID : ")
id2 = raw_input("How Many Rows : ")
# id1 is start id2 is how many lines
for row in c.execute('SELECT rowid, * from ipynb LIMIT ? OFFSET ?',  (id2, id1)):
    count=count+1
    #print row[0],row[1],"\n",row[2]
    print row[0]
    if count > req:
        conn.close()
        sys.exit()

# %% [markdown]
# # Delete by Rowid

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
ROWID = 
c.execute("DELETE FROM ipynb WHERE rowid = ?", (ROWID,))
conn.commit()
conn.close()

# %%
import sqlite3
database = "test.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c = conn.cursor()
for row in c.execute('SELECT rowid, file, description FROM ipynb WHERE file = "Index" '):
    print row[0],row[1],row[2]       

c.close()
conn.close()

# %% [markdown]
# # XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# # XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
from time import sleep
title = "ipynb.list"
lines = open(title,"r")
for line in lines.readlines():
    sleep(1)
    #print os.path.basename(line)
    print line
# Out:
# /home/jack/Untitled.ipynb
#
# /home/jack/Julia-Intro Good.ipynb
#
# /home/jack/Untitled1.ipynb
#
# /home/jack/Untitled3.ipynb
#
# /home/jack/Untitled2.ipynb
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-215-2247aed0e499> in <module>()
#       3 lines = open(title,"r")
#       4 for line in lines.readlines():
# ----> 5     sleep(1)
#       6     #print os.path.basename(line)
#       7     print line
#
# KeyboardInterrupt:

# %% [markdown]
# # Workshop - EXTRAS

# %%
import re
title = "ipynb.list"
titles = open(title,"r")
for title in titles.readlines():
            filename = os.path.basename(title)
            description = filename
            description = description.replace("-", " ")
            description = description.replace("_", " ")
            description = description.replace(".ipynb", " ")
            description = re.sub("([a-z])([A-Z])","\g<1> \g<2>",description)
            print title, filename, description,"\n\n\n"

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
#database = "FTS4_IPYNB_indexed.db"
database = "sept8_IPNB.list.db"
conn = sqlite3.connect(database)
conn.text_factory=str
c = conn.cursor()
c.execute("SELECT COUNT(*) from ipynb")
print c.fetchone()

#print number_of_rows
# Out:
# (1444,)

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
#database = "junk.db"
database = "test.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
count = 1
search = "Index"
for row in c.execute('SELECT rowid, * FROM ipynb WHERE content = ?', (search,)):
        print count,"\n", row[0],row[1],row[3],"\n-----------------"
        count=count+1
        if count>10:break
conn.close()
f.close()

# %%
# !rm test.db

# %% [markdown]
# # Create the notebooks.db Database and column

# %%
from time import sleep
import sqlite3
database = "ipynb-list.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS4(title, line);
""")
conn.commit()
title = "ipynb.list"
titles = open(title,"r")
for title in titles.readlines():
    with open(title, 'r') as f:
        lines = f.readlines()
        for line in lines:
            c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
            conn.commit()

        line = title
        title = "index"
        c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
        conn.commit()


conn.close()
f.close()

# %%
import sqlite3
database = "/home/jack/postit.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS3(title, line);
""")
conn.commit()
conn.close()

# %% [markdown]
# # Insert the notebook into a Database

# %%
import base64
from time import sleep
title = "ALL-WORKNG-SQLITE_and_MYSQL.ipynb"
import sqlite3
conn = sqlite3.connect('sept8_IPNB.list.db')
conn.text_factory=str 
c = conn.cursor()
with open(title, 'r') as f:
    lines = f.readlines()
    for line in lines:
        c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
        conn.commit()
        #print encodedlistvalue

conn.close()
f.close()

# %% [markdown]
# # ALL-IN-ONE Enter book and title into database and

# %%
import os
PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/"
for file in os.listdir(PATH):
    if file.endswith(".ipynb"):
        print(os.path.join(PATH, file))

# %%
import base64
from time import sleep
import os
import sqlite3
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/"
PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/postit/"
database = "/home/jack/postit.db"
for file in os.listdir(PATH):
    if file.endswith(".ipynb"):
        print(os.path.join(PATH, file))
        title2 = PATH+file
        conn = sqlite3.connect(database)
        conn.text_factory=str 
        c = conn.cursor()
        with open(title2, 'r') as f:
            lines = f.readlines()
            for line in lines:
                c.execute("INSERT INTO ipynb VALUES (?,?)", (file, line)) 
                conn.commit()

        conn.close()
        f.close()
        conn = sqlite3.connect(database)
        conn.text_factory=str 
        c = conn.cursor()
        line = file
        #line ="Good-mouse-sizing-and-cropping.ipynb"
        title = "index"
        c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
        conn.commit()
        conn.close()
        f.close()
# Out:
# /home/jack/Desktop/deep-dream-generator/notebooks/postit/chainer.ipynb
# /home/jack/Desktop/deep-dream-generator/notebooks/postit/caffe-pb_converter.ipynb
# /home/jack/Desktop/deep-dream-generator/notebooks/postit/c-dream.ipynb
# /home/jack/Desktop/deep-dream-generator/notebooks/postit/c-experiments.ipynb

# %% [markdown]
# # XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXx

# %%
from time import sleep
database = "/home/jack/postit.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS4(title, line);
""")
conn.commit()
conn.close()

title2 = PATH+title
import sqlite3
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
with open(title2, 'r') as f:
    lines = f.readlines()
    for line in lines:
        c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
        conn.commit()

    line = title
    title = "index"
    c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
    conn.commit()


conn.close()
f.close()

# %% [markdown]
# # XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %%
# !rm /home/jack/Desktop/text_stuff/postit.db
# Out:
# rm: cannot remove '/home/jack/Desktop/text_stuff/postit.db': No such file or directory

# %%
# !rm /home/jack/Desktop/text_stuff/postit.db

# %%
import base64
from time import sleep
import os
title = "Title-and-Sign-titlenpost.py.ipynb"
import sqlite3
conn = sqlite3.connect('newipynb.db')
conn.text_factory=str 
c = conn.cursor()
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS3(title, line);
""")

#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/"
PATH = "/home/jack/Desktop/text_stuff/"
for file in os.listdir(PATH):
    if file.endswith(".ipynb"):
        print(os.path.join(PATH, file))
        title2 = PATH+file
        with open(title2, 'r') as f:
            lines = f.readlines()
            for line in lines:
                c.execute("INSERT INTO ipynb VALUES (?,?)", (file, line)) 
                conn.commit()
                #print encodedlistvalue
            conn = sqlite3.connect('newipynb.db')
            conn.text_factory=str 
            c = conn.cursor()

            line = file
            #line ="Good-mouse-sizing-and-cropping.ipynb"
            title = "index"
            c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
            conn.commit()
                    #print encodedlistvalue

conn.close()
f.close()

# %%
# !rm newtest.db

# %% [markdown]
# # Working

# %%
file = 'deep-dream-generator.ipynb'
PATH = "/home/jack/python3-starter/notebooks/"
filename = PATH+file
filein = PATH
filein = filein.replace("/home/jack/", "")
filein = filein.replace("/", "_")
filein = filein+file
description = filein
description = description.replace("_", " ")
description = description.replace("-", " ")
description = description.replace("/", " ")
description = description+"\n"+PATH+file+"\n"+file
print filein, "\n\n", description
# Out:
# python3-starter_notebooks_deep-dream-generator.ipynb
#
# python3 starter notebooks deep dream generator.ipynb
# /home/jack/python3-starter/notebooks/deep-dream-generator.ipynb
# deep-dream-generator.ipynb

# %%
file = 'SOme.txt'
PATH = "/home/jack/python3-starter/notebooks/"

description = PATH
description = description.replace("_", " ")
description = description.replace("-", " ")
description = description.replace("/", " ")
filename = PATH+file
description = description+(file)
#filein = "python3-starter-notebooks_"+file
print description
# Out:
#  home jack python3 starter notebooks SOme.txt

# %%
# !rm FTS4_notebooks.db

# %% [markdown]
# # Search by words in title

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("Title :")
for row in c.execute('SELECT rowid, * FROM ipynb WHERE file MATCH ?',(search,)):
    print row[0],row[1]

c.close()
conn.close()
# Out:
# Title :Image
# 417 _home_conda_anaconda3_envs_py35_lib_python3.5_site-packages_nbconvert_preprocessors_tests_files_Inline Image_Inline Image.ipynb
# 499 Desktop_JupyterNotebook-Graphics_Image-Stuff-001_Image-Stuff-001.ipynb
# 745 _home_conda_Desktop_NoteBooks_pycode_Part7_Image_Statistics149904603492149904603492_Part7_Image_Statistics149904603492149904603492.ipynb
# 819 _home_conda_anaconda3_envs_py35_lib_python3.5_site-packages_nbconvert_tests_files_latex-linked-image_latex-linked-image.ipynb
# 847 Desktop_C++Stuff_Creating-C++-Image-viewer-checkpoint_Creating-C++-Image-viewer-checkpoint.ipynb
# 1089 Desktop_C++Stuff_Creating-C++-Image-blender-checkpoint_Creating-C++-Image-blender-checkpoint.ipynb
# 1111 _home_conda_Desktop_NoteBooks_TEXT_NLTK_text_stuff_Image_Pack1507258228615072582286_Image_Pack1507258228615072582286.ipynb
# 1133 _home_conda_Desktop_NoteBooks_TWITTER_args_csv_Twython_ImageBot_notebooks_Twitter-_image-and-comment-manual-upload-checkpoint_Twitter-_image-and-comment-manual-upload-checkpoint.ipynb
# 1213 Desktop_JupyterNotebook-Graphics_save-image-and-array-for-seamless-cloning-checkpoint_save-image-and-array-for-seamless-cloning-checkpoint.ipynb
# 1277 _home_conda_Desktop_NoteBooks_TWITTER_args_csv_Twython_ImageBot_notebooks_Meanshift-Image-Segmentation-checkpoint_Meanshift-Image-Segmentation-checkpoint.ipynb
# 1333 _home_conda_Desktop_NoteBooks_GRAPHICS_gmic_GMIC-Image-Processing152525532884152525532884_GMIC-Image-Processing152525532884152525532884.ipynb
# 1345 _home_conda_Desktop_NoteBooks_GRAPHICS_gmic_image-magik152525597675152525597675_image-magik152525597675152525597675.ipynb

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "test.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ROWID :")
for row in c.execute('SELECT content, * FROM ipynb WHERE rowid = ?',(search,)):
    print row[0],row[1]

c.close()
conn.close()

# %%
database = "newtest.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
with open("Output.ipynb", "wb") as output_file:
    c.execute("SELECT content FROM ipynb WHERE rowid = '1753'")
    ablob = c.fetchone()
    output_file.write(ablob[0])

c.close()
conn.close()

# %%
import sqlite3
database = "newtest.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS3(file, content);
""")
conn.commit()
conn.close()
conn = sqlite3.connect(database)
c = conn.cursor()
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/"
#PATH = "/home/jack/Desktop/text_stuff/"
#PATH = "/home/jack/Desktop/imagebot/"
#PATH = "/home/jack/Desktop/Snippet_Warehouse/"
#PATH = "/home/jack/Desktop/gitjupyter/"
#PATH = "/home/jack/Desktop/jack_watch/"
#PATH = "/home/jack/Desktop/jack_watch/nltk/"
#PATH = "/home/jack/Desktop/jack_watch/Python-Lectures/"
#PATH = "/home/jack/Desktop/jack_watch/jupyter_examples-master/"
#PATH = "/home/jack/Desktop/Books/numerical-python-book-code/"
#PATH = "/home/jack/Desktop/Books/pydata-book/"
#PATH = "/home/jack/Desktop/Ruby/"
#PATH = "/home/jack/Desktop/alice/ChatterBot/"
#PATH = "/home/jack/Desktop/deep-dream-generator/LOCAL-notebooks/"
#PATH = "/home/jack/Desktop/numpy-array-filters/"
#PATH = "/home/jack/Desktop/pycode/"
#PATH = "/home/jack/Desktop/pycode/vpython2/TrigonometryBot/"
#PATH = "/home/jack/Desktop/temp/args_csv_Twython_ImageBot/"
PATH = "/home/jack/python3-starter/notebooks/"
for file in os.listdir(PATH):
    if file.endswith(".ipynb"):
        
        filename = PATH+file
        #filein = "deep-dream-generator_"+file
        #filein = "text_stuff_"+file
        filein = "python3-starter-notebooks_"+file
        with open(filename, "rb") as input_file:
            ablob = input_file.read()
            #content = [sqlite3.Binary(ablob)]
            content  = sqlite3.Binary(ablob)
            c.execute("INSERT INTO ipynb (file, content) VALUES(?, ?)", (filein, content))
            print os.path.join(PATH, file, filein)
            conn.commit()
        

c.close()
conn.close()
    
conn = sqlite3.connect(database) 
conn.text_factory=str 
c = conn.cursor()
#for row in c.execute('SELECT rowid, file FROM ipynb'):
#    print row[0],row[1]       

c.close()
conn.close()

# %%
import sqlite3
database = "newtest.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c = conn.cursor()
for row in c.execute('SELECT rowid, file FROM ipynb WHERE rowid = '):
    print row[0],row[1]       

c.close()
conn.close()

# %%
import sqlite3
database = "newtest.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS3(file, content);
""")
conn.commit()
conn.close()
conn = sqlite3.connect(database)
c = conn.cursor()
file = "jupyter-to-database-FTS4.ipynb"
with open(filename, "rb") as input_file:
    ablob = input_file.read()
    #content = [sqlite3.Binary(ablob)]
    content  = sqlite3.Binary(ablob)
    c.execute("INSERT INTO ipynb (file, content) VALUES(?, ?)", (file, content))
    conn.commit()

with open("Output.ipynb", "wb") as output_file:
    c.execute("SELECT content FROM ipynb WHERE file = 'jupyter-to-database-FTS4.ipynb'")
    ablob = c.fetchone()
    output_file.write(ablob[0])

c.close()
conn.close()

# %%
import sqlite3
database = "newtest.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS3(file, content);
""")
conn.commit()
conn.close()
conn = sqlite3.connect(database)
c = conn.cursor()
filename = "jupyter-to-database-FTS4.ipynb"
with open(filename, "rb") as input_file:
    ablob = input_file.read()
    c.execute("INSERT INTO ipynb (file, content) VALUES(?, ?)", (filename, [sqlite3.Binary(ablob)]))
    conn.commit()

with open("Output.ipynb", "wb") as output_file:
    #c.execute("SELECT file FROM file WHERE id = 0")
    c.execute('SELECT content FROM ipynb WHERE file MATCH ?',(file,))   
    ablob = cursor.fetchone()
    output_file.write(ablob[0])

cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-93-bd81ee6a78a6> in <module>()
#      16 with open(filename, "rb") as input_file:
#      17     ablob = input_file.read()
# ---> 18     c.execute("INSERT INTO ipynb (file, content) VALUES(?, ?)", (filename, [sqlite3.Binary(ablob)]))
#      19     conn.commit()
#      20
#
# InterfaceError: Error binding parameter 1 - probably unsupported type.

# %%
import base64
from time import sleep
import os
import sqlite3
database = "/home/jack/Desktop/text_stuff/postit.db"
#database = "/home/jack/Desktop/text_stuff/notebooks.db"
conn = sqlite3.connect(database)
c = conn.cursor()
conn.text_factory=str 
c.execute("""
CREATE VIRTUAL TABLE IF NOT EXISTS ipynb 
USING FTS3(file, content);
""")
conn.commit()
conn.close()
#PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/"
PATH = "/home/jack/Desktop/text_stuff/"
for file in os.listdir(PATH):
    if file.endswith(".ipynb"):
        print(os.path.join(PATH, file))
        title2 = PATH+file
        conn = sqlite3.connect(database)
        conn.text_factory=str 
        c = conn.cursor()
        #with open(title2, 'r') as f:
        keyword = file
        #content=open(title2, 'r').read().decode("utf-8", "ignore")
        content=open(title2, 'r').read()   
        c.execute("INSERT INTO ipynb VALUES (?,?)", (file,content))
        #c.execute("INSERT INTO ipynb VALUES (?,?)", (file, content)) 
        conn.commit()

        conn.close()
        f.close()
        conn = sqlite3.connect(database)
        conn.text_factory=str 
        c = conn.cursor()
        line = file
        #line ="Good-mouse-sizing-and-cropping.ipynb"
        content = "Index"
        c.execute("INSERT INTO ipynb VALUES (?,?)", (file, content)) 
        conn.commit()
        conn.close()
        f.close()
        
conn = sqlite3.connect(database) 
conn.text_factory=str 
c = conn.cursor()
for row in c.execute('SELECT rowid, file FROM ipynb'):
#for row in c.execute('SELECT line FROM ipynb WHERE file MATCH ?',(file,)):    
    sleep(.5)
    #row0 = base64.b64decode(row[0])
    #print row0, row[1]
    print row[0],row[1]

# %%
import base64
from time import sleep
import sqlite3
database = "/home/jack/Desktop/text_stuff/postit.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
line ="ALL-WORKNG-SQLITE_and_MYSQL.ipynb"
#line ="Good-mouse-sizing-and-cropping.ipynb"
title = "index"
c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
conn.commit()
        #print encodedlistvalue

conn.close()
f.close()

# %% [markdown]
# # XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# # View the notebooks.db file row by row

# %%
import json
import sys
from time import sleep
import sqlite3
database = "/home/jack/Desktop/text_stuff/postit2.db"
#database = '/home/jack/Desktop/text_stuff/notebooks.db'
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
#for row in c.execute('SELECT title, line  FROM ipynb'):
search = "jupyter-to-database-FTS4.ipynb"
#with open('jupyter-to-database-FTS4-2.ipynb', 'a') as outfile:
for row in c.execute('SELECT line FROM ipynb WHERE title MATCH ?',(search,)):    
    
    
    sleep(.5)
    #row0 = base64.b64decode(row[0])
    #print row0, row[1]
    print row[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-d391d4a300da> in <module>()
#      17     #row0 = base64.b64decode(row[0])
#      18     #print row0, row[1]
# ---> 19     print row[1]
#
# IndexError: tuple index out of range

# %% [markdown]
# # index each Jupyter Notebooks one - one in the database

# %%
import base64
from time import sleep
import sqlite3
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
line ="ALL-WORKNG-SQLITE_and_MYSQL.ipynb"
#line ="Good-mouse-sizing-and-cropping.ipynb"
title = "index"
c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
conn.commit()
        #print encodedlistvalue

conn.close()
f.close()

# %% [markdown]
# # Insert a group of notebooks into an index field

# %%
import base64
from time import sleep
import sqlite3
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
line ="""
astral.py.ipynb
Astronomy-II.ipynb
Astronomy-I.ipynb 
DEEP-DREAM-ONLY.ipynb
earth-satellites.ipynb
jupyter-to-database-FTS4.ipynb
Image_Pack.ipynb    
Snippet_Warehouse-MySQL-SQLite-code-storage-search.ipynb    
WikiPedia.ipynb
Creation-of-collection.db.ipynb    
Palett_Swap.ipynb    
Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb
Creating-C++-Image-blender.ipynb
Creating-C++-Image-viewer.ipynb
Text_Generation-BEST.ipynb
Words-and-Sentences.ipynb
Bible_Search_in_SQL.ipynb
"""
title = "index"
c.execute("INSERT INTO ipynb VALUES (?,?)", (title, line)) 
conn.commit()
        #print encodedlistvalue

conn.close()
f.close()

# %% [markdown]
# # Write the Jupyter Notebook stored in database
# # to *.ipynb file

# %%
import json
import sys
from time import sleep
import sqlite3
import csv

f= open('newtest.ipynb',"w")
f.close()
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
#search = raw_input("Title :")
search = "Matplotlib.ipynb"
with open('newtest.ipynb', 'a') as outfile:
    for row in c.execute('SELECT line FROM ipynb WHERE title MATCH ?',\
                         (search,)):
        row0 = row[0]
        #row0 =str(row0,"\n")
        outfile.write(row0)
        
conn.close()
f.close()

# %%
import json
import sys
from time import sleep
import sqlite3
import csv

f= open('jupyter-to-database-FTS4-2.ipynb',"w")
f.close()
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
#search = raw_input("Title :")
search = 13
with open('jupyter-to-database-FTS4-2.ipynb', 'a') as outfile:
    c.execute('SELECT rowid, * FROM ipynb WHERE rowid = ?',(search,))
    print row[0],row[1]

conn.close()
f.close()
# Out:
# 92 sat2db.ipynb

# %% [markdown]
# # Search by Title ( on title is index)
# # This Creates an index.txt file

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
title = "index.txt"
f= open(title,"w")
f.close()
database = "/home/jack/Desktop/text_stuff/postit.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
with open(title, 'a') as outfile:
    for row in c.execute('SELECT rowid, title, line, keyword FROM ipynb WHERE title MATCH ?', ("Index",)):
        row0 =row[0], row[3]
        row0 =str(row0)
        row0 = row0+"\n"
        outfile.write(row0)
conn.close()
f.close()

# %% [markdown]
# # List Jupyter Notebooks in Database via index column

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "/home/jack/Desktop/text_stuff/postit.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
#with open(title, 'a') as outfile:
#content=open(filename, 'r').read().decode("utf-8", "ignore")    
for row in c.execute('SELECT rowid, title, line FROM ipynb WHERE title = ?', ("Index",)):
    row0 = row[0],row[2]
    sleep(1)
    print row0
conn.close()

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "/home/jack/Desktop/text_stuff/postit.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
#with open(title, 'a') as outfile:
#content=open(filename, 'r').read().decode("utf-8", "ignore")    
c.execute('SELECT rowid, title, line, keyword FROM ipynb WHERE title = ?', ("jupyter-to-database-FTS4.ipynb",))
print row[0:]
conn.close()
# Out:
# (6, 'index', 'TensorFlow-dream.ipynb')

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "/home/jack/Desktop/text_stuff/postit.db"
conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
#with open(title, 'a') as outfile:
#content=open(filename, 'r').read().decode("utf-8", "ignore")    
for row in c.execute('SELECT rowid, title, line FROM ipynb'):
    row0 = row[0],row[1]
    sleep(1)
    print row0
conn.close()

# %% [markdown]
# # Search Notebook Database by lines

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "/home/jack/Desktop/text_stuff/postit.db"
conn = sqlite3.connect(database)

conn.text_factory=str 
c = conn.cursor()
#search = "FTS3_Database.ipynb"
search = raw_input("SEARCH : ")
with open(title, 'a') as outfile:
    for row in c.execute('SELECT rowid, title, keyword FROM ipynb WHERE rowid = ?', (search,)):
        print row[0],row[1],row[2]

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
#search = "FTS3_Database.ipynb"
search = raw_input("SEARCH : ")
with open(title, 'a') as outfile:
    for row in c.execute('SELECT rowid, title, line FROM ipynb WHERE line MATCH ?', (search,)):
        print row[0],row[1],"\n",row[2]

# %% [markdown]
# # Delete by index - Had a power failure will
# # loading a notebook so this came in handy

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
#c.execute("DELETE title, line FROM ipynb where rowid MATCH '362113' "):
#c.execute("delete from ipynb where rowid=362113;"):
c.execute("DELETE FROM ipynb WHERE title = ?", ('Good-mouse-sizing-and-cropping.ipynb',))
conn.commit()
conn.close()

# %% [markdown]
# # Print a Span of Rows
# <b>Sometimes the whole jupyter notebook does not need printed just a " code hint" is all required</b>

# %%
import sqlite3
import sys
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory = str
c = conn.cursor()
count=0;req=200
id1 = raw_input("Starting ID : ")
id2 = raw_input("How Many Rows : ")
# id1 is start id2 is how many lines
for row in c.execute('SELECT rowid, * from ipynb LIMIT ? OFFSET ?',  (id2, id1)):
    count=count+1
    #print row[0],row[1],"\n",row[2]
    print row[2]
    if count > req:
        conn.close()
        sys.exit()

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
data
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory=str 
c = conn.cursor()
search = "earth-satellites.ipynb"
with open(title, 'a') as outfile:
    for row in c.execute("SELECT rowid, file FROM ipynb where title MATCH 'jupyter-to-database-FTS4.ipynb' "):
        row0 = row[1]
        sleep(1)
        print row[0],row[1]

# %%
import sqlite3
import sys
conn = sqlite3.connect('/home/jack/Desktop/text_stuff/notebooks.db')
conn.text_factory = str
c = conn.cursor()
count=0;req=20
search = raw_input("Search : ")
for row in c.execute('SELECT rowid, title, line FROM ipynb WHERE title MATCH ?', (search,)):    
    count=count+1
    print row[0],row[1],"\n",row[2]
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Search : jupyter-to-database-FTS4.ipynb

# %%
import sqlite3
import sys
database = "test.db"
conn = sqlite3.connect(database)
conn.text_factory = str
c = conn.cursor()
count=0;req=50
search = raw_input("Search : ")
for row in c.execute('SELECT rowid, file, description FROM ipynb WHERE file MATCH ?', (search,)):    
    count=count+1
    print row[0],"\n",row[1],"\n",row[2]
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Search : astronomy
# 1747
# Desktop_jupnote_Astronomy-II_Astronomy-II.ipynb
#
# Astronomy II
#
# Wed Oct 18 16:02:53 2017
# 1759
# Desktop_jupnote_Astronomy-I_Astronomy-I.ipynb
#
# Astronomy I
#
# Wed Oct 18 16:02:53 2017
# 1825
# Desktop_text_stuff_Astronomy-II_Astronomy-II.ipynb
#
# Astronomy II
#
# Thu Oct 19 10:25:20 2017
# 1843
# Desktop_text_stuff_Astronomy-I_Astronomy-I.ipynb
#
# Astronomy I
#
# Thu Oct 19 10:22:54 2017

# %%
# !sqlite3 unique-End2.db "pragma integrity_check;"
# Out:
# ok

# %% [markdown]
# # XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# # SNIPPET STORAGE

# %%
# !locate snippet.db
# Out:
# /home/jack/Desktop/Processing/Processing/snippet.db
# /home/jack/Desktop/jupnote/snippet.db
# /home/jack/Desktop/text_stuff/snippet.db

# %%
import sqlite3
import sys
database = "/home/jack/snippet.db""
conn = sqlite3.connect(database)
ID = raw_input("Delete ID Number : ")
c = conn.cursor()
c.execute('DELETE FROM snippet WHERE id=?',(ID))
conn.commit()
conn.close()

# %%
Search : remove duplicate
ID :  78 
# %%writefile HashCheck.py
"" USEAGE:
(insert hash)

for example to get hash of a filename:
def md5(Path):
    hash_md5 = hashlib.md5()
    with open(Path, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()

Hash = md5(title)

import HashCheck
hasht = "jsudsfhndsfjunjsd"
HashCheck.hashfill(Hash)
---------------
import HashCheck
HashCheck.hashcheck()

import HashCheck
HashCheck.killmem()
""
import sqlite3
import sys
import os

def md5(Path):
    hash_md5 = hashlib.md5()
    with open(Path, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()

# %%
# !ls ~/hubiC/Databases
# Out:
# bigfeedfts.db	hashtest1.db	      pages.db	   sniptest.db
# chat.db		news.db		      pde2db.db    SQLITE_DATABASES.db
# database001.db	nltk.db		      PDE2db.db    test0.db
# dataTXT.db	NoteBook_Binary.db    pdefts4.db   test1.db
# Default.db	nov19a.db	      pdfsBK.db    test2.db
# gitJson1.db	nov19b.db	      runit.db	   testBLOB.db
# gitJson2.db	nov19.db	      salaries.db  testBLOBS.db
# gitJson.db	NSQLITE_DATABASES.db  snippet.db

# %%
import sqlite3
import sys
database = "/home/jack/hubiC/Databases/snippet.db"
conn = sqlite3.connect(database)
conn.text_factory = str
c = conn.cursor()
count=0;req=200
search = raw_input("Search : ")
for row in c.execute('SELECT rowid, * FROM snippet WHERE snippet MATCH ?', (search,)):    
    count=count+1
    print "ID : ",(row)[0],(row)[2]," -- KEYWORDS",(row)[3],"\n"
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Search : unknown database
# ID :  84
# #find table names, unknown sqlite database
# import sqlite3
# import sys
# from time import sleep
# parts = []
# database = "/home/jack/Desktop/text_stuff/database-bak/collection.db"
# conn = sqlite3.connect(database)
# conn.text_factory = str
# c = conn.cursor()
# res = c.execute("SELECT name FROM sqlite_master WHERE type='table';")
# for name in res:
#     sleep(2)
#
#     print name[0]
#
# #explore a database unknown database find lost table tables sqlite_master sqlite tricks
#
# #recover column names recover field names, unknown database, unknown sqlite
# import sqlite3
# database = "/home/jack/Desktop/text_stuff/database-bak/collection.db"
# conn = sqlite3.connect(database)
# c = conn.cursor()
# cur = c.execute('select * from tweets')
#
# #this also works
# #names = list(map(lambda x: x[0], cur.description))
#
# names = [description[0] for description in cur.description]
# print names[0:]
#  -- KEYWORDS explore a database unknown database find lost table tables sqlite_master sqlite tricks
# recover column names recover field names, unknown database, unknown sqlite
#
#
# ID :  100
# %%writefile dbINFO.py
# ""
# Gets tablename and column names from unknown database
# just enter database name.
# USAGE:
# import dbINFO
# database= "databases/history.db"
# #database= "databases/sat2.db"
# #database= "databases/ImageD.db"
# dbINFO.dbinfo(database)
#
# ""
#
# import sqlite3
# def dbinfo(database):
#     conn = sqlite3.connect(database)
#     conn.text_factory = str
#     c = conn.cursor()
#     res = c.execute("SELECT name FROM sqlite_master WHERE type='table';")
#     row = c.fetchone()
#     row = str(row)
#     row = row.replace("(","");row = row.replace(",)","")
#     row = row.replace("'","")
#     print row
#     cur = c.execute("select * from "%s"" %  row)
#     columns = [description[0] for description in cur.description]
#     return columns
#
# # if run directly
# #database = "databases/history.db"
# #dbinfo(database)
#
# unknown database get database info get SQLite info lost column names get tablename
# retrieve database info get table get rows
#  -- KEYWORDS
# unknown database get database info get SQLite info lost column names get tablename
# retrieve database info get table get rows

# %% [markdown]
# # Print a text file that contains all snippets

# %%
import sqlite3
import sys
from time import sleep
database = "/home/jack/snippet.db"
conn = sqlite3.connect(database)
conn.text_factory = str
c = conn.cursor()
count = 0
f = open("All-Snippets.txt", "w");f.close()
f = open("All-Snippets.txt", "a")
#search = raw_input("Search : ")
search = 'sqlite'
for row in c.execute('SELECT rowid, * FROM snippet'):    
    count=count+1
    count = str(count)
    iD = row[0]
    iD = str(iD)
    line = row[2]
    desc = (row)[3]
    j = "Line No. :",count,"\nROWID :",iD,"\n",line,"\nDescription :",desc,"\n\n-------new entry -------"
    line = "".join(j)
    #line = (count+(row)[0]+(row)[2]+" -- KEYWORDS"*(row)[3]+"\n")
    sleep(1)
    f.write(line)
    print line
    count = int(count)
    
conn.close()
Print "Search is Completed"
sys.exit()
# Out:
# Line No. :1
# ROWID :1
#
# delimiters = ['\n', ' ', ',', '.', '?', '!', ':', 'and_what_else_you_need']
# words = content
# for delimiter in delimiters:
#     new_words = []
#     for word in words:
#         new_words += word.split(delimiter)
#     words = new_words
#
# Description :words, delimiter, split
#
# -------new entry -------
# Line No. :2
# ROWID :2
#
# def insert_info(store):
#     with sqlite3.connect("misc.db") as db:
#         #use a text_factory that can interpret 8-bit bytestrings
#         db.text_factory = str
#         cursor = db.cursor()
#         #db.text_factory = str
#         sql = "insert into storeit (data0, data1, data2) values (?, ?, ?)"
#         cursor.execute(sql, store)
#         db.commit()
#
#         OR
#         conn.text_factory = str
#
# Description :text_factory, 8-bit bytestrings, 8-bit
#
# -------new entry -------
# Line No. :3
# ROWID :3
#
# import sqlite3
# import sys
# conn = sqlite3.connect('snippet.db')
# conn.text_factory = str
# c = conn.cursor()
# count=0
# req=200
# search = raw_input("Search")
# #for row in c.execute('SELECT rowid,* FROM tweets WHERE text MATCH %s' % search):
# for row in c.execute('SELECT * FROM snippet WHERE keywords MATCH ?', (search,)):
#     count=count+1
#     #print count,"by",(row)[2],"
# ",(row)[1],"
# "
#     print count,"-",(row)[1]," -- by",(row)[2],"
# "
#     if count > req:
#         conn.close()
#         sys.exit()
#
# Description :text_factory, 8-bit bytestrings, 8-bit
#
# -------new entry -------
# Line No. :4
# ROWID :4
#
# with open("Use.txt",'r') as f:
#     get_all=f.readlines()
#
# ----------------
# with open("file.txt",'w') as f:
#     for i,line in enumerate(get_all,1):  ## STARTS THE NUMBERING FROM 1 (by default it begins with 0)
#         if i == 2:                       ## OVERWRITES line:2
#             f.writelines("XXXXXXXXXXXXXXXXXXXXXXX
# ")
#         else:
#             f.writelines(line)
#
# Description :enumerate, edit line, edit, edit line number
#
# -------new entry -------
# Line No. :5
# ROWID :5
#
# %%writefile Key.py
# def twiter():
#     CONSUMER_KEY = 'WWWWWWWWWWWWWWWW'
#     CONSUMER_SECRET = 'XXXXXXXXXXXXXXXXX'
#     ACCESS_KEY = 'YYYYYYYYYYYYYYYYYYY'
#     ACCESS_SECRET = 'ZZZZZZZZZZZZZZZZ'
#     twir = (CONSUMER_KEY, CONSUMER_SECRET, ACCESS_KEY, ACCESS_SECRET)
#     return twir
#
# Description :Key, Key.py, twitter api, Twitter API
#
# -------new entry -------
# Line No. :6
# ROWID :6
#
# from itertools import tee
# count=0
# with open("symmetrymag_tweets.csv") as inf:
#     for line in inf:
#         lines  = line[39:]
#         outf = open("symmetrymag.txt", "a")
#         outf.write(lines)
# outf.close()
#
# Description :CSV, clean csv, edit csv, prepare for database
#
# -------new entry -------
# Line No. :7
# ROWID :7
#
# search = raw_input("find : ")
# file = open("symmetrymag.txt")
# lines = file.readlines()
# for line in lines:
#     if search in line:print line
#     if search == True:
#         file.close()
#         exit()
# file.close()
#
#
# Description :search, search text file, textfile, edit textfile
#
# -------new entry -------
# Line No. :8
# ROWID :8
#
# import sqlite3
# import time
# #account = "TEDTalks.txt"
# account = "symmetrymag.txt"
# #account = "elonmusk.txt"
# #account = "realDonaldTrump.txt"
# user = account[:-4]
# lines = open(account,"r")
# line = lines.readline()
# for line in lines:
#     conn = sqlite3.connect('collection.db')
#     conn.text_factory = str
#     c = conn.cursor()
#     c.execute("INSERT INTO tweets VALUES (?,?)", (line, user))
#     conn.commit()
#     conn.close()
#
#     #print line
#
# conn.commit()
# conn.close()
#
# Description :insert data, text file to database, text to data
#
# -------new entry -------
# Line No. :9
# ROWID :9
#
# import Key
# from random import randint
#
# #Twitter API credentials
# consumer_key = Key.twiter()[0]
# consumer_secret = Key.twiter()[1]
# access_key = Key.twiter()[2]
# access_secret = Key.twiter()[3]
#
#
# def get_all_tweets(screen_name):
#     #Twitter only allows access to a users most recent 3240 tweets with this method
#
#     #authorize twitter, initialize tweepy
#     auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#     auth.set_access_token(access_key, access_secret)
#     api = tweepy.API(auth)
#
#
# Description :Key , using Key.py, using Key, API key
#
# -------new entry -------
# Line No. :10
# ROWID :10
#
# conn = GetSqliteConnection(db_path)
# conn.text_factory = lambda x: unicode(x, 'utf-8', 'ignore')
#
# Description :text_factory , utf-8, unicode, lambda
#
# -------new entry -------
# Line No. :11
# ROWID :11
#
# %%writefile /home/jack/hidden/Authorize.py
# def keys():
#     ftp = "ftp.MYsite.com"
#     username = "Josephine"
#     password = "WhaWah2525"
#     login = (ftp,username,password)
#     return login
#     ------------
# import sys
# sys.path.insert(0, "/home/jack/hidden"
# import Authorize
# ftp = Authorize.keys()[0]
# username = Authorize.keys()[1]
# password = Authorize.keys()[2]
#
# print ftp, username, password
#
#
# Description :Authorize, ftp, hidden passwords, Authorize.keys
#
# -------new entry -------
# Line No. :12
# ROWID :12
#
# !sqlite3 ipydb.db "pragma integrity_check;"
#
# Description :verify database, pragma, integrity_check, check database
#
# -------new entry -------
# Line No. :13
# ROWID :13
#
# import base64
# string="This is the text above Encoded Base64"
# encodedlistvalue=base64.b64encode(string)
#
# string = encodedlistvalue
# print encodedlistvalue,"
# ",base64.b64decode(string)
#
# Description :base64, encoding base64, decoding base64, Encoded Base64
#
# -------new entry -------
# Line No. :14
# ROWID :14
#
# import base64 #encode muliple lines and keep the format
# string =
# ╲╲╭━━━━━━━╮╱╱
# ╲╭╯╭━╮┈╭━╮╰╮╱
# ╲┃┈┃┈▊┈┃┈▊┈┃╱
# ╲┃┈┗━┛┈┗━┛┈┃╱
# ╱┃┈┏━━━━━┓┈┃╲
# ╱┃┈┃┈┈╭━╮┃┈┃╲
# ╱╰╮╰━━┻━┻╯╭╯╲
# ╱╱╰━━━━━━━╯╲╲ FROM: http://copy.r74n.com/ascii-art
# EncodedStringValue=base64.b64encode(string)
# string2 = EncodedStringValue
# print "Decoded String2 : ",base64.b64decode(string2)
#
# Description :base64, encoding base64, decoding base64, Encoded Base64
#
# -------new entry -------
# Line No. :15
# ROWID :15
#
# import sqlite3
# conn = sqlite3.connect('ipydb.db')
# c = conn.cursor()# Never
# for row in c.execute('SELECT * FROM python ORDER BY code'):
#         print"entry :",(row[0]).encode('ascii'),"
# "
#         print"keywords :",(row[1]).encode('ascii'),"
# -----
# ","
# "
#         #data = c.fetchall()
#         #print data
#
# Description :ascii, encode('ascii'), fetchall, sqlite3
#
# -------new entry -------
# Line No. :16
# ROWID :16
#
# import sqlite3
# import feedparser
# import time
# import sqlite3
# Dbase = 'bigfeedfts.db'
# conn = sqlite3.connect(Dbase)
# c = conn.cursor()
# c.execute(
# CREATE VIRTUAL TABLE IF NOT EXISTS bbctech
# USING FTS3(head, feed);
# )
# count=0
# while count<35:
#     count=count+1
#     if count==1:feed='http://feeds.bbci.co.uk/news/technology/rss.xml'
#     if count==2:feed='http://www.cbn.com/cbnnews/us/feed/'
#     d = feedparser.parse(feed)
#     for post in d.entries:
#         aa = `d['feed']['title'],d['feed']['link'],d.entries[0]['link']`
#         bb = `post.title + ": " + post.link + ""`
#         conn = sqlite3.connect(Dbase)
#         c = conn.cursor()
#         c.execute("INSERT INTO bbctech VALUES (?,?)", (aa,bb))
#         conn.commit()
#         conn.close()
#
#
# conn = sqlite3.connect(Dbase)
# c = conn.cursor()# Never
# count=0
# for row in c.execute('SELECT * FROM bbctech ORDER BY rowid DESC'):
#     row=str(row)
#     row=row.replace("(u","");row=row.replace('", u"u',"
# ")
#     row=row.replace("/', u'","   ");row=row.replace('"',"")
#     row=row.replace("', u'","  ");row=row.replace("')","  ")
#     row=row.replace("'","");row=row.replace("  , uu","
# ")
#     count=count+1
#     print"
# Number :",count," -----
# ",(row)
#
# Description :rss, RSS, rss feeds, sqlite3
#
# -------new entry -------
# Line No. :17
# ROWID :17
#
# import sqlite3
# import sys
# conn = sqlite3.connect('bigfeedfts.db')
# c = conn.cursor()
# count=0
# # Limited Amount of Results to 100
# req=100
# term = raw_input("Search Term : ")
# for row in c.execute("SELECT * FROM bbctech WHERE feed MATCH ?", (term,)):
#     row=str(row)
#     row=row.replace("(u"(u","");row=row.replace("', u'","  ");
#     row=row.replace("u'"," ");row=row.replace(')", u" ', "
# ");
#     row=row.replace(" http://","
# http://");row=row.replace('")','')
#     row=row.replace("'","");row=row.replace("#tk.rss_all", "")
#     count=count+1
#     print "
# ",count,"-----
# ",(row)
#     if count > req:
#         conn.close()
#         sys.exit()
#
# Description :search rss, RSS, rss feeds, search sqlite3
#
# -------new entry -------
# Line No. :18
# ROWID :18
#
# #This is a great search
# #Much better that a regular browser search.
# #This search keeps a google page that may be scrapedor gleaned or just used as a hyperlink documant.
# #Results are fantastic.
# from bs4 import BeautifulSoup
# import requests
# url = u'https://www.google.com/search?num=30&newwindow=1&client=ubuntu&channel=fs&btnG=Search&q='
# query = u'Trump, idiot '
# r = requests.get(url+query)
# soup = BeautifulSoup(r.text, 'html.parser')
# for list in soup:
#     print list
# text = str(list)
# html_str = text
# Html_file= open("filename4.html","w")
# Html_file.write(html_str)
# Html_file.close()#This is a great search
# #Much better that a regular browser search.
# #This search keeps a google page that may be scrapedor gleaned or just used as a hyperlink documant.
# #Results are fantastic.
# from bs4 import BeautifulSoup
# import requests
# url = u'https://www.google.com/search?num=30&newwindow=1&client=ubuntu&channel=fs&btnG=Search&q='
# query = u'Trump, idiot '
# r = requests.get(url+query)
# soup = BeautifulSoup(r.text, 'html.parser')
# for list in soup:
#     print list
# text = str(list)
# html_str = text
# Html_file= open("filename4.html","w")
# Html_file.write(html_str)
# Html_file.close()
# -----
# READ THE HTML
# from lxml import html
# print html.parse('filename4.html').xpath('//body')[0].text_content()
#
# Description :google search, parse html, html, read html
#
# -------new entry -------
# Line No. :19
# ROWID :19
#
# from PIL import Image, ImageFont
# import GenIm
#
# img = Image.open('tmmpp/HURRICANE_01.png')
# position = (340,600)
# text= "JackNorthrup_ImageBot"
# font = ImageFont.truetype("/home/jack/.fonts/Exo-Black.ttf", 25)
# col = (255,255,255,150)
# halo_col = (0,0,0)
# newim = GenIm.Draw_text_with_halo(img, position, text, font, col, halo_col)
# newim.save("tmmpp/HURRICANE_02.png")
# !showme tmmpp/HURRICANE_02.png
#
# Description :text on an image, image, text image, text, words on image
#
# -------new entry -------
# Line No. :20
# ROWID :20
#
# from itertools import tee
# count=0
# with open("realDonaldTrump_tweets.csv") as inf:
#     # set up iterators
#     cfg,res = tee(inf)
#     # advance cfg by four lines
#     for i in range(4):
#         next(cfg)
#
#     for c,r in zip(cfg, res):
#         count=count+1
#         if "campaign" in c:
#             #print "Date :",c[21:]
#             print c[39:]
#
# Description :cvs, remove characters, text edit, clean, clean text
#
# -------new entry -------
# Line No. :21
# ROWID :21
#
# import tweepy #https://github.com/tweepy/tweepy
# import csv
# import sys
# sys.path.insert(0,"/home/jack/anaconda2/envs/py27/lib/python2.7/site-packages")
# import Key
# from random import randint
# consumer_key = Key.twiter()[0]
# consumer_secret = Key.twiter()[1]
# access_key = Key.twiter()[2]
# access_secret = Key.twiter()[3]
#
# def get_all_tweets(screen_name):
#     auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#     auth.set_access_token(access_key, access_secret)
#     api = tweepy.API(auth)
#     alltweets = []
#     new_tweets = api.user_timeline(screen_name = screen_name,count=200)
#     alltweets.extend(new_tweets)
#     oldest = alltweets[-1].id - 1
#     while len(new_tweets) > 0:
#         print "getting tweets before %s" % (oldest)
#         new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)
#         alltweets.extend(new_tweets)
#         oldest = alltweets[-1].id - 1
#         print (len(alltweets))
#         if (len(alltweets)) >200:
#             outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]
#             with open('%s_tweets.csv' % screen_name, 'wb') as f:
#                 writer = csv.writer(f)
#                 writer.writerow(["id","created_at","text"])
#                 writer.writerows(outtweets)
#             pass
# if __name__ == '__main__':
#     USER = raw_input("User  : ") or "CNN"
#     get_all_tweets(USER)
# ---
# get all tweets, csv, get many tweets, tweets to csv, tweets.csv
#
# Description :get all tweets, csv, get many tweets, tweets to csv, tweets.csv
#
# -------new entry -------
# Line No. :22
# ROWID :22
#
# # TOP ONE IS BEST
# textin= open('hashtag.txt', 'r')
# lines = textin.readlines()
# for line in lines:
#     time.sleep(1)
#     print line
# ---
# import time
# textin= open('hashtag.txt', 'r')
# lines = textin.read()
# time.sleep(1)
# print lines,
# ---
# textin= open('hashtag.txt', 'r')
# lines = textin.read().splitlines()
# time.sleep(1)
# print lines,
# ---
# read line by line, read(), splitlines(), read().splitlines(), read files
#
# Description :read line by line, read(), splitlines(), read().splitlines(), read files
#
# -------new entry -------
# Line No. :23
# ROWID :23
#
# import markovify
# f = open("grimm.txt")
# text = f.read()
# text_model_a = markovify.Text(text)
#
#
# ebook_b =open('hekel.txt')
# text0 = ebook_b.read()
# text_model_b = markovify.Text(text0)
# for i in range(5):
#     print(text_model_b.make_short_sentence(140))
#     STR0 = (text_model_b.make_short_sentence(140))
#     savE = open('savE.txt', 'a')
#     savE.write(STR0)
#     savE.close()
#
# # 2. Print five randomly-generated sentences
# for i in range(5):
#     print(text_model_a.make_short_sentence(140))
#     STR = (text_model_a.make_short_sentence(140))
#     savE = open('savE.txt', 'a')
#     savE.write(STR)
#     savE.close()
# # 3. Print three randomly-generated sentences of no more than 140 characters
# for i in range(5):
#     print(text_model_a.make_short_sentence(140))
#     STR2 = (text_model_a.make_short_sentence(140))
#     savE = open('savE.txt', 'a')
#     savE.write(STR2)
#     savE.close()
# # Combine the models into a single one
# both_models = markovify.combine([text_model_a,text_model_b])
# for i in range(5):
#     print(both_models.make_short_sentence(140))
#     STR3 = (both_models.make_short_sentence(140))
#     savE = open('savE.txt', 'a')
#     savE.write(STR3)
#     savE.close()
# ---
# markovify , combine , text_model_a ,
#
# Description :markovify, combine, text_model_a, markovify, generated sentences
#
# -------new entry -------
# Line No. :24
# ROWID :24
#
# Using shutil
#
# from shutil import copyfile
# copyfile(src, dst)
# ----
# # Python Copy File - Sample Code
# from shutil import copyfile
# from sys import exit
# source = input("Enter source file with full path: ")
# target = input("Enter target file with full path: ")
# # adding exception handling
# try:
#     copyfile(source, target)
# except IOError as e:
#     print("Unable to copy file. %s" % e)
#     exit(1)
# except:
#     print("Unexpected error:", sys.exc_info())
#     exit(1)
# print("
# File copy done!
# ")
# while True:
#     print("Do you like to print the file ? (y/n): ")
#     check = input()
#     if check == 'n':
#         break
#     elif check == 'y':
#         file = open(target, "r")
#         print("
# Here follows the file content:
# ")
#         print(file.read())
#         file.close()
#         print()
#         break
#     else:
#         continue
#
# Description :copy, copy file, copy a file, from shutil import copyfile, shutil, copyfile
#
# -------new entry -------
# Line No. :25
# ROWID :25
#
# how to turn on the keyboard backlight
#
# USE:   xset led on
#
# keyboard backlight
#
# Description :how to turn on backlight, turn on backlight, keyboard backlight, keyboard, backlight
#
# -------new entry -------
# Line No. :26
# ROWID :26
#
# import sqlite3
# import os.path
# from os import listdir, getcwd
# from IPython.core.display import Image
#
# def get_picture_list(rel_path):
#     abs_path = os.path.join(os.getcwd(),rel_path)
#     print 'abs_path =', abs_path
#     dir_files = os.listdir(abs_path)
#     #print dir_files
#     return dir_files
#
# picture_list = get_picture_list('snippets')
# print picture_list
# ------------
# get_picture_list, get list of files, get a file list in memory
# files in memeory , file list memory
#
# Description :get_picture_list, get list of files, get a file list in memory
#
# -------new entry -------
# Line No. :27
# ROWID :27
#
# import sqlite3
# import sys
# conn = sqlite3.connect('pdfs.db')
# conn.text_factory = str
# c = conn.cursor()
# count=0;req=200
# search = raw_input("Search : ")
# for row in c.execute('SELECT rowid, text FROM pdfs WHERE text MATCH ?', (search,)):
#     count=count+1
#     print (row)[0],"-",(row)[1],
#     if count > req:
#         conn.close()
#         sys.exit()
#
#  --------
#  search database, search db, raw_input, SQLite search
#
#
# Description :search database, search db, raw_input, SQLite search
#
# -------new entry -------
# Line No. :28
# ROWID :28
#
# Creating a MySQL database with Python
# If you don't have it you may need:
# sudo apt-get install libmysqlclient-dev
#
# # Works
# import MySQLdb as db
# con = db.connect("localhost","root","")
# cur = con.cursor()
# cur.execute('CREATE DATABASE searchdb01;')
#
#
# Description :MySQL, Creating a MySQL database, libmysqlclient-dev, searchdb01
#
# -------new entry -------
# Line No. :29
# ROWID :29
#
# # works
# import MySQLdb as db
# import json
# import base64
#
# con = db.connect("localhost","root","ThinkPadT$#", "searchdb01")
# file = ""[mylist.jsn
# while 1:
#     line = file.readline()
#     if not line:
#         break
#     pass # do something
# #listname='mylist.json'
# #stringlistvalue=json.dumps(listname)
# ""
# keywords = ""
# database, code, python, lesson 1, Oh234
# ""
# encodedlistvalue=base64.b64encode(file)
# with con:
#     cur = con.cursor()
#     cur.execute("CREATE TABLE Code(Id INT PRIMARY KEY AUTO_INCREMENT,                   Name VARCHAR(2500), Keywords VARCHAR(500))")
#     #cur.execute("INSERT INTO Code(Name) VALUES('%s')" % (encodedlistvalue))
#     cur.execute("INSERT INTO Code(Name, Keywords) VALUES('%s','%s')" % (encodedlistvalue, keywords))
#
# Description :MySQL, Creating a MySQL database, libmysqlclient-dev, searchdb01
#
# -------new entry -------
# Line No. :30
# ROWID :30
#
# #!/usr/bin/python
# import MySQLdb
# import sys
# import base64
# con = db.connect("localhost","root"," ", "searchdb01")
# cur = con.cursor()
# # execute the SQL query using execute() method.
# cur.execute ("select Id, Name, Keywords from Code")
#
# data = cur.fetchall ()
# # print the rows
# for row in data :
#     encodedlistvalue=base64.b64decode(row[1])
#     print row[0], encodedlistvalue, '
# ', 'Keywords:', row[2],    '
#  -----------------------------
# '
# # close the cursor object
# cur.close ()
# # close the connection
# con.close ()
# # exit the program
# sys.exit()
#
# Description :MySQL, base64 , b64decode, libmysqlclient-dev, searchdb01
#
# -------new entry -------
# Line No. :31
# ROWID :31
#
# import MySQLdb
# con = db.connect("localhost","root","ThinkPadT$#", "searchdb01")
#
# param = "lesson"
# c = con.cursor()
# c.execute("SELECT * FROM Code WHERE Keywords LIKE %s LIMIT 1", ("%" + param + "%",))
#
# data = c.fetchall()
# for row in data :
#     encodedlistvalue=base64.b64decode(row[1])
#     print row[0], encodedlistvalue, '
# ', 'Keywords:', row[2],    '
#  -----------------------------
# '
# c.close()
#
# Description :MySQL, base64 , b64decode, libmysqlclient-dev, searchdb01
#
# -------new entry -------
# Line No. :32
# ROWID :32
#
# def createdb(dbnew):
#     import sqlite3
#     conn = sqlite3.connect(dbnew)
#     c = conn.cursor()
#
#     query1 = "DROP TABLE IF EXISTS Junk"
#     query2 = ""CREATE TABLE IF NOT EXISTS Junk(
#     "language" VARCHAR(32) NOT NULL,
#     "keywords" VARCHAR(500) default NULL,
#     "script" VARCHAR(2500) default NULL
#     )
#     ""
#     c.execute(query1)
#     c.execute(query2)
#
# dbnew = "newdb.db"
# createdb(dbnew)
#
# Description :function to create a database, function, database function
#
# -------new entry -------
# Line No. :33
# ROWID :33
#
# import sqlite3
# import os.path
# from os import listdir, getcwd
# from IPython.core.display import Image
#
# def get_picture_list(rel_path):
#     abs_path = os.path.join(os.getcwd(),rel_path)
#     print 'abs_path =', abs_path
#     dir_files = os.listdir(abs_path)
#     #print dir_files
#     return dir_files
#
# picture_list = get_picture_list('snippets')
# print picture_list
# import sqlite3
# import os.path
# from os import listdir, getcwd
# from IPython.core.display import Image
#
# def create_or_open_db(db_file):
#     db_is_new = not os.path.exists(db_file)
#     conn = sqlite3.connect(db_file)
#     if db_is_new:
#         print 'Creating schema'
#         sql = '''create table if not exists PICTURES(
#         ID INTEGER PRIMARY KEY AUTOINCREMENT,
#         PICTURE BLOB,
#         TYPE TEXT,
#         FILE_NAME TEXT);'''
#         conn.execute(sql) # shortcut for conn.cursor().execute(sql)
#     else:
#         print 'Schema exists
# '
#     return conn
#
# def insert_picture(picture_file):
#     with open(picture_file, 'rb') as input_file:
#         conn = sqlite3.connect(dbname)
#         c = conn.cursor()
#         ablob = input_file.read()
#         base=os.path.basename(picture_file)
#         afile, ext = os.path.splitext(base)
#         sql = '''INSERT INTO PICTURES
#         (PICTURE, TYPE, FILE_NAME)
#         VALUES(?, ?, ?);'''
#         c.execute(sql,[sqlite3.Binary(ablob), ext, afile])
#         conn.commit()
#
# def loadimages(dbname, path):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     #conn.execute("DELETE FROM PICTURES")
#     for fn in picture_list:
#         picture_file = path+"/"+fn
#         insert_picture(picture_file)
#
#     for r in c.execute("SELECT rowid, FILE_NAME FROM PICTURES"):
#         print r[0],r[1]
#
#     conn.commit()
#
#
# def get_image(picture_id):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     c.execute("SELECT PICTURE, TYPE, FILE_NAME FROM PICTURES WHERE id = ?;",(picture_id,))
#     #sql = "SELECT PICTURE, TYPE, FILE_NAME FROM PICTURES WHERE id = 19"
#     param = {'id': picture_id}
#     #c.execute(sql, param)
#     ablob, ext, afile = c.fetchone()
#     filename = afile + ext
#     with open(filename, 'wb') as output_file:
#         output_file.write(ablob)
#     return filename
#
#
# dbname = "ImageC.db"
# db_file = create_or_open_db(dbname)
# path = "snippets/"
# loadimages(dbname, path)
# filename = get_image(16)
# print filename
# Image(filename=filename)
#
# -----------------
# store, retrieve images,SQLite Databasestore,
# retrieve images, from SQLite , Database
#
# Description :store, retrieve images, from SQLite Database
#
# -------new entry -------
# Line No. :34
# ROWID :34
#
# try:
#         mercury = wikipedia.summary("Mercury")
# except wikipedia.exceptions.DisambiguationError as e:
#         lines = str(e.options)
#         lines=lines.replace("u'","");lines=lines.replace("', ","
# ")
#         lines=lines.replace("[","");lines=lines.replace("]","")
#         lines=lines.replace('u"','');lines=lines.replace('"','')
#         with open("textwik.txt", "w")as f:
#                 f.write(lines)
# f.close()
# bad_words = ['(disambiguation)', 'All pages']
# with open('textwik.txt') as oldfile, open('usewik.txt', 'w') as newfile:
#     for line in oldfile:
#         if not any(bad_word in line for bad_word in bad_words):
#             newfile.write(line)
#
# ---------------
# wikipedia , bad_words, bad words, disambiguation, remove lines from text
#
# Description :wikipedia , bad_words, bad words, disambiguation, remove lines from text
#
# -------new entry -------
# Line No. :35
# ROWID :35
#
# %%writefile Image2SQLite.py
# import sqlite3
# import os.path
# from os import listdir, getcwd
# from IPython.core.display import Image
#
# def getImage_list(rel_path):
#     abs_path = os.path.join(os.getcwd(),rel_path)
#     print 'abs_path =', abs_path
#     dir_files = os.listdir(abs_path)
#     return dir_files
#
# def create_or_open_db(dbname):
#     db_is_new = not os.path.exists(db_file)
#     conn = sqlite3.connect(db_file)
#     if db_is_new:
#         print 'Creating schema'
#         sql = '''create table if not exists images(
#         ID INTEGER PRIMARY KEY AUTOINCREMENT,
#         image BLOB,
#         TYPE TEXT,
#         imagE TEXT);'''
#         conn.execute(sql) # shortcut for conn.cursor().execute(sql)
#     else:
#         print 'Schema exists
# '
#         conn.commit()
#         conn.close()
#     return conn
#
# def insertImage(dbname, imageFile):
#     with open(imageFile, 'rb') as input_file:
#         conn = sqlite3.connect(dbname)
#         c = conn.cursor()
#         ablob = input_file.read()
#         base=os.path.basename(imageFile)
#         afile, ext = os.path.splitext(base)
#         sql = '''INSERT INTO images
#         (image, TYPE, imagE)
#         VALUES(?, ?, ?);'''
#         c.execute(sql,[sqlite3.Binary(ablob), ext, afile])
#         conn.commit()
#
# def loadimagE(dbname, path):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     #conn.execute("DELETE FROM images")
#     for fn in image_list:
#         imageFile = path+"/"+fn
#         insertImage(imageFile)
#
#     for r in c.execute("SELECT rowid, imagE FROM images"):
#         print r[0],r[1]
#
#     conn.commit()
#     conn.close()
#
# def image_id(dbname):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     rows = c.execute("SELECT rowid, TYPE, imagE FROM images")
#     for row in rows:
#         print row[0],row[2]+row[1]
#     return
#
# def get_image(dbname,image_id):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     c.execute("SELECT image, TYPE, imagE FROM images WHERE id = ?;",(image_id,))
#     #sql = "SELECT image, TYPE, imagE FROM images WHERE id = 19"
#     param = {'id': image_id}
#     #c.execute(sql, param)
#     ablob, ext, afile = c.fetchone()
#     filename = afile + ext
#     with open(filename, 'wb') as output_file:
#         output_file.write(ablob)
#     return filename
# ---------------
# USAGE:
# import Image2Data
# picture_list = Image2Data.get_picture_list('snippets')
# print picture_list
#
# import Image2Data
# dbname = "ImageE.db"
# Image2Data.create_or_open_db(dbname)
#
# #insert one image
# import Image2Data
# dbname = "ImageD.db"
# picture_file = "01.jpg"
# Image2Data.insert_picture(dbname, picture_file)
#
# import Image2Data
# dbname = "ImageD.db"
# path = "snippets"
# loadimages(dbname, path)
#
# def image_id(dbname):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     rows = c.execute("SELECT rowid, TYPE, FILE_NAME FROM PICTURES")
#     for row in rows:
#         print row[0],row[2]+row[1]
#
# #list images by id
# dbname = "ImageD.db"
# image_id(dbname)
#
# #retrieve image by id
# filename = get_image(dbname,1)
# print filename
# Image(filename=filename)
#
#
#
# Description :wikipedia , bad_words, bad words, disambiguation, remove lines from text
#
# -------new entry -------
# Line No. :36
# ROWID :36
#
# %%writefile Image2SQLite.py
# import sqlite3
# import os.path
# from os import listdir, getcwd
# from IPython.core.display import Image
#
# def getImage_list(rel_path):
#     abs_path = os.path.join(os.getcwd(),rel_path)
#     print 'abs_path =', abs_path
#     dir_files = os.listdir(abs_path)
#     return dir_files
#
# def create_or_open_db(dbname):
#     db_is_new = not os.path.exists(db_file)
#     conn = sqlite3.connect(db_file)
#     if db_is_new:
#         print 'Creating schema'
#         sql = '''create table if not exists images(
#         ID INTEGER PRIMARY KEY AUTOINCREMENT,
#         image BLOB,
#         TYPE TEXT,
#         imagE TEXT);'''
#         conn.execute(sql) # shortcut for conn.cursor().execute(sql)
#     else:
#         print 'Schema exists
# '
#         conn.commit()
#         conn.close()
#     return conn
#
# def insertImage(dbname, imageFile):
#     with open(imageFile, 'rb') as input_file:
#         conn = sqlite3.connect(dbname)
#         c = conn.cursor()
#         ablob = input_file.read()
#         base=os.path.basename(imageFile)
#         afile, ext = os.path.splitext(base)
#         sql = '''INSERT INTO images
#         (image, TYPE, imagE)
#         VALUES(?, ?, ?);'''
#         c.execute(sql,[sqlite3.Binary(ablob), ext, afile])
#         conn.commit()
#
# def loadimagE(dbname, path):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     #conn.execute("DELETE FROM images")
#     for fn in image_list:
#         imageFile = path+"/"+fn
#         insertImage(imageFile)
#
#     for r in c.execute("SELECT rowid, imagE FROM images"):
#         print r[0],r[1]
#
#     conn.commit()
#     conn.close()
#
# def image_id(dbname):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     rows = c.execute("SELECT rowid, TYPE, imagE FROM images")
#     for row in rows:
#         print row[0],row[2]+row[1]
#     return
#
# def get_image(dbname,image_id):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     c.execute("SELECT image, TYPE, imagE FROM images WHERE id = ?;",(image_id,))
#     #sql = "SELECT image, TYPE, imagE FROM images WHERE id = 19"
#     param = {'id': image_id}
#     #c.execute(sql, param)
#     ablob, ext, afile = c.fetchone()
#     filename = afile + ext
#     with open(filename, 'wb') as output_file:
#         output_file.write(ablob)
#     return filename
# ---------------
# USAGE:
# import Image2Data
# picture_list = Image2Data.get_picture_list('snippets')
# print picture_list
#
# import Image2Data
# dbname = "ImageE.db"
# Image2Data.create_or_open_db(dbname)
#
# #insert one image
# import Image2Data
# dbname = "ImageD.db"
# picture_file = "01.jpg"
# Image2Data.insert_picture(dbname, picture_file)
#
# import Image2Data
# dbname = "ImageD.db"
# path = "snippets"
# loadimages(dbname, path)
#
# def image_id(dbname):
#     conn = sqlite3.connect(dbname)
#     c = conn.cursor()
#     rows = c.execute("SELECT rowid, TYPE, FILE_NAME FROM PICTURES")
#     for row in rows:
#         print row[0],row[2]+row[1]
#
# #list images by id
# dbname = "ImageD.db"
# image_id(dbname)
#
# #retrieve image by id
# filename = get_image(dbname,1)
# print filename
# Image(filename=filename)
# ------------
# images to database , image2data , store images, store images as data, SQLite images
#
#
# Description :images to database , image2data , store images, store images as data, SQLite images
#
# -------new entry -------
# Line No. :37
# ROWID :37
#
# # Get number of words in a file
# fname = raw_input("Enter file name: ")
# num_words = 0
# with open(fname, 'r') as f:
#     for line in f:
#         words = line.split()
#         num_words += len(words)
# print "Number of words: ",num_words
#
#
# Description :Get words file number words file 'Get number of words in a file'
#
# -------new entry -------
# Line No. :38
# ROWID :38
#
# from time import sleep
# topic = raw_input("Research : ")
# fname = topic.replace(" ", "")+".txt"
# fname = "Wiki_"+fname
# f =open(fname, "w")
# f.close()
# import wikipedia
# rows = wikipedia.search(topic)
# for row in rows:
#     sleep(1)
#     para = wikipedia.summary(row)
#     para = '
#
# '.join((row, para)).encode('utf-8').strip()
#     enter = open(fname, "a")
#     enter.write(para)
#     enter.close()
#     print para
# enter.close()
#
# Description :search summary wikipedia text file
#
# -------new entry -------
# Line No. :39
# ROWID :39
#
# # %load SearchFilename.py
# '''
# Search a filename for a phrase and how many following lines to display
# USAGE:
# import SearchFilename
# filename = "hek.txt"
# length = 4
# SearchFilename.searchfilename(filename, length)
# '''
# def searchfilename(filename, length):
#     f = open(filename, "r")
#     searchlines = f.readlines()
#     f.close()
#     search = str(raw_input("Search Phrase : "))
#     for i, line in enumerate(searchlines):
#         if search in line:
#             for l in searchlines[i:i+length]: print l,
#             print
#
# USAGE:
# import SearchFilename
# filename = "Automate-the-Boring-Stuff.txt"
# # length = how many lines after
# length = 4
# SearchFilename.searchfilename(filename, length)
#
# ------
# search text file search file module import searchfile
#
#
#
# Description :search text file search file module import searchfile
#
# -------new entry -------
# Line No. :40
# ROWID :40
#
# import os
# import timeit
# def txsearch():
#     # Ask to enter string to search
#     Sstring = raw_input("Search Phrase")
#     for fname in os.listdir('./'):
#        # Apply file type filter
#        if fname.endswith(".txt"):
#             # Open file for reading
#             fo = open(fname)
#             # Read the first line from the file
#             line = fo.readline()
#             # Initialize counter for line number
#             line_no = 1
#             # Loop until EOF
#             while line != '' :
#                     index = line.find(Sstring)
#                     if ( index != -1) :
#                         # Set some parameters no lines longer than 240 characters
#                         # or less than search phrase +30 characters
#                         if len(line)< 240 and len(line)> len(Sstring)+20 :
#                             #print(fname, "[", line_no, ",", index, "] ", line)
#                             #print fname,line[1:-8],"  "
#                             print fname,line_no,line
#                     # Read next line
#                     line = fo.readline()
#                     # Increment line counter
#                     line_no += 1
#             # Close the files
#             fo.close()
#
#
# ------
# search text file search file module import searchfile
#
#
#
# Description :search text file search file module import searchfile
#
# -------new entry -------
# Line No. :41
# ROWID :41
#
# import sys
# import tweepy
# import csv
# import Key
#
# #pass security information to variables
# consumer_key = Key.twiter()[0]
# consumer_secret = Key.twiter()[1]
# access_key = Key.twiter()[2]
# access_secret = Key.twiter()[3]
#
# #use variables to access twitter
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_key, access_secret)
# api = tweepy.API(auth)
#
# #create an object called 'customStreamListener'
# class CustomStreamListener(tweepy.StreamListener):
#
#     def on_status(self, status):
#         print (status.author.screen_name, status.created_at, status.text)
#         # Writing status data
#         with open('OutputStreaming.txt', 'a') as f:
#             writer = csv.writer(f)
#             #status.author.screen_name = status.author.screen_name.encode('UTF-8')
#             #status.text.encode = status.text.encode('UTF-8')
#             writer.writerow([status.author.screen_name.encode('UTF-8'), status.created_at, status.text.encode('utf8')])
#
#
#     def on_error(self, status_code):
#         print >> sys.stderr, 'Encountered error with status code:', status_code
#         return True # Don't kill the stream
#
#     def on_timeout(self):
#         print >> sys.stderr, 'Timeout...'
#         return True # Don't kill the stream
#
#
#     def titles():
#         # Writing csv titles
#         with open('OutputStreaming.txt', 'a') as f:
#                     writer = csv.writer(f)
#                     writer.writerow(['Author', 'Date', 'Text'])
#
# def main():
#     streamingAPI = tweepy.streaming.Stream(auth, CustomStreamListener())
#     #with open("tokens.txt", "r") as f:
#     with open("tokens2.txt", "r") as f:
#         tokens = f.readlines()
#
#         streamingAPI.filter(track=tokens)
#         #streamingAPI.filter(track=['Dallas', 'NewYork'])
#
#
#         #status.text.encode('utf-8')
#         #writer.writerow([unicode(s).encode("utf-8") for s in row])
#         #writer.writerow([unicode('Author', 'Date', 'Text').encode("utf-8") for 'Author', 'Date', 'Text' in row])
#
#
#
# Description :csv to text tweepy to text tweepy tweepy streaming twitter import tweepy
#
# -------new entry -------
# Line No. :42
# ROWID :42
#
# def tidyt(in_string):
#     texout = in_string.replace("', u'", "  ");texout = texout.replace("\u2018", "")
#     texout = texout.replace("\u2019 ", "");texout = texout.replace("%", "")
#     texout = texout.replace("[u'", "");texout = texout.replace(" u'", "")
#     texout = texout.replace(', u"', ' ');texout = texout.replace('",', ' ')
#     texout = texout.replace("'", '');texout = texout.replace("Mr.  ", 'Mr. ')
#     texout = texout.replace(",", '');texout = texout.replace(".", '')
#     ftexout =texout.replace("']", "")
#     return ftexout
#
#
# Description :clean text tidy text textout replace string.replace
#
# -------new entry -------
# Line No. :43
# ROWID :43
#
# from textblob import TextBlob
# import random
# import sys
#
# # stdin's read() method just reads in all of standard input as a string;
# # use the decode method to convert to ascii (textblob prefers ascii)
# text = sys.stdin.read().decode('ascii', errors="replace")
# blob = TextBlob(text)
#
# short_sentences = list()
# for sentence in blob.sentences:
#     if len(sentence.words) <= 5:
#         short_sentences.append(sentence.replace("
# ", " "))
#
# for item in random.sample(short_sentences, 10):
# 	print item
#
# Description :blob text blob TextBlog stdin Short Sentences
#
# -------new entry -------
# Line No. :44
# ROWID :44
#
# Datetime objects ephem
#
#     When creating an ephem.Date, you can specify the date as either a date or datetime object from the datetime standard Python module. You can also ask a PyEphem date to convert itself the other direction by calling its datetime() method.
#
#     >>> from datetime import date, datetime
#     >>> print(ephem.Date(datetime(2005, 4, 18, 22, 15)))
#     2005/4/18 22:15:00
#
#     >>> d = ephem.Date('2000/12/25 12:41:16')
#     >>> d.datetime()
#     datetime.datetime(2000, 12, 25, 12, 41, 15, 999999)
#
#     In those last two commands, note that slight round-off error has converted sixteen seconds to 15.999999 seconds! The inevitability of such errors is why PyEphem exposes its own date type instead of returning Python datetime objects automatically.
# Tuples
#
#     PyEphem can return a date as a six-element tuple giving the year, month, day, hour, minute, and seconds, where the seconds include any fractions of a second. You can also provide such a tuple when creating a PyEphem date.
#
#     >>> timetuple = (1984, 5, 30, 12, 23, 45)
#     >>> print(ephem.Date(timetuple))
#     1984/5/30 12:23:45
#
#     >>> d = ephem.Date('2001/12/14 16:07:57')
#     >>> print(d.tuple())
#     (2001, 12, 14, 16, 7, 57.00000002514571)
#
#     Several functions in the Python standard module time will accept the time formatted as one of these six-element tuples. This feature was used in the Time Zones section, above, to convert a PyEphem date into local time.
# Triples
#
#     There may be occasions where you need to manipulate the year and month but do not need to break the day into hours and minutes. In these cases, you can provide a three-item tuple (a “triple” of values) when creating a PyEphem date, and receive one back by calling the triple() method.
#
#     >>> timetriple = (1998, 2, 26.691458333334594)
#     >>> print(ephem.Date(timetriple))
#     1998/2/26 16:35:42
#
#     >>> d = ephem.Date('1996/4/17 22:37:11.5')
#     >>> print(d.triple())
#     (1996, 4, 17.94249421296263)
#
# Floats
#
#     Finally, since a PyEphem date is really just a floating-point number, so you can manually supply the value you want it to have.
#
#     >>> print(ephem.Date(37238.1721875))
#     2001/12/14 16:07:57
#
#     >>> d = ephem.Date('2000/12/25 12:41:16')
#     >>> print('%.6f' % d)
#     36884.028657
#
#
#
# Description :store, retrieve images, from SQLite Database
#
# -------new entry -------
# Line No. :45
# ROWID :45
#
# import numpy as np
# import matplotlib.pyplot as plt
# from jplephem.spk import SPK
# import time
#
# ephem = 'de421.bsp'
# ephem = 'de405.bsp'
#
# kernel = SPK.open(ephem)
#
# jd_1900_01_01 = 2415020.5004882407
#
# ntimes = [i*10**n for n in range(5) for i in [1, 2, 5]]
#
# years  = [np.zeros(1)] + [np.linspace(0, 100, n) for n in ntimes[1:]] # 100 years
#
# barytup  = (0, 3)
# earthtup = (3, 399)
# # moontup  = (3, 301)
#
# microsecs = []
# for y in years:
#     mics = []
#     #for thing in things:
#
#     jd = jd_1900_01_01 + y * 365.25 # roughly, it doesn't matter here
#
#     tstart = time.clock()
#     answer = kernel[earthtup].compute(jd) + kernel[barytup].compute(jd)
#     mics.append(1E+06 * (time.clock() - tstart))
#
#     microsecs.append(mics)
#
# microsecs = np.array(microsecs)
#
# many = [len(y) for y in years]
#
# fig = plt.figure()
# ax  = plt.subplot(111, xlabel='length of JD object',
#                        ylabel='microseconds',
#                        title='time for jplephem [0,3] and [3,399] with ' + ephem )
#
# #   from here: http://stackoverflow.com/a/14971193/3904031
# for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
#              ax.get_xticklabels() + ax.get_yticklabels()):
#     item.set_fontsize(item.get_fontsize() + 4)
#
# #for name, mics in zip(names, microsecs):
# ax.plot(many, microsecs, lw=2, label='earth')
# plt.legend(loc='upper left', shadow=False, fontsize='x-large')
# plt.xscale('log')
# plt.yscale('log')
# plt.ylim(1E+02, 1E+06)
#
# plt.savefig("jplephem speed test " + ephem.split('.')[0])
#
# plt.show()
#
#
#
# Description :store, retrieve images, from SQLite Database
#
# -------new entry -------
# Line No. :46
# ROWID :46
#
# import numpy as np
# import matplotlib.pyplot as plt
# from   skyfield.api import load, JulianDate
# import time
#
# ephem = 'de421.bsp'
# ephem = 'de405.bsp'
#
# de = load(ephem)
#
# earth            = de['earth']
# moon             = de['moon']
# earth_barycenter = de['earth barycenter']
# mercury          = de['mercury']
# jupiter          = de['jupiter barycenter']
# pluto            = de['pluto barycenter']
#
# things = [ earth,   moon,   earth_barycenter,   mercury,   jupiter,   pluto ]
# names  = ['earth', 'moon', 'earth barycenter', 'mercury', 'jupiter', 'pluto']
#
# ntimes = [i*10**n for n in range(5) for i in [1, 2, 5]]
#
# years  = [np.zeros(1)] + [np.linspace(0, 100, n) for n in ntimes[1:]] # 100 years
#
# microsecs = []
# for y in years:
#
#     from skyfield.api import load
#     ts = load.timescale()
#     t = ts.utc(1980, 4, 20)       # the new way
#
#     jd = ts.tt(jd=2444349.500592)  # jd is also supported for tai, tt, tdb
#
#     # Depreciated
#     #jd = JulianDate(utc=(1900 + y, 1, 1))
#     mics = []
#     for thing in things:
#
#         tstart = time.clock()
#         answer = thing.at(jd).position.km
#         mics.append(1E+06 * (time.clock() - tstart))
#
#     microsecs.append(mics)
#
# microsecs = np.array(microsecs).T
#
# many = [len(y) for y in years]
#
#
# fig = plt.figure(figsize=(10, 8))
# ax  = plt.subplot(111, xlabel='length of JD object',
#                        ylabel='microseconds',
#                        title='time for thing.at(jd).position.km with ' + ephem )
#
# for item in ([ax.title, ax.xaxis.label, ax.yaxis.label] +
#              ax.get_xticklabels() + ax.get_yticklabels()):
#     item.set_fontsize(item.get_fontsize() + 4) # http://stackoverflow.com/a/14971193/3904031
#
# for name, mics in zip(names, microsecs):
#     ax.plot(many, mics, lw=2, label=name)
# plt.legend(loc='upper left', shadow=False, fontsize='x-large')
# plt.xscale('log')
# plt.yscale('log')
# plt.savefig("skyfield speed test " + ephem.split('.')[0])
# plt.show()
#
# Description :store, retrieve images, from SQLite Database
#
# -------new entry -------
# Line No. :47
# ROWID :47
#
# # Some helper functions
# def norm(x, x0, sigma):
#     return np.exp(-0.5 * (x - x0) ** 2 / sigma ** 2)
#
# def sigmoid(x, x0, alpha):
#     return 1. / (1. + np.exp(- (x - x0) / alpha))
#
# # define the curves
# x = np.linspace(0, 1, 100)
# y1 = np.sqrt(norm(x, 0.7, 0.05)) + 0.2 * (1.5 - sigmoid(x, 0.8, 0.05))
#
# y2 = 0.2 * norm(x, 0.5, 0.2) + np.sqrt(norm(x, 0.6, 0.05)) + 0.1 * (1 - sigmoid(x, 0.75, 0.05))
#
# y3 = 0.05 + 1.4 * norm(x, 0.85, 0.08)
# y3[x > 0.85] = 0.05 + 1.4 * norm(x[x > 0.85], 0.85, 0.3)
#
# # draw the curves
# ax = pl.axes()
# ax.plot(x, y1, c='gray')
# ax.plot(x, y2, c='blue')
# ax.plot(x, y3, c='red')
#
# ax.text(0.3, -0.1, "Yard")
# ax.text(0.5, -0.1, "Steps")
# ax.text(0.7, -0.1, "Door")
# ax.text(0.9, -0.1, "Inside")
#
# ax.text(0.05, 1.1, "fear that
# there's
# something
# behind me")
# ax.plot([0.15, 0.2], [1.0, 0.2], '-k', lw=0.5)
#
# ax.text(0.25, 0.8, "forward
# speed")
# ax.plot([0.32, 0.35], [0.75, 0.35], '-k', lw=0.5)
#
# ax.text(0.9, 0.4, "embarrassment")
# ax.plot([1.0, 0.8], [0.55, 1.05], '-k', lw=0.5)
#
# ax.set_title("Walking back to my
# front door at night:")
#
# ax.set_xlim(0, 1)
# ax.set_ylim(0, 1.5)
#
# # modify all the axes elements in-place
# XKCDify(ax, expand_axes=True)
#
#
# Description :store, retrieve images, from SQLite Database
#
# -------new entry -------
# Line No. :48
# ROWID :48
#
# np.random.seed(0)
#
# ax = pylab.axes()
#
# x = np.linspace(0, 10, 100)
# ax.plot(x, np.sin(x) * np.exp(-0.1 * (x - 5) ** 2), 'b', lw=1, label='damped sine')
# ax.plot(x, -np.cos(x) * np.exp(-0.1 * (x - 5) ** 2), 'r', lw=1, label='damped cosine')
#
# ax.set_title('check it out!')
# ax.set_xlabel('x label')
# ax.set_ylabel('y label')
#
# ax.legend(loc='lower right')
#
# ax.set_xlim(0, 10)
# ax.set_ylim(-1.0, 1.0)
#
# #XKCDify the axes -- this operates in-place
# XKCDify(ax, xaxis_loc=0.0, yaxis_loc=1.0,
#         xaxis_arrow='+-', yaxis_arrow='+-',
#         expand_axes=True)
#
# Description :store, retrieve images, from SQLite Database
#
# -------new entry -------
# Line No. :49
# ROWID :49
#
# ""
# XKCD plot generator
# -------------------
# Author: Jake Vanderplas
#
# This is a script that will take any matplotlib line diagram, and convert it
# to an XKCD-style plot.  It will work for plots with line & text elements,
# including axes labels and titles (but not axes tick labels).
#
# The idea for this comes from work by Damon McDougall
#   http://www.mail-archive.com/matplotlib-users@lists.sourceforge.net/msg25499.html
# ""
# import numpy as np
# import pylab as pl
# from scipy import interpolate, signal
# import matplotlib.font_manager as fm
#
#
# # We need a special font for the code below.  It can be downloaded this way:
# import os
# import urllib2
# if not os.path.exists('Humor-Sans.ttf'):
#     fhandle = urllib2.urlopen('http://antiyawn.com/uploads/Humor-Sans-1.0.ttf')
#     open('Humor-Sans.ttf', 'wb').write(fhandle.read())
#
#
# def xkcd_line(x, y, xlim=None, ylim=None,
#               mag=1.0, f1=30, f2=0.05, f3=15):
#     ""
#     Mimic a hand-drawn line from (x, y) data
#
#     Parameters
#     ----------
#     x, y : array_like
#         arrays to be modified
#     xlim, ylim : data range
#         the assumed plot range for the modification.  If not specified,
#         they will be guessed from the  data
#     mag : float
#         magnitude of distortions
#     f1, f2, f3 : int, float, int
#         filtering parameters.  f1 gives the size of the window, f2 gives
#         the high-frequency cutoff, f3 gives the size of the filter
#
#     Returns
#     -------
#     x, y : ndarrays
#         The modified lines
#     ""
#     x = np.asarray(x)
#     y = np.asarray(y)
#
#     # get limits for rescaling
#     if xlim is None:
#         xlim = (x.min(), x.max())
#     if ylim is None:
#         ylim = (y.min(), y.max())
#
#     if xlim[1] == xlim[0]:
#         xlim = ylim
#
#     if ylim[1] == ylim[0]:
#         ylim = xlim
#
#     # scale the data
#     x_scaled = (x - xlim[0]) * 1. / (xlim[1] - xlim[0])
#     y_scaled = (y - ylim[0]) * 1. / (ylim[1] - ylim[0])
#
#     # compute the total distance along the path
#     dx = x_scaled[1:] - x_scaled[:-1]
#     dy = y_scaled[1:] - y_scaled[:-1]
#     dist_tot = np.sum(np.sqrt(dx * dx + dy * dy))
#
#     # number of interpolated points is proportional to the distance
#     Nu = int(200 * dist_tot)
#     u = np.arange(-1, Nu + 1) * 1. / (Nu - 1)
#
#     # interpolate curve at sampled points
#     k = min(3, len(x) - 1)
#     res = interpolate.splprep([x_scaled, y_scaled], s=0, k=k)
#     x_int, y_int = interpolate.splev(u, res[0])
#
#     # we'll perturb perpendicular to the drawn line
#     dx = x_int[2:] - x_int[:-2]
#     dy = y_int[2:] - y_int[:-2]
#     dist = np.sqrt(dx * dx + dy * dy)
#
#     # create a filtered perturbation
#     coeffs = mag * np.random.normal(0, 0.01, len(x_int) - 2)
#     b = signal.firwin(f1, f2 * dist_tot, window=('kaiser', f3))
#     response = signal.lfilter(b, 1, coeffs)
#
#     x_int[1:-1] += response * dy / dist
#     y_int[1:-1] += response * dx / dist
#
#     # un-scale data
#     x_int = x_int[1:-1] * (xlim[1] - xlim[0]) + xlim[0]
#     y_int = y_int[1:-1] * (ylim[1] - ylim[0]) + ylim[0]
#
#     return x_int, y_int
#
#
# def XKCDify(ax, mag=1.0,
#             f1=50, f2=0.01, f3=15,
#             bgcolor='w',
#             xaxis_loc=None,
#             yaxis_loc=None,
#             xaxis_arrow='+',
#             yaxis_arrow='+',
#             ax_extend=0.1,
#             expand_axes=False):
#     ""Make axis look hand-drawn
#
#     This adjusts all lines, text, legends, and axes in the figure to look
#     like xkcd plots.  Other plot elements are not modified.
#
#     Parameters
#     ----------
#     ax : Axes instance
#         the axes to be modified.
#     mag : float
#         the magnitude of the distortion
#     f1, f2, f3 : int, float, int
#         filtering parameters.  f1 gives the size of the window, f2 gives
#         the high-frequency cutoff, f3 gives the size of the filter
#     xaxis_loc, yaxis_log : float
#         The locations to draw the x and y axes.  If not specified, they
#         will be drawn from the bottom left of the plot
#     xaxis_arrow, yaxis_arrow : str
#         where to draw arrows on the x/y axes.  Options are '+', '-', '+-', or ''
#     ax_extend : float
#         How far (fractionally) to extend the drawn axes beyond the original
#         axes limits
#     expand_axes : bool
#         if True, then expand axes to fill the figure (useful if there is only
# ...
#
# string1 = "Hello World
# "
# m_obj = re.search(r"(\S*)\s*(\S*)", string1)
# if m_obj:
#     print "The first two groups of NON-whitespace characters"
#     print "are '%s' and '%s'." % m_obj.groups()
#
# Output:   The first two groups of NON-whitespace characters
#           are 'Hello' and 'World'.
#
# \d 	Matches a digit, same as [0-9].
#
# string1 = "99 bottles of beer on the wall."
# m_obj = re.search(r"(\d+)", string1)
# if m_obj:
#     print m_obj.group(1), "is the first number in '" +                          string1 + "'"
#
# Output:   99 is the first number in '99 bottles of beer on the wall.'
#
# \D 	Matches a non-digit.
#
# string1 = "Hello World"
# if re.search(r"\D", string1):
#     print "There is at least one character in", string1,
#     print "that is not a digit."
#
# ^ 	Matches the beginning of a line or string.
#
# string1 = "Hello World"
# if re.search(r"^He", string1):
#     print string1, "starts with the characters 'He'"
#
# $ 	Matches the end of a line or string.
#
# string1 = "Hello World"
# if re.search(r"rld$", string1):
#     print string1, "is a line or string " +          "that ends with 'rld'"
#
# \A 	Matches the beginning of a string (but not an internal line).
#
# string1 = "Hello
# World
# "
# if re.search(r"\AH", string1):
#     print string1, "is a string",
#     print "that starts with 'H'"
#
# Output:  Hello
#          World
#          is a string that starts with 'H'
#
# \Z 	Matches the end of a string (but not an internal line).
#
# string1 = "Hello
# World
# "
# if re.search(r"d
# \Z", string1):
#     print string1, "is a string",
#     print "that ends with 'd\n'"
#
# [^...] 	Matches every character except the ones inside brackets.
#
# string1 = "Hello World
# "
# if re.search(r"[^abc]", string1):
#     print string1 + " contains a character other than " +          "a, b, and c"
#
# Description :
# string manipulation re module re module examples
#
#
# -------new entry -------
# Line No. :90
# ROWID :90
#
# # Print the first word of a random line from a file
# import random
# def generate_the_word(infile):
#         with open(infile) as f:
#             contents_of_file = f.read()
#         lines = contents_of_file.splitlines()
#         line_number = random.randrange(0, len(lines))
#         return lines[line_number]
#
# infile = "/home/jack/Desktop/text_stuff/ALL_WIKI_GOOD.txt"
# line = generate_the_word(infile)
# print line.split(' ', 1)[0]
#
# Description :
# Print, first word, random line, file
# generate_the_word infile
# first word random line, file
#
#
#
# -------new entry -------
# Line No. :91
# ROWID :91
#
# num = raw_input ("Type Number : ")
# search = open("file.txt")
# for line in search:
#  if num in line:
#   print line
#
# ---------------
# search text, locate text, line number, print by line number
# search strings, locate strings, line numbers, print by line string
# find text in file, search a file
#
# Description :
# search text, locate text, line number, print by line number
# search strings, locate strings, line numbers, print by line string
# find text in file, search a file
#
#
# -------new entry -------
# Line No. :92
# ROWID :92
#
# with open('largeFile', 'r') as inF:
#     for line in inF:
#         if 'myString' in line:
#             # do_something
# ---------------
# search text, locate text, line number, print by line number
# search strings, locate strings, line numbers, print by line string
# find text in file, search a file
#
# Description :
# search text, locate text, line number, print by line number
# search strings, locate strings, line numbers, print by line string
# find text in file, search a file
#
#
# -------new entry -------
# Line No. :93
# ROWID :93
#
# import re
# def check_string():
#     #no need to pass arguments to function if you're not using them
#     w = raw_input("Input the English word: ")
#
#     #open the file using `with` context manager, it'll automatically close the file for you
#     with open("example.txt") as f:
#         found = False
#         for line in f:  #iterate over the file one line at a time(memory efficient)
#             if re.search({0".format(w),line):    #if string found is in current line then print it
#                 print line
#                 found = True
#         if not found:
#             print('The translation cannot be found!')
#
# check_string() #now call the function
# ---------------
# search function, search with function,
# search text, locate text, line number, print by line number
# search strings, locate strings, line numbers, print by line string
# find text in file, search a file
#
# Description :
# search text, locate text, line number, print by line number
# search strings, locate strings, line numbers, print by line string
# find text in file, search a file
#
#
# -------new entry -------
# Line No. :94
# ROWID :94
#
# The idiomatic way to do this in Python is to use rstrip('
# '):
#
# for line in open('myfile.txt'):  # opened in text-mode; all EOLs are converted to '
# '
#     line = line.rstrip('
# ')
#     process(line)
# ----------------
# rstrip('
# ') , rstrip(), rmove
#  , strip
#  , delete
#
#
# Description :
# rstrip('
# ') , rstrip(), rmove
#  , strip
#  , delete
#
#
#
# -------new entry -------
# Line No. :95
# ROWID :95
#
# #remove characters fron front or rear of a line
# STR ="'The idiomatic way to do this in Python is to use rstrip('
# '):'"
#
# STR = STR.strip("'")
# #Result: The idiomatic way to do this in Python is to use rstrip('
# #        '):
#
# STR = STR.rstrip("('
# '):")
# #Result: The idiomatic way to do this in Python is to use rstrip
#
# STR = STR.lstrip("The")
# # result:
# # idiomatic way to do this in Python is to use rstrip
#
# print STR
# ----------------
# rstrip('
# ') , rstrip(), rmove
#  , strip
#  , delete
#
#
# Description :
# rstrip('
# ') , rstrip(), rmove
#  , strip
#  , delete
#
#
#
# -------new entry -------
# Line No. :96
# ROWID :96
#
# STR = "Citizen of the Year\u2019 \u2014 \u2018Richly Deserved\u2019."
# wordList = re.sub("[^\w]", " ",  STR).split()
# has_string=False
# Find = "u"
# count=0
# for item in wordList:
#     count=count+1
#     if Find in item:
#         has_string=True
#
#         print count,"***Has string ",Find," TRUE*****"
#
# print " ".join(wordList),
#
# ------------------
# create list from str string list from string find string in list search list \
#
# Description :
# create list from str string list from string find string in list search list \
#
#
# -------new entry -------
# Line No. :97
# ROWID :97
#
# from time import sleep
# # Method to check a given sentence for given rules
# def checkSentence(string):
#     # Calculate the length of the string.
#     length = len(string)
#
#     # Check that the first character lies in [A-Z].
#     # Otherwise return false.
#     if string[0] < 'A' or string[0] > 'Z':
#         return False
#
#     # If the last character is not a full stop(.) no
#     # need to check further.
#     if string[length-1] != '.':
#         return False
#
#     # Maintain 2 states. Previous and current state based
#     # on which vertex state you are. Initialise both with
#     # 0 = start state.
#     prev_state = 0
#     curr_state = 0
#
#     # Keep the index to the next character in the string.
#     index = 1
#
#     # Loop to go over the string.
#     while (string[index]):
#         # Set states according to the input characters in the
#         # string and the rule defined in the description.
#         # If current character is [A-Z]. Set current state as 0.
#         if string[index] >= 'A' and string[index] <= 'Z':
#             curr_state = 0
#
#         # If current character is a space. Set current state as 1.
#         elif string[index] == ' ':
#             curr_state = 1
#
#         # If current character is a space. Set current state as 2.
#         elif string[index] >= 'a' and string[index] <= 'z':
#             curr_state = 2
#
#         # If current character is a space. Set current state as 3.
#         elif string[index] == '.':
#             curr_state = 3
#
#         # Validates all current state with previous state for the
#         # rules in the description of the problem.
#         if prev_state == curr_state and curr_state != 2:
#             return False
#
#         # If we have reached last state and previous state is not 1,
#         # then check next character. If next character is '', then
#         # return true, else false
#         if prev_state == 2 and curr_state == 0:
#             return False
#
#         # Set previous state as current state before going over
#         # to the next character.
#         if curr_state == 3 and prev_state != 1:
#             return True
#
#         index += 1
#
#         prev_state = curr_state
#
#     return False
# def sent(line):
#     if line[0] < 'A' or line[0] > 'Z':
#         return False
#
# def addperiod(line):
#     line = [ (str.rstrip('
# ') + "." + "
# " ) for str in line ]
#     return line
#
# def period(line):
#     line = [ (str.rstrip('
# ') + "." + "
# " ) for str in line ]
#     return line
# def sent(line):
#     if line[0] < 'A' or line[0] > 'Z':
#         return False
#
# infile = open("Alltext_good_no_dup.txt")
# lines = infile.readlines()
# for line in lines:
#     line = line.split(".")
#     line = period(line)
#     sleep(1)
#     sentence = line[0]
#     sentence = sentence.rstrip("
# ").capitalize()
#      if not sentence[0].isupper() and sentence[-1] != '.': # You can check the last character using sentence[-1]
#         # both the conditions are not satisfied
#         print 'Your sentence does not start with a capital letter and has no full stop at the end.'
#     elif not sentence[0].isupper():
#         # sentence does not start with a capital letter
#         print 'Your sentence does not start with a capital letter.'
#     elif sentence[-1] != '.':
#         # sentence does not end with a full stop
#         print 'Your sentence does not end with a full stop.'
#     else:
#         # sentence is perfect
#         print 'Your sentence is perfect.'
#
#         #if "//tw" in sentence:pass
#         if "//tw" != sentence and len(sentence)> 40:
#             print sentence
#         else: print len(sentence),"SKIPPED   SKIPPED   SKIPPED   SKIPPED   SKIPPED   SKIPPED   "
# sentence is good verify sentence perfect sentence good sentence
#
# Description :
# sentence is good verify sentence perfect sentence good sentence
#
#
# -------new entry -------
# Line No. :98
# ROWID :98
#
# from enchant.checker import SpellChecker
# def evaluate(line):
#     chkr = SpellChecker("en_US")
#     value = True
#     chkr.set_text(line)
#     for err in chkr:
#         #print "ERROR:", err.word
#         if err.word > "":value=False;break
#     #print value
#     return value
#
# STR = "You have a sequence of items, and you'd like to determine the most frequently occurring."
# evaluate(STR)
#
# -------------
# enchant.checker import Spell Checker
# enchant spell checker import SpellChecker
#
# Description :
# enchant.checker import Spell Checker
# enchant spell checker import SpellChecker
#
#
# -------new entry -------
# Line No. :99
# ROWID :99
#
# jack@jack-desktop:~/Desktop/Processing/Processing$ fuser runit.db
# /home/jack/Desktop/Processing/Processing/runit.db: 20512
# jack@jack-desktop:~/Desktop/Processing/Processing$ kill 20512
# jack@jack-desktop:~/Desktop/Processing/Processing$ fuser runit.db
# jack@jack-desktop:~/Desktop/Processing/Processing$ fuser runit.db
# jack@jack-desktop:~/Desktop/Processing/Processing$ kill 20512
# bash: kill: (20512) - No such process
# jack@jack-desktop:~/Desktop/Processing/Processing$ fuser nltk.db
# /home/jack/Desktop/Processing/Processing/nltk.db: 29997
# jack@jack-desktop:~/Desktop/Processing/Processing$ kill 29997
# jack@jack-desktop:~/Desktop/Processing/Processing$
#
# -------------
# unlock a locked database unlock db database is locked how to unlock database
#
# Description :
# unlock a locked database unlock db database is locked how to unlock database
# unlock, locked database, unlock db, database locked, how to unlock database,
#
#
# -------new entry -------
# Line No. :100
# ROWID :100
#
# %%writefile dbINFO.py
# ""
# Gets tablename and column names from unknown database
# just enter database name.
# USAGE:
# import dbINFO
# database= "databases/history.db"
# #database= "databases/sat2.db"
# #database= "databases/ImageD.db"
# dbINFO.dbinfo(database)
#
# ""
#
# import sqlite3
# def dbinfo(database):
#     conn = sqlite3.connect(database)
#     conn.text_factory = str
#     c = conn.cursor()
#     res = c.execute("SELECT name FROM sqlite_master WHERE type='table';")
#     row = c.fetchone()
#     row = str(row)
#     row = row.replace("(","");row = row.replace(",)","")
#     row = row.replace("'","")
#     print row
#     cur = c.execute("select * from "%s"" %  row)
#     columns = [description[0] for description in cur.description]
#     return columns
#
# # if run directly
# #database = "databases/history.db"
# #dbinfo(database)
#
# unknown database get database info get SQLite info lost column names get tablename
# retrieve database info get table get rows
#
# Description :
# unknown database get database info get SQLite info lost column names get tablename
# retrieve database info get table get rows
#
#
# -------new entry -------
# Line No. :101
# ROWID :101
#
# %%writefile UnicodeToAscii.py
# def unicodetoascii(text):
#
#     uni2ascii = {
#             ord('’'.decode('utf-8')): ord("'"),
#             ord('“'.decode('utf-8')): ord('"'),
#             ord('”'.decode('utf-8')): ord('"'),
#             ord('„'.decode('utf-8')): ord('"'),
#             ord('‟'.decode('utf-8')): ord('"'),
#             ord('é'.decode('utf-8')): ord('e'),
#             ord('“'.decode('utf-8')): ord('"'),
#             ord('–'.decode('utf-8')): ord('-'),
#             ord('‒'.decode('utf-8')): ord('-'),
#             ord('—'.decode('utf-8')): ord('-'),
#             ord('—'.decode('utf-8')): ord('-'),
#             ord('‘'.decode('utf-8')): ord("'"),
#             ord('‛'.decode('utf-8')): ord("'"),
#
#             ord('‐'.decode('utf-8')): ord('-'),
#             ord('‑'.decode('utf-8')): ord('-'),
#
#             ord('′'.decode('utf-8')): ord("'"),
#             ord('″'.decode('utf-8')): ord("'"),
#             ord('‴'.decode('utf-8')): ord("'"),
#             ord('‵'.decode('utf-8')): ord("'"),
#             ord('‶'.decode('utf-8')): ord("'"),
#             ord('‷'.decode('utf-8')): ord("'"),
#
#             ord('⁺'.decode('utf-8')): ord("+"),
#             ord('⁻'.decode('utf-8')): ord("-"),
#             ord('⁼'.decode('utf-8')): ord("="),
#             ord('⁽'.decode('utf-8')): ord("("),
#             ord('⁾'.decode('utf-8')): ord(")"),
#
#                             }
#     return text.decode('utf-8').translate(uni2ascii).encode('ascii')
#
# #print unicodetoascii("weren’t")
#
# -------------
# text decode utf-8 translate ascii).encode('ascii')
#
#  decode('utf-8').translate uni2ascii encode ascii
#
#
#
# Description :text decode utf-8 translate ascii).encode('ascii')
# decode('utf-8').translate uni2ascii encode ascii
#
# -------new entry -------
# Line No. :102
# ROWID :102
#
# import os.path
# from os import listdir, getcwd
# def mp3list(PATH):
#     abs_path = os.path.join(os.getcwd(),PATH)
#     dir_files = os.listdir(abs_path)
#     return dir_files
#
# def mkFile(mfile, PATH):
#     mFiles = open(mfile, "w");mFiles.close()
#     lst = mp3list(PATH)
#     lst = str(lst)
#     lst = lst.replace(",","
# ");lst = lst.replace("'","")
#     lst = lst.replace("[","");lst = lst.replace("]","")
#     lst = lst.replace(" ","")
#     print lst
#     mFiles = open(mfile, "a")
#     mFiles.write(lst)
#     mFiles.close()
#
# PATH = "MP3/"
# mfile = "GISTstore/muz.list"
# mkFile(mfile, PATH)
# ---
# list directory, list to file directory, list to file
#
# Description :list directory, list to file directory, list to file
#
# -------new entry -------
# Line No. :103
# ROWID :103
#
# # Find all files with a specific EXT and list in a file
# import os
# import os.path
# title = "MP3/MP3-list.list"
# f= open(title,"w")
# f.close()
# count=0
# for dirpath, dirnames, filenames in os.walk("/home/jack/Desktop/Processing/Processing/MP3/"):
#     for filename in [f for f in filenames if f.endswith(".mp3")]:
#         count=count+1
#         Path = os.path.join(dirpath, filename)
#         with open(title, 'a') as outfile:
#             path = Path+"
# "
#             outfile.write(path)
# -------------------------------
# dirpath, dirnames, filenames in os.walk
#
#
# Description :list directory, specific EXT list to file directory, list to file
# dirpath, dirnames, filenames in os.walk
#
# -------new entry -------
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
test_input = []
keep = set(mapping[data] for data in test_input)

inpuT = raw_input("Test : ").split("/")
keep.update(inpuT)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-140-3661660466cb> in <module>()
#       2 keep = set(mapping[data] for data in test_input)
#       3
# ----> 4 inpuT = raw_input("Test : ").split("/")
#       5 keep.update(inpuT)
#
# /home/jack/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# /home/jack/anaconda2/lib/python2.7/site-packages/ipykernel/kernelbase.pyc in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %%
print keep
# Out:
# set([])

# %%
import sqlite3
import sys
from time import sleep

def md5(line):
    hash_md5 = hashlib.md5()
    for chunk in iter(lambda: line(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()




database = "/home/jack/snippet.db"
conn = sqlite3.connect(database)
conn.text_factory = str
c = conn.cursor()
count = 0
f = open("this-Snippets.txt", "w");f.close()
f = open("this-Snippets.txt", "a")
search = raw_input("Search : ")
for row in c.execute('SELECT rowid, * FROM snippet WHERE snippet MATCH ?', (search,)):  
    count=count+1
    count = str(count)
    iD = row[0]
    iD = str(iD)
    line = row[2]
    desc = (row)[3]
    j = "Line No. :",count,"\nROWID :",iD,"\n",line,"\nDescription :",desc,"\n\n-------new entry -------"
    line = "".join(j)
    sleep(1)
    f.write(line)
    print line
    count = int(count)
    
conn.close()
print "Results Complete"
sys.exit()
# Out:
# Search : remove duplicate
# Line No. :1
# ROWID :78
#
# %%writefile HashCheck.py
# "" USEAGE:
# (insert hash)
#
# for example to get hash of a filename:
# def md5(Path):
#     hash_md5 = hashlib.md5()
#     with open(Path, "rb") as f:
#         for chunk in iter(lambda: f.read(4096), b""):
#             hash_md5.update(chunk)
#     return hash_md5.hexdigest()
#
# Hash = md5(title)
#
# import HashCheck
# hasht = "jsudsfhndsfjunjsd"
# HashCheck.hashfill(Hash)
# ---------------
# import HashCheck
# HashCheck.hashcheck()
#
# import HashCheck
# HashCheck.killmem()
# ""
# import sqlite3
# import sys
# import os
#
# def md5(Path):
#     hash_md5 = hashlib.md5()
#     with open(Path, "rb") as f:
#         for chunk in iter(lambda: f.read(4096), b""):
#             hash_md5.update(chunk)
#     return hash_md5.hexdigest()
#
# def hashfill(Hash):
#     import sqlite3
#     database ="tmp-mem"
#     conn = sqlite3.connect(database)
#     c = conn.cursor()
#     c.execute("CREATE TABLE IF NOT EXISTS Hash(hasht TEXT);")
#     c.execute("INSERT INTO Hash(hasht) VALUES(?)",(Hash,))
#     conn.commit()
#     conn.close()
#
# def hashcheck():
#     import sqlite3
#     database ="tmp-mem"
#     conn = sqlite3.connect(database)
#     c = conn.cursor()
#     rows = c.execute("SELECT rowid, hasht FROM Hash")
#     for row in rows:
#         print row[1]
#     return
#
# def killmem():
#     os.remove(database)
#     print(database,"Removed!")
#
# Description :verify files, hash , duplicate find duplicate files, hashfill (Hash),HashCheck .py,HashCheck.py
#
# -------new entry -------
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit

# %%
# !ls ~/Desktop/text_stuff
# Out:
# 01a.jpg
# 01.jpg
# 02a.jpg
# 02.jpg
# 1.mp3
# 20171020100525.jpg
# aa.png
# abc.png
# AllBooksOfEnoch_djvu.txt
# ALLtextCleanC.txt
# ALLtextClean.txt
# ALLtextC.txt
# ALLtextnbCleaner.text
# ALLtextnbCleaner.txt
# ALLtextnbClean.txt
# ALLtextnbC.txt
# ALLtextnb.txt
# ALLtext.txt
# ALL_TLE.TXT
# ALL_WIKI_GOOD.txt
# ALL_WIKI.txt
# ALLWIKI.txt
# ALLWORKNGSQLITE_and_MYSQL.ipynb
# analemma.py
# ariver001.jpg
# ariver002.jpg
# astralGOOD.txt
# astral.pdf
# astral.py.ipynb
# astral.txt
# astral.txtGOOD.txt
# astronomy2.ipynb
# AstronomyII.ipynb
# AstronomyI.ipynb
# AstroRead.py
# AstroRead.pyc
# AstroStore.db
# AstroStore.py
# AstroStore.pyc
# Authorize.py
# Automate-the-Boring-Stuff.txt
# bashhis.txt
# bb.png
# Bible_Search_in_SQL.ipynb
# bigfeedfts.db
# BookOfEnochGood2.txt
# BookOfEnochGOOD.db
# BookOfEnochGOOD.txt
# BookOfEnoch.pdf
# BookOfEnochpdf.db
# BookOfEnochpdf.txt
# BooksOfEnoch.txt
# Bt.py
# calcSun.py
# calcSun.pyc
# clean2.txt
# cleanout.txt
# clean.py
# cleanstream.txt
# clean.txt
# cleanwords.txt
# collagemaker.py
# collection.db
# colormapSAZ.png
# colormapSZA.png
# controlBlend
# controlBlend.cpp
# converted2a.bmp
# converted2.bmp
# converted.bmp
# coordinates
# CreatingC++Imageblender.ipynb
# CreatingC++Imageviewer.ipynb
# Creationofcollection.db.ipynb
# credentials.json
# CSSReset.com - Keeping Footer At The Bottom Of The Page
# DailyPythonTips_tweets.csv
# database003.png
# database005.png
# database006.png
# database010.png
# database013.jpg
# database016.png
# database017.png
# database019.png
# database024.png
# database030.png
# database-bak
# DBread.py
# DBread.pyc
# DBstore.py
# DBstore.pyc
# de405.bsp
# de421.bsp
# DEEPDREAMONLY.ipynb
# deltat.data
# deltat.preds
# demopanels.py
# diveintopython
# do i need, to use, Quotes
# DonaldTrump_tweets.csv
# download_test.ipynb
# e_101.txt
# earthsatellites.ipynb
# editTest.txt
# Effective_Python.txt
# elonmusk_tweets.csv
# elonmusk.txt
# ephem-3.7.6.0
# ephrem_manual_text.txt
# exp001C.txt
# exp001.txt
# ex.pdf
# FileLen.py
# filename4.html
# file.txt
# foo.png
# ftp2.ipynb
# FTP_and_Editor.ipynb
# ftp.db
# FTPit.py
# FTS3_Database.ipynb
# fts4.db
# fts4_experiment.rb
# ftsfromdb.ipynb
# geckodriver.log
# generate.py
# ghostdriver.log
# Goodmousesizingandcropping.ipynb
# good.mp3
# grab_pdfs.py
# grab_pdfs.pyc
# grimm.txt
# hardread.txt
# hashonly2.txt
# hashonlyNoBlank2.txt
# hashonlyNoBlankNoDupsNoHash.txt
# hashonlyNoBlankNoDups.txt
# hashonlyS.txt
# hashtag-nouns.txt
# hashtag.txt
# heatmap.py
# hekel.txt
# hek.txt
# Here.py
# Here.pyc
# hex.jpg
# history2.db
# history.db
# historyFTS4.db
# history.txt
# Humor-Sans.ttf
# Image2Data.py
# Image2Data.pyc
# image2.db
# Image2SQLite.py
# image3.db
# "ImageB.db"
# ImageB.db
# ImageC.db
# image.db
# ImageD.db
# ImageF.db
# Image_Pack.ipynb
# importpython_tweets.csv
# importpython.txt
# INDEX.ipynb
# index.txt
# io
# ipynb2.db
# ipynb.db
# IPythonComputing.txt
# IPythonInteractiveComputing.txt
# jplephem speed test de405.png
# junk
# junks
# junqueC.txt
# JupyterNotebookStuff.ipynb
# jupytertodatabaseFTS4.ipynb
# jupytertodatabase.ipynb
# Key.py
# Key.pyc
# Leap_Second.dat
# links.txt
# littlewood_10_200.png
# littlewood_16_200.png
# littlewood_18_200.png
# littlewood_20_200a.png
# littlewood_20_400.png
# littlewood2.py
# littlewood.ipynb
# littlewood.py
# MarkovifyWikipedia.txt
# MaskGeneratorCopy1.ipynb
# masks
# mathbooks
# misc.db
# misc_twitter_stuff.ipynb
# MutaGen96F06.png
# MutaGen-Large00.png
# mynotebooks.tx
# newdatabase02
# newdb.db
# NewNotebook1Copy1.ipynb
# NewNotebook1.ipynb
# NewNotebook.ipynb
# newtest.txt
# nodupsnohash2.txt
# nodupsnohash.txt
# nodupStreaming.txt
# notebooks.db
# notebooks.db-bak
# NShashonlyS.txt
# oceanlarge.jpg
# opengl_programming_guide_8th_edition.pdf
# output2.jpg
# output2.png
# output2.txt
# OutputStreaming.txt
# output.txt
# palettize.py
# paletts.py
# Palett_Swap.ipynb
# pallet_test.jpg
# Parsing_and_Storing_RSS_newsfeeds_in_SQLite.ipynb
# pass_phrase
# PDF.html
# PDF.list
# pdfminer-20140328.tar.gz
# pdfs.db
# PDFshort.html
# pdf.txt
# phrases2.txt
# phrases.txt
# polar_heatmap.py
# postit2.db
# postit.db
# PyEphem_Reference.pdf
# PyEphem_swedish.pdf
# pyexiftool
# pysolar-0.6.zip
# pysolar.pdf
# pythonbot__tweets.csv
# pythonbot__.txt
# Python_Cookbook_3rd_Edition.txt
# Python_Cookbook.txt
# PythonRR_tweets.csv
# PythonRR.txt
# QUICKdb():
# QUICKdb.py
# quicktest.ipynb
# RandCap.py
# RandLine.py
# RandNoun.py
# RandomLine.py
# readme
# realDonaldTrump_tweets.csv
# realDonaldTrump.txt
# reducedsize.jpg
# result.png
# roots.py
# sample.txt
# sat2.db
# sat2db.ipynb
# SatInfo.py
# SatInfo.pyc
# savE_patern.txt
# savE_sentence.txt
# savE.txt
# SavE.txt
# SAZmap.png
# searchBlend
# searchBlend.cpp
# SearchFilename.py
# SearchFilename.pyc
# searcH.py
# --skyfield
# skyfield speed test de405.png
# Slite.py
# SMSSpamCollection
# snakewave.jpg
# snakewave.png
# Snip
# snippet
# snippet1.pdf
# snippet2.db
# snippet2.pdf
# snippet3.pdf
# snippet4.pdf
# snippet_base.png
# snippetbase.xcf
# snippet.db
# snippet.pdf
# snippets
# snippetsTX.txt
# Snippet_WarehouseMySQLSQLitecodestoragesearch.ipynb
# Snip.py
# Snip.pyc
# spam.csv
# speechclusterscraping.ipynb
# stars_print_out_ra_and_dec.out
# stations.txt
# storeit.data
# storeit.data1
# sunpos
# SUNposition
# super.txt
# symmetrymagexp.txt
# symmetrymag_tweets.csv
# symmetrymag.txt
# syn.py
# SZAmap.png
# TCI_Sahara.jp2
# TCI_SanFrancisco.jp2
# TEDTalks_tweets.csv
# TEDTalks.txt
# temp2.txt
# tempfile2.txt
# tempfile.txt
# temp.txt
# test1.ipynb
# test22.db
# test.db
# testfile002.txt
# testfile.txt
# testingagain.jpg
# test.ipynb
# testnotebook.ipynb
# test.txt
# text2sent.py
# Text_GenerationBEST.ipynb
# Text_Generationfromtwitter.ipynb
# Text_Generation.ipynb
# textwik.txt
# There.py
# There.pyc
# Tidyt.py
# TitleandSigntitlenpost.py.ipynb
# tkSimpleDialog.py
# TLE.py
# TLE.pyc
# tmp
# tmp.prototxt
# tokens2.txt
# tokens.txt
# ToUse.txt
# Tpost.py
# tree.png
# TweepyToCSV.ipynb
# TweepyToCSV.py
# tweets.db
# TwitterBot.py
# twittertext2.db
# twittertext64.db
# twittertext.db
# Txsearch.py
# TxSearch.py
# untitled.sh
# usersNoBlank.txt
# usersNoDups.txt
# users.txt
# Use.txt
# usewik.txt
# virtual2.txt
# virtual.txt
# visual.tmp
# visual.txt
# WebScrapingwithPython.txt
# Wiki_Abiogenesis.txt
# Wiki_Analemma.txt
# Wiki_AncientEgypt.txt
# Wiki_ancientmanuscripts.txt
# Wiki_assemblylanguage.txt
# Wiki_Asteroidbelt.txt
# Wiki_astrologicalConstellation.txt
# Wiki_Astrology.txt
# Wiki_Biblicalmanuscript.txt
# Wiki_BookofEnoch.txt
# Wiki_C++compiler.txt
# Wiki_computerdata.txt
# Wiki_computerprogramming.txt
# Wiki_Cradleofcivilization.txt
# Wiki_Darwinism.txt
# WIKIData.db
# WIKIData.db-bak
# Wiki_DonaldTrump.txt
# Wiki_Enoch(ancestorofNoah).txt
# Wiki_enochNephilim.txt
# Wiki_Extraterrestriallife.txt
# Wiki_FederalReserveSystem.txt
# Wiki_firstBookofEnoch.txt
# Wiki_GeographyofEthiopia.txt
# Wiki_HistoryofEarth.txt
# Wiki_Human–computerinteraction.txt
# Wiki_Illuminati:NewWorldOrder.txt
# Wiki_InternationalMonetaryFund.txt
# Wiki_Javavirtualmachine.txt
# Wiki_KnightsTemplar.txt
# Wiki_linuxoperatingsystem.txt
# wikilist2.txt
# wikilist.txt
# Wiki_MachineLearning.txt
# Wiki_memoryconformity.txt
# Wiki_memoryresearch.txt
# Wiki_MySQL.txt
# Wiki_NaturalLanguageToolkit.txt
# Wiki_NewWorldOrderconspiracytheory.txt
# Wiki_opensource.txt
# Wiki_Orbitalelements.txt
# Wiki_OriginofwateronEarth.txt
# wikipedia.db
# WikiPedia.ipynb
# Wiki_programmingcode.txt
# Wiki_programmingdebug.txt
# Wiki_Prokaryote.txt
# Wiki_Pythonprogramminglanguage.txt
# Wiki_quantummechanics.txt
# Wiki_SecondBookofEnoch.txt
# Wiki_SolarSystem.txt
# Wiki_Sourcecode.txt
# Wiki_SQLite.txt
# Wiki_Sunpath.txt
# Wiki_Ubuntu(operatingsystem).txt
# Wiki_Ubuntu(philosophy).txt
# Wiki_UnitedStates.txt
# Wiki_war.txt
# Wiki_WebScraping.txt
# Wiki_worldeconomy.txt
# WordsandSentences.ipynb
# words.db
# wordsdb.ipynb
# Working_with_Tweets_and_Text_Results.ipynb
# XPfts4.db

# %%
import os
import timeit
import sqlite3
def txsearch():
    
    #database = "FTS4_IPYNB.db"
    database = "PythonCode.db"
    conn = sqlite3.connect(database)
    c = conn.cursor()
    conn.text_factory=str 
    c.execute("""
    CREATE VIRTUAL TABLE IF NOT EXISTS PYTHON 
    USING FTS4(PATH, fname, line);
    """)
    conn.commit()
    
    # Ask to enter string to search
    Sstring = raw_input("Search Phrase")
    for fname in os.listdir('/home/jack/Desktop/text_stuff'):
       # Apply file type filter 
       path = "/home/jack/Desktop/text_stuff/" 
       if fname.endswith(".txt"):
            # Open file for reading
            PATH = path+fname
            fo = open(PATH)
            # Read the first line from the file
            line = fo.readline()
            # Initialize counter for line number
            line_no = 1
            # Loop until EOF
            while line != '' :
                    index = line.find(Sstring)
                    c.execute("INSERT INTO PYTHON VALUES (?,?,?)", (PATH, fname, line))
                    conn.commit()
                    if ( index != -1) :
                        # Set some parameters no lines longer than 240 characters 
                        # or less than search phrase +30 characters 
                        if len(line)< 240 and len(line)> len(Sstring)+20 :
                            #print(fname, "[", line_no, ",", index, "] ", line)
                            #print fname,line[1:-8],"  "
                            print fname,line_no,line
                    # Read next line
                    line = fo.readline()  
                    # Increment line counter
                    line_no += 1
            # Close the files
            fo.close()
    conn.close()                
            
txsearch()
# Out:
# Search Phrasew565w666

# %%
import sqlite3
from time import sleep
database = "PythonCode.db"
conn = sqlite3.connect(database)
c = conn.cursor()
search = raw_input("SEARCH : ")
#for row in c.execute("SELECT rowid,* from PYTHON WHERE line MATCH ?", (search,)):
for row in c.execute("SELECT rowid,* from PYTHON "):   
    sleep(1)                 
    print row[0],row[1],row[2]

conn.close()
# Out:
# SEARCH :

# %%
import os
import timeit
def txsearch():
    # Ask to enter string to search
    Sstring = raw_input("Search Phrase  : ")
    for fname in os.listdir('/home/jack/Desktop/text_stuff'):
       # Apply file type filter 
       path = "/home/jack/Desktop/text_stuff/" 
       if fname.endswith(".txt"):
            # Open file for reading
            fo = open(path+fname)
            # Read the first line from the file
            line = fo.readline()
            # Initialize counter for line number
            line_no = 1
            # Loop until EOF
            while line != '' :
                    index = line.find(Sstring)
                    if ( index != -1) :
                        # Set some parameters no lines longer than 240 characters 
                        # or less than search phrase +30 characters 
                        if len(line)< 240 and len(line)> len(Sstring)+20 :
                            #print(fname, "[", line_no, ",", index, "] ", line)
                            #print fname,line[1:-8],"  "
                            print fname,line_no,line
                    # Read next line
                    line = fo.readline()  
                    # Increment line counter
                    line_no += 1
            # Close the files
            fo.close()
            
txsearch()
# Out:
# Search Phrase  : import
# grab_pdfs.py 24 from urlparse import urljoin
#
# grab_pdfs.py 25 from os import path, getcwd
#
# grab_pdfs.py 26 from bs4 import BeautifulSoup as soup
#
# RandCap.py 3 from random import randint
#
# RandCap.py 10     os.system("import -window root screencap/temp.png")
#
# SatInfo.py 1 from itertools import izip, islice
#
# SatInfo.py 10     from time import sleep
#
# SatInfo.py 20     from time import sleep
#
# SatInfo.py 30     from time import sleep
#
# calcSun.py 415     from dateutil.relativedelta import relativedelta
#
# clean.py 1 from datetime import datetime
#
# clean.py 5 from nltk.stem.lancaster import LancasterStemmer
#
# clean.py 6 from nltk.corpus import stopwords
#
# demopanels.py 17 #from tkinter.simpledialog import Dialog
#
# demopanels.py 18 from tkSimpleDialog import Dialog
#
# demopanels.py 19 from PIL import Image, ImageTk
#
# Image2SQLite.py 3 from os import listdir, getcwd
#
# Image2SQLite.py 4 from IPython.core.display import Image
#
# Tpost.py 6 from twython import Twython
#
# RandomLine.py 3     from random import randint
#
# text2sent.py 1 from textblob import TextBlob
#
# Image2Data.py 3 from os import listdir, getcwd
#
# Image2Data.py 4 from IPython.core.display import Image

# %%
# !mkdir Databases
# Out:
# ls: cannot access 'Databases': No such file or directory

# %%
import sqlite3
import sys
database = "/home/TEMP/Databases/SNIPPETS.db"
conn = sqlite3.connect(database)
conn.text_factory = str
c = conn.cursor()
count=0;req=200
search = raw_input("Search : ")
for row in c.execute('SELECT rowid, * FROM snippets WHERE snippets MATCH ?', (search,)):    
    count=count+1
    print "ID : ",(row)[0],(row)[1]," -- KEYWORDS",(row)[2],"\n"
    if count > req:
        conn.close()
        sys.exit()
# Out:
# Search : fts4
#  ID :  69
# import sqlite3
# import re
# import sys
# import time
# database = "test.db"
# #database = "junk2.db"
# conn = sqlite3.connect(database)
# conn.text_factory = lambda x: unicode(x, "utf-8", "ignore")
# c = conn.cursor()
# c.execute(""
# CREATE VIRTUAL TABLE IF NOT EXISTS ipynb
# USING FTS4(file, content, description);
# "")
# conn.commit()
# conn.close()
# conn = sqlite3.connect(database)
# c = conn.cursor()
# count=1
# titlelist = "ipynb-clean.list"
# titles = open(titlelist,"r")
# for title in titles.readlines():
#     filename = os.path.basename(title)
#     # Use for debug print filename,":"
#     description = filename
#     description = description.replace("-", " ")
#     description = description.replace("_", " ")
#     description = description.replace(".ipynb", " ")
#     description = re.sub("([a-z])([A-Z])","\g<1> \g<2>",description)
#     title = title.replace("
# ", "")
#
#     dt=time.ctime(os.path.getctime(title))
#     dt=str(dt)
#     #dt = dt.replace(" ","")
#     description = description+"Date :"+dt
#     suf = title.replace("/home/jack/","")
#     suf = suf.replace(".ipynb","_")
#     suf = suf.replace("/","_")
#     filename = suf+filename
#     with open(title, "rb") as input_file:
#                 ablob = input_file.read()
#                 content  = sqlite3.Binary(ablob)
#                 c.execute("INSERT INTO ipynb (file, content, description) VALUES(?, ?, ?)",
#                       (filename, content, description))
#
#                 conn.commit()
#     line = file
#     #line ="Good-mouse-sizing-and-cropping.ipynb"
#     index = "Index"
#     c.execute("INSERT INTO ipynb VALUES (?,?,?)", (index, filename, description))
#     conn.commit()
#     count=count+1
#     print count,filename, description
#
# c.close()
# conn.close()
#
#  -- KEYWORDS BEST best create a database of jupyter notebooks notebook to database SQLite notebook 2 database
#
# ID :  70
# import sqlite3
# #database = "FTS4_IPYNB_indexed.db"
# database = "test.db"
# #database = "/home/jack/Desktop/text_stuff/notebooks.db"
# conn = sqlite3.connect(database)
# conn.text_factory=str
# c = conn.cursor()
# c.execute("SELECT COUNT(*) from ipynb")
# (number_of_rows,)=c.fetchone()
# print (number_of_rows,)
#
#  -- KEYWORDS count rows in sqlite database count rows SQLite
#
# ID :  72
# import sqlite3
# #database = "FTS4_IPYNB.db"
# database = "FTS4_IPYNB_indexed.db"
# conn = sqlite3.connect(database)
# c = conn.cursor()
# conn.text_factory=str
# c.execute(""
# CREATE VIRTUAL TABLE IF NOT EXISTS ipynb
# USING FTS4(file, content, description);
# "")
# conn.commit()
# conn.close()
# conn = sqlite3.connect(database)
# c = conn.cursor()
# count=0
# while count<19:
#     count=count+1
#     if count==1:PATH = "/home/jack/Desktop/deep-dream-generator/notebooks/"
#     if count==2:PATH = "/home/jack/Desktop/text_stuff/"
#     if count==3:PATH = "/home/jack/Desktop/imagebot/"
#     if count==4:PATH = "/home/jack/Desktop/Snippet_Warehouse/"
#     if count==5:PATH = "/home/jack/Desktop/gitjupyter/"
#     if count==6:PATH = "/home/jack/Desktop/jack_watch/"
#     if count==7:PATH = "/home/jack/Desktop/jack_watch/nltk/"
#     if count==8:PATH = "/home/jack/Desktop/jack_watch/Python-Lectures/"
#     if count==9:PATH = "/home/jack/Desktop/jack_watch/jupyter_examples-master/"
#     if count==10:PATH = "/home/jack/Desktop/Books/numerical-python-book-code/"
#     if count==11:PATH = "/home/jack/Desktop/Books/pydata-book/"
#     if count==12:PATH = "/home/jack/Desktop/Ruby/"
#     if count==13:PATH = "/home/jack/Desktop/alice/ChatterBot/"
#     if count==14:PATH = "/home/jack/Desktop/deep-dream-generator/LOCAL-notebooks/"
#     if count==15:PATH = "/home/jack/Desktop/numpy-array-filters/"
#     if count==16:PATH = "/home/jack/Desktop/pycode/"
#     if count==17:PATH = "/home/jack/Desktop/pycode/vpython2/TrigonometryBot/"
#     if count==18:PATH = "/home/jack/Desktop/temp/args_csv_Twython_ImageBot/"
#     if count==19:PATH = "/home/jack/python3-starter/notebooks/"
#     for file in os.listdir(PATH):
#         if file.endswith(".ipynb"):
#             filename = PATH+file
#             filein = PATH
#             filein = filein.replace("/home/jack/", "")
#             filein = filein.replace("/", "_")
#             filein = filein+file
#             description = filein
#             description = description.replace("_", " ")
#             description = description.replace("-", " ")
#             description = description.replace("/", " ")
#             description = description+"
# "+PATH+file+"
# "+file
#             with open(filename, "rb") as input_file:
#                     ablob = input_file.read()
#                     content  = sqlite3.Binary(ablob)
#                     c.execute("INSERT INTO ipynb (file, content, description) VALUES(?, ?, ?)",
#                               (filein, content, description))
#                     print os.path.join(PATH, file, filein)
#                     conn.commit()
#             line = file
#             #line ="Good-mouse-sizing-and-cropping.ipynb"
#             title = "index"
#             c.execute("INSERT INTO ipynb VALUES (?,?,?)", (title, file, description))
#             conn.commit()
#
# c.close()
# conn.close()
#
#
#  -- KEYWORDS SQLite inserting files by directory walk - adding files to database by extension
#
# ID :  79
# #%%writefile GISTstore/post2gist.py
# import os
# from time import sleep
# import sqlite3
# import os, requests, sys, json
# import GISTkey
# username=GISTkey.gistkey()[0]
# password=GISTkey.gistkey()[1]
# database ="GISTstore/gist.db"
# conn = sqlite3.connect(database)
# c = conn.cursor()
# c.execute(""
# CREATE VIRTUAL TABLE IF NOT EXISTS gist
# USING FTS4(content, description, filename);
# "")
# c.close()
# conn.close()
# conn = sqlite3.connect(database)
# conn.text_factory=str
# c = conn.cursor()
# if not os.path.exists('GISTstore'):
#     os.makedirs('GISTstore')
# #PATH = "GISTstore/"
# #filename = "UnCamel.py"
# #content=open(PATH+filename, 'r').read()
# filename = "Post_To_Gist _PostToGist.py.ipynb"
# content=open(filename, 'r').read()
# post = 'https://api.github.com/gists'
# r = requests.post(post,json.dumps({'files':{filename:{"content":content}}}),
#                   auth=requests.auth.HTTPBasicAuth(username, password))
# sleep(2)
# Url= (r.json()['html_url'])
# c.execute("INSERT INTO gist VALUES (?,?,?)", (content, Url, filename))
# conn.commit()
# title = "Index"
# c.execute("INSERT INTO gist VALUES (?,?,?)", (title, Url, filename))
# conn.commit()
# for row in c.execute('SELECT rowid, content, description, filename FROM gist     WHERE filename MATCH ?', (filename,)):
#         print Url,"
# ",row[0],row[1],row[2],row[3]
# c.close()
# conn.close()
#  -- KEYWORDS gist, gist.gisthub , post to gist, save file to sqlite database

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"

conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ID :")
filename = search+"DB.ipynb"
f= open(filename,"w");f.close()
SEARCH = search+1
for row in c.execute('SELECT content FROM ipynb WHERE rowid == ?', (SEARCH,)):
        print row[1]
with open(filename, 'a') as outfile:
    for row in c.execute('SELECT content FROM ipynb WHERE rowid == ?', (search,)):
        row0 = row[1]
        #row0 =str(row0,"\n")
        #outfile.write(row0)
        print row0
        
conn.close()
f.close()

  # 427

# %%
import json
import sys
from time import sleep
import sqlite3
import csv
database = "sept8_IPNB.list.db"

conn = sqlite3.connect(database)
conn.text_factory=str 
c = conn.cursor()
search = raw_input("ID :")
#filename = search+"DB.ipynb"
#f= open(filename,"w");f.close()
SEARCH = int(search)+1
for row in c.execute('SELECT content FROM ipynb WHERE rowid == ?', (SEARCH,)):
        filename = row[0]
with open(filename, 'w') as outfile:
    for row in c.execute('SELECT content FROM ipynb WHERE rowid == ?', (search,)):
        row0 = row[0]
        #row0 =str(row0,"\n")
        outfile.write(row0)
        print row0
print filename        
conn.close()
f.close()


  # 427
# Out:
# ID :427
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 1,
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "\n",
#       "\t\t\t<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n",
#       "\t\t\t<ttFont sfntVersion=\"\u0000\u0001\u0000\u0000\" ttLibVersion=\"3.21\">\n",
#       "\n",
#       "\t\t\t  <GlyphOrder>\n",
#       "\t\t\t\t<!-- The 'id' attribute is only for humans; it is ignored when parsed. -->\n",
#       "\t\t\t\t<GlyphID id=\"0\" name=\".notdef\"/>\n",
#       "\t\t\t\t<GlyphID id=\"1\" name=\".null\"/>\n",
#       "\t\t\t\t<GlyphID id=\"2\" name=\"uni000D\"/>\n",
#       "\t\t\t\t<GlyphID id=\"3\" name=\"space\"/>\n",
#       "\t\t\t\t<GlyphID id=\"4\" name=\"exclam\"/>\n",
#       "\t\t\t\t<GlyphID id=\"5\" name=\"quotedbl\"/>\n",
#       "\t\t\t\t<GlyphID id=\"6\" name=\"numbersign\"/>\n",
#       "\t\t\t\t<GlyphID id=\"7\" name=\"dollar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"8\" name=\"percent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"9\" name=\"ampersand\"/>\n",
#       "\t\t\t\t<GlyphID id=\"10\" name=\"quotesingle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"11\" name=\"parenleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"12\" name=\"parenright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"13\" name=\"asterisk\"/>\n",
#       "\t\t\t\t<GlyphID id=\"14\" name=\"plus\"/>\n",
#       "\t\t\t\t<GlyphID id=\"15\" name=\"comma\"/>\n",
#       "\t\t\t\t<GlyphID id=\"16\" name=\"hyphen\"/>\n",
#       "\t\t\t\t<GlyphID id=\"17\" name=\"period\"/>\n",
#       "\t\t\t\t<GlyphID id=\"18\" name=\"slash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"19\" name=\"zero\"/>\n",
#       "\t\t\t\t<GlyphID id=\"20\" name=\"one\"/>\n",
#       "\t\t\t\t<GlyphID id=\"21\" name=\"two\"/>\n",
#       "\t\t\t\t<GlyphID id=\"22\" name=\"three\"/>\n",
#       "\t\t\t\t<GlyphID id=\"23\" name=\"four\"/>\n",
#       "\t\t\t\t<GlyphID id=\"24\" name=\"five\"/>\n",
#       "\t\t\t\t<GlyphID id=\"25\" name=\"six\"/>\n",
#       "\t\t\t\t<GlyphID id=\"26\" name=\"seven\"/>\n",
#       "\t\t\t\t<GlyphID id=\"27\" name=\"eight\"/>\n",
#       "\t\t\t\t<GlyphID id=\"28\" name=\"nine\"/>\n",
#       "\t\t\t\t<GlyphID id=\"29\" name=\"colon\"/>\n",
#       "\t\t\t\t<GlyphID id=\"30\" name=\"semicolon\"/>\n",
#       "\t\t\t\t<GlyphID id=\"31\" name=\"less\"/>\n",
#       "\t\t\t\t<GlyphID id=\"32\" name=\"equal\"/>\n",
#       "\t\t\t\t<GlyphID id=\"33\" name=\"greater\"/>\n",
#       "\t\t\t\t<GlyphID id=\"34\" name=\"question\"/>\n",
#       "\t\t\t\t<GlyphID id=\"35\" name=\"at\"/>\n",
#       "\t\t\t\t<GlyphID id=\"36\" name=\"A\"/>\n",
#       "\t\t\t\t<GlyphID id=\"37\" name=\"B\"/>\n",
#       "\t\t\t\t<GlyphID id=\"38\" name=\"C\"/>\n",
#       "\t\t\t\t<GlyphID id=\"39\" name=\"D\"/>\n",
#       "\t\t\t\t<GlyphID id=\"40\" name=\"E\"/>\n",
#       "\t\t\t\t<GlyphID id=\"41\" name=\"F\"/>\n",
#       "\t\t\t\t<GlyphID id=\"42\" name=\"G\"/>\n",
#       "\t\t\t\t<GlyphID id=\"43\" name=\"H\"/>\n",
#       "\t\t\t\t<GlyphID id=\"44\" name=\"I\"/>\n",
#       "\t\t\t\t<GlyphID id=\"45\" name=\"J\"/>\n",
#       "\t\t\t\t<GlyphID id=\"46\" name=\"K\"/>\n",
#       "\t\t\t\t<GlyphID id=\"47\" name=\"L\"/>\n",
#       "\t\t\t\t<GlyphID id=\"48\" name=\"M\"/>\n",
#       "\t\t\t\t<GlyphID id=\"49\" name=\"N\"/>\n",
#       "\t\t\t\t<GlyphID id=\"50\" name=\"O\"/>\n",
#       "\t\t\t\t<GlyphID id=\"51\" name=\"P\"/>\n",
#       "\t\t\t\t<GlyphID id=\"52\" name=\"Q\"/>\n",
#       "\t\t\t\t<GlyphID id=\"53\" name=\"R\"/>\n",
#       "\t\t\t\t<GlyphID id=\"54\" name=\"S\"/>\n",
#       "\t\t\t\t<GlyphID id=\"55\" name=\"T\"/>\n",
#       "\t\t\t\t<GlyphID id=\"56\" name=\"U\"/>\n",
#       "\t\t\t\t<GlyphID id=\"57\" name=\"V\"/>\n",
#       "\t\t\t\t<GlyphID id=\"58\" name=\"W\"/>\n",
#       "\t\t\t\t<GlyphID id=\"59\" name=\"X\"/>\n",
#       "\t\t\t\t<GlyphID id=\"60\" name=\"Y\"/>\n",
#       "\t\t\t\t<GlyphID id=\"61\" name=\"Z\"/>\n",
#       "\t\t\t\t<GlyphID id=\"62\" name=\"bracketleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"63\" name=\"backslash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"64\" name=\"bracketright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"65\" name=\"asciicircum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"66\" name=\"underscore\"/>\n",
#       "\t\t\t\t<GlyphID id=\"67\" name=\"grave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"68\" name=\"a\"/>\n",
#       "\t\t\t\t<GlyphID id=\"69\" name=\"b\"/>\n",
#       "\t\t\t\t<GlyphID id=\"70\" name=\"c\"/>\n",
#       "\t\t\t\t<GlyphID id=\"71\" name=\"d\"/>\n",
#       "\t\t\t\t<GlyphID id=\"72\" name=\"e\"/>\n",
#       "\t\t\t\t<GlyphID id=\"73\" name=\"f\"/>\n",
#       "\t\t\t\t<GlyphID id=\"74\" name=\"g\"/>\n",
#       "\t\t\t\t<GlyphID id=\"75\" name=\"h\"/>\n",
#       "\t\t\t\t<GlyphID id=\"76\" name=\"i\"/>\n",
#       "\t\t\t\t<GlyphID id=\"77\" name=\"j\"/>\n",
#       "\t\t\t\t<GlyphID id=\"78\" name=\"k\"/>\n",
#       "\t\t\t\t<GlyphID id=\"79\" name=\"l\"/>\n",
#       "\t\t\t\t<GlyphID id=\"80\" name=\"m\"/>\n",
#       "\t\t\t\t<GlyphID id=\"81\" name=\"n\"/>\n",
#       "\t\t\t\t<GlyphID id=\"82\" name=\"o\"/>\n",
#       "\t\t\t\t<GlyphID id=\"83\" name=\"p\"/>\n",
#       "\t\t\t\t<GlyphID id=\"84\" name=\"q\"/>\n",
#       "\t\t\t\t<GlyphID id=\"85\" name=\"r\"/>\n",
#       "\t\t\t\t<GlyphID id=\"86\" name=\"s\"/>\n",
#       "\t\t\t\t<GlyphID id=\"87\" name=\"t\"/>\n",
#       "\t\t\t\t<GlyphID id=\"88\" name=\"u\"/>\n",
#       "\t\t\t\t<GlyphID id=\"89\" name=\"v\"/>\n",
#       "\t\t\t\t<GlyphID id=\"90\" name=\"w\"/>\n",
#       "\t\t\t\t<GlyphID id=\"91\" name=\"x\"/>\n",
#       "\t\t\t\t<GlyphID id=\"92\" name=\"y\"/>\n",
#       "\t\t\t\t<GlyphID id=\"93\" name=\"z\"/>\n",
#       "\t\t\t\t<GlyphID id=\"94\" name=\"braceleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"95\" name=\"bar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"96\" name=\"braceright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"97\" name=\"asciitilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"98\" name=\"exclamdown\"/>\n",
#       "\t\t\t\t<GlyphID id=\"99\" name=\"cent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"100\" name=\"sterling\"/>\n",
#       "\t\t\t\t<GlyphID id=\"101\" name=\"currency\"/>\n",
#       "\t\t\t\t<GlyphID id=\"102\" name=\"yen\"/>\n",
#       "\t\t\t\t<GlyphID id=\"103\" name=\"brokenbar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"104\" name=\"section\"/>\n",
#       "\t\t\t\t<GlyphID id=\"105\" name=\"dieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"106\" name=\"copyright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"107\" name=\"ordfeminine\"/>\n",
#       "\t\t\t\t<GlyphID id=\"108\" name=\"guillemotleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"109\" name=\"logicalnot\"/>\n",
#       "\t\t\t\t<GlyphID id=\"110\" name=\"uni00AD\"/>\n",
#       "\t\t\t\t<GlyphID id=\"111\" name=\"registered\"/>\n",
#       "\t\t\t\t<GlyphID id=\"112\" name=\"macron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"113\" name=\"degree\"/>\n",
#       "\t\t\t\t<GlyphID id=\"114\" name=\"plusminus\"/>\n",
#       "\t\t\t\t<GlyphID id=\"115\" name=\"twosuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"116\" name=\"threesuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"117\" name=\"acute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"118\" name=\"uni00B5\"/>\n",
#       "\t\t\t\t<GlyphID id=\"119\" name=\"paragraph\"/>\n",
#       "\t\t\t\t<GlyphID id=\"120\" name=\"periodcentered\"/>\n",
#       "\t\t\t\t<GlyphID id=\"121\" name=\"cedilla\"/>\n",
#       "\t\t\t\t<GlyphID id=\"122\" name=\"onesuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"123\" name=\"ordmasculine\"/>\n",
#       "\t\t\t\t<GlyphID id=\"124\" name=\"guillemotright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"125\" name=\"onequarter\"/>\n",
#       "\t\t\t\t<GlyphID id=\"126\" name=\"onehalf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"127\" name=\"threequarters\"/>\n",
#       "\t\t\t\t<GlyphID id=\"128\" name=\"questiondown\"/>\n",
#       "\t\t\t\t<GlyphID id=\"129\" name=\"Agrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"130\" name=\"Aacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"131\" name=\"Acircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"132\" name=\"Atilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"133\" name=\"Adieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"134\" name=\"Aring\"/>\n",
#       "\t\t\t\t<GlyphID id=\"135\" name=\"AE\"/>\n",
#       "\t\t\t\t<GlyphID id=\"136\" name=\"Ccedilla\"/>\n",
#       "\t\t\t\t<GlyphID id=\"137\" name=\"Egrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"138\" name=\"Eacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"139\" name=\"Ecircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"140\" name=\"Edieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"141\" name=\"Igrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"142\" name=\"Iacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"143\" name=\"Icircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"144\" name=\"Idieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"145\" name=\"Eth\"/>\n",
#       "\t\t\t\t<GlyphID id=\"146\" name=\"Ntilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"147\" name=\"Ograve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"148\" name=\"Oacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"149\" name=\"Ocircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"150\" name=\"Otilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"151\" name=\"Odieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"152\" name=\"multiply\"/>\n",
#       "\t\t\t\t<GlyphID id=\"153\" name=\"Oslash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"154\" name=\"Ugrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"155\" name=\"Uacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"156\" name=\"Ucircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"157\" name=\"Udieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"158\" name=\"Yacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"159\" name=\"Thorn\"/>\n",
#       "\t\t\t\t<GlyphID id=\"160\" name=\"germandbls\"/>\n",
#       "\t\t\t\t<GlyphID id=\"161\" name=\"agrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"162\" name=\"aacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"163\" name=\"acircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"164\" name=\"atilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"165\" name=\"adieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"166\" name=\"aring\"/>\n",
#       "\t\t\t\t<GlyphID id=\"167\" name=\"ae\"/>\n",
#       "\t\t\t\t<GlyphID id=\"168\" name=\"ccedilla\"/>\n",
#       "\t\t\t\t<GlyphID id=\"169\" name=\"egrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"170\" name=\"eacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"171\" name=\"ecircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"172\" name=\"edieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"173\" name=\"igrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"174\" name=\"iacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"175\" name=\"icircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"176\" name=\"idieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"177\" name=\"eth\"/>\n",
#       "\t\t\t\t<GlyphID id=\"178\" name=\"ntilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"179\" name=\"ograve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"180\" name=\"oacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"181\" name=\"ocircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"182\" name=\"otilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"183\" name=\"odieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"184\" name=\"divide\"/>\n",
#       "\t\t\t\t<GlyphID id=\"185\" name=\"oslash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"186\" name=\"ugrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"187\" name=\"uacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"188\" name=\"ucircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"189\" name=\"udieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"190\" name=\"yacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"191\" name=\"thorn\"/>\n",
#       "\t\t\t\t<GlyphID id=\"192\" name=\"ydieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"193\" name=\"Amacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"194\" name=\"amacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"195\" name=\"Abreve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"196\" name=\"abreve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"197\" name=\"Aogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"198\" name=\"aogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"199\" name=\"Cacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"200\" name=\"cacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"201\" name=\"Ccircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"202\" name=\"ccircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"203\" name=\"Cdotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"204\" name=\"cdotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"205\" name=\"Ccaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"206\" name=\"ccaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"207\" name=\"Dcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"208\" name=\"dcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"209\" name=\"Dcroat\"/>\n",
#       "\t\t\t\t<GlyphID id=\"210\" name=\"dcroat\"/>\n",
#       "\t\t\t\t<GlyphID id=\"211\" name=\"Emacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"212\" name=\"emacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"213\" name=\"Edotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"214\" name=\"edotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"215\" name=\"Eogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"216\" name=\"eogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"217\" name=\"Ecaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"218\" name=\"ecaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"219\" name=\"Gcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"220\" name=\"gcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"221\" name=\"Gbreve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"222\" name=\"gbreve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"223\" name=\"Gdotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"224\" name=\"gdotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"225\" name=\"Gcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"226\" name=\"gcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"227\" name=\"Hcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"228\" name=\"hcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"229\" name=\"Hbar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"230\" name=\"hbar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"231\" name=\"Itilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"232\" name=\"itilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"233\" name=\"Imacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"234\" name=\"imacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"235\" name=\"Iogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"236\" name=\"iogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"237\" name=\"Idotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"238\" name=\"dotlessi\"/>\n",
#       "\t\t\t\t<GlyphID id=\"239\" name=\"Jcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"240\" name=\"jcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"241\" name=\"Kcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"242\" name=\"kcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"243\" name=\"kgreenlandic\"/>\n",
#       "\t\t\t\t<GlyphID id=\"244\" name=\"Lacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"245\" name=\"lacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"246\" name=\"Lcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"247\" name=\"lcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"248\" name=\"Lcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"249\" name=\"lcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"250\" name=\"Lslash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"251\" name=\"lslash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"252\" name=\"Nacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"253\" name=\"nacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"254\" name=\"Ncommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"255\" name=\"ncommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"256\" name=\"Ncaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"257\" name=\"ncaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"258\" name=\"Eng\"/>\n",
#       "\t\t\t\t<GlyphID id=\"259\" name=\"eng\"/>\n",
#       "\t\t\t\t<GlyphID id=\"260\" name=\"Omacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"261\" name=\"omacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"262\" name=\"Ohungarumlaut\"/>\n",
#       "\t\t\t\t<GlyphID id=\"263\" name=\"ohungarumlaut\"/>\n",
#       "\t\t\t\t<GlyphID id=\"264\" name=\"OE\"/>\n",
#       "\t\t\t\t<GlyphID id=\"265\" name=\"oe\"/>\n",
#       "\t\t\t\t<GlyphID id=\"266\" name=\"Racute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"267\" name=\"racute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"268\" name=\"Rcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"269\" name=\"rcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"270\" name=\"Rcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"271\" name=\"rcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"272\" name=\"Sacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"273\" name=\"sacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"274\" name=\"Scircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"275\" name=\"scircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"276\" name=\"Scedilla\"/>\n",
#       "\t\t\t\t<GlyphID id=\"277\" name=\"scedilla\"/>\n",
#       "\t\t\t\t<GlyphID id=\"278\" name=\"Scaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"279\" name=\"scaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"280\" name=\"Tcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"281\" name=\"tcommaaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"282\" name=\"Tcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"283\" name=\"tcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"284\" name=\"Tbar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"285\" name=\"tbar\"/>\n",
#       "\t\t\t\t<GlyphID id=\"286\" name=\"Utilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"287\" name=\"utilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"288\" name=\"Umacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"289\" name=\"umacron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"290\" name=\"Ubreve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"291\" name=\"ubreve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"292\" name=\"Uring\"/>\n",
#       "\t\t\t\t<GlyphID id=\"293\" name=\"uring\"/>\n",
#       "\t\t\t\t<GlyphID id=\"294\" name=\"Uhungarumlaut\"/>\n",
#       "\t\t\t\t<GlyphID id=\"295\" name=\"uhungarumlaut\"/>\n",
#       "\t\t\t\t<GlyphID id=\"296\" name=\"Uogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"297\" name=\"uogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"298\" name=\"Wcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"299\" name=\"wcircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"300\" name=\"Ycircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"301\" name=\"ycircumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"302\" name=\"Ydieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"303\" name=\"Zacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"304\" name=\"zacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"305\" name=\"Zdotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"306\" name=\"zdotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"307\" name=\"Zcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"308\" name=\"zcaron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"309\" name=\"florin\"/>\n",
#       "\t\t\t\t<GlyphID id=\"310\" name=\"circumflex\"/>\n",
#       "\t\t\t\t<GlyphID id=\"311\" name=\"caron\"/>\n",
#       "\t\t\t\t<GlyphID id=\"312\" name=\"breve\"/>\n",
#       "\t\t\t\t<GlyphID id=\"313\" name=\"dotaccent\"/>\n",
#       "\t\t\t\t<GlyphID id=\"314\" name=\"ring\"/>\n",
#       "\t\t\t\t<GlyphID id=\"315\" name=\"ogonek\"/>\n",
#       "\t\t\t\t<GlyphID id=\"316\" name=\"tilde\"/>\n",
#       "\t\t\t\t<GlyphID id=\"317\" name=\"hungarumlaut\"/>\n",
#       "\t\t\t\t<GlyphID id=\"318\" name=\"uni0338\"/>\n",
#       "\t\t\t\t<GlyphID id=\"319\" name=\"Omega\"/>\n",
#       "\t\t\t\t<GlyphID id=\"320\" name=\"pi\"/>\n",
#       "\t\t\t\t<GlyphID id=\"321\" name=\"uni1E02\"/>\n",
#       "\t\t\t\t<GlyphID id=\"322\" name=\"uni1E03\"/>\n",
#       "\t\t\t\t<GlyphID id=\"323\" name=\"uni1E0A\"/>\n",
#       "\t\t\t\t<GlyphID id=\"324\" name=\"uni1E0B\"/>\n",
#       "\t\t\t\t<GlyphID id=\"325\" name=\"uni1E1E\"/>\n",
#       "\t\t\t\t<GlyphID id=\"326\" name=\"uni1E1F\"/>\n",
#       "\t\t\t\t<GlyphID id=\"327\" name=\"uni1E40\"/>\n",
#       "\t\t\t\t<GlyphID id=\"328\" name=\"uni1E41\"/>\n",
#       "\t\t\t\t<GlyphID id=\"329\" name=\"uni1E56\"/>\n",
#       "\t\t\t\t<GlyphID id=\"330\" name=\"uni1E57\"/>\n",
#       "\t\t\t\t<GlyphID id=\"331\" name=\"uni1E60\"/>\n",
#       "\t\t\t\t<GlyphID id=\"332\" name=\"uni1E61\"/>\n",
#       "\t\t\t\t<GlyphID id=\"333\" name=\"uni1E6A\"/>\n",
#       "\t\t\t\t<GlyphID id=\"334\" name=\"uni1E6B\"/>\n",
#       "\t\t\t\t<GlyphID id=\"335\" name=\"Wgrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"336\" name=\"wgrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"337\" name=\"Wacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"338\" name=\"wacute\"/>\n",
#       "\t\t\t\t<GlyphID id=\"339\" name=\"Wdieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"340\" name=\"wdieresis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"341\" name=\"Ygrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"342\" name=\"ygrave\"/>\n",
#       "\t\t\t\t<GlyphID id=\"343\" name=\"endash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"344\" name=\"emdash\"/>\n",
#       "\t\t\t\t<GlyphID id=\"345\" name=\"quoteleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"346\" name=\"quoteright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"347\" name=\"quotesinglbase\"/>\n",
#       "\t\t\t\t<GlyphID id=\"348\" name=\"quotedblleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"349\" name=\"quotedblright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"350\" name=\"quotedblbase\"/>\n",
#       "\t\t\t\t<GlyphID id=\"351\" name=\"dagger\"/>\n",
#       "\t\t\t\t<GlyphID id=\"352\" name=\"daggerdbl\"/>\n",
#       "\t\t\t\t<GlyphID id=\"353\" name=\"bullet\"/>\n",
#       "\t\t\t\t<GlyphID id=\"354\" name=\"ellipsis\"/>\n",
#       "\t\t\t\t<GlyphID id=\"355\" name=\"perthousand\"/>\n",
#       "\t\t\t\t<GlyphID id=\"356\" name=\"guilsinglleft\"/>\n",
#       "\t\t\t\t<GlyphID id=\"357\" name=\"guilsinglright\"/>\n",
#       "\t\t\t\t<GlyphID id=\"358\" name=\"fraction\"/>\n",
#       "\t\t\t\t<GlyphID id=\"359\" name=\"zerosuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"360\" name=\"foursuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"361\" name=\"fivesuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"362\" name=\"sixsuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"363\" name=\"sevensuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"364\" name=\"eightsuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"365\" name=\"ninesuperior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"366\" name=\"zeroinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"367\" name=\"oneinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"368\" name=\"twoinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"369\" name=\"threeinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"370\" name=\"fourinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"371\" name=\"fiveinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"372\" name=\"sixinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"373\" name=\"seveninferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"374\" name=\"eightinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"375\" name=\"nineinferior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"376\" name=\"Euro\"/>\n",
#       "\t\t\t\t<GlyphID id=\"377\" name=\"afii61289\"/>\n",
#       "\t\t\t\t<GlyphID id=\"378\" name=\"afii61352\"/>\n",
#       "\t\t\t\t<GlyphID id=\"379\" name=\"trademark\"/>\n",
#       "\t\t\t\t<GlyphID id=\"380\" name=\"estimated\"/>\n",
#       "\t\t\t\t<GlyphID id=\"381\" name=\"partialdiff\"/>\n",
#       "\t\t\t\t<GlyphID id=\"382\" name=\"uni2206\"/>\n",
#       "\t\t\t\t<GlyphID id=\"383\" name=\"product\"/>\n",
#       "\t\t\t\t<GlyphID id=\"384\" name=\"summation\"/>\n",
#       "\t\t\t\t<GlyphID id=\"385\" name=\"minus\"/>\n",
#       "\t\t\t\t<GlyphID id=\"386\" name=\"radical\"/>\n",
#       "\t\t\t\t<GlyphID id=\"387\" name=\"infinity\"/>\n",
#       "\t\t\t\t<GlyphID id=\"388\" name=\"integral\"/>\n",
#       "\t\t\t\t<GlyphID id=\"389\" name=\"approxequal\"/>\n",
#       "\t\t\t\t<GlyphID id=\"390\" name=\"notequal\"/>\n",
#       "\t\t\t\t<GlyphID id=\"391\" name=\"lessequal\"/>\n",
#       "\t\t\t\t<GlyphID id=\"392\" name=\"greaterequal\"/>\n",
#       "\t\t\t\t<GlyphID id=\"393\" name=\"lozenge\"/>\n",
#       "\t\t\t\t<GlyphID id=\"394\" name=\"f_f\"/>\n",
#       "\t\t\t\t<GlyphID id=\"395\" name=\"fi\"/>\n",
#       "\t\t\t\t<GlyphID id=\"396\" name=\"fl\"/>\n",
#       "\t\t\t\t<GlyphID id=\"397\" name=\"f_f_i\"/>\n",
#       "\t\t\t\t<GlyphID id=\"398\" name=\"ffl\"/>\n",
#       "\t\t\t\t<GlyphID id=\"399\" name=\"s_t\"/>\n",
#       "\t\t\t\t<GlyphID id=\"400\" name=\"exclamdown.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"401\" name=\"zero.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"402\" name=\"one.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"403\" name=\"two.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"404\" name=\"three.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"405\" name=\"four.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"406\" name=\"five.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"407\" name=\"six.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"408\" name=\"seven.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"409\" name=\"eight.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"410\" name=\"nine.oldstyle\"/>\n",
#       "\t\t\t\t<GlyphID id=\"411\" name=\"questiondown.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"412\" name=\"at.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"413\" name=\"g.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"414\" name=\"ampersand.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"415\" name=\"a.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"416\" name=\"b.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"417\" name=\"c.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"418\" name=\"d.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"419\" name=\"e.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"420\" name=\"f.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"421\" name=\"g.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"422\" name=\"h.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"423\" name=\"i.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"424\" name=\"j.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"425\" name=\"k.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"426\" name=\"l.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"427\" name=\"m.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"428\" name=\"n.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"429\" name=\"o.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"430\" name=\"p.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"431\" name=\"q.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"432\" name=\"r.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"433\" name=\"s.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"434\" name=\"t.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"435\" name=\"u.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"436\" name=\"v.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"437\" name=\"w.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"438\" name=\"x.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"439\" name=\"y.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"440\" name=\"z.superior\"/>\n",
#       "\t\t\t\t<GlyphID id=\"441\" name=\"zero.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"442\" name=\"one.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"443\" name=\"two.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"444\" name=\"three.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"445\" name=\"four.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"446\" name=\"five.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"447\" name=\"six.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"448\" name=\"seven.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"449\" name=\"eight.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"450\" name=\"nine.tnum\"/>\n",
#       "\t\t\t\t<GlyphID id=\"451\" name=\"zero.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"452\" name=\"one.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"453\" name=\"two.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"454\" name=\"three.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"455\" name=\"four.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"456\" name=\"five.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"457\" name=\"six.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"458\" name=\"seven.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"459\" name=\"eight.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"460\" name=\"nine.tosf\"/>\n",
#       "\t\t\t\t<GlyphID id=\"461\" name=\"gbreve.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"462\" name=\"gdotaccent.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"463\" name=\"gcircumflex.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"464\" name=\"c_t\"/>\n",
#       "\t\t\t\t<GlyphID id=\"465\" name=\"t_t\"/>\n",
#       "\t\t\t\t<GlyphID id=\"466\" name=\"f_t\"/>\n",
#       "\t\t\t\t<GlyphID id=\"467\" name=\"t_y\"/>\n",
#       "\t\t\t\t<GlyphID id=\"468\" name=\"f_y\"/>\n",
#       "\t\t\t\t<GlyphID id=\"469\" name=\"gcommaaccent.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"470\" name=\"exclam.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"471\" name=\"quotedbl.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"472\" name=\"numbersign.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"473\" name=\"dollar.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"474\" name=\"percent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"475\" name=\"ampersand.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"476\" name=\"quotesingle.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"477\" name=\"asterisk.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"478\" name=\"zero.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"479\" name=\"one.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"480\" name=\"two.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"481\" name=\"three.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"482\" name=\"four.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"483\" name=\"five.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"484\" name=\"six.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"485\" name=\"seven.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"486\" name=\"eight.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"487\" name=\"nine.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"488\" name=\"question.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"489\" name=\"at.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"490\" name=\"a.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"491\" name=\"b.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"492\" name=\"c.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"493\" name=\"d.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"494\" name=\"e.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"495\" name=\"f.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"496\" name=\"g.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"497\" name=\"h.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"498\" name=\"i.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"499\" name=\"j.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"500\" name=\"k.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"501\" name=\"l.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"502\" name=\"m.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"503\" name=\"n.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"504\" name=\"o.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"505\" name=\"p.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"506\" name=\"q.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"507\" name=\"r.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"508\" name=\"s.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"509\" name=\"t.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"510\" name=\"u.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"511\" name=\"v.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"512\" name=\"w.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"513\" name=\"x.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"514\" name=\"y.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"515\" name=\"z.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"516\" name=\"grave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"517\" name=\"aogonek.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"518\" name=\"rcommaaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"519\" name=\"itilde.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"520\" name=\"lcommaaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"521\" name=\"dieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"522\" name=\"scaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"523\" name=\"emacron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"524\" name=\"gcommaaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"525\" name=\"tbar.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"526\" name=\"zcaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"527\" name=\"macron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"528\" name=\"degree.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"529\" name=\"acute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"530\" name=\"caron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"531\" name=\"eng.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"532\" name=\"amacron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"533\" name=\"aacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"534\" name=\"acircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"535\" name=\"atilde.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"536\" name=\"adieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"537\" name=\"aring.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"538\" name=\"ae.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"539\" name=\"iogonek.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"540\" name=\"ccaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"541\" name=\"eacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"542\" name=\"eogonek.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"543\" name=\"edieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"544\" name=\"edotaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"545\" name=\"iacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"546\" name=\"icircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"547\" name=\"imacron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"548\" name=\"dcroat.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"549\" name=\"ncommaaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"550\" name=\"omacron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"551\" name=\"kcommaaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"552\" name=\"ocircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"553\" name=\"otilde.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"554\" name=\"odieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"555\" name=\"oslash.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"556\" name=\"uogonek.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"557\" name=\"uacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"558\" name=\"ucircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"559\" name=\"udieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"560\" name=\"utilde.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"561\" name=\"umacron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"562\" name=\"germandbls.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"563\" name=\"agrave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"564\" name=\"ccedilla.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"565\" name=\"eth.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"566\" name=\"egrave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"567\" name=\"ecircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"568\" name=\"igrave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"569\" name=\"idieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"570\" name=\"ntilde.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"571\" name=\"ograve.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"572\" name=\"oacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"573\" name=\"ugrave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"574\" name=\"yacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"575\" name=\"thorn.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"576\" name=\"quotesinglbase.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"577\" name=\"quotedblleft.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"578\" name=\"quotedblright.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"579\" name=\"quotedblbase.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"580\" name=\"exclamdown.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"581\" name=\"ordmasculine.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"582\" name=\"ordfeminine.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"583\" name=\"Euro.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"584\" name=\"lcaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"585\" name=\"sacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"586\" name=\"scedilla.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"587\" name=\"tcaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"588\" name=\"zacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"589\" name=\"zdotaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"590\" name=\"racute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"591\" name=\"abreve.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"592\" name=\"lacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"593\" name=\"cacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"594\" name=\"ecaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"595\" name=\"dcaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"596\" name=\"nacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"597\" name=\"ncaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"598\" name=\"ohungarumlaut.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"599\" name=\"rcaron.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"600\" name=\"uring.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"601\" name=\"uhungarumlaut.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"602\" name=\"tcommaaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"603\" name=\"lslash.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"604\" name=\"questiondown.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"605\" name=\"oe.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"606\" name=\"ydieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"607\" name=\"sterling.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"608\" name=\"yen.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"609\" name=\"perthousand.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"610\" name=\"circumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"611\" name=\"tilde.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"612\" name=\"ring.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"613\" name=\"hbar.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"614\" name=\"hcircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"615\" name=\"gbreve.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"616\" name=\"jcircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"617\" name=\"cdotaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"618\" name=\"ccircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"619\" name=\"gdotaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"620\" name=\"gcircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"621\" name=\"ubreve.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"622\" name=\"scircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"623\" name=\"Idotaccent.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"624\" name=\"periodcentered.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"625\" name=\"bullet.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"626\" name=\"quoteleft.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"627\" name=\"quoteright.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"628\" name=\"uni1E03.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"629\" name=\"uni1E0B.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"630\" name=\"uni1E1F.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"631\" name=\"uni1E41.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"632\" name=\"wgrave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"633\" name=\"uni1E57.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"634\" name=\"wacute.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"635\" name=\"ygrave.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"636\" name=\"wdieresis.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"637\" name=\"uni1E61.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"638\" name=\"wcircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"639\" name=\"uni1E6B.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"640\" name=\"ycircumflex.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"641\" name=\"c_k\"/>\n",
#       "\t\t\t\t<GlyphID id=\"642\" name=\"N.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"643\" name=\"M.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"644\" name=\"uni1E40.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"645\" name=\"Ntilde.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"646\" name=\"Nacute.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"647\" name=\"Ncaron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"648\" name=\"Ncommaaccent.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"649\" name=\"zero.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"650\" name=\"one.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"651\" name=\"two.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"652\" name=\"three.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"653\" name=\"four.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"654\" name=\"five.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"655\" name=\"six.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"656\" name=\"seven.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"657\" name=\"eight.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"658\" name=\"nine.numerator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"659\" name=\"zero.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"660\" name=\"one.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"661\" name=\"two.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"662\" name=\"three.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"663\" name=\"four.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"664\" name=\"five.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"665\" name=\"six.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"666\" name=\"seven.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"667\" name=\"eight.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"668\" name=\"nine.denominator\"/>\n",
#       "\t\t\t\t<GlyphID id=\"669\" name=\"c_h\"/>\n",
#       "\t\t\t\t<GlyphID id=\"670\" name=\"m.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"671\" name=\"n.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"672\" name=\"ntilde.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"673\" name=\"ncommaaccent.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"674\" name=\"ncaron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"675\" name=\"nacute.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"676\" name=\"uni1E41.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"677\" name=\"r.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"678\" name=\"racute.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"679\" name=\"rcaron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"680\" name=\"rcommaaccent.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"681\" name=\"x.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"682\" name=\"X.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"683\" name=\"a.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"684\" name=\"agrave.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"685\" name=\"aacute.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"686\" name=\"atilde.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"687\" name=\"aring.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"688\" name=\"acircumflex.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"689\" name=\"adieresis.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"690\" name=\"aogonek.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"691\" name=\"abreve.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"692\" name=\"amacron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"693\" name=\"u.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"694\" name=\"uhungarumlaut.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"695\" name=\"ugrave.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"696\" name=\"uacute.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"697\" name=\"utilde.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"698\" name=\"uring.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"699\" name=\"ucircumflex.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"700\" name=\"udieresis.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"701\" name=\"uogonek.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"702\" name=\"ubreve.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"703\" name=\"umacron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"704\" name=\"b.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"705\" name=\"d.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"706\" name=\"f.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"707\" name=\"p.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"708\" name=\"t.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"709\" name=\"uni1E03.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"710\" name=\"uni1E0B.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"711\" name=\"uni1E1F.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"712\" name=\"uni1E57.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"713\" name=\"dcroat.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"714\" name=\"tbar.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"715\" name=\"tcommaaccent.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"716\" name=\"tcaron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"717\" name=\"dcaron.salt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"718\" name=\"hyphen.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"719\" name=\"uni00AD.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"720\" name=\"endash.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"721\" name=\"emdash.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"722\" name=\"hyphen.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"723\" name=\"uni00AD.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"724\" name=\"endash.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"725\" name=\"emdash.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"726\" name=\"parenleft.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"727\" name=\"parenright.alt\"/>\n",
#       "\t\t\t\t<GlyphID id=\"728\" name=\"parenleft.smcp\"/>\n",
#       "\t\t\t\t<GlyphID id=\"729\" name=\"parenright.smcp\"/>\n",
#       "\t\t\t  </GlyphOrder>\n",
#       "\n",
#       "\t\t\t  <head>\n",
#       "\t\t\t\t<!-- Most of this table will be recalculated by the compiler -->\n",
#       "\t\t\t\t<tableVersion value=\"1.0\"/>\n",
#       "\t\t\t\t<fontRevision value=\"1.0\"/>\n",
#       "\t\t\t\t<checkSumAdjustment value=\"0xce9e49c4\"/>\n",
#       "\t\t\t\t<magicNumber value=\"0x5f0f3cf5\"/>\n",
#       "\t\t\t\t<flags value=\"00000000 00001011\"/>\n",
#       "\t\t\t\t<unitsPerEm value=\"1000\"/>\n",
#       "\t\t\t\t<created value=\"Fri Feb  3 21:37:00 2012\"/>\n",
#       "\t\t\t\t<modified value=\"Fri Feb  3 21:37:00 2012\"/>\n",
#       "\t\t\t\t<xMin value=\"-101\"/>\n",
#       "\t\t\t\t<yMin value=\"-315\"/>\n",
#       "\t\t\t\t<xMax value=\"1424\"/>\n",
#       "\t\t\t\t<yMax value=\"1002\"/>\n",
#       "\t\t\t\t<macStyle value=\"00000000 00000001\"/>\n",
#       "\t\t\t\t<lowestRecPPEM value=\"8\"/>\n",
#       "\t\t\t\t<fontDirectionHint value=\"2\"/>\n",
#       "\t\t\t\t<indexToLocFormat value=\"0\"/>\n",
#       "\t\t\t\t<glyphDataFormat value=\"0\"/>\n",
#       "\t\t\t  </head>\n",
#       "\n",
#       "\t\t\t  <hhea>\n",
#       "\t\t\t\t<tableVersion value=\"0x00010000\"/>\n",
#       "\t\t\t\t<ascent value=\"1002\"/>\n",
#       "\t\t\t\t<descent value=\"-326\"/>\n",
#       "\t\t\t\t<lineGap value=\"0\"/>\n",
#       "\t\t\t\t<advanceWidthMax value=\"1446\"/>\n",
#       "\t\t\t\t<minLeftSideBearing value=\"-101\"/>\n",
#       "\t\t\t\t<minRightSideBearing value=\"-63\"/>\n",
#       "\t\t\t\t<xMaxExtent value=\"1424\"/>\n",
#       "\t\t\t\t<caretSlopeRise value=\"1\"/>\n",
#       "\t\t\t\t<caretSlopeRun value=\"0\"/>\n",
#       "\t\t\t\t<caretOffset value=\"0\"/>\n",
#       "\t\t\t\t<reserved0 value=\"0\"/>\n",
#       "\t\t\t\t<reserved1 value=\"0\"/>\n",
#       "\t\t\t\t<reserved2 value=\"0\"/>\n",
#       "\t\t\t\t<reserved3 value=\"0\"/>\n",
#       "\t\t\t\t<metricDataFormat value=\"0\"/>\n",
#       "\t\t\t\t<numberOfHMetrics value=\"729\"/>\n",
#       "\t\t\t  </hhea>\n",
#       "\n",
#       "\t\t\t  <maxp>\n",
#       "\t\t\t\t<!-- Most of this table will be recalculated by the compiler -->\n",
#       "\t\t\t\t<tableVersion value=\"0x10000\"/>\n",
#       "\t\t\t\t<numGlyphs value=\"730\"/>\n",
#       "\t\t\t\t<maxPoints value=\"102\"/>\n",
#       "\t\t\t\t<maxContours value=\"7\"/>\n",
#       "\t\t\t\t<maxCompositePoints value=\"0\"/>\n",
#       "\t\t\t\t<maxCompositeContours value=\"0\"/>\n",
#       "\t\t\t\t<maxZones value=\"2\"/>\n",
#       "\t\t\t\t<maxTwilightPoints value=\"0\"/>\n",
#       "\t\t\t\t<maxStorage value=\"1\"/>\n",
#       "\t\t\t\t<maxFunctionDefs value=\"1\"/>\n",
#       "\t\t\t\t<maxInstructionDefs value=\"0\"/>\n",
#       "\t\t\t\t<maxStackElements value=\"64\"/>\n",
#       "\t\t\t\t<maxSizeOfInstructions value=\"0\"/>\n",
#       "\t\t\t\t<maxComponentElements value=\"0\"/>\n",
#       "\t\t\t\t<maxComponentDepth value=\"0\"/>\n",
#       "\t\t\t  </maxp>\n",
#       "\n",
#       "\t\t\t  <OS_2>\n",
#       "\t\t\t\t<!-- The fields 'usFirstCharIndex' and 'usLastCharIndex'\n",
#       "\t\t\t\t\t will be recalculated by the compiler -->\n",
#       "\t\t\t\t<version value=\"4\"/>\n",
#       "\t\t\t\t<xAvgCharWidth value=\"548\"/>\n",
#       "\t\t\t\t<usWeightClass value=\"900\"/>\n",
#       "\t\t\t\t<usWidthClass value=\"5\"/>\n",
#       "\t\t\t\t<fsType value=\"00000000 00000000\"/>\n",
#       "\t\t\t\t<ySubscriptXSize value=\"650\"/>\n",
#       "\t\t\t\t<ySubscriptYSize value=\"700\"/>\n",
#       "\t\t\t\t<ySubscriptXOffset value=\"0\"/>\n",
#       "\t\t\t\t<ySubscriptYOffset value=\"140\"/>\n",
#       "\t\t\t\t<ySuperscriptXSize value=\"650\"/>\n",
#       "\t\t\t\t<ySuperscriptYSize value=\"700\"/>\n",
#       "\t\t\t\t<ySuperscriptXOffset value=\"0\"/>\n",
#       "\t\t\t\t<ySuperscriptYOffset value=\"480\"/>\n",
#       "\t\t\t\t<yStrikeoutSize value=\"49\"/>\n",
#       "\t\t\t\t<yStrikeoutPosition value=\"258\"/>\n",
#       "\t\t\t\t<sFamilyClass value=\"0\"/>\n",
#       "\t\t\t\t<panose>\n",
# ...
#       "\t\t\t\t\t  <Substitution in=\"three\" out=\"three.tnum\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"three.oldstyle\" out=\"three.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"two\" out=\"two.tnum\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"two.oldstyle\" out=\"two.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"zero\" out=\"zero.tnum\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"zero.oldstyle\" out=\"zero.tosf\"/>\n",
#       "\t\t\t\t\t</SingleSubst>\n",
#       "\t\t\t\t  </Lookup>\n",
#       "\t\t\t\t  <Lookup index=\"15\">\n",
#       "\t\t\t\t\t<LookupType value=\"1\"/>\n",
#       "\t\t\t\t\t<LookupFlag value=\"0\"/>\n",
#       "\t\t\t\t\t<!-- SubTableCount=1 -->\n",
#       "\t\t\t\t\t<SingleSubst index=\"0\" Format=\"2\">\n",
#       "\t\t\t\t\t  <Substitution in=\"eight\" out=\"eight.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"eight.tnum\" out=\"eight.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"five\" out=\"five.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"five.tnum\" out=\"five.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"four\" out=\"four.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"four.tnum\" out=\"four.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"nine\" out=\"nine.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"nine.tnum\" out=\"nine.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"one\" out=\"one.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"one.tnum\" out=\"one.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"seven\" out=\"seven.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"seven.tnum\" out=\"seven.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"six\" out=\"six.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"six.tnum\" out=\"six.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"three\" out=\"three.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"three.tnum\" out=\"three.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"two\" out=\"two.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"two.tnum\" out=\"two.tosf\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"zero\" out=\"zero.oldstyle\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"zero.tnum\" out=\"zero.tosf\"/>\n",
#       "\t\t\t\t\t</SingleSubst>\n",
#       "\t\t\t\t  </Lookup>\n",
#       "\t\t\t\t  <Lookup index=\"16\">\n",
#       "\t\t\t\t\t<LookupType value=\"3\"/>\n",
#       "\t\t\t\t\t<LookupFlag value=\"0\"/>\n",
#       "\t\t\t\t\t<!-- SubTableCount=1 -->\n",
#       "\t\t\t\t\t<AlternateSubst index=\"0\" Format=\"1\">\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"M\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"M.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"N\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"N.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"Nacute\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"Nacute.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"Ncaron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"Ncaron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"Ncommaaccent\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"Ncommaaccent.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"Ntilde\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"Ntilde.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"X\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"X.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"a\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"a.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"aacute\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"aacute.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"acircumflex\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"acircumflex.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"adieresis\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"adieresis.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"agrave\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"agrave.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"amacron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"amacron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ampersand\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ampersand.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"aogonek\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"aogonek.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"aring\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"aring.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"atilde\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"atilde.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"b\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"b.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"d\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"d.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"dcaron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"dcaron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"dcroat\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"dcroat.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"f\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"f.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"g\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"g.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"gbreve\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"gbreve.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"gcircumflex\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"gcircumflex.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"gcommaaccent\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"gcommaaccent.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"gdotaccent\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"gdotaccent.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"m\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"m.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"n\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"n.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"nacute\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"nacute.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ncaron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ncaron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ncommaaccent\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ncommaaccent.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ntilde\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ntilde.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"p\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"p.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"r\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"r.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"racute\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"racute.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"rcaron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"rcaron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"rcommaaccent\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"rcommaaccent.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"t\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"t.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"tbar\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"tbar.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"tcaron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"tcaron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"tcommaaccent\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"tcommaaccent.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"u\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"u.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uacute\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uacute.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ubreve\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ubreve.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ucircumflex\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ucircumflex.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"udieresis\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"udieresis.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"ugrave\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"ugrave.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uhungarumlaut\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uhungarumlaut.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"umacron\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"umacron.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uni1E03\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uni1E03.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uni1E0B\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uni1E0B.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uni1E1F\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uni1E1F.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uni1E40\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uni1E40.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uni1E41\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uni1E41.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uni1E57\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uni1E57.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uogonek\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uogonek.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"uring\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"uring.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"utilde\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"utilde.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t  <AlternateSet glyph=\"x\">\n",
#       "\t\t\t\t\t\t<Alternate glyph=\"x.salt\"/>\n",
#       "\t\t\t\t\t  </AlternateSet>\n",
#       "\t\t\t\t\t</AlternateSubst>\n",
#       "\t\t\t\t  </Lookup>\n",
#       "\t\t\t\t  <Lookup index=\"17\">\n",
#       "\t\t\t\t\t<LookupType value=\"1\"/>\n",
#       "\t\t\t\t\t<LookupFlag value=\"0\"/>\n",
#       "\t\t\t\t\t<!-- SubTableCount=1 -->\n",
#       "\t\t\t\t\t<SingleSubst index=\"0\" Format=\"2\">\n",
#       "\t\t\t\t\t  <Substitution in=\"eight\" out=\"eightsuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"five\" out=\"fivesuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"four\" out=\"foursuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"nine\" out=\"ninesuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"one\" out=\"onesuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"seven\" out=\"sevensuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"six\" out=\"sixsuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"three\" out=\"threesuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"two\" out=\"twosuperior\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"zero\" out=\"zerosuperior\"/>\n",
#       "\t\t\t\t\t</SingleSubst>\n",
#       "\t\t\t\t  </Lookup>\n",
#       "\t\t\t\t  <Lookup index=\"18\">\n",
#       "\t\t\t\t\t<LookupType value=\"1\"/>\n",
#       "\t\t\t\t\t<LookupFlag value=\"0\"/>\n",
#       "\t\t\t\t\t<!-- SubTableCount=1 -->\n",
#       "\t\t\t\t\t<SingleSubst index=\"0\" Format=\"2\">\n",
#       "\t\t\t\t\t  <Substitution in=\"at\" out=\"at.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"emdash\" out=\"emdash.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"endash\" out=\"endash.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"exclamdown\" out=\"exclamdown.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"hyphen\" out=\"hyphen.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"parenleft\" out=\"parenleft.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"parenright\" out=\"parenright.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"questiondown\" out=\"questiondown.alt\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"uni00AD\" out=\"uni00AD.alt\"/>\n",
#       "\t\t\t\t\t</SingleSubst>\n",
#       "\t\t\t\t  </Lookup>\n",
#       "\t\t\t\t  <Lookup index=\"19\">\n",
#       "\t\t\t\t\t<LookupType value=\"1\"/>\n",
#       "\t\t\t\t\t<LookupFlag value=\"0\"/>\n",
#       "\t\t\t\t\t<!-- SubTableCount=1 -->\n",
#       "\t\t\t\t\t<SingleSubst index=\"0\" Format=\"1\">\n",
#       "\t\t\t\t\t  <Substitution in=\"eight\" out=\"eight.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"five\" out=\"five.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"four\" out=\"four.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"nine\" out=\"nine.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"one\" out=\"one.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"seven\" out=\"seven.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"six\" out=\"six.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"three\" out=\"three.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"two\" out=\"two.denominator\"/>\n",
#       "\t\t\t\t\t  <Substitution in=\"zero\" out=\"zero.denominator\"/>\n",
#       "\t\t\t\t\t</SingleSubst>\n",
#       "\t\t\t\t  </Lookup>\n",
#       "\t\t\t\t</LookupList>\n",
#       "\t\t\t  </GSUB>\n",
#       "\n",
#       "\t\t\t  <DSIG>\n",
#       "\t\t\t\t<!-- note that the Digital Signature will be invalid after recompilation! -->\n",
#       "\t\t\t\t<tableHeader flag=\"0x0\" numSigs=\"0\" version=\"1\"/>\n",
#       "\t\t\t  </DSIG>\n",
#       "\n",
#       "\t\t\t</ttFont>\n",
#       "\t\t\t\n"
#      ]
#     }
#    ],
#    "source": [
#     "import Black\n",
#     "from Black import FNT\n",
#     "print FNT()"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "metadata": {},
#    "outputs": [],
#    "source": []
#   }
#  ],
#  "metadata": {
#   "kernelspec": {
#    "display_name": "DefaultPY",
#    "language": "python",
#    "name": "default_py"
#   },
#   "language_info": {
#    "codemirror_mode": {
#     "name": "ipython",
#     "version": 2
#    },
#    "file_extension": ".py",
#    "mimetype": "text/x-python",
#    "name": "python",
#    "nbconvert_exporter": "python",
#    "pygments_lexer": "ipython2",
#    "version": "2.7.14"
#   }
#  },
#  "nbformat": 4,
#  "nbformat_minor": 2
# }
#
# Desktop_JupyterNotebook-Graphics_import-Black152491175686152491175686_import-Black152491175686152491175686.ipynb
