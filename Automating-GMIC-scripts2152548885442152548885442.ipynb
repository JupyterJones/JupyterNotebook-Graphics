# %%
count = 0
while True:
    filein = LST[count]
    print count,filein
    count = count +1
    if count==114:break

# %%
import os
import random
path0 = r"640x640/"
random_filename0 = random.choice([
y for y in os.listdir(path0)
if os.path.isfile(os.path.join(path0, y)) ])
RandIm = path0+random_filename0
# !gmic -i 640x640/P_20180411_062100.jpg \
-v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
-o cartoon0022A.jpg
# !showme cartoon0022A.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/P_20180411_062100.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set verbosity level to 0.
# [gmic]-1./ Apply cartoon effect on image [0], with smoothness 1, sharpening 124.771, threshold 20, thickness 0.5, color 1.5 and quantization 8.
# [gmic]-1./ Output image [0] as jpg file 'cartoon0022A.jpg', with quality 100% (1 image 640x640x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
import os
import random
path0 = r"640x640/"
random_filename0 = random.choice([
y for y in os.listdir(path0)
if os.path.isfile(os.path.join(path0, y)) ])
RandIm = path0+random_filename0
# !gmic -i 640x640/P_20180411_062100.jpg \
-v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
-o cartoon0022A.jpg
# !showme cartoon0022A.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/P_20180411_062100.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set verbosity level to 0.
# [gmic]-1./ Apply cartoon effect on image [0], with smoothness 1, sharpening 124.771, threshold 20, thickness 0.5, color 1.5 and quantization 8.
# [gmic]-1./ Output image [0] as jpg file 'cartoon0022A.jpg', with quality 100% (1 image 640x640x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
f = open("640x640.list").readlines()
LST = []
for lines in f:
    line = lines.replace("\n","")
    PATH = "640x640/"+line
    LST.append(PATH)

# %%
# !ls 640x640/P_20180416_164243.jpg
# Out:
# 640x640/P_20180416_164243.jpg

# %%
# !ls cartoon
# Out:
# 20180501085921_000000.jpg  20180501085921_000001.jpg

# %%
# WORKS GOOD cartoon
# 114 images in 640x640.list
import subprocess
count = 0
filein = LST[0]
filein = filein.replace("\n","")
count = count +1
print count,line
filename = time.strftime("cartoon/%Y%m%d%H%M%S.jpg")
com ="gmic -input "+filein+ "-resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% \
-quantize[-1] 10  -output "+filename+", shell=True"
subprocess.call(com)
# Out:
# 1 640x640/P_20180416_164243.jpg
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-52-6a10e6dc617c> in <module>()
#       9 filename = time.strftime("cartoon/%Y%m%d%H%M%S.jpg")
#      10 com ="gmic -input "+filein+ "-resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% -quantize[-1] 10  -output "+filename+", shell=True"
# ---> 11 subprocess.call(com)
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in call(*popenargs, **kwargs)
#     166     retcode = call(["ls", "-l"])
#     167     """
# --> 168     return Popen(*popenargs, **kwargs).wait()
#     169
#     170
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     388                                 p2cread, p2cwrite,
#     389                                 c2pread, c2pwrite,
# --> 390                                 errread, errwrite)
#     391         except Exception:
#     392             # Preserve original exception in case os.close raises.
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#    1023                         raise
#    1024                 child_exception = pickle.loads(data)
# -> 1025                 raise child_exception
#    1026
#    1027
#
# OSError: [Errno 2] No such file or directory

# %%
import subprocess
import os
filein = LST[0]
filein = filein.replace("\n","")
count = count +1
print count,line
filename = time.strftime("cartoon/%Y%m%d%H%M%S.jpg")

com ="gmic -input "+filein+ " -resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% \
-quantize[-1] 10  -output "+filename+", shell=True"
subprocess.call(com)
# Out:
# 3 640x640/P_20180416_164243.jpg
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-55-871c63b14de3> in <module>()
#       8
#       9 com ="gmic -input "+filein+ " -resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% -quantize[-1] 10  -output "+filename+", shell=True"
# ---> 10 subprocess.call(com)
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in call(*popenargs, **kwargs)
#     166     retcode = call(["ls", "-l"])
#     167     """
# --> 168     return Popen(*popenargs, **kwargs).wait()
#     169
#     170
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     388                                 p2cread, p2cwrite,
#     389                                 c2pread, c2pwrite,
# --> 390                                 errread, errwrite)
#     391         except Exception:
#     392             # Preserve original exception in case os.close raises.
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#    1023                         raise
#    1024                 child_exception = pickle.loads(data)
# -> 1025                 raise child_exception
#    1026
#    1027
#
# OSError: [Errno 2] No such file or directory

# %%
# !ls 640x640/P_20180416_164243.jpg
# Out:
# 640x640/P_20180416_164243.jpg

# %%
import subprocess
import os
import time
filein = LST[0]
filein = filein.replace("\n","")
count = count +1
print count,line
filename = time.strftime("cartoon/%Y%m%d%H%M%S.jpg")

com =["gmic -input 640x640/P_20180416_164243.jpg -resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% \
-quantize[-1] 10  -output TESTING.jpg"]
subprocess.call(com)
# Out:
# 10 640x640/P_20180416_164243.jpg
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-64-7f5804731c97> in <module>()
#       9
#      10 com =["gmic -input 640x640/P_20180416_164243.jpg -resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% -quantize[-1] 10  -output TESTING.jpg"]
# ---> 11 subprocess.call(com)
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in call(*popenargs, **kwargs)
#     166     retcode = call(["ls", "-l"])
#     167     """
# --> 168     return Popen(*popenargs, **kwargs).wait()
#     169
#     170
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags)
#     388                                 p2cread, p2cwrite,
#     389                                 c2pread, c2pwrite,
# --> 390                                 errread, errwrite)
#     391         except Exception:
#     392             # Preserve original exception in case os.close raises.
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in _execute_child(self, args, executable, preexec_fn, close_fds, cwd, env, universal_newlines, startupinfo, creationflags, shell, to_close, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite)
#    1023                         raise
#    1024                 child_exception = pickle.loads(data)
# -> 1025                 raise child_exception
#    1026
#    1027
#
# OSError: [Errno 2] No such file or directory

# %%
# cartoon Images
# !gmic -i /home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180416_163956_BF.jpg \
-v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
-normalize[-0] 60,255 \
-o cartoon0022A.jpg
# !showme cartoon0022A.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180416_163956_BF.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set verbosity level to 0.
# [gmic]-1./ Apply cartoon effect on image [0], with smoothness 1, sharpening 124.771, threshold 20, thickness 0.5, color 1.5 and quantization 8.
# [gmic]-1./ Normalize image [0] in range [60,255].
# [gmic]-1./ Output image [0] as jpg file 'cartoon0022A.jpg', with quality 100% (1 image 640x640x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
# cartoon Images
# !gmic -i /home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180416_163956_BF.jpg \
-v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
-normalize[-0] 60,255 \
-o cartoon0022A.jpg
# !showme cartoon0022A.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180416_163956_BF.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set verbosity level to 0.
# [gmic]-1./ Apply cartoon effect on image [0], with smoothness 1, sharpening 124.771, threshold 20, thickness 0.5, color 1.5 and quantization 8.
# [gmic]-1./ Normalize image [0] in range [60,255].
# [gmic]-1./ Output image [0] as jpg file 'cartoon0022A.jpg', with quality 100% (1 image 640x640x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
# !gmic -i 640x640/P_20180416_164243.jpg \
-normalize[-0] 60,255 \
-o junk/LIGHTER_P_20180416_164243.jpg
# !showme junk/LIGHTER_P_20180416_164243.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/P_20180416_164243.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Normalize image [0] in range [60,255].
# [gmic]-1./ Output image [0] as jpg file 'junk/LIGHTER_P_20180416_164243.jpg', with quality 100% (1 image 640x640x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
# 114 images in 640x640.list
import subprocess
count = 35
filein = LST[count]
count = count +1
print count,line
filename = time.strftime("junk/cartoon_%Y%m%d%H%M%S.jpg")
subprocess.call("gmic -input "+line+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0  -normalize[-0] 60,255 -output "+filename, shell=True)
# Out:
# 36 640x640/P_20180416_164243.jpg
# 0

# %%
# !gmic -v 99 -i 640x640/181.jpg -hotchocolate.gmic -o chocolate-test.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Set verbosity level to 99.
# [gmic]-0./ Input file '640x640/181.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Input custom command file '-hotchocolate.gmic'
# [gmic]-1./ *** Error *** gmic::fopen(): Failed to open file '-hotchocolate.gmic' with mode 'rb'.

# %%
# 114 images in 640x640.list
import subprocess
count = 0
filein = LST[count]
count = count +1
print count,line
filename = time.strftime("junk/%Y%m%d%H%M%S.jpg")
subprocess.call("gmic -input "+line+" -resize2dx[-1] 1024 lh='{h}' --blur[-1] 0.35% \
-quantize[-1] 8  -output "+filename, shell=True)
# Out:
# 1 640x640/P_20180416_164243.jpg
# 0

# %%
# !ls junk
# Out:
# 20180501093236_000000.jpg  20180501093236_000001.jpg

# %%
# !gmic v + sp tiger v
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Increment verbosity level (set to 1).
# [gmic]-0./sp/ Skip argument 'tiger,0'.
# [gmic]-0./sp/ Decrement verbosity level (set to 0).
# [gmic]-0./sp/_sample/*if/ Set local variable 'N=1'.
# [gmic]-0./sp/_sample/*if/ Set local variable 'W=0'.
# [gmic]-0./sp/_sample/*if/ Set local variable 'H=0'.
# [gmic]-0./sp/_sample/ Set local variable 'arg0=_sample'.
# [gmic]-0./sp/_sample/ Set local variable 'arg1=tiger'.
# [gmic]-0./sp/_sample/ Set local variable 'arg2=0'.
# [gmic]-0./sp/_sample/ Set local variable 'M=40'.
# [gmic]-0./sp/_sample/ Set local variable 'is_arg=1'.
# [gmic]-0./sp/_sample/*repeat/ Set local variable 'arg=tiger'.
# [gmic]-0./sp/_sample/*repeat/ Set local variable 'is_rand1=0'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=apples'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=barbara'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=boats'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=bottles'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=butterfly'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=cameraman'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=car'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=cat'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=cliff'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=david'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=dog'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=duck'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=eagle'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=elephant'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=earth'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=flower'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=fruits'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=greece'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=gummy'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=house'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=inside'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=landscape'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=leaf'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=lena'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=leno'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=lion'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=mandrill'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=monalisa'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=monkey'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=parrots'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=pencils'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=peppers'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=rooster'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=rose'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=square'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=teddy'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/ Set local variable 'name=tiger'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/*if/ Set local variable 'arg=37'.
# [gmic]-0./sp/_sample/*repeat/*if/*repeat/*if/ Break current 'repeat...done' block.
# [gmic]-0./sp/_sample/*repeat/ Set local variable 'arg1=37'.
# [gmic]-0./sp/_sample/*repeat/ Set local variable 'name=tiger'.
# [gmic]-0./sp/_sample/*repeat/ Set local variable 'filename=/home/jack/.config/gmic/sample_tiger.png'.
# [gmic]-0./sp/_sample/*repeat/ Set local variable 'url=http://gmic.eu/img/sample_tiger.png'.
# [gmic]-0./sp/_sample/*repeat/*if/*if/ Input file 'http://gmic.eu/img/sample_tiger.png' at position 0 (1 image 750x500x1x3).
# [gmic]-1./sp/_sample/*repeat/*if/*if/ Output image [0] as png file '/home/jack/.config/gmic/sample_tiger.png' (1 image 750x500x1x3).
# [gmic]-1./sp/_sample/*repeat/ Set name of image [0] to 'tiger'.
# [gmic]-1./sp/_sample/*repeat/ Increment verbosity level (set to 1).
# [gmic]-1./ Input sample image 'tiger' (1 image 750x500x1x3).
# [gmic]-1./sp/_sample/*repeat/ Decrement verbosity level (set to 0).
# [gmic]-1./sp/_sample/ Add 0 to image [0].
# [gmic]-1./sp/_sample/ Set status to '1'.
# [gmic]-1./sp/ Increment verbosity level (set to 1).
# [gmic]-1./ *** Error *** Command 'verbose': Invalid argument ''.
# [gmic] Command 'verbose' has the following description:
#
#     verbose (+):
#         level |
#         { + | - }
#
#       Set or increment/decrement the verbosity level. Default level is 0.
#       (equivalent to shorcut command 'v').
#
#       When 'level'>=0, G'MIC log messages are displayed on the standard error (stderr).
#
#       Default value: 'level=0'.

# %%
# !ls /home/jack/.config/gmic/
# Out:
# gmicky_small_deevad.cimgz  hotchocolate.gmic	   sample_greece.png
# gui_dialog_params	   lightleak_000000.cimgz  sample_tiger.png
# gui_filters		   sample_boats.png	   update222.gmic
# gui_update.lock		   sample_elephant.png

# %%
# !showme /home/jack/.config/gmic/sample_tiger.png

# %%
# %load /home/jack/.config/gmic/hotchocolate.gmic
#@gimp <span color="red">&#x2764; <b>One-click chocolate !</b></span> : gimp_hotchocolate, gimp_hotchocolate_preview
#@gimp : note = note{"Want to send a <b>free hot chocolate</b> to the <b>hard-working</b> developers who provide G'MIC <b>for free</b> ?\n
#@gimp : Just follow the link below (or copy/paste into your browser) and click <b>on the sponsored link</b> that is shown. It's as simple as that and
#@gimp : we'll drink to you :)"}
#@gimp : link = link{"Send a free hot chocolate to the G'MIC developers","http://gmic.eu/freechocolate.shtml"}
#@gimp : link = link{"http://gmic.eu/freechocolate.shtml"}
#@gimp : sep = separator()
#@gimp : note = note{"If you'd like to send <b>more</b> than a single hot chocolate for our efforts, please visit the following page where you can contribute
#@gimp : extra to help keep us motivated (via <b>Paypal</b>):"}
#@gimp : link = link{"Offer even more hot chocolate to the G'MIC developers","http://gmic.eu/morechocolate.shtml"}
#@gimp : link = link{"http://gmic.eu/morechocolate.shtml"}
#@gimp : sep = separator()
#@gimp : note = note{"<small><b>Note:</b> This filter won't appear anymore after you re-run the plug-in. So, don't miss the occasion!</small>"}
#@gimp : sep = separator(), note = note("<small>Author: <i>David Tschumperl&#233;</i>.      Latest update: <i>11/30/2015</i>.</small>")
gimp_hotchocolate : (10) -o. raw:/home/jack/.config/gmic/hotchocolate.gmic,uchar -rm. 
gimp_hotchocolate_preview : -gimp_hotchocolate -gimp_friends

# %%
# !gmic -i 640x640/171.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/171.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Display image [0] = '171.jpg'.
# [0] = '640x640/171.jpg':
#   size = (640,640,1,3) [4800 Kio of floats].
#   data = (146,147,145,145,146,147,146,146,139,136,130,129,(...),254,255,255,255,254,253,252,252,253,254,255,255).
#   min = 0, max = 255, mean = 132.191, std = 77.8613, coords_min = (557,63,0,0), coords_max = (564,156,0,0).
# [gmic]-1./ End G'MIC interpreter.

# %%
# !gmic -v 6 -i 640x640/171.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Set verbosity level to 6.
# [gmic]-0./ Input file '640x640/171.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Display image [0] = '171.jpg'.
# [0] = '640x640/171.jpg':
#   size = (640,640,1,3) [4800 Kio of floats].
#   data = (146,147,145,145,146,147,146,146,139,136,130,129,(...),254,255,255,255,254,253,252,252,253,254,255,255).
#   min = 0, max = 255, mean = 132.191, std = 77.8613, coords_min = (557,63,0,0), coords_max = (564,156,0,0).
# [gmic]-1./ End G'MIC interpreter.

# %%
f = open("GMIC-documents.txt", "r").readlines()
count = 0
start = raw_input("Start: ")
for line in f:
    line = line.replace("\n", "")
    count = count +1
    start = int(start)
    end = start +150
    if count>start:
        print line
# Out:
# Start: 45
#  3. Image definition and terminology
#     --------------------------------
#
#   - In G'MIC, each image is modeled as a 1d, 2d, 3d or 4d array of scalar values, uniformly
#      discretized on a rectangular/parallelepipedic domain.
#
#   - The four dimensions of this array are respectively denoted by:
#
#     . 'width', the number of image columns (size along the 'x'-axis).
#     . 'height', the number of image rows (size along the 'y'-axis).
#     . 'depth', the number of image slices (size along the 'z'-axis).
#         (the depth is equal to 1 for usual color or grayscale 2d images).
#     . 'spectrum', the number of image channels (size along the 'c'-axis).
#         (the spectrum is respectively equal to 3 and 4 for usual RGB and RGBA color images).
#
#   - There are no hard limitations on the size of the image along each dimension. For instance,
#      the number of image slices or channels can be of arbitrary size within the limits of
#      the available memory.
#
#   - The width, height and depth of an image are considered as spatial dimensions, while the
#      spectrum has a multi-spectral meaning. Thus, a 4d image in G'MIC should be most often
#      regarded as a 3d dataset of multi-spectral voxels. Most of the G'MIC commands will stick with
#      this idea (e.g. command '' blurs images only along the spatial 'xyz'-axes).
#
#   - G'MIC stores all the image data as buffers of 'float' values (32 bits, value range
#      [-3.4E38,+3.4E38]). It performs all its image processing operations with floating point
#      numbers. Each image pixel takes then 32bits/channel (except if double-precision buffers have
#      been enabled during the compilation of the software, in which case 64bits/channel can be the
#      default).
#
#   - Considering 'float'-valued pixels ensure to keep the numerical precision when executing
#      image processing pipelines. For image input/output operations, you may want to prescribe the
#      image datatype to be different than 'float' (like 'bool', 'char', 'int', etc...).
#      This is possible by specifying it as a file option when using I/O commands.
#      (see section 'Input/output properties' to learn more about file options).
#
#  4. Items of a processing pipeline
#     ------------------------------
#
#   - In G'MIC, an image processing pipeline is described as a sequence of items separated by the
#      space character ' '. Such items are interpreted and executed from the left to the right.
#      For instance, the expression:
#
#        filename.jpg blur 3,0 sharpen 10 resize 200%,200% output file_out.jpg
#
#      defines a valid pipeline composed of nine G'MIC items.
#
#   - Each G'MIC item is a string that is either a command, a list of command arguments,
#      a filename, or a special input string.
#
#   - Escape characters '\' and double quotes '"' can be used to define items containing spaces or
#      other special characters. For instance, the two strings 'single\ item' and '"single item"'
#      both define the same single item, with a space in it.
#
#  5. Input data items
#     ----------------
#
#   - If a specified G'MIC item appears to be an existing filename, the corresponding image data
#      are loaded and inserted at the end of the image list (which is equivalent to the use of
#      ' filename').
#
#   - Special filenames '-' and '-.ext' stand for the standard input/output streams, optionally
#      forced to be in a specific 'ext' file format (e.g. '-.jpg' or '-.png').
#
#   - The following special input strings may be used as G'MIC items to create and insert new
#      images with prescribed values, at the end of the image list:
#
#     . '[selection]' or '[selection]xN': Insert 1 or N copies of already existing images.
#        'selection' may represent one or several images
#        (see section 'Command items and selections' to learn more about selections).
#
#     . 'width[%],_height[%],_depth[%],_spectrum[%],_values': Insert a new image with specified
#        size and values (adding '%' to a dimension means 'percentage of the size along the same
#        axis, taken from the last image '[-1]''). Any specified dimension can be also written as
#        '[image]', and is then set to the size (along the same axis) of the existing specified image
#        [image]. 'values' can be either a sequence of numbers separated by commas ',', or a
#        mathematical expression, as e.g. in input item '256,256,1,3,if(c==0,x,if(c==1,y,0))' which
#        creates a 256x256 RGB color image with a spatial shading on the red and green channels.
#        (see section 'Mathematical expressions' to learn more about mathematical expressions).
#
#     . '(v1,v2,..)': Insert a new image from specified prescribed values. Value separator inside
#        parentheses can be ',' (column separator), ';' (row separator), '/' (slice separator) or
#        '^' (channel separator). For instance, expression '(1,2,3;4,5,6;7,8,9)' creates a 3x3 matrix
#        (scalar image), with values running from 1 to 9.
#
#     . '0': Insert a new 'empty' image, containing no pixel data. Empty images are used only in rare
#        occasions.
#
#   - Input item 'name=value' declares a new local or global variable 'name', or assign a new value
#      to an existing variable. Variable names must use the character set [a-zA-Z0-9_] and cannot
#      start with a number.
#
#   - A variable definition is always local to the current command except when it starts by the
#      underscore character '_'. In that case, it becomes also accessible by any command invoked
#      outside the current command scope (global variable).
#
#   - If a variable name starts with two underscores '__', the global variable is also shared among
#      different threads and can be read/set by commands running in parallel (see command 'parallel'
#      for this purpose). Otherwise, it remains local to the thread that defined it.
#
#   - Numerical variables can be updated with the use of these special operators:
#      '+=' (addition), '-=' (subtraction), '*=' (multiplication), '/=' (division), '%=' (modulo),
#      '&=' (bitwise and), '|=' (bitwise or), '^=' (power), '<<=' and '>>=' (bitwise left and right
#      shifts). For instance, 'foo=1 foo+=3'.
#
#   - Input item 'name.=string' concatenates specified 'string' to the end of variable 'name'.
#
#   - Multiple variable assignments and updates are allowed, with expressions:
#      'name1,name2,...,nameN=value' or 'name1,name2,...,nameN=value1,value2,...,valueN'
#      where assignment operator '=' can be replaced by one of the allowed operators
#      (e.g. '+=').
#
#  6. Command items and selections
#     ----------------------------
#
#   - A G'MIC item that is not a filename nor a special input string designates a command,
#      most of the time. Generally, commands perform image processing operations on one or several
#      available images of the list.
#
#   - Reccurent commands have two equivalent names (regular and short). For instance, command names
#      'resize' and 'r' refer to the same image resizing action.
#
#   - A G'MIC command may have mandatory or optional arguments. Command arguments must be specified
#      in the next item on the command line. Commas ',' are used to separate multiple arguments of a
#      single command, when required.
#
#   - The execution of a G'MIC command may be restricted only to a subset of the image list, by
#      appending '[selection]' to the command name. Examples of valid syntaxes for 'selection' are:
#
#     . 'command[-2]': Apply command only on the penultimate image [-2] of the list.
#     . 'command[0,1,3]': Apply command only on images [0],[1] and [3].
#     . 'command[3-6]': Apply command only on images [3] to [6] (i.e, [3],[4],[5] and [6]).
#     . 'command[50%-100%]': Apply command only on the second half of the image list.
#     . 'command[0,-4--1]': Apply command only on the first image and the last four images.
#     . 'command[0-9:3]': Apply command only on images [0] to [9], with a step of 3
#                           (i.e. on images [0], [3], [6] and [9]).
#     . 'command[0--1:2]': Apply command only on images of the list with even indices.
#     . 'command[0,2-4,50%--1]': Apply command on images [0],[2],[3],[4] and on the second half of
#                                  the image list.
#     . 'command[^0,1]': Apply command on all images except the two first.
#     . 'command[name1,name2]': Apply command on named images 'name1' and 'name2'.
#
#   - Indices in selections are always sorted in increasing order, and duplicate indices are
#      discarded. For instance, selections '[3-1,1-3]' and '[1,1,1,3,2]' are both equivalent to
#      '[1-3]'. If you want to repeat a single command multiple times on an image, use a
#      'repeat..done' loop instead. Inverting the order of images for a command is achieved by
#      explicitly inverting the order of the images in the list, with command 'reverse[selection]'.
#
#   - Command selections '[-1]','[-2]' and '[-3]' are so often used that they have their own
#      shortcuts, respectively '.', '..' and '...'. For instance, command 'blur..' is equivalent to
#      'blur[-2]'. These shortcuts work also when specifying command arguments.
#
#   - G'MIC commands invoked without '[selection]' are applied on all images of the list, i.e. the
#      default selection is '[0--1]' (except for command 'input' whose default selection is '[-1]').
#
#   - Prepending a single hyphen '-' to a G'MIC command has no effect. This may be useful to recognize
#      command items more easily in a one-liner pipeline (typically invoked from a shell).
#
#   - A G'MIC command prepended with a plus sign '+' or a double hyphen '--' does not act 'in-place'
#      but inserts its result as one or several new images at the end of the image list.
#
#   - There are two different types of commands that can be run by the G'MIC interpreter:
#
#     . Builtin commands, are the hard-coded functionalities in the interpreter core. They are thus
#        compiled as binary code and run fast, most of the time. Omitting an argument when invoking a
#        builtin command is not permitted, except if all following arguments are also omitted.
#        For instance, invoking 'plasma 10,,5' is invalid but 'plasma 10' is correct.
#     . Custom commands, are defined as G'MIC pipelines of builtin or other custom commands.
#        They are interpreted by the G'MIC interpreter, and thus run a bit slower than builtin commands.
#        Omitting arguments when invoking a custom command is permitted. For instance, expressions
#        'flower ,,,100,,2' or 'flower ,' are correct.
#
#   - Most of the existing commands in G'MIC are actually defined as custom commands.
#
#   - A user can easily add its own custom commands to the G'MIC interpreter (see section
#      'Adding custom commands' for more details). New builtin commands cannot be added
#      (unless you modify the G'MIC interpreter source code and recompile it).
#
#  7. Input/output properties
#     -----------------------
#
#   - G'MIC is able to read/write most of the classical image file formats, including:
#
#     . 2d grayscale/color files: .png, .jpeg, .gif, .pnm, .tif, .bmp, ...
#     . 3d volumetric files: .dcm, .hdr, .nii, .pan, .inr, .pnk, ...
#     . video files: .mpeg, .avi, .mov, .ogg, .flv, ...
#     . Generic ascii or binary data files: .gmz, .cimg, .cimgz, .dlm, .asc, .pfm, .raw, .txt, .h.
#     . 3d object files: .off.
#
#   - When dealing with color images, G'MIC generally reads, writes and displays data using the usual
#      sRGB color space.
#
#   - G'MIC is able to manage 3d objects that may be read from files or generated by G'MIC commands.
#      A 3d object is stored as a one-column scalar image containing the object data, in the
#      following order: { magic_number; sizes; vertices; primitives; colors; opacities }.
#      These 3d representations can be then processed as regular images.
#      (see command 'split3d' for accessing each of these 3d object data separately).
#
#   - Be aware that usual file formats may be sometimes not adapted to store all the available image
#      data, since G'MIC uses float-valued image buffers. For instance, saving an image that was
#      initially loaded as a 16bits/channel image, as a .jpg file will result in a loss of
#      information. Use the G'MIC-specific file extensions .cimgz or .gmz to ensure that all data
#      precision are preserved when saving images.
#
#   - Sometimes, file options may/must be set for file formats:
#
#     . Video files: Only sub-frames of an image sequence may be loaded, using the input expression
#        'filename.ext,[first_frame[,last_frame[,step]]]'. Set 'last_frame==-1' to tell it must be
#        the last frame of the video. Set 'step' to 0 to force an opened video file to be
#        opened/closed. Output framerate and codec can be also set by using the output expression
#        'filename.avi,_fps,_codec,_keep_open={ 0 | 1 }'. 'codec' is a 4-char string
#        (see http://www.fourcc.org/codecs.php) or '0' for the default codec. 'keep_open' tells if
#        the output video file must be kept open for appending new frames afterwards.
#
#     . .cimg[z] files: Only crops and sub-images of .cimg files can be loaded, using the input
#       expressions 'filename.cimg,N0,N1', 'filename.cimg,N0,N1,x0,x1',
#       'filename.cimg,N0,N1,x0,y0,x1,y1', 'filename.cimg,N0,N1,x0,y0,z0,x1,y1,z1' or
#       'filename.cimg,N0,N1,x0,y0,z0,c0,x1,y1,z1,c1'.
#       Specifying '-1' for one coordinates stands for the maximum possible value. Output expression
#       'filename.cimg[z][,datatype]' can be used to force the output pixel type. 'datatype' can be
#       { uchar | char | ushort | short | uint | int | uint64 | int64 | float | double }.
#
#     . .raw binary files: Image dimensions and input pixel type may be specified when loading .raw
#        files with input expression
#        'filename.raw[,datatype][,width][,height[,depth[,dim[,offset]]]]]'. If no dimensions are
#        specified, the resulting image is a one-column vector with maximum possible height. Pixel
#        type can also be specified with the output expression 'filename.raw[,datatype]'.
#        'datatype' can be the same as for .cimg[z] files.
#
#     . .yuv files: Image dimensions must be specified when loading, and only sub-frames of an image sequence
#        may be loaded, using the input expression
#        'filename.yuv,width,height[,chroma_subsampling[,first_frame[,last_frame[,step]]]'.
#        'chroma_subsampling' can be { 420 | 422 | 444 }.
#        When saving, chroma subsampling mode can be specified with output expression
#        'filename.yuv[,chroma_subsampling]'.
#
#     . .tiff files: Only sub-images of multi-pages tiff files can be loaded, using the input
#        expression 'filename.tif,_first_frame,_last_frame,_step'.
#        Output expression 'filename.tiff,_datatype,_compression,_force_multipage,_use_bigtiff' can
#        be used to specify the output pixel type, as well as the compression method.
#        'datatype' can be the same as for .cimg[z] files. 'compression' can be
#        { none (default) | lzw | jpeg }. 'force_multipage can be { 0=no (default) | 1=yes }.
#        'use_bigtiff can be { 0=no | 1=yes (default) }.
#
#     . .gif files: Animated gif files can be saved, using the input expression
#        'filename.gif,fps>0,nb_loops'. Specify 'nb_loops=0' to get an infinite number of animation
#        loops (this is the default behavior).
#
#     . .jpeg files: The output quality may be specified (in %), using the output expression
#        'filename.jpg,30' (here, to get a 30% quality output). '100' is the default.
#
#     . .mnc files: The output header can set from another file, using the output expression
#        'filename.mnc,header_template.mnc'.
#
#     . .pan, .cpp, .hpp, .c and .h files: The output datatype can be selected with output expression
#        'filename[,datatype]'. 'datatype' can be the same as for .cimg[z] files.
#
#     . .gmic files: These filenames are assumed to be G'MIC custom commands files. Loading such a
#        file will add the commands it defines to the interpreter. Debug information can be
#        enabled/disabled by the input expression 'filename.gmic[,add_debug_info={ 0 | 1 }]'.
#
#     . Inserting 'ext:' on the beginning of a filename (e.g. 'jpg:filename') forces G'MIC to
#        read/write the file as it would have been done if it had the specified extension '.ext'.
#
#   - Some input/output formats and options may not be supported, depending on the configuration
#      flags that have been set during the build of the G'MIC software.
#
#  8. Substitution rules
#     ------------------
#
#   - G'MIC items containing '$' or '{}' are substituted before being interpreted. Use these
#      substituting expressions to access various data from the interpreter environment.
#
#   - '$name' and '${name}' are both substituted by the value of the specified named variable
#      (set previously by the item 'name=value'). If this variable has not been already set, the
#      expression is substituted by the highest positive indice of the named image '[name]'. If no
#      image has this name, the expression is substituted by the value of the OS environment variable
#      with same name (it may be thus an empty string).
#      The following reserved variables are predefined by the G'MIC interpreter:
#
#        . '$!': The current number of images in the list.
#        . '$>' and '$<': The increasing/decreasing indice of the latest (currently running)
#           'repeat...done' loop.
#        . '$/': The current call stack. Stack items are separated by slashes '/'.
#        . '$|': The current value (expressed in seconds) of a millisecond precision timer.
#        . '$^': The current verbosity level.
#        . '$_cpus': The number of computation cores available on your machine.
#        . '$_pid': The current process identifier, as an integer.
#        . '$_prerelease': For pre-releases only, the date of the pre-release as 'yymmdd'.
#           For stable releases, this variable is not defined.
#        . '$_version': A 3-digits number telling about the current version of the G'MIC interpreter
#           (currently '222').
#        . '$_vt100': Set to 1 (default value) if colored text output is allowed on the console.
#        . '$_path_rc': The path to the G'MIC folder used to store resources and configuration files
#          (its value is OS-dependent).
#        . '$_path_user': The path to the G'MIC user file .gmic or user.gmic (its value is
#           OS-dependent).
#
#   - '$$name' and '$${name}' are both substituted by the G'MIC script code of the specified named
#      custom command, or by an empty string if no custom command with specified name exists.
#
#   - '${"-command line"}' is substituted by the status value set by the execution of the specified
#      command line (see command 'status' to learn more about status). Expression '${}' thus stands
#      for the current status value.
#
#   - '{``string}' (starting with two backquotes) is substituted by a double-quoted version of the
#      specified string.
#
#   - '{/string}' is substituted by the escaped version of the specified string.
#
#   - '{'string'}' (between single quotes) is substituted by the sequence of ascii codes that compose
#      the specified string, separated by commas ','. For instance, item '{'foo'}' is substituted
#      by '102,111,111'.
#
#   - '{image,feature}' is substituted by a specific feature of the image [image]. 'image' can be
#      either an image number or an image name. It can be also eluded, in which case, the last image
#      '[-1]' of the list is considered for the requested feature.
#      Specified 'feature' can be one of:
#
#        . 'b': The image basename (i.e. filename without the folder path nor extension).
#        . 'f': The image folder name.
#        . 'n': The image name or filename (if the image has been read from a file).
#        . 't': The text string from the image values regarded as ascii codes.
#        . 'x': The image extension (i.e last characters after the last '.' in the image name).
#        . '^ : The sequence of all image values, separated by commas ','.
#        . '@subset': The sequence of image values corresponding to the specified subset, and
#           separated by commas ','.
#        . Any other 'feature' is considered as a mathematical expression associated to the image
#           [image] and is substituted by the result of its evaluation (float value). For instance,
#           expression '{0,w+h}' is substituted by the sum of the width and height of the first image
#           (see section 'Mathematical expressions' for more details). If a mathematical expression
#           starts with an underscore '_', the resulting value is truncated to a readable format.
#           For instance, item '{_pi}' is substituted by '3.14159' (while '{pi}' is substituted by
#           '3.141592653589793').
#        . A 'feature' delimited by backquotes is replaced by a string whose ascii codes correspond
#           to the list of values resulting from the evaluation of the specified mathematical
#           expression. For instance, item '{`[102,111,111]`}' is substituted by 'foo' and item
#           '{`vector8(65)`}' by 'AAAAAAAA'.
#
#   - '{*}' is substituted by the visibility state of the instant display window [0] (can be
#      { 0=closed | 1=visible }).
#
#   - '{*,feature}' or '{*indice,feature}' is substituted by a specific feature of the instant
#      display window #0 (or #indice, if specified). Requested 'feature' can be:
#
#        . 'w': display width (i.e. width of the display area managed by the window).
#        . 'h': display height (i.e. height of the display area managed by the window).
#        . 'wh': display width x display height.
#        . 'd': window width (i.e. width of the window widget).
#        . 'e': window height (i.e. height of the window widget).
#        . 'de': window width x window height.
#        . 'u': screen width (actually independent on the window size).
#        .' v': screen height (actually independent on the window size).
#        . 'uv': screen width x screen height.
#        . 'n': current normalization type of the instant display.
#        . 't': window title of the instant display.
#        . 'x': X-coordinate of the mouse position (or -1, if outside the display area).
#        . 'y': Y-coordinate of the mouse position (or -1, if outside the display area).
#        . 'b': state of the mouse buttons { 1=left-but. | 2=right-but. | 4=middle-but. }.
#        . 'o': state of the mouse wheel.
#        . 'k': decimal code of the pressed key if any, 0 otherwise.
#        . 'c': boolean (0 or 1) telling if the instant display has been closed recently.
#        . 'r': boolean telling if the instant display has been resized recently.
#        . 'm': boolean telling if the instant display has been moved recently.
#        . Any other 'feature' stands for a keycode name (in capital letters), and is substituted by
#           a boolean describing the current key state { 0=pressed | 1=released }.
#        . You can also prepend a hyphen '-' to a 'feature' (that supports it) to flush the
#           corresponding event immediately after reading its state (works for keys, mouse and
#           window events).
#
#   - Item substitution is never performed in items between double quotes. One must break the quotes
#     to enable substitution if needed, as in "3+8 kg = "{3+8}" kg". Using double quotes is then
#     a convenient way to disable the substitutions mechanism in items, when necessary.
#
#   - One can also disable the substitution mechanism on items outside double quotes, by escaping the
#      '{','}' or '$' characters, as in '\{3+4\}\ doesn't\ evaluate'.
#
#  9. Mathematical expressions
#     ------------------------
#
#   - G'MIC has an embedded mathematical parser. It is used to evaluate (possibly complex) expressions
#      inside braces '{}', or formulas in commands that may take one as an argument (e.g. 'fill').
#
#   - When the context allows it, a formula is evaluated for each pixel of the selected images
#      (e.g. 'fill').
#
#   - A math expression may return a scalar or vector-valued result (with a fixed number of
#      components).
#
#   - The mathematical parser understands the following set of functions, operators and variables:
#
#     _ Usual operators: || (logical or), && (logical and), | (bitwise or), & (bitwise and),
#        !=, ==, <=, >=, <, >, << (left bitwise shift), >> (right bitwise shift), -, +, *, /,
#        % (modulo), ^ (power), ! (logical not), ~ (bitwise not),
#        ++, --, +=, -=, *=, /=, %=, &=, |=, ^=, >>=, <<= (in-place operators).
#
#     _ Usual math functions: abs(), acos(), arg(), argkth(), argmax(), argmin(), asin(), atan(),
#        atan2(), avg(), bool(), cbrt(), ceil(), cos(), cosh(), cut(), exp(), fact(), fibo(), floor(), gauss(), int(),
#        isval(), isnan(), isinf(), isint(), isbool(), isfile(), isdir(), isin(), kth(), log(), log2(), log10(),
#        max(), mean(), med(), min(), narg(), prod(), rol() (left bit rotation),
#        ror() (right bit rotation), round(), sign(), sin(), sinc(), sinh(), sqrt(), std(),
#        srand(_seed), sum(), tan(), tanh(), variance(), xor().
#
#        . 'atan2(y,x)' is the version of 'atan()' with two arguments 'y' and 'x' (as in C/C++).
#        . 'permut(k,n,with_order)' computes the number of permutations of k objects from a set of
#           n objects.
#        . 'gauss(x,_sigma)' returns 'exp(-x^2/(2*s^2))/sqrt(2*pi*sigma^2)'.
#        . 'cut(value,min,max)' returns value if it is in range [min,max], or min or max otherwise.
#        . 'narg(a_1,...,a_N)' returns the number of specified arguments (here, N).
#        . 'arg(i,a_1,..,a_N)' returns the ith argument a_i.
#        . 'isval()', 'isnan()', 'isinf()', 'isint()', 'isbool()' test the type of the given
#           number or expression, and return 0 (false) or 1 (true).
#        . 'isfile()' (resp. 'isdir()') returns 0 (false) or 1 (true) whether its argument is a
#           path to an existing file (resp. to a directory) or not.
#        . 'isin(v,a_1,...,a_n)' returns 0 (false) or 1 (true) whether the first value 'v' appears
#           in the set of other values 'a_i'.
#        . 'argmin()', 'argmax()', 'kth()', 'max()', 'mean()', 'med()', 'min()', 'std()', 'sum()'
#           and 'variance()' can be called with an arbitrary number of scalar/vector arguments.
#        . 'round(value,rounding_value,direction)' returns a rounded value. 'direction' can be
#           { -1=to-lowest | 0=to-nearest | 1=to-highest }.
#
#     _ Variable names below are pre-defined. They can be overridden.
#
#        . 'l': length of the associated list of images.
#        . 'w': width of the associated image, if any (0 otherwise).
#        . 'h': height of the associated image, if any (0 otherwise).
#        . 'd': depth of the associated image, if any (0 otherwise).
#        . 's': spectrum of the associated image, if any (0 otherwise).
#        . 'r': shared state of the associated image, if any (0 otherwise).
#        . 'wh': shortcut for width x height.
#        . 'whd': shortcut for width x height x depth.
#        . 'whds': shortcut for width x height x depth x spectrum (i.e. number of image values).
#        . 'im','iM','ia','iv','is','ip','ic': Respectively the minimum, maximum, average,
#           variance, sum, product and median value of the associated image, if any (0 otherwise).
#        . 'xm','ym','zm','cm': The pixel coordinates of the minimum value in the associated
#           image, if any (0 otherwise).
#        . 'xM','yM','zM','cM': The pixel coordinates of the maximum value in the associated
#           image, if any (0 otherwise).
#        . All these variables are considered as constant values by the math parser (for optimization
#           purposes) which is indeed the case most of the time. Anyway, this might not be the case,
#           if function 'resize(#ind,..)' is used in the math expression.
#           If so, it is safer to invoke functions 'l()', 'w(_#ind)', 'h(_#ind)', ... 's(_#ind)'
#           and 'ic(_#ind)' instead of the corresponding named variables.
#        . 'i': current processed pixel value (i.e. value located at (x,y,z,c)) in the associated
#           image, if any (0 otherwise).
#        . 'iN': Nth channel value of current processed pixel (i.e. value located at (x,y,z,N)) in
#           the associated image, if any (0 otherwise). 'N' must be an integer in range [0,9].
#        . 'R','G','B' and 'A' are equivalent to 'i0', 'i1', 'i2' and 'i3' respectively.
#        . 'I': current vector-valued processed pixel in the associated image, if any (0 otherwise).
#           The number of vector components is equal to the number of image channels
#           (e.g. I = [ R,G,B ] for a RGB image).
#        . You may add '#ind' to any of the variable name above to retrieve the information for any
#           numbered image [ind] of the list (when this makes sense). For instance 'ia#0' denotes the
#           average value of the first image of the list).
#        . 'x': current processed column of the associated image, if any (0 otherwise).
#        . 'y': current processed row of the associated image, if any (0 otherwise).
#        . 'z': current processed slice of the associated image, if any (0 otherwise).
#        . 'c': current processed channel of the associated image, if any (0 otherwise).
#        . 't': thread id when an expression is evaluated with multiple threads (0 means
#           'master thread').
#        . 'e': value of e, i.e. 2.71828...
#        . 'pi': value of pi, i.e. 3.1415926...
#        . 'u': a random value between [0,1], following a uniform distribution.
#        . 'g': a random value, following a gaussian distribution of variance 1
#           (roughly in [-6,6]).
#        . 'interpolation': value of the default interpolation mode used when reading pixel values
#            with the pixel access operators (i.e. when the interpolation argument is not explicitly
#            specified, see below for more details on pixel access operators). Its initial default
#            value is 0.
#        . 'boundary': value of the default boundary conditions used when reading pixel values with
#            the pixel access operators (i.e. when the boundary condition argument is not explicitly
#            specified, see below for more details on pixel access operators). Its initial default
#            value is 0.
#
#     _ Vector calculus: Most operators are also able to work with vector-valued elements.
#
#        . '[ a0,a1,...,aN ]' defines a (N+1)-dimensional vector with scalar coefficients ak.
#        . 'vectorN(a0,a1,,...,)' does the same, with the ak being repeated periodically if only a
#           few are specified.
#        . In both previous expressions, the ak can be vectors themselves, to be concatenated into a
#           single vector.
#        . The scalar element ak of a vector X is retrieved by 'X[k]'.
#        . The sub-vector [ X[p]...X[p+q-1] ] (of size q) of a vector X is retrieved by 'X[p,q]'.
#        . Equality/inequality comparisons between two vectors is done with operators '==' and '!='.
#        . Some vector-specific functions can be used on vector values:
#          'cross(X,Y)' (cross product), 'dot(X,Y)' (dot product), 'size(X)' (vector dimension),
#          'sort(X,_is_increasing,_chunk_size)' (sorting values), 'reverse(A)' (reverse order of
#          components), 'shift(A,_length,_boundary_conditions)' and
#          'same(A,B,_nb_vals,_is_case_sensitive)' (vector equality test).
#        . Function 'normP(u1,...,un)' computes the LP-norm of the specified vector
#           (P being an unsigned integer constant or 'inf'). If P is omitted, the L2 norm is used.
#        . Function 'resize(A,size,_interpolation,_boundary_conditions)' returns a resized version of
#           a vector 'A' with specified interpolation mode. 'interpolation' can be { -1=none
#           (memory content) | 0=none | 1=nearest | 2=average | 3=linear | 4=grid | 5=bicubic |
#           6=lanczos }, and 'boundary_conditions'  can be { 0=dirichlet | 1=neumann | 2=periodic | 3=mirror }.
#        . Function 'find(A,B,_is_forward,_starting_indice)' returns the index where sub-vector B
#           appears in vector A, (or -1 if B is not found in A). Argument A can be also replaced by
#           an image indice #ind.
#        . A 2-dimensional vector may be seen as a complex number and used in those particular
#           functions/operators:
#           '**' (complex multiplication), '//' (complex division), '^^' (complex exponentiation),
#           '**=' (complex self-multiplication), '//=' (complex self-division), '^^=' (complex
#           self-exponentiation), 'cabs()' (complex modulus), 'carg()' (complex argument), 'cconj()'
#           (complex conjugate), 'cexp()' (complex exponential) and 'clog()' (complex logarithm).
#        . A MN-dimensional vector may be seen as a M x N matrix and used in those particular
#           functions/operators:
#           '*' (matrix-vector multiplication), 'det(A)' (determinant), 'diag(V)' (diagonal matrix
#           from a vector), 'eig(A)' (eigenvalues/eigenvectors), 'eye(n)' (n x n identity matrix),
#           'inv(A)' (matrix inverse), 'mul(A,B,_nb_colsB)' (matrix-matrix multiplication),
#           'pseudoinv(A,_nb_colsA)', 'rot(u,v,w,angle)' (3d rotation matrix), 'rot(angle)' (2d
#           rotation matrix), 'solve(A,B,_nb_colsB)' (least-square solver of linear system A.X = B),
#           'svd(A,_nb_colsA)' (singular value decomposition), 'trace(A)' (matrix trace) and
#           'transp(A,nb_colsA)' (matrix transpose). Argument 'nb_colsB' may be omitted if it is
#           equal to 1.
#        . Specifying a vector-valued math expression as an argument of a command that operates on
#           image values (e.g. 'fill') modifies the whole spectrum range of the processed image(s),
#           for each spatial coordinates (x,y,z). The command does not loop over the C-axis in this
#           case.
#
#     _ String manipulation: Character strings are defined and managed as vectors objects.
#        Dedicated functions and initializers to manage strings are
#
#        . [ 'string' ] and 'string' define a vector whose values are the ascii codes of the
#           specified character string (e.g. 'foo' is equal to [ 102,111,111 ]).
#        . _'character' returns the (scalar) ascii code of the specified character (e.g. _'A' is
#           equal to 65).
#        . A special case happens for empty strings: Values of both expressions [ '' ] and '' are 0.
#        . Functions 'lowercase()' and 'uppercase()' return string with all string characters
#           lowercased or uppercased.
#        . Function 'stov(str,_starting_indice,_is_strict)' parses specified string 'str' and returns the value
#           contained in it.
#        . Function 'vtos(expr,_nb_digits,_siz)' returns a vector of size 'siz' which contains
#           the ascii representation of values described by expression 'expr'.
#           'nb_digits' can be { -1=auto-reduced | 0=all | >0=max number of digits }.
#        . Function 'echo(str1,str2,...,strN)' prints the concatenation of given string arguments
#           on the console.
#        . Function 'cats(str1,str2,...,strN,siz)' returns the concatenation of given string arguments
#           as a new vector of size 'siz'.
#
#     _ Special operators can be used:
#
#        . ';': expression separator. The returned value is always the last encountered expression.
#           For instance expression '1;2;pi' is evaluated as 'pi'.
#        . '=': variable assignment. Variables in mathematical parser can only refer to numerical
#           values (vectors or scalars). Variable names are case-sensitive. Use this operator in
#           conjunction with ';' to define more complex evaluable expressions, such as
#           't=cos(x);3*t^2+2*t+1'.
#           These variables remain local to the mathematical parser and cannot be accessed outside
#            the evaluated expression.
#        . Variables defined in math parser may have a constant property, by specifying keyword const
#           before the variable name (e.g. const foo = pi/4;). The value set to such a variable must
#           be indeed a constant scalar. Constant variables allows certain types of optimizations in
#           the math JIT compiler.
#
#     _ The following specific functions are also defined:
#
#        . 'u(max)' or 'u(min,max)': return a random value between [0,max] or [min,max], following
#           a uniform distribution.
#        . 'i(_a,_b,_c,_d,_interpolation_type,_boundary_conditions)': return the value of the pixel
#           located at position (a,b,c,d) in the associated image, if any (0 otherwise).
#           'interpolation_type' can be { 0=nearest neighbor | other=linear }.
#           'boundary_conditions' can be { 0=dirichlet | 1=neumann | 2=periodic | 3=mirror }.
#           Omitted coordinates are replaced by their default values which are respectively
#           x, y, z, c, interpolation and boundary.
#           For instance command 'fill 0.5*(i(x+1)-i(x-1))' will estimate the X-derivative of an
#           image with a classical finite difference scheme.
#        . 'j(_dx,_dy,_dz,_dc,_interpolation_type,_boundary_conditions)' does the same for the pixel
#           located at position (x+dx,y+dy,z+dz,c+dc) (pixel access relative to the current
#           coordinates).
#        . 'i[offset,_boundary_conditions]' returns the value of the pixel located at specified
#           'offset' in the associated image buffer (or 0 if offset is out-of-bounds).
#        . 'j[offset,_boundary_conditions]' does the same for an offset relative to the current pixel
#           coordinates (x,y,z,c).
#        . 'i(#ind,_x,_y,_z,_c,_interpolation,_boundary_conditions)',
#           'j(#ind,_dx,_dy,_dz,_dc,_interpolation,_boundary_conditions)',
#           'i[#ind,offset,_boundary_conditions]' and 'i[offset,_boundary_conditions]' are similar expressions used to
#           access pixel values for any numbered image [ind] of the list.
#        . 'I/J[offset,_boundary_conditions]' and 'I/J(#ind,_x,_y,_z,_interpolation,_boundary_conditions)' do
#           the same as 'i/j[offset,_boundary_conditions]' and
#           'i/j(#ind,_x,_y,_z,_c,_interpolation,_boundary_conditions)' but return a vector instead of a scalar
#           (e.g. a vector [ R,G,B ] for a pixel at (a,b,c) in a color image).
#        . 'sort(#ind,_is_increasing,_axis)' sorts the values in the specified image [ind].
#        . 'crop(_#ind,_x,_y,_z,_c,_dx,_dy,_dz,_dc,_boundary_conditions)' returns a vector whose values come
#           from the cropped region of image [ind] (or from default image selected if 'ind' is not
#           specified). Cropped region starts from point (x,y,z,c) and has a size of
#           dx x dy x dz x dc. Arguments for coordinates and sizes can be omitted if they are not
#           ambiguous (e.g. 'crop(#ind,x,y,dx,dy)' is a valid invocation of this function).
#        . 'draw(_#ind,S,x,y,z,c,dx,_dy,_dz,_dc,_opacity,_M,_max_M)' draws a sprite S in image [ind]
#           (or in default image selected if 'ind' is not specified) at coordinates (x,y,z,c).
#           The size of the sprite dx x dy x dz x dc must be specified. You can also specify a
#           corresponding opacity mask M if its size matches S.
#        . 'polygon(_#ind,nb_vertices,coords,_opacity,_color)' draws a filled polygon in image [ind]
#           (or in default image selected if 'ind' is not specified) at specified coordinates.
#           It draws a single line if 'nb_vertices' is set to 2.
#        . 'ellipse(_#ind,xc,yc,radius1,_radius2,_angle,_opacity,_color)' draws a filled ellipse in image [ind]
#           (or in default image selected if 'ind' is not specified) with specified coordinates and geometry.
#        . 'resize(#ind,w,_h,_d,_s,_interp,_boundary_conditions,cx,_cy,_cz,_cc)' resizes an image of the
#           associated list with specified dimension and interpolation method. When using this,
#           function, you should consider retrieving the (non-constant) image dimensions using the
#           dynamic functions 'w(_#ind)', 'h(_#ind)', 'd(_#ind)', 's(_#ind)', 'wh(_#ind)',
#           'whd(_#ind)' and 'whds(_#ind)' instead of the corresponding constant variables.
#        . 'if(condition,expr_then,_expr_else)': return value of 'expr_then' or 'expr_else',
#           depending on the value of 'condition' (0=false, other=true). 'expr_else' can be omitted
#           in which case 0 is returned if the condition does not hold. Using the ternary operator
#           'condition?expr_then[:expr_else]' gives an equivalent expression.
#           For instance, G'MIC commands 'fill if(x%10==0,255,i)' and 'fill x%10?i:255' both draw
#           blank vertical lines on every 10th column of an image.
#        . 'dowhile(expression,_condition)' repeats the evaluation of 'expression' until 'condition'
#           vanishes (or until 'expression' vanishes if no 'condition' is specified). For instance,
#           the expression: 'if(N<2,N,n=N-1;F0=0;F1=1;dowhile(F2=F0+F1;F0=F1;F1=F2,n=n-1))' returns
#           the Nth value of the Fibonacci sequence, for N>=0 (e.g., 46368 for N=24).
#           'dowhile(expression,condition)' always evaluates the specified expression at least once,
#           then check for the loop condition. When done, it returns the last value of 'expression'.
#        . 'for(init,condition,_procedure,body)' first evaluates the expression 'init', then
#           iteratively evaluates 'body' (followed by 'procedure' if specified) while 'condition'
#           is verified (i.e. not zero). It may happen that no iteration is done, in which case the
#           function returns nan. Otherwise, it returns the last value of 'body'.
#           For instance, the expression: 'if(N<2,N,for(n=N;F0=0;F1=1,n=n-1,F2=F0+F1;F0=F1;F1=F2))'
#           returns the Nth value of the Fibonacci sequence, for N>=0 (e.g., 46368 for N=24).
#        . 'whiledo(condition,expression)' is exactly the same as 'for(init,condition,expression)'
#           without the specification of an initializing expression.
#        . 'break()' and 'continue()' respectively breaks and continues the current running bloc
#           (loop, init or main environment).
#        . 'fsize(filename)' returns the size of the specified 'filename' (or '-1' if file does not exist).
#        . 'date(attr,path)' returns the date attribute for the given 'path' (file or directory),
#           with 'attr' being { 0=year | 1=month | 2=day | 3=day of week | 4=hour | 5=minute |
#           6=second }, or a vector of those values.
#        . 'date(_attr) returns the specified attribute for the current (locale) date.
#        . 'print(expr1,expr2,...) or 'print(#ind) prints the value of the specified expressions
#           (or image information) on the console, and returns the value of the last expression
#           (or nan in case of an image). Function 'prints(expr)' also prints the string composed
#           of the ascii characters defined by the vector-valued expression (e.g. 'prints('Hello')').
#        . 'debug(expression) prints detailed debug information about the sequence of operations done
#           by the math parser to evaluate the expression (and returns its value).
#        . 'display(_X,_w,_h,_d,_s) or 'display(#ind) display the contents of the vector 'X'
#           (or specified image) and wait for user events. if no arguments are provided, a memory
#           snapshot of the math parser environment is displayed instead.
#        . 'init(expression) and 'end(expression) evaluates the specified expressions only once,
#           respectively at the beginning and end of the evaluation procedure, and this,
#           even when multiple evaluations are required (e.g. in 'fill init(foo=0);++foo').
#        . 'copy(dest,src,_nb_elts,_inc_d,_inc_s,_opacity) copies an entire memory block of 'nb_elts'
#           elements starting from a source value 'src' to a specified destination 'dest', with
#           increments defined by 'inc_d' and 'inc_s' respectively for the destination and source
#           pointers.
#        . 'stats(_#ind) returns the statistics vector of the running image '[ind]', i.e the vector
#           [ im,iM,ia,iv,xm,ym,zm,cm,xM,yM,zM,cM,is,ip ] (14 values).
#        . 'unref(a,b,...) destroys references to the named variable given as arguments.
#        . 'breakpoint() inserts a possible computation breakpoint (not supported by the cli interface).
#        . '_(expr) just ignores its arguments (mainly useful for debugging).
#        . 'ext('pipeline') executes the specified G'MIC pipeline as if it was called outside
#           the currently evaluated expression.
#
#     - User-defined macros:
#
#        . Custom macro functions can be defined in a math expression, using the assignment operator
#           '=', e.g. 'foo(x,y) = cos(x + y); result = foo(1,2) + foo(2,3)'.
#        . Trying to override a built-in function (e.g. 'abs()') has no effect.
#        . Overloading macros with different number of arguments is possible. Re-defining a
#           previously defined macro with the same number of arguments discards its previous
#           definition.
#        . Macro functions are indeed processed as macros by the mathematical evaluator. You should
#           avoid invoking them with arguments that are themselves results of assignments or
#           self-operations. For instance, 'foo(x) = x + x; z = 0; foo(++z)' returns '4' rather
#           than expected value '2'.
#        . When substituted, macro arguments are placed inside parentheses, except if a number sign
#           '#' is located just before or after the argument name. For instance, expression
#           'foo(x,y) = x*y; foo(1+2,3)' returns '9' (being substituted as '(1+2)*(3)'), while
#           expression 'foo(x,y) = x#*y#; foo(1+2,3)' returns '7' (being substituted as '1+2*3').
#        . Number signs appearing between macro arguments function actually count for 'empty'
#           separators. They may be used to force the substitution of macro arguments in unusual
#           places, e.g. as in 'str(N) = ['I like N#'];'.
#
#     - Multi-threaded and in-place evaluation:
#
#        . If your image data are large enough and you have several CPUs available, it is likely that
#           the math expression passed to a 'fill' or 'input' command is evaluated in parallel,
#           using multiple computation threads.
#        . Starting an expression with ':' or '*' forces the evaluations required for an image to be
#           run in parallel, even if the amount of data to process is small (beware, it may be slower
#           to evaluate in this case!). Specify ':' (instead of '*') to avoid possible image copy
#           done before evaluating the expression (this saves memory, but do this only if you are
#           sure this step is not required!)
#        . If the specified expression starts with '>' or '<', the pixel access operators
#           'i(), i[], j()' and 'j[]' return values of the image being currently modified,
#           in forward ('>') or backward ('<') order. The multi-threading evaluation of the
#           expression is also disabled in this case.
#        . Function 'critical(operands)' forces the execution of the given operands in a single thread at a
#           time.
#
#     _ Expressions 'i(_#ind,x,_y,_z,_c)=value', 'j(_#ind,x,_y,_z,_c)=value', 'i[_#ind,offset]=value'
#        and 'j[_#ind,offset]=value' set a pixel value at a different location than the running one
#        in the image [ind] (or in the associated image if argument '#ind' is omitted), either with
#        global coordinates/offsets (with 'i(...)' and 'i[...]'), or relatively to the current
#        position (x,y,z,c) (with 'j(...)' and 'j[...]'). These expressions always return 'value'.
#
#   - The last image of the list is always associated to the evaluations of '{expressions}',
#      e.g. G'MIC sequence '256,128 fill {w}' will create a 256x128 image filled with value 256.
#
#  10. Image and data viewers
#      ----------------------
#
# ...
#
#       Return 1 if extension of specified filename is typical from video files.
#
#     is_windows:
#
#       Return 1 if current computer OS is Windows, 0 otherwise.
#
#     math_lib:
#
#       Return string that defines a set of several useful macros for the embedded math evaluator.
#
#     mad:
#
#       Return the MAD (Maximum Absolute Deviation) of the last selected image.
#       The MAD is defined as MAD = med_i|x_i-med_j(x_j)|
#
#     max_w:
#
#       Return the maximal width between selected images.
#
#     max_h:
#
#       Return the maximal height between selected images.
#
#     max_d:
#
#       Return the maximal depth between selected images.
#
#     max_s:
#
#       Return the maximal spectrum between selected images.
#
#     max_wh:
#
#       Return the maximal wxh size of selected images.
#
#     max_whd:
#
#       Return the maximal wxhxd size of selected images.
#
#     max_whds:
#
#       Return the maximal wxhxdxs size of selected images.
#
#     med:
#
#       Return the median value of the last selected image.
#
#     median_color:
#
#       Return the median color value of the last selected image.
#
#     min_w:
#
#       Return the minimal width between selected images.
#
#     min_h:
#
#       Return the minimal height between selected images.
#
#     min_d:
#
#       Return the minimal depth between selected images.
#
#     min_s:
#
#       Return the minimal s size of selected images.
#
#     min_wh:
#
#       Return the minimal wxh size of selected images.
#
#     min_whd:
#
#       Return the minimal wxhxd size of selected images.
#
#     min_whds:
#
#       Return the minimal wxhxdxs size of selected images.
#
#     normalize_filename:
#         filename
#
#       Return a "normalized" version of the specified filename, without spaces and capital letters.
#
#     oct:
#         octal_int1,...
#
#       Print specified octal integers into their binary, decimal, hexadecimal and string
#         representations.
#
#     oct2dec:
#         octal_int1,...
#
#       Convert specified octal integers into their decimal representations.
#
#     padint:
#         number,_size>0
#
#       Return a integer with 'size' digits (eventually left-padded with '0').
#
#     path_gimp:
#
#       Return a path to store GIMP configuration files for one user (whose value is OS-dependent).
#
#     path_tmp:
#
#       Return a path to store temporary files (whose value is OS-dependent).
#
#     reset:
#
#       Reset global parameters of the interpreter environment.
#
#     RGB:
#
#       Return a random int-valued RGB color.
#
#     RGBA:
#
#       Return a random int-valued RGBA color.
#
#     std_noise:
#
#       Return the estimated noise standard deviation of the last selected image.
#
#     str:
#         string
#
#       Print specified string into its binary, octal, decimal and hexadecimal representations.
#
#     str2hex:
#         string
#
#       Convert specified string into a sequence of hexadecimal values.
#
#     stresc:
#         val1,...,valN
#
#       Return escaped string from specified ascii codes.
#
#     strcat:
#         "string1","string2",...
#
#       Return the concatenation of all strings passed as arguments.
#
#     strcmp:
#         "string1","string2",_nb_characters>=0
#
#       Return '1' if the two specified strings are equals, '0' otherwise.
#       If 'nb_characters' is specified, the comparison is done only for the 'nb_characters' first
#         characters.
#
#     strcontains:
#         string1,string2
#
#       Return 1 if the first string contains the second one.
#
#     strlen:
#         string1
#
#       Return the length of specified string argument.
#
#     strreplace:
#         string,search,replace
#
#       Search and replace substrings in an input string.
#
#     strlowercase:
#         string
#
#       Return a lower-case version of the specified string.
#
#     strvar:
#         string
#
#       Return a simplified version of the specified string, that can be used as a variable name.
#
#     strver:
#         _version
#
#       Return the specified version number of the G'MIC interpreter, as a string.
#
#       Default value: 'version=$_version'.
#
#     tic:
#
#       Initialize tic-toc timer.
#       Use it in conjunction with 'toc'.
#
#     toc:
#
#       Display elapsed time of the tic-toc timer since the last call to 'tic'.
#       This command returns the elapsed time in the status value.
#       Use it in conjunction with 'tic'.
#
#     uchar2str:
#
#       Encode the latest of the selected image as a string.
#       The string can be decoded using command 'str2uchar'.
#       Input image must have values that are integers in [0,255].
#
#     str2uchar:
#         "string"
#
#       Decode given string as a newly inserted image at the end of the list.
#       The argument string should have been generated using command 'uchar2str'.
#
#
#  **** Other interactive commands:
#
#
#     demo:
#         _run_in_parallel={ 0=no | 1=yes | 2=auto }
#
#       Show a menu to select and view all G'MIC interactive demos.
#
#     x_2048:
#
#       Launch the 2048 game.
#
#     x_blobs:
#
#       Launch the blobs editor.
#
#     x_bouncing:
#
#       Launch the bouncing balls demo.
#
#     x_color_curves:
#         _colorspace={ rgb | cmy | cmyk | hsi | hsl | hsv | lab | lch | ycbcr | last }
#
#       Apply color curves on selected RGB[A] images, using an interactive window.
#       Set 'colorspace' to 'last' to apply last defined color curves without opening interactive windows.
#
#       Default value: 'colorspace=rgb'.
#
#     x_colorize:
#         _is_lineart={ 0 | 1 },_max_resolution={ 0 | >=128 },_multichannels_output={ 0 | \
#          1 },_[palette1],_[palette2],_[grabber1]
#
#       Colorized selected B&W images, using an interactive window.
#       When >0, argument 'max_resolution' defines the maximal image resolution used in the interactive window.
#
#       Default values: 'is_lineart=1', 'max_resolution=1024' and 'multichannels_output=0'.
#
#     x_connect4:
#
#       Launch the Connect Four game.
#
#     x_fire:
#
#       Launch the fire effect demo.
#
#     x_fireworks:
#
#       Launch the fireworks demo.
#
#     x_fisheye:
#
#       Launch the fish-eye effect demo.
#
#     x_fourier:
#
#       Launch the fourier filtering demo.
#
#     x_grab_color:
#         _variable_name
#
#       Open a color grabber widget from the first selected image.
#       Argument 'variable_name' specifies the variable that contains the selected color values at any time.
#       Assigning '-1' to it forces the interactive window to close.
#
#       Default values: 'variable_name=xgc_variable'.
#
#     x_hanoi:
#
#       Launch the Tower of Hanoi game.
#
#     x_histogram:
#
#       Launch the histogram demo.
#
#     x_hough:
#
#       Launch the hough transform demo.
#
#     x_jawbreaker:
#         0<_width<20,0<_height<20,0<_balls<=8
#
#       Launch the Jawbreaker game.
#
#     x_landscape:
#
#       Launch the virtual landscape demo.
#
#     x_life:
#
#       Launch the game of life.
#
#     x_light:
#
#       Launch the light effect demo.
#
#     x_mandelbrot:
#         _julia={ 0 | 1 },_c0r,_c0i
#
#       Launch Mandelbrot/Julia explorer.
#
#     x_mask_color:
#         _colorspace={ all | rgb | lrgb | ycbcr | lab | lch | hsv | hsi | hsl | cmy | \
#          cmyk | yiq },_spatial_tolerance>=0,_color_tolerance>=0
#
#       Interactively select a color, and add an alpha channel containing the corresponding color mask.
#       Argument 'colorspace' refers to the color metric used to compute color similarities, and can be
#         basically one of { rgb | lrgb | ycbcr | lab | lch | hsv | hsi | hsl | cmy | cmyk | yiq }.
#       You can also select one one particular channel of this colorspace, by setting 'colorspace' as
#         'colorspace_channel' (e.g. 'hsv_h' for the hue).
#
#       Default values: 'colorspace=all', 'spatial_tolerance=5' and 'color_tolerance=5'.
#
#     x_metaballs3d:
#
#       Launch the 3d metaballs demo.
#
#     x_minesweeper:
#         8<=_width=<20,8<=_height<=20
#
#       Launch the Minesweeper game.
#
#     x_minimal_path:
#
#       Launch the minimal path demo.
#
#     x_pacman:
#
#       Launch pacman game.
#
#     x_paint:
#
#       Launch the interactive painter.
#
#     x_plasma:
#
#       Launch the plasma effect demo.
#
#     x_quantize_rgb:
#         _nbcolors>=2
#
#       Launch the RGB color quantization demo.
#
#     x_reflection3d:
#
#       Launch the 3d reflection demo.
#
#     x_rubber3d:
#
#       Launch the 3d rubber object demo.
#
#     x_segment:
#         _max_resolution={ 0 | >=128 }
#
#       Segment foreground from background in selected opaque RGB images, interactively.
#       Return RGBA images with binary alpha-channels.
#
#       Default value: 'max_resolution=1024'.
#
#     x_select_color:
#         _variable_name
#
#       Display a RGB or RGBA color selector.
#       Argument 'variable_name' specifies the variable that contains the selected color values (as R,G,
#         B,[A]) at any time.
#       Its value specifies the initial selected color. Assigning '-1' to it forces the interactive
#         window to close.
#
#       Default value: 'variable_name=xsc_variable'.
#
#     x_select_function1d:
#         _variable_name,_background_curve_R,_background_curve_G,_background_curve_B
#
#       Open an interactive window, where the user can defined its own 1d function.
#       If an image is selected, it is used to display additional information :
#       - The first row defines the values of a background curve displayed on the window (e.g. an
#         histogram).
#       - The 2nd, 3rd and 4th rows define the R,G,B color components displayed beside the X and Y axes.
#       Argument 'variable_name' specifies the variable that contains the selected function keypoints
#         at any time.
#       Assigning '-1' to it forces the interactive window to close.
#
#       Default values: 'variable_name=xsf_variable', 'background_curve_R=220',
#         'background_curve_G=background_curve_B=background_curve_T'.
#
#     x_select_palette:
#         _variable_name,_number_of_columns={ 0=auto | >0 }
#
#       Open a RGB or RGBA color selector widget from a palette.
#       The palette is given as a selected image.
#       Argument 'variable_name' specifies the variable that contains the selected color values (as R,G,
#         B,[A]) at any time.
#       Assigning '-1' to it forces the interactive window to close.
#
#       Default values: 'variable_name=xsp_variable' and 'number_of_columns=2'.
#
#     x_shadebobs:
#
#       Launch the shade bobs demo.
#
#     x_spline:
#
#       Launch spline curve editor.
#
#     x_starfield3d:
#
#       Launch the 3d starfield demo.
#
#     x_tetris:
#
#       Launch tetris game.
#
#     x_tictactoe:
#
#       Launch tic-tac-toe game.
#
#     x_waves:
#
#       Launch the image waves demo.
#
#     x_whirl:
#         _opacity>=0
#
#       Launch the fractal whirls demo.
#
#       Default values: 'opacity=0.2'.
#
#
#  **** Command shortcuts:
#
#
#     h : eq. to 'help'.
#     m  (+): eq. to 'command'.
#     d  (+): eq. to 'display'.
#     d0 : eq. to 'display0'.
#     d3d  (+): eq. to 'display3d'.
#     da : eq. to 'display_array'.
#     dfft : eq. to 'display_fft'.
#     dg : eq. to 'display_graph'.
#     dh : eq. to 'display_histogram'.
#     dp : eq. to 'display_parallel'.
#     dp0 : eq. to 'display_parallel0'.
#     dq : eq. to 'display_quiver'.
#     drgba : eq. to 'display_rgba'.
#     dt : eq. to 'display_tensors'.
#     dw : eq. to 'display_warp'.
#     e  (+): eq. to 'echo'.
#     i  (+): eq. to 'input'.
#     ig : eq. to 'input_glob'.
#     o  (+): eq. to 'output'.
#     on : eq. to 'outputn'.
#     op : eq. to 'outputp'.
#     ow : eq. to 'outputw'.
#     ox : eq. to 'outputx'.
#     p  (+): eq. to 'print'.
#     sh  (+): eq. to 'shared'.
#     sp : eq. to 'sample'.
#     up : eq. to 'update'.
#     v  (+): eq. to 'verbose'.
#     w  (+): eq. to 'window'.
#     k  (+): eq. to 'keep'.
#     mv  (+): eq. to 'move'.
#     nm  (+): eq. to 'name'.
#     rm  (+): eq. to 'remove'.
#     rv  (+): eq. to 'reverse'.
#     +  (+): eq. to 'add'.
#     &  (+): eq. to 'and'.
#     <<  (+): eq. to 'bsl'.
#     >>  (+): eq. to 'bsr'.
#     /  (+): eq. to 'div'.
#     ==  (+): eq. to 'eq'.
#     >=  (+): eq. to 'ge'.
#     >  (+): eq. to 'gt'.
#     <=  (+): eq. to 'le'.
#     <  (+): eq. to 'lt'.
#     m/  (+): eq. to 'mdiv'.
#     %  (+): eq. to 'mod'.
#     m*  (+): eq. to 'mmul'.
#     *  (+): eq. to 'mul'.
#     !=  (+): eq. to 'neq'.
#     |  (+): eq. to 'or'.
#     ^  (+): eq. to 'pow'.
#     -  (+): eq. to 'sub'.
#     c  (+): eq. to 'cut'.
#     f  (+): eq. to 'fill'.
#     ir : eq. to 'inrange'.
#     n  (+): eq. to 'normalize'.
#     =  (+): eq. to 'set'.
#     ac : eq. to 'apply_channels'.
#     fc : eq. to 'fill_color'.
#     a  (+): eq. to 'append'.
#     z  (+): eq. to 'crop'.
#     r  (+): eq. to 'resize'.
#     rr2d : eq. to 'resize_ratio2d'.
#     r2dx : eq. to 'resize2dx'.
#     r2dy : eq. to 'resize2dy'.
#     r3dx : eq. to 'resize3dx'.
#     r3dy : eq. to 'resize3dy'.
#     r3dz : eq. to 'resize3dz'.
#     s  (+): eq. to 'split'.
#     y  (+): eq. to 'unroll'.
#     b  (+): eq. to 'blur'.
#     g  (+): eq. to 'gradient'.
#     j  (+): eq. to 'image'.
#     j3d  (+): eq. to 'object3d'.
#     t  (+): eq. to 'text'.
#     to : eq. to 'text_outline'.
#     +3d  (+): eq. to 'add3d'.
#     c3d : eq. to 'center3d'.
#     col3d  (+): eq. to 'color3d'.
#     /3d  (+): eq. to 'div3d'.
#     db3d  (+): eq. to 'double3d'.
#     f3d  (+): eq. to 'focale3d'.
#     l3d  (+): eq. to 'light3d'.
#     m3d  (+): eq. to 'mode3d'.
#     md3d  (+): eq. to 'moded3d'.
#     *3d  (+): eq. to 'mul3d'.
#     n3d : eq. to 'normalize3d'.
#     o3d  (+): eq. to 'opacity3d'.
#     p3d  (+): eq. to 'primitives3d'.
#     rv3d  (+): eq. to 'reverse3d'.
#     r3d  (+): eq. to 'rotate3d'.
#     sl3d  (+): eq. to 'specl3d'.
#     ss3d  (+): eq. to 'specs3d'.
#     s3d  (+): eq. to 'split3d'.
#     -3d  (+): eq. to 'sub3d'.
#     t3d  (+): eq. to 'texturize3d'.
#     ap : eq. to 'apply_parallel'.
#     apc : eq. to 'apply_parallel_channels'.
#     apo : eq. to 'apply_parallel_overlap'.
#     at : eq. to 'apply_tiles'.
#     fi  (+): eq. to 'endif'.
#     endl  (+): eq. to 'endlocal'.
#     x  (+): eq. to 'exec'.
#     l  (+): eq. to 'local'.
#     q  (+): eq. to 'quit'.
#     u  (+): eq. to 'status'.
#     frame : eq. to 'frame_xy'.
#
#    [ Total number of commands: 973 ]
#
#  13. Examples of use
#      ---------------
#
#  'gmic' is a generic image processing tool which can be used in a wide variety of situations.
#  The few examples below illustrate possible uses of this tool:
#
#   - View a list of images:
#      gmic file1.bmp file2.jpeg
#
#   - Convert an image file:
#      gmic input.bmp output output.jpg
#
#   - Create a volumetric image from a movie sequence:
#      gmic input.mpg append z output output.hdr
#
#   - Compute image gradient norm:
#      gmic input.bmp gradient_norm
#
#   - Denoise a color image:
#      gmic image.jpg denoise 30,10 output denoised.jpg
#
#   - Compose two images using overlay layer blending:
#      gmic image1.jpg image2.jpg blend overlay output blended.jpg
#
#   - Evaluate a mathematical expression:
#      gmic echo "cos(pi/4)^2+sin(pi/4)^2={cos(pi/4)^2+sin(pi/4)^2}"
#
#   - Plot a 2d function:
#      gmic 1000,1,1,2 fill "X=3*(x-500)/500;X^2*sin(3*X^2)+if(c==0,u(0,-1),cos(X*10))" plot
#
#   - Plot a 3d elevated function in random colors:
#      gmic 128,128,1,3,"u(0,255)" plasma 10,3 blur 4 sharpen 10000 \
#       elevation3d[-1] "'X=(x-64)/6;Y=(y-64)/6;100*exp(-(X^2+Y^2)/30)*abs(cos(X)*sin(Y))'"
#
#   - Plot the isosurface of a 3d volume:
#      gmic mode3d 5 moded3d 5 double3d 0 isosurface3d "'x^2+y^2+abs(z)^abs(4*cos(x*y*z*3))'",3
#
#   - Render a G'MIC 3d logo:
#      gmic 0 text G\'MIC,0,0,53,1,1,1,1 expand_xy 10,0 blur 1 normalize 0,100 +plasma 0.4 add \
#       blur 1 elevation3d -0.1 moded3d 4
#
#   - Generate a 3d ring of torii:
#      gmic repeat 20 torus3d 15,2 color3d[-1] "{u(60,255)},{u(60,255)},{u(60,255)}" \
#       *3d[-1] 0.5,1 if "{$>%2}" rotate3d[-1] 0,1,0,90 endif add3d[-1] 70 add3d \
#       rotate3d 0,0,1,18 done moded3d 3 mode3d 5 double3d 0
#
#   - Create a vase from a 3d isosurface:
#      gmic moded3d 4 isosurface3d "'x^2+2*abs(y/2)*sin(2*y)^2+z^2-3',0" sphere3d 1.5 \
#       sub3d[-1] 0,5 plane3d 15,15 rotate3d[-1] 1,0,0,90 center3d[-1] add3d[-1] 0,3.2 \
#       color3d[-1] 180,150,255 color3d[-2] 128,255,0 color3d[-3] 255,128,0 add3d
#
#   - Display filtered webcam stream:
#      gmic apply_camera \"+mirror x +mirror y add div 4\"
#
#   - Launch a set of G'MIC interactive demos:
#      gmic demo
#
#  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **

# %%
text = "gmic -i 640x640/153.jpg blur 3,0 sharpen 10 resize 200%,200% -o junk/.jpg"
name = "".join(text.split())
print name
# Out:
# gmic-i640x640/153.jpgblur3,0sharpen10resize200%,200%-ojunk/.jpg

# %%
# !gmic -i 640x640/153.jpg resize 75%,75% -o junk/blur-sharpen-resize.jpg
# !showme junk/blur-sharpen-resize.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/153.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Resize image [0] to 75%x75%x100%x100% , with nearest-neighbor interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-1./ Output image [0] as jpg file 'junk/blur-sharpen-resize.jpg', with quality 100% (1 image 480x480x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
from random import randint
sm =randint(0,5)
sh =randint(50,250)
thres = randint(5,50)
thk = randint(1,5)*.1
col = randint(1,4)*.1
quant = randint(3,10)
print sm, sh, thres, thk, col, quant
# Out:
# 2 245 14 0.4 0.2 7

# %%
Apply cartoon effect on selected images.
Default values: 
smoothness=3 sharpening=150 threshold=20 thickness=0.25 color=1.5 quantization=8

# %%
import os
import sys
sys.path.insert(0, "GRAPHICS/gmic")
from SEARCHdocs import searchdocs
searchdocs("GRAPHICS/gmic/GMIC-documents.txt")
# Out:
# SEARCH: invert
# 188   - Indices in selections are always sorted in increasing order, and duplicate indices are
# 189      discarded. For instance, selections '[3-1,1-3]' and '[1,1,1,3,2]' are both equivalent to
# 190      '[1-3]'. If you want to repeat a single command multiple times on an image, use a
# 191      'repeat..done' loop instead. Inverting the order of images for a command is achieved by
# 192      explicitly inverting the order of the images in the list, with command 'reverse[selection]'.
# 194   - Command selections '[-1]','[-2]' and '[-3]' are so often used that they have their own
# 195      shortcuts, respectively '.', '..' and '...'. For instance, command 'blur..' is equivalent to
# 196      'blur[-2]'. These shortcuts work also when specifying command arguments.
# 4579       Compute the eigenvalues and eigenvectors of selected symmetric matrices or matrix fields.
# 4580       If one selected image has 3 or 6 channels, it is regarded as a field of 2x2 or 3x3 symmetric matrices,
# 4581       whose eigen elements are computed at each point of the field.
# 4583     invert (+):
# 4585       Compute the inverse of the selected matrices.
# 4587     solve (+):
# 4588         [image]

# %%
from SEARCHdocs import searchdocs
searchdocs("/home/jack/.config/gmic/update222.gmic")
# Out:
# SEARCH: sepia
# 1259 #@cli : Insert one or several frames from specified camera.
# 1260 #@cli : When 'nb_frames==0', the camera stream is released instead of capturing new images.
# 1261 #@cli : Default values: 'camera_index=0' (default camera), 'nb_frames=1', 'skip_frames=0' and 'capture_width=capture_height=0' (default size).
# 1262 #@cli clut : "clut_name",_resolution>0
# 1263 #@cli : Insert one of the pre-defined CLUTs at the end of the image list.\n
# 1264 #@cli : 'clut_name' can be { 60's | 60's_faded | 60's_faded_alt | agfa_apx_100 | agfa_apx_25 | agfa_precisa_100 | agfa_ultra_color_100 | agfa_vista_200 | alien_green | analogfx_anno_1870_color | analogfx_old_style_i | analogfx_old_style_ii | analogfx_old_style_iii | analogfx_sepia_color | analogfx_soft_sepia_i | analogfx_soft_sepia_ii | black_and_white | bleach_bypass | blue_mono | color_rich | expired_fade | expired_polaroid | extreme | fade | faded | faded_alt | faded_analog | faded_extreme | faded_vivid | faux_infrared | fuji3510_constlclip | fuji3510_constlmap | fuji3510_cuspclip | fuji3513_constlclip | fuji3513_constlmap | fuji3513_cuspclip | fuji_160c | fuji_160c_+ | fuji_160c_++ | fuji_160c_- | fuji_400h | fuji_400h_+ | fuji_400h_++ | fuji_400h_- | fuji_800z | fuji_800z_+ | fuji_800z_++ | fuji_800z_- | fuji_astia_100f | fuji_fp-100c | fuji_fp-100c_+ | fuji_fp-100c_++ | fuji_fp-100c_+++ | fuji_fp-100c_++_alt | fuji_fp-100c_- | fuji_fp-100c_-- | fuji_fp-100c_cool | fuji_fp-100c_cool_+ | fuji_fp-100c_cool_++ | fuji_fp-100c_cool_- | fuji_fp-100c_cool_-- | fuji_fp-100c_negative | fuji_fp-100c_negative_+ | fuji_fp-100c_negative_++ | fuji_fp-100c_negative_+++ | fuji_fp-100c_negative_++_alt | fuji_fp-100c_negative_- | fuji_fp-100c_negative_-- | fuji_fp-3000b | fuji_fp-3000b_+ | fuji_fp-3000b_++ | fuji_fp-3000b_+++ | fuji_fp-3000b_- | fuji_fp-3000b_-- | fuji_fp-3000b_hc | fuji_fp-3000b_negative | fuji_fp-3000b_negative_+ | fuji_fp-3000b_negative_++ | fuji_fp-3000b_negative_+++ | fuji_fp-3000b_negative_- | fuji_fp-3000b_negative_-- | fuji_fp-3000b_negative_early | fuji_fp_100c | fuji_ilford_delta_3200 | fuji_ilford_delta_3200_+ | fuji_ilford_delta_3200_++ | fuji_ilford_delta_3200_- | fuji_ilford_hp5 | fuji_ilford_hp5_+ | fuji_ilford_hp5_++ | fuji_ilford_hp5_- | fuji_neopan_1600 | fuji_neopan_1600_+ | fuji_neopan_1600_++ | fuji_neopan_1600_- | fuji_neopan_acros_100 | fuji_provia_100f | fuji_provia_400f | fuji_provia_400x | fuji_sensia_100 | fuji_superia_100 | fuji_superia_100_+ | fuji_superia_100_++ | fuji_superia_100_- | fuji_superia_1600 | fuji_superia_1600_+ | fuji_superia_1600_++ | fuji_superia_1600_- | fuji_superia_200 | fuji_superia_200_xpro | fuji_superia_400 | fuji_superia_400_+ | fuji_superia_400_++ | fuji_superia_400_- | fuji_superia_800 | fuji_superia_800_+ | fuji_superia_800_++ | fuji_superia_800_- | fuji_superia_hg_1600 | fuji_superia_reala_100 | fuji_superia_x-tra_800 | fuji_velvia_50 | fuji_xtrans_ii_astia_v2 | fuji_xtrans_ii_classic_chrome_v1 | fuji_xtrans_ii_pro_neg_hi_v2 | fuji_xtrans_ii_pro_neg_std_v2 | fuji_xtrans_ii_provia_v2 | fuji_xtrans_ii_velvia_v2 | generic_fuji_astia_100 | generic_fuji_provia_100 | generic_fuji_velvia_100 | generic_kodachrome_64 | generic_kodak_ektachrome_100_vs | golden | golden_bright | golden_fade | golden_mono | golden_vibrant | goldfx_bright_spring_breeze | goldfx_bright_summer_heat | goldfx_hot_summer_heat | goldfx_perfect_sunset_01min | goldfx_perfect_sunset_05min | goldfx_perfect_sunset_10min | goldfx_spring_breeze | goldfx_summer_heat | green_mono | hong_kong | ilford_delta_100 | ilford_delta_3200 | ilford_delta_400 | ilford_fp4_plus_125 | ilford_hp5_plus_400 | ilford_hps_800 | ilford_pan_f_plus_50 | ilford_xp2 | kodak2383_constlclip | kodak2383_constlmap | kodak2383_cuspclip | kodak2393_constlclip | kodak2393_constlmap | kodak2393_cuspclip | kodak_bw_400_cn | kodak_e-100_gx_ektachrome_100 | kodak_ektachrome_100_vs | kodak_elite_100_xpro | kodak_elite_chrome_200 | kodak_elite_chrome_400 | kodak_elite_color_200 | kodak_elite_color_400 | kodak_elite_extracolor_100 | kodak_hie_(hs_infra) | kodak_kodachrome_200 | kodak_kodachrome_25 | kodak_kodachrome_64 | kodak_portra_160 | kodak_portra_160_+ | kodak_portra_160_++ | kodak_portra_160_- | kodak_portra_160_nc | kodak_portra_160_nc_+ | kodak_portra_160_nc_++ | kodak_portra_160_nc_- | kodak_portra_160_vc | kodak_portra_160_vc_+ | kodak_portra_160_vc_++ | kodak_portra_160_vc_- | kodak_portra_400 | kodak_portra_400_+ | kodak_portra_4 ...
# 1265 #@cli : $ clut summer
# 1266 clut : check "isval(${2=64}) && $2>0"
# 1267 e[^-1] "Input CLUT with name '$1' and resolution $2."
# 1268 v - l[]
# 1269 if ${_path_rc}clut_"$1".cimgz i ${_path_rc}clut_"$1".cimgz fi
# 3449 x "ln -fs ../highslide ."
# 3450 categories=arrays,artistic,blackandwhite,colors,deformations,filtering,patterns,3drendering,codesamples
# 3451 nb_categories={narg($categories)}
# 3452 commands_arrays=gallery_arrays,array,array_fade,array_mirror,frame_blur,frame_cube,frame_painting,img2ascii,imagegrid,rotate_tiles,vignette,tunnel
# 3453 commands_artistic=gallery_artistic,boxfitting,cartoon,cubism,draw_whirl,fractalize,halftone,light_relief,sketchbw,linify,mosaic,polaroid,polygonize,poster_hope,rodilius,stained_glass,stencil
# 3454 commands_blackandwhite=gallery_blackandwhite,pencilbw,old_photo,sepia
# 3455 commands_colors=gallery_colors,solarize,hsv2rgb,transfer_rgb
# 3456 commands_deformations=gallery_deformations,deform,map_sphere,seamcarve,spherize,twirl,warp_perspective,water,wave
# 3457 commands_filtering=gallery_filtering,blur_angular,blur_linear,blur_radial,glow,smooth,bilateral,dog,deriche,distance,gradient_norm,normalize_local,sharpen,solidify
# 3458 commands_patterns=gallery_patterns,tsp,chessboard,mandelbrot,maze_mask,plasma,shape_fern,shape_snowflake,sierpinski,syntexturize_patchmatch,truchet,turbulence,watermark_visible,weave
# 3459 commands_3drendering=gallery_3drendering,add3d,distribution3d,elevation3d,gmic3d,imageblocks3d,imagerubik3d,skeleton3d,spherical3d,tensors3d,text3d,torus3d,weird3d
# 6199 select_color : skip ${1=0}
# 6200 e[^-1] "Select color (${2--1}) in image$?, with tolerance $1."
# 6201 v - repeat $! l[$>]
# 6202 +fc ${2--1} - norm <= $1
# 6203 endl done v +
# 6204 #@cli sepia
# 6205 #@cli : Apply sepia tones effect on selected images.
# 6206 #@cli : $ image.jpg sepia
# 6207 sepia :
# 6208 e[^-1] "Apply sepia tones effect on image$?."
# 6209 v - (0,44,115,143,196,244^0,20,84,119,184,235^0,5,44,73,144,200) r. 256,1,1,3,3
# 13816 #@cli old_photo
# 13817 #@cli : Apply old photo effect on selected images.
# 13818 #@cli : $ image.jpg old_photo
# 13819 old_photo :
# 13820 e[^-1] "Apply old photo effect on image$?."
# 13821 v - noise 20 bilateral 30,60 b 2 sharpen 100 frame_fuzzy 8%,8%,6,3 to_rgb shadow_patch 0.75 n 0,255 sepia v +
# 13822 #@cli pencilbw : _size>=0,_amplitude>=0
# 13823 #@cli : Apply B&W pencil effect on selected images.
# 13824 #@cli : Default values: 'size=0.3' and 'amplitude=60'.
# 13825 #@cli : $ image.jpg pencilbw ,
# 13826 pencilbw : skip ${1=0.3},${2=60}
# 20940 #@gui_ja : &#33258;&#24049;&#20132;&#24046;&#12434;&#35377;&#21487; = bool(1)
# 20941 #@gui_ja : sep = separator(), &#12503;&#12524;&#12499;&#12517;&#12540;&#12398;&#31278;&#39006; = choice(0,"Colored geometry","Colored regions","Colored lineart")
# 20942 #@gui_ja : sep = separator(), note = note("<small>&#20316;&#32773;: David Tschumperl&#233;&#12289;S&#233;bastien Fourey&#12289;David Revoy</i> &#26368;&#32066;&#26356;&#26032;: <i>2016/12/13</i></small>")
# 20943 #@gui _
# 20944 #@gui_ja <b>&#33394;</b>
# 20945 #@gui_ja &#12475;&#12500;&#12450; : fx_sepia, fx_sepia_preview
# 20946 #@gui_ja : &#12460;&#12531;&#12510; = float(0,-1.2,1.2)
# 20947 #@gui_ja : &#12467;&#12531;&#12488;&#12521;&#12473;&#12488; = float(1,0,4)
# 20948 #@gui_ja : &#36637;&#24230; = float(0,-255,255)
# 20949 #@gui_ja : sep = separator(), &#12503;&#12524;&#12499;&#12517;&#12540;&#12398;&#34920;&#31034;&#26041;&#27861; = choice("&#20840;&#20307;","&#19979;&#21322;&#20998;","&#21491;&#21322;&#20998;","&#19978;&#21322;&#20998;","&#24038;&#21322;&#20998;","&#19978;&#31471;&#37096;&#12434;&#35079;&#35069;","&#24038;&#31471;&#37096;&#12434;&#35079;&#35069;","&#19979;&#31471;&#37096;&#12434;&#35079;&#35069;","&#21491;&#31471;&#37096;&#12434;&#35079;&#35069;")
# 20950 #@gui_ja : sep = separator(), note = note("<small>&#20316;&#32773;: <i><a href="https://goo.gl/Ryf7Cv">David Tschumperl&#233;</a></i> &#26368;&#32066;&#26356;&#26032;: <i>2010/12/29</i></small>")
# 27278 a c hsl2rgb
# 27279 endl a c endl done
# 27280 fx_selective_desaturation_preview :
# 27281 gui_split_preview "fx_selective_desaturation $*",$-1
# 27282 #@gui Sepia : fx_sepia, fx_sepia_preview(1)+
# 27283 #@gui : Brightness (%) = float(0,-100,100)
# 27283 #@gui : Brightness (%) = float(0,-100,100)
# 27284 #@gui : Contrast (%) = float(0,-100,100)
# 27284 #@gui : Contrast (%) = float(0,-100,100)
# 27285 #@gui : Gamma (%) = float(0,-100,100)
# 27285 #@gui : Gamma (%) = float(0,-100,100)
# 27286 #@gui : sep = separator(), Preview type = choice("Full","Forward horizontal","Forward vertical","Backward horizontal","Backward vertical","Duplicate top","Duplicate left","Duplicate bottom","Duplicate right")
# 27286 #@gui : sep = separator(), Preview type = choice("Full","Forward horizontal","Forward vertical","Backward horizontal","Backward vertical","Duplicate top","Duplicate left","Duplicate bottom","Duplicate right")
# 27287 #@gui : sep = separator(), note = note("<small>Author: <i><a href="https://goo.gl/Ryf7Cv">David Tschumperl&#233;</a></i>.      Latest update: <i>2010/29/12</i>.</small>")
# 27287 #@gui : sep = separator(), note = note("<small>Author: <i><a href="https://goo.gl/Ryf7Cv">David Tschumperl&#233;</a></i>.      Latest update: <i>2010/29/12</i>.</small>")
# 27288 fx_sepia :
# 27289 sepia adjust_colors ${1-3},0,0,0,255
# 27290 fx_sepia_preview :
# 27291 gui_split_preview "fx_sepia $*",$-1
# 27292 #@gui Specific saturation : gcd_hio_levels, gcd_hio_levels_preview(1)
# 27293 #@gui : note = note("\n<i>Hue Levels</i>"), sep = separator()
# 31350 fx_emulate_film_picturefx :
# 31351 _fx_emulate_film $1,${arg\ {max(1,$1)},${-_$0}},${2--1}
# 31352 _fx_emulate_film_picturefx :
# 31353 u analogfx_anno_1870_color,\
# 31354 analogfx_old_style_i,analogfx_old_style_ii,analogfx_old_style_iii,\
# 31355 analogfx_sepia_color,analogfx_soft_sepia_i,analogfx_soft_sepia_ii,\
# 31356 goldfx_perfect_sunset_01min,goldfx_perfect_sunset_05min,goldfx_perfect_sunset_10min,\
# 31357 goldfx_spring_breeze,goldfx_bright_spring_breeze,goldfx_summer_heat,goldfx_bright_summer_heat,goldfx_hot_summer_heat,\
# 31358 technicalfx_backlight_filter,\
# 31359 zilverfx_b_w_solarization,zilverfx_infrared,zilverfx_vintage_b_w
# 31360 fx_emulate_film_picturefx_preview :
# 37877 #@gui : End frame number = int(1,1,99999)
# 37878 #@gui : Frame files format = choice(".png",".bmp")
# 37879 #@gui : sep = separator()
# 37880 #@gui : note = note("<b>Advanced editing:</b>")
# 37881 #@gui : Activate custom filter = choice("off","on","left stream only", "right stream only")
# 37882 #@gui : Custom filter code = text(1,"# old movie #\n#-luminance -fx_stripes_y 10,3,0 -sepia \n\n#simple vintage#\n#--fc 0,15,125 -rv -fx_compose_exclusion 0.3 \n\n# HDR popout #\n#-fx_map_tones_fast 2,0.3,3,2 -fx_unsharp_octave 4,5,3,0,0,0\n\n")
# 37883 #@gui : Depth fade in frames = int(0,0,120)
# 37884 #@gui : Depth fade out frames = int(0,0,120)
# 37885 #@gui : sep = separator()
# 37886 #@gui : note = note("<b>Advanced quality control:</b>")
# 37887 #@gui : Key frame rate = int(1,1,100)
# 39781 -fx_bwrecolorize 1,1,0,0,0,1,0,6,0,0,0,255,27,25,55,255,137,152,189,255,191,217,228,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,255,0
# 39782 --noise[0] {$1/1},4
# 39783 -compose_interpolation
# 39784 -else
# 39785 -if {$3==1}
# 39786 -sepia
# 39787 --fc[0] 0,65,00 -to_rgba[0]
# 39788 -compose_interpolation
# 39788 -compose_interpolation
# 39789 -noise[0] {$1/1},4
# 39789 -noise[0] {$1/1},4
# 39790 -compose_grainmerge
# 39790 -compose_grainmerge
# 39791 -else
# 39791 -else
# 39792 -if {$2==0}
# 39793 -sepia
# 39794 --noise[0] $1,4
# 39795 -compose_grainmerge
# 39796 -else
# 39797 -sepia
# 39798 --fc[0] 0,0,255 -to_rgba[0]

# %%
# !gmic -v 99 -i posterize0022B.jpg old_photo -display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Set verbosity level to 99.
# [gmic]-0./ Input file 'posterize0022B.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Apply old photo effect on image [0].
# [gmic]-1./old_photo/ Decrement verbosity level (set to 98).
# [gmic]-1./old_photo/ Add gaussian noise to image [0], with standard deviation 20.
# [gmic]-1./old_photo/ Apply bilateral filter on image [0], with standard deviations (30,60) and sampling (0,0).
# [gmic]-1./old_photo/ Blur image [0] with standard deviation 2, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-1./old_photo/ Sharpen image [0] with inverse diffusion and amplitude 100.
# [gmic]-1./old_photo/frame_fuzzy/ Skip argument '8%,6,3,255,255,255,255'.
# [gmic]-1./old_photo/ Draw 8%x8% fuzzy frame on image [0], with fuzzyness 6, smoothness 3 and RGBA color (255,255,255,255).
# [gmic]-1./old_photo/frame_fuzzy/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/ Force image [0] to be in RGBA mode.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Reach 'elif' block -> condition '1' holds.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Keep channels 0...3 of image [0].
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Insert shared buffer from channel 3 of image [0].
# [gmic]-2./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Fill image [1] with 255.
# [gmic]-2./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Input image at position 1, with values '1' (1 image 640x640x1x1).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Decrement verbosity level (set to 96).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Set status to '1'.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Set local variable 'padx=25.560000000000002'.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Decrement verbosity level (set to 96).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Set status to '1'.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Set local variable 'pady=25.560000000000002'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Skip argument '1,0,0'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Skip argument '1'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Set status to '0'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Draw filled rectangle from (25.560000000000002,25.560000000000002) to (613.44000000000005,613.44000000000005) on image [1], with opacity 1 and color (0,0).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Draw 4-vertices filled polygon on image [0], with opacity 1 and color (0,0).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/ Skip argument '6,6,0'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Spread pixel of image [1] randomly, with amplitudes (6,6,0).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Input black image at position 1 (1 image 640x640x1x3).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Insert shared buffer from channel 0 of image [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Fill image [2] with random values, in range [-6,6].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [2] (2 images left).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Insert shared buffer from channel 1 of image [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Fill image [2] with random values, in range [-6,6].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [2] (2 images left).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Insert shared buffer from channel 2 of image [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Fill image [2] with random values, in range [0,0].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [2] (2 images left).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Warp image [0] with backward-relative displacement field [1], linear interpolation, neumann boundary conditions.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Blur image [1] with standard deviation 3, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Input black image at position 2 (1 image 640x640x1x4).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/ Set global variable '_gmic_s= [2]'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Fill image [2] with color (255,255,255,255).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Start 'repeat...done' block (4 iterations).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 0 of image [0].
# [gmic]-2./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [1] with 255.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 1 of image [0].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [2] with 255.
# [gmic]-3./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 2 of image [0].
# [gmic]-4./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [3] with 255.
# [gmic]-4./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 3 of image [0].
# [gmic]-5./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [4] with 255.
# [gmic]-5./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ End 'repeat...done' block.
# [gmic]-5./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ Keep image [0] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ Set name of image [0] to '[unnamed]'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/ Increment verbosity level (set to 97).
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/ Draw image [2] at (0,0,0,0) on image [0], with opacity 1 and mask [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/ Keep image [0] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/ Force image [0] to be in RGB mode.
# [gmic]-1./old_photo/to_rgb/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/to_rgb/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/to_rgb/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '1' holds.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Keep channels 0...2 of image [0].
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/to_rgb/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/to_rgb/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/shadow_patch/ Skip argument '0.75'.
# [gmic]-1./old_photo/ Apply shadow patches to image [0], with opacity 0.75.
# [gmic]-1./old_photo/shadow_patch/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/shadow_patch/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/shadow_patch/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/shadow_patch/*repeat/*local/ Input black image at position 1 (1 image 640x640x1x1).
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Shift image [1] by displacement vector (-2,-2,0,0), dirichlet boundary conditions and nearest-neighbor interpolation.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Shift image [1] by displacement vector (1,1,0,0), dirichlet boundary conditions and nearest-neighbor interpolation.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Draw plasma fractal on image [1], with alpha 3, beta 0.3 and scale 8.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Compute pointwise absolute value of image [1].
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Blur image [1] with standard deviation 1, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Cut image [1] in range [3%,15%].
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Resize image [1] to 640x640x1x3, with nearest-neighbor interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Normalize image [1] in range [0.75,1].
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Multiply images [0,1].
# [gmic]-1./old_photo/shadow_patch/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/shadow_patch/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/shadow_patch/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/ Normalize image [0] in range [0,255].
# [gmic]-1./old_photo/ Apply sepia tones effect on image [0].
# [gmic]-1./old_photo/sepia/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/sepia/ Input image at position 1, with values (0,44,115,143,196,244^0,20,84,119,184,235^0,5,44,73,144,200) (1 image 6x1x1x3).
# [gmic]-2./old_photo/sepia/ Resize image [1] to 256x1x1x3, with linear interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-2./old_photo/sepia/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-2./old_photo/sepia/*repeat/*local/ Start 'local...endlocal' block, with selected images [0,1].
# [gmic]-2./old_photo/sepia/*repeat/*local/ Split color and opacity parts of images [0,1].
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/ Decrement verbosity level (set to 96).
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/ Start 'repeat...done' block (2 iterations).
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [1].
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Split image [0] along the 'c'-axis, into blocs of 3 pixels.
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Split image [0] along the 'c'-axis, into blocs of 3 pixels.
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/ End 'repeat...done' block.
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/sepia/*repeat/*local/ Compute luminance of image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Remove opacity channel of image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/ Decrement verbosity level (set to 95).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/sepia/*repeat/(...)/remove_opacity/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/sepia/*repeat/(...)/remove_opacity/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/sepia/*repeat/(...)/remove_opacity/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ Set name of image [0] to 'posterize0022B.jpg'.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/ Increment verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Convert color representation of image [0] from sRGB to linear RGB.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/srgb2rgb/ Decrement verbosity level (set to 95).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/srgb2rgb/ Fill image [0] with expression 'sval = i/255; val = sval<=0.04045?sval(...)055)/(1.055))^2.4; cut(255*val,0,255)'.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/srgb2rgb/ Increment verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Start 'if...endif' block -> condition '1' holds.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 0 of image [0].
# [gmic]-2./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 1 of image [0].
# [gmic]-3./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 2 of image [0].
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [1] by 0.222488.
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [2] by 0.716904.
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [3] by 0.0606079.
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Add images [1,2,3].
# [gmic]-2./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Keep channel 0 of image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Convert color representation of image [0] from linear RGB to sRGB.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/rgb2srgb/ Decrement verbosity level (set to 95).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/rgb2srgb/ Fill image [0] with expression 'val = i/255; sval = val<=0.0031308?val(...)0.416667 - 0.055; cut(255*sval,0,255)'.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/rgb2srgb/ Increment verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/sepia/*repeat/*local/ Map LUT [1] on image [0], with dirichlet boundary conditions.
# [gmic]-2./old_photo/sepia/*repeat/*local/ Append image [0] along the 'c'-axis, with alignment 0.
# [gmic]-2./old_photo/sepia/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./old_photo/sepia/*repeat/ End 'repeat...done' block.
# [gmic]-2./old_photo/sepia/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/sepia/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/ Increment verbosity level (set to 99).
# [gmic]-1./ Display image [0] = 'posterize0022B.jpg'.
# [0] = 'posterize0022B.jpg':
#   size = (640,640,1,3) [4800 Kio of floats].
#   data = (244,244,244,244,244,244,244,244,244,244,244,244,(...),200,200,200,200,200,200,200,200,200,200,200,200).
#   min = 0, max = 244, mean = 82.1264, std = 77.8052, coords_min = (375,450,0,0), coords_max = (0,0,0,0).
# [gmic]-1./ End G'MIC interpreter.

# %%
# !gmic -v 99 -i posterize0022B.jpg sepia -display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Set verbosity level to 99.
# [gmic]-0./ Input file 'posterize0022B.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Apply sepia tones effect on image [0].
# [gmic]-1./sepia/ Decrement verbosity level (set to 98).
# [gmic]-1./sepia/ Input image at position 1, with values (0,44,115,143,196,244^0,20,84,119,184,235^0,5,44,73,144,200) (1 image 6x1x1x3).
# [gmic]-2./sepia/ Resize image [1] to 256x1x1x3, with linear interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-2./sepia/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-2./sepia/*repeat/*local/ Start 'local...endlocal' block, with selected images [0,1].
# [gmic]-2./sepia/*repeat/*local/ Split color and opacity parts of images [0,1].
# [gmic]-2./sepia/*repeat/*local/split_opacity/ Decrement verbosity level (set to 97).
# [gmic]-2./sepia/*repeat/*local/split_opacity/*repeat/ Start 'repeat...done' block (2 iterations).
# [gmic]-2./sepia/*repeat/*local/split_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [1].
# [gmic]-1./sepia/*repeat/*local/split_opacity/*repeat/*local/ Split image [0] along the 'c'-axis, into blocs of 3 pixels.
# [gmic]-1./sepia/*repeat/*local/split_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./sepia/*repeat/*local/split_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./sepia/*repeat/*local/split_opacity/*repeat/*local/ Split image [0] along the 'c'-axis, into blocs of 3 pixels.
# [gmic]-1./sepia/*repeat/*local/split_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./sepia/*repeat/*local/split_opacity/*repeat/ End 'repeat...done' block.
# [gmic]-2./sepia/*repeat/*local/split_opacity/ Increment verbosity level (set to 98).
# [gmic]-1./sepia/*repeat/*local/ Compute luminance of image [0].
# [gmic]-1./sepia/*repeat/*local/luminance/ Decrement verbosity level (set to 97).
# [gmic]-1./sepia/*repeat/*local/luminance/ Remove opacity channel of image [0].
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/ Decrement verbosity level (set to 96).
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ Set name of image [0] to 'posterize0022B.jpg'.
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/*repeat/ End 'repeat...done' block.
# [gmic]-1./sepia/*repeat/*local/luminance/remove_opacity/ Increment verbosity level (set to 97).
# [gmic]-1./sepia/*repeat/*local/luminance/ Convert color representation of image [0] from sRGB to linear RGB.
# [gmic]-1./sepia/*repeat/*local/luminance/srgb2rgb/ Decrement verbosity level (set to 96).
# [gmic]-1./sepia/*repeat/*local/luminance/srgb2rgb/ Fill image [0] with expression 'sval = i/255; val = sval<=0.04045?sval(...)055)/(1.055))^2.4; cut(255*val,0,255)'.
# [gmic]-1./sepia/*repeat/*local/luminance/srgb2rgb/ Increment verbosity level (set to 97).
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Start 'if...endif' block -> condition '1' holds.
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 0 of image [0].
# [gmic]-2./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 1 of image [0].
# [gmic]-3./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 2 of image [0].
# [gmic]-4./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [1] by 0.222488.
# [gmic]-4./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [2] by 0.716904.
# [gmic]-4./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [3] by 0.0606079.
# [gmic]-4./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Add images [1,2,3].
# [gmic]-2./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Remove image [1] (1 image left).
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./sepia/*repeat/*local/luminance/*repeat/ End 'repeat...done' block.
# [gmic]-1./sepia/*repeat/*local/luminance/ Keep channel 0 of image [0].
# [gmic]-1./sepia/*repeat/*local/luminance/ Convert color representation of image [0] from linear RGB to sRGB.
# [gmic]-1./sepia/*repeat/*local/luminance/rgb2srgb/ Decrement verbosity level (set to 96).
# [gmic]-1./sepia/*repeat/*local/luminance/rgb2srgb/ Fill image [0] with expression 'val = i/255; sval = val<=0.0031308?val(...)0.416667 - 0.055; cut(255*sval,0,255)'.
# [gmic]-1./sepia/*repeat/*local/luminance/rgb2srgb/ Increment verbosity level (set to 97).
# [gmic]-1./sepia/*repeat/*local/luminance/ Increment verbosity level (set to 98).
# [gmic]-2./sepia/*repeat/*local/ Map LUT [1] on image [0], with dirichlet boundary conditions.
# [gmic]-2./sepia/*repeat/*local/ Append image [0] along the 'c'-axis, with alignment 0.
# [gmic]-2./sepia/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./sepia/*repeat/ End 'repeat...done' block.
# [gmic]-2./sepia/ Remove image [1] (1 image left).
# [gmic]-1./sepia/ Increment verbosity level (set to 99).
# [gmic]-1./ Display image [0] = 'posterize0022B.jpg'.
# [0] = 'posterize0022B.jpg':
#   size = (640,640,1,3) [4800 Kio of floats].
#   data = (213.882,213.882,213.882,213.882,213.882,213.882,213.882,213.882,213.882,213.882,213.882,213.882,(...),4.21569,4.21569,4.21569,4.21569,4.21569,4.21569,4.21569,4.21569,4.21569,4.21569,4.21569,4.21569).
#   min = 4.01961, max = 231.765, mean = 82.5411, std = 66.4387, coords_min = (135,215,0,2), coords_max = (25,53,0,0).
# [gmic]-1./ End G'MIC interpreter.

# %%
v - noise 20 bilateral 30,60 b 2 sharpen 100 frame_fuzzy 8%,8%,6,3 to_rgb shadow_patch 0.75 n 0,255 sepia v +

# %%
from SEARCHdocs import searchdocs
searchdocs("GMIC-documents.txt")
# Out:
# SEARCH: halftone
# 85   - In G'MIC, an image processing pipeline is described as a sequence of items separated by the
# 86      space character ' '. Such items are interpreted and executed from the left to the right.
# 87      For instance, the expression:
# 89        filename.jpg blur 3,0 sharpen 10 resize 200%,200% output file_out.jpg
# 91      defines a valid pipeline composed of nine G'MIC items.
# 93   - Each G'MIC item is a string that is either a command, a list of command arguments,
# 94      a filename, or a special input string.
# 161   - A G'MIC item that is not a filename nor a special input string designates a command,
# 162      most of the time. Generally, commands perform image processing operations on one or several
# 163      available images of the list.
# 165   - Reccurent commands have two equivalent names (regular and short). For instance, command names
# 166      'resize' and 'r' refer to the same image resizing action.
# 168   - A G'MIC command may have mandatory or optional arguments. Command arguments must be specified
# 169      in the next item on the command line. Commas ',' are used to separate multiple arguments of a
# 170      single command, when required.
# 403        . 'y': Y-coordinate of the mouse position (or -1, if outside the display area).
# 404        . 'b': state of the mouse buttons { 1=left-but. | 2=right-but. | 4=middle-but. }.
# 405        . 'o': state of the mouse wheel.
# 406        . 'k': decimal code of the pressed key if any, 0 otherwise.
# 407        . 'c': boolean (0 or 1) telling if the instant display has been closed recently.
# 408        . 'r': boolean telling if the instant display has been resized recently.
# 409        . 'm': boolean telling if the instant display has been moved recently.
# 410        . Any other 'feature' stands for a keycode name (in capital letters), and is substituted by
# 411           a boolean describing the current key state { 0=pressed | 1=released }.
# 412        . You can also prepend a hyphen '-' to a 'feature' (that supports it) to flush the
# 413           corresponding event immediately after reading its state (works for keys, mouse and
# 481           image, if any (0 otherwise).
# 482        . 'xM','yM','zM','cM': The pixel coordinates of the maximum value in the associated
# 483           image, if any (0 otherwise).
# 484        . All these variables are considered as constant values by the math parser (for optimization
# 485           purposes) which is indeed the case most of the time. Anyway, this might not be the case,
# 486           if function 'resize(#ind,..)' is used in the math expression.
# 487           If so, it is safer to invoke functions 'l()', 'w(_#ind)', 'h(_#ind)', ... 's(_#ind)'
# 488           and 'ic(_#ind)' instead of the corresponding named variables.
# 489        . 'i': current processed pixel value (i.e. value located at (x,y,z,c)) in the associated
# 490           image, if any (0 otherwise).
# 491        . 'iN': Nth channel value of current processed pixel (i.e. value located at (x,y,z,N)) in
# 532          'sort(X,_is_increasing,_chunk_size)' (sorting values), 'reverse(A)' (reverse order of
# 533          components), 'shift(A,_length,_boundary_conditions)' and
# 534          'same(A,B,_nb_vals,_is_case_sensitive)' (vector equality test).
# 535        . Function 'normP(u1,...,un)' computes the LP-norm of the specified vector
# 536           (P being an unsigned integer constant or 'inf'). If P is omitted, the L2 norm is used.
# 537        . Function 'resize(A,size,_interpolation,_boundary_conditions)' returns a resized version of
# 538           a vector 'A' with specified interpolation mode. 'interpolation' can be { -1=none
# 539           (memory content) | 0=none | 1=nearest | 2=average | 3=linear | 4=grid | 5=bicubic |
# 540           6=lanczos }, and 'boundary_conditions'  can be { 0=dirichlet | 1=neumann | 2=periodic | 3=mirror }.
# 541        . Function 'find(A,B,_is_forward,_starting_indice)' returns the index where sub-vector B
# 542           appears in vector A, (or -1 if B is not found in A). Argument A can be also replaced by
# 637        . 'polygon(_#ind,nb_vertices,coords,_opacity,_color)' draws a filled polygon in image [ind]
# 638           (or in default image selected if 'ind' is not specified) at specified coordinates.
# 639           It draws a single line if 'nb_vertices' is set to 2.
# 640        . 'ellipse(_#ind,xc,yc,radius1,_radius2,_angle,_opacity,_color)' draws a filled ellipse in image [ind]
# 641           (or in default image selected if 'ind' is not specified) with specified coordinates and geometry.
# 642        . 'resize(#ind,w,_h,_d,_s,_interp,_boundary_conditions,cx,_cy,_cz,_cc)' resizes an image of the
# 643           associated list with specified dimension and interpolation method. When using this,
# 644           function, you should consider retrieving the (non-constant) image dimensions using the
# 645           dynamic functions 'w(_#ind)', 'h(_#ind)', 'd(_#ind)', 's(_#ind)', 'wh(_#ind)',
# 646           'whd(_#ind)' and 'whds(_#ind)' instead of the corresponding constant variables.
# 647        . 'if(condition,expr_then,_expr_else)': return value of 'expr_then' or 'expr_else',
# 2895       Permute selected image axes by specified permutation.
# 2896       'permutation' is a combination of the character set {x|y|z|c},
# 2897       e.g. 'xycz', 'cxyz', ...
# 2899     resize (+):
# 2900         [image],_interpolation,_boundary_conditions,_ax,_ay,_az,_ac |
# 2901         {[image_w] | width>0[%]},_{[image_h] | height>0[%]},_{[image_d] | depth>0[%]},\
# 2902          _{[image_s] | spectrum>0[%]},_interpolation,_boundary_conditions,_ax,_ay,_az,_ac |
# 2903         (no arg)
# 2916       (set to '0' by default, must be defined in range [0,1]).
# 2917       (no arg) runs interactive mode (uses the instant display window [0] if opened).
# 2918
# 2919       Default values: 'interpolation=1', 'boundary_conditions=0' and 'ax=ay=az=ac=0'.
# 2921     resize_mn:
# 2922         width[%]>=0,_height[%]>=0,_depth[%]>=0,_B_value,_C_value
# 2924       Resize selected images with Mitchell-Netravali filter (cubic).
# 2924       Resize selected images with Mitchell-Netravali filter (cubic).
# 2925       For details about the method, see: https://de.wikipedia.org/wiki/Mitchell-Netravali-Filter
# 2925       For details about the method, see: https://de.wikipedia.org/wiki/Mitchell-Netravali-Filter
# 2926
# 2926
# 2927       Default values: 'height=100%', 'depth=100%', 'B=0.3333' and 'C=0.3333'.
# 2929     resize_pow2:
# 2930         _interpolation,_boundary_conditions,_ax,_ay,_az,_ac
# 2932       Resize selected images so that each dimension is a power of 2.
# 2933       'interpolation' can be { -1=none (memory content) | 0=none | 1=nearest | 2=average | 3=linear |
# 2934         4=grid | 5=bicubic | 6=lanczos }.
# 2940       'ax,ay,az,ac' set the centering along each axis when 'interpolation=0'
# 2941       (set to '0' by default, must be defined in range [0,1]).
# 2942
# 2943       Default values: 'interpolation=0', 'boundary_conditions=0' and 'ax=ay=az=ac=0'.
# 2945     resize_ratio2d:
# 2946         width>0,height>0,_mode={ 0=inside | 1=outside | 2=padded },0=<_interpolation<=6
# 2948       Resize selected images while preserving their aspect ratio.
# 2948       Resize selected images while preserving their aspect ratio.
# 2949       (equivalent to shorcut command 'rr2d').
# 2949       (equivalent to shorcut command 'rr2d').
# 2950
# 2950
# 2951       Default values: 'mode=0' and 'interpolation=6'.
# 2953     resize2dx:
# 2954         width[%]>0,_interpolation,_boundary_conditions,_ax,_ay,_az,_ac
# 2956       Resize selected images along the x-axis, preserving 2d ratio.
# 2957       (equivalent to shorcut command 'r2dx').
# 2966       'ax,ay,az,ac' set the centering along each axis when 'interpolation=0'
# 2967       (set to '0' by default, must be defined in range [0,1]).
# 2968
# 2969       Default values: 'interpolation=3', 'boundary_conditions=0' and 'ax=ay=az=ac=0'.
# 2971     resize2dy:
# 2972         height[%]>=0,_interpolation,_boundary_conditions,_ax,_ay,_az,_ac
# 2974       Resize selected images along the y-axis, preserving 2d ratio.
# 2975       (equivalent to shorcut command 'r2dy').
# 2984       'ax,ay,az,ac' set the centering along each axis when 'interpolation=0'
# 2985       (set to '0' by default, must be defined in range [0,1]).
# 2986
# 2987       Default values: 'interpolation=3', 'boundary_conditions=0' and 'ax=ay=az=ac=0'.
# 2989     resize3dx:
# 2990         width[%]>0,_interpolation,_boundary_conditions,_ax,_ay,_az,_ac
# 2992       Resize selected images along the x-axis, preserving 3d ratio.
# 2993       (equivalent to shorcut command 'r3dx').
# 3002       'ax,ay,az,ac' set the centering along each axis when 'interpolation=0'
# 3003       (set to '0' by default, must be defined in range [0,1]).
# 3004
# 3005       Default values: 'interpolation=3', 'boundary_conditions=0' and 'ax=ay=az=ac=0'.
# 3007     resize3dy:
# 3008         height[%]>0,_interpolation,_boundary_conditions,_ax,_ay,_az,_ac
# 3010       Resize selected images along the y-axis, preserving 3d ratio.
# 3011       (equivalent to shorcut command 'r3dy').
# 3020       'ax,ay,az,ac' set the centering along each axis when 'interpolation=0'
# 3021       (set to '0' by default, must be defined in range [0,1]).
# 3022
# 3023       Default values: 'interpolation=3', 'boundary_conditions=0' and 'ax=ay=az=ac=0'.
# 3025     resize3dz:
# 3026         depth[%]>0,_interpolation,_boundary_conditions,_ax,_ay,_az,_ac
# 3028       Resize selected images along the z-axis, preserving 3d ratio.
# 3029       (equivalent to shorcut command 'r3dz').
# 4528       (equivalent to shorcut command 't').
# 4530       Exact pre-defined sizes are '13','23','53' and '103'. Using these sizes ensures you draw binary
# 4531         letters without anti-aliasing.
# 4532       Any other font size is interpolated from an exact size (the upper when possible).
# 4533       Specifying an empty target image resizes it to new dimensions such that the image contains
# 4534       the entire text string.
# 4535
# 4536       Default values: 'opacity=1' and 'color1=0'.
# 4538     text_outline:
# 5703       Add random color ellipses to selected images.
# 5704
# 5705       Default values: 'count=400', 'radius=5' and 'opacity=0.1'.
# 5707     cubism:
# 5708         _density>=0,0<=_thickness<=50,_max_angle,_opacity,_smoothness>=0
# 5710       Apply cubism effect on selected images.
# 5711
# 5712       Default values: 'density=50', 'thickness=10', 'max_angle=75', 'opacity=0.7' and 'smoothness=0'.
# 5762       Add soft glow on selected images.
# 5763
# 5764       Default value: 'amplitude=1%'.
# 5766     halftone:
# 5767         nb_levels>=2,_size_dark>=2,_size_bright>=2,_shape={ 0=square | 1=diamond | \
# 5768          2=circle | 3=inv-square | 4=inv-diamond | 5=inv-circle },_smoothness[%]>=0
# 5770       Apply halftone dithering to selected images.
# 5771
# 7221     =  (+): eq. to 'set'.
# 7222     ac : eq. to 'apply_channels'.
# 7223     fc : eq. to 'fill_color'.
# 7224     a  (+): eq. to 'append'.
# 7225     z  (+): eq. to 'crop'.
# 7226     r  (+): eq. to 'resize'.
# 7227     rr2d : eq. to 'resize_ratio2d'.
# 7228     r2dx : eq. to 'resize2dx'.
# 7229     r2dy : eq. to 'resize2dy'.
# 7230     r3dx : eq. to 'resize3dx'.
# 7231     r3dy : eq. to 'resize3dy'.

# %%
f = open("GMIC-documents.txt", "r").readlines()
count = 0
search = raw_input("Search: ")
for line in f:
    line = line.replace("\n", "")
    count = count +1
    start = int(start)
    end = start +150
    if count>start:
        print line
# Out:
# Start: 45
#  3. Image definition and terminology
#     --------------------------------
#
#   - In G'MIC, each image is modeled as a 1d, 2d, 3d or 4d array of scalar values, uniformly
#      discretized on a rectangular/parallelepipedic domain.
#
#   - The four dimensions of this array are respectively denoted by:
#
#     . 'width', the number of image columns (size along the 'x'-axis).
#     . 'height', the number of image rows (size along the 'y'-axis).
#     . 'depth', the number of image slices (size along the 'z'-axis).
#         (the depth is equal to 1 for usual color or grayscale 2d images).
#     . 'spectrum', the number of image channels (size along the 'c'-axis).
#         (the spectrum is respectively equal to 3 and 4 for usual RGB and RGBA color images).
#
#   - There are no hard limitations on the size of the image along each dimension. For instance,
#      the number of image slices or channels can be of arbitrary size within the limits of
#      the available memory.
#
#   - The width, height and depth of an image are considered as spatial dimensions, while the
#      spectrum has a multi-spectral meaning. Thus, a 4d image in G'MIC should be most often
#      regarded as a 3d dataset of multi-spectral voxels. Most of the G'MIC commands will stick with
#      this idea (e.g. command '' blurs images only along the spatial 'xyz'-axes).
#
#   - G'MIC stores all the image data as buffers of 'float' values (32 bits, value range
#      [-3.4E38,+3.4E38]). It performs all its image processing operations with floating point
#      numbers. Each image pixel takes then 32bits/channel (except if double-precision buffers have
#      been enabled during the compilation of the software, in which case 64bits/channel can be the
#      default).
#
#   - Considering 'float'-valued pixels ensure to keep the numerical precision when executing
#      image processing pipelines. For image input/output operations, you may want to prescribe the
#      image datatype to be different than 'float' (like 'bool', 'char', 'int', etc...).
#      This is possible by specifying it as a file option when using I/O commands.
#      (see section 'Input/output properties' to learn more about file options).
#
#  4. Items of a processing pipeline
#     ------------------------------
#
#   - In G'MIC, an image processing pipeline is described as a sequence of items separated by the
#      space character ' '. Such items are interpreted and executed from the left to the right.
#      For instance, the expression:
#
#        filename.jpg blur 3,0 sharpen 10 resize 200%,200% output file_out.jpg
#
#      defines a valid pipeline composed of nine G'MIC items.
#
#   - Each G'MIC item is a string that is either a command, a list of command arguments,
#      a filename, or a special input string.
#
#   - Escape characters '\' and double quotes '"' can be used to define items containing spaces or
#      other special characters. For instance, the two strings 'single\ item' and '"single item"'
#      both define the same single item, with a space in it.
#
#  5. Input data items
#     ----------------
#
#   - If a specified G'MIC item appears to be an existing filename, the corresponding image data
#      are loaded and inserted at the end of the image list (which is equivalent to the use of
#      ' filename').
#
#   - Special filenames '-' and '-.ext' stand for the standard input/output streams, optionally
#      forced to be in a specific 'ext' file format (e.g. '-.jpg' or '-.png').
#
#   - The following special input strings may be used as G'MIC items to create and insert new
#      images with prescribed values, at the end of the image list:
#
#     . '[selection]' or '[selection]xN': Insert 1 or N copies of already existing images.
#        'selection' may represent one or several images
#        (see section 'Command items and selections' to learn more about selections).
#
#     . 'width[%],_height[%],_depth[%],_spectrum[%],_values': Insert a new image with specified
#        size and values (adding '%' to a dimension means 'percentage of the size along the same
#        axis, taken from the last image '[-1]''). Any specified dimension can be also written as
#        '[image]', and is then set to the size (along the same axis) of the existing specified image
#        [image]. 'values' can be either a sequence of numbers separated by commas ',', or a
#        mathematical expression, as e.g. in input item '256,256,1,3,if(c==0,x,if(c==1,y,0))' which
#        creates a 256x256 RGB color image with a spatial shading on the red and green channels.
#        (see section 'Mathematical expressions' to learn more about mathematical expressions).
#
#     . '(v1,v2,..)': Insert a new image from specified prescribed values. Value separator inside
#        parentheses can be ',' (column separator), ';' (row separator), '/' (slice separator) or
#        '^' (channel separator). For instance, expression '(1,2,3;4,5,6;7,8,9)' creates a 3x3 matrix
#        (scalar image), with values running from 1 to 9.
#
#     . '0': Insert a new 'empty' image, containing no pixel data. Empty images are used only in rare
#        occasions.
#
#   - Input item 'name=value' declares a new local or global variable 'name', or assign a new value
#      to an existing variable. Variable names must use the character set [a-zA-Z0-9_] and cannot
#      start with a number.
#
#   - A variable definition is always local to the current command except when it starts by the
#      underscore character '_'. In that case, it becomes also accessible by any command invoked
#      outside the current command scope (global variable).
#
#   - If a variable name starts with two underscores '__', the global variable is also shared among
#      different threads and can be read/set by commands running in parallel (see command 'parallel'
#      for this purpose). Otherwise, it remains local to the thread that defined it.
#
#   - Numerical variables can be updated with the use of these special operators:
#      '+=' (addition), '-=' (subtraction), '*=' (multiplication), '/=' (division), '%=' (modulo),
#      '&=' (bitwise and), '|=' (bitwise or), '^=' (power), '<<=' and '>>=' (bitwise left and right
#      shifts). For instance, 'foo=1 foo+=3'.
#
#   - Input item 'name.=string' concatenates specified 'string' to the end of variable 'name'.
#
#   - Multiple variable assignments and updates are allowed, with expressions:
#      'name1,name2,...,nameN=value' or 'name1,name2,...,nameN=value1,value2,...,valueN'
#      where assignment operator '=' can be replaced by one of the allowed operators
#      (e.g. '+=').
#
#  6. Command items and selections
#     ----------------------------
#
#   - A G'MIC item that is not a filename nor a special input string designates a command,
#      most of the time. Generally, commands perform image processing operations on one or several
#      available images of the list.
#
#   - Reccurent commands have two equivalent names (regular and short). For instance, command names
#      'resize' and 'r' refer to the same image resizing action.
#
#   - A G'MIC command may have mandatory or optional arguments. Command arguments must be specified
#      in the next item on the command line. Commas ',' are used to separate multiple arguments of a
#      single command, when required.
#
#   - The execution of a G'MIC command may be restricted only to a subset of the image list, by
#      appending '[selection]' to the command name. Examples of valid syntaxes for 'selection' are:
#
#     . 'command[-2]': Apply command only on the penultimate image [-2] of the list.
#     . 'command[0,1,3]': Apply command only on images [0],[1] and [3].
#     . 'command[3-6]': Apply command only on images [3] to [6] (i.e, [3],[4],[5] and [6]).
#     . 'command[50%-100%]': Apply command only on the second half of the image list.
#     . 'command[0,-4--1]': Apply command only on the first image and the last four images.
#     . 'command[0-9:3]': Apply command only on images [0] to [9], with a step of 3
#                           (i.e. on images [0], [3], [6] and [9]).
#     . 'command[0--1:2]': Apply command only on images of the list with even indices.
#     . 'command[0,2-4,50%--1]': Apply command on images [0],[2],[3],[4] and on the second half of
#                                  the image list.
#     . 'command[^0,1]': Apply command on all images except the two first.
#     . 'command[name1,name2]': Apply command on named images 'name1' and 'name2'.
#
#   - Indices in selections are always sorted in increasing order, and duplicate indices are
#      discarded. For instance, selections '[3-1,1-3]' and '[1,1,1,3,2]' are both equivalent to
#      '[1-3]'. If you want to repeat a single command multiple times on an image, use a
#      'repeat..done' loop instead. Inverting the order of images for a command is achieved by
#      explicitly inverting the order of the images in the list, with command 'reverse[selection]'.
#
#   - Command selections '[-1]','[-2]' and '[-3]' are so often used that they have their own
#      shortcuts, respectively '.', '..' and '...'. For instance, command 'blur..' is equivalent to
#      'blur[-2]'. These shortcuts work also when specifying command arguments.
#
#   - G'MIC commands invoked without '[selection]' are applied on all images of the list, i.e. the
#      default selection is '[0--1]' (except for command 'input' whose default selection is '[-1]').
#
#   - Prepending a single hyphen '-' to a G'MIC command has no effect. This may be useful to recognize
#      command items more easily in a one-liner pipeline (typically invoked from a shell).
#
#   - A G'MIC command prepended with a plus sign '+' or a double hyphen '--' does not act 'in-place'
#      but inserts its result as one or several new images at the end of the image list.
#
#   - There are two different types of commands that can be run by the G'MIC interpreter:
#
#     . Builtin commands, are the hard-coded functionalities in the interpreter core. They are thus
#        compiled as binary code and run fast, most of the time. Omitting an argument when invoking a
#        builtin command is not permitted, except if all following arguments are also omitted.
#        For instance, invoking 'plasma 10,,5' is invalid but 'plasma 10' is correct.
#     . Custom commands, are defined as G'MIC pipelines of builtin or other custom commands.
#        They are interpreted by the G'MIC interpreter, and thus run a bit slower than builtin commands.
#        Omitting arguments when invoking a custom command is permitted. For instance, expressions
#        'flower ,,,100,,2' or 'flower ,' are correct.
#
#   - Most of the existing commands in G'MIC are actually defined as custom commands.
#
#   - A user can easily add its own custom commands to the G'MIC interpreter (see section
#      'Adding custom commands' for more details). New builtin commands cannot be added
#      (unless you modify the G'MIC interpreter source code and recompile it).
#
#  7. Input/output properties
#     -----------------------
#
#   - G'MIC is able to read/write most of the classical image file formats, including:
#
#     . 2d grayscale/color files: .png, .jpeg, .gif, .pnm, .tif, .bmp, ...
#     . 3d volumetric files: .dcm, .hdr, .nii, .pan, .inr, .pnk, ...
#     . video files: .mpeg, .avi, .mov, .ogg, .flv, ...
#     . Generic ascii or binary data files: .gmz, .cimg, .cimgz, .dlm, .asc, .pfm, .raw, .txt, .h.
#     . 3d object files: .off.
#
#   - When dealing with color images, G'MIC generally reads, writes and displays data using the usual
#      sRGB color space.
#
#   - G'MIC is able to manage 3d objects that may be read from files or generated by G'MIC commands.
#      A 3d object is stored as a one-column scalar image containing the object data, in the
#      following order: { magic_number; sizes; vertices; primitives; colors; opacities }.
#      These 3d representations can be then processed as regular images.
#      (see command 'split3d' for accessing each of these 3d object data separately).
#
#   - Be aware that usual file formats may be sometimes not adapted to store all the available image
#      data, since G'MIC uses float-valued image buffers. For instance, saving an image that was
#      initially loaded as a 16bits/channel image, as a .jpg file will result in a loss of
#      information. Use the G'MIC-specific file extensions .cimgz or .gmz to ensure that all data
#      precision are preserved when saving images.
#
#   - Sometimes, file options may/must be set for file formats:
#
#     . Video files: Only sub-frames of an image sequence may be loaded, using the input expression
#        'filename.ext,[first_frame[,last_frame[,step]]]'. Set 'last_frame==-1' to tell it must be
#        the last frame of the video. Set 'step' to 0 to force an opened video file to be
#        opened/closed. Output framerate and codec can be also set by using the output expression
#        'filename.avi,_fps,_codec,_keep_open={ 0 | 1 }'. 'codec' is a 4-char string
#        (see http://www.fourcc.org/codecs.php) or '0' for the default codec. 'keep_open' tells if
#        the output video file must be kept open for appending new frames afterwards.
#
#     . .cimg[z] files: Only crops and sub-images of .cimg files can be loaded, using the input
#       expressions 'filename.cimg,N0,N1', 'filename.cimg,N0,N1,x0,x1',
#       'filename.cimg,N0,N1,x0,y0,x1,y1', 'filename.cimg,N0,N1,x0,y0,z0,x1,y1,z1' or
#       'filename.cimg,N0,N1,x0,y0,z0,c0,x1,y1,z1,c1'.
#       Specifying '-1' for one coordinates stands for the maximum possible value. Output expression
#       'filename.cimg[z][,datatype]' can be used to force the output pixel type. 'datatype' can be
#       { uchar | char | ushort | short | uint | int | uint64 | int64 | float | double }.
#
#     . .raw binary files: Image dimensions and input pixel type may be specified when loading .raw
#        files with input expression
#        'filename.raw[,datatype][,width][,height[,depth[,dim[,offset]]]]]'. If no dimensions are
#        specified, the resulting image is a one-column vector with maximum possible height. Pixel
#        type can also be specified with the output expression 'filename.raw[,datatype]'.
#        'datatype' can be the same as for .cimg[z] files.
#
#     . .yuv files: Image dimensions must be specified when loading, and only sub-frames of an image sequence
#        may be loaded, using the input expression
#        'filename.yuv,width,height[,chroma_subsampling[,first_frame[,last_frame[,step]]]'.
#        'chroma_subsampling' can be { 420 | 422 | 444 }.
#        When saving, chroma subsampling mode can be specified with output expression
#        'filename.yuv[,chroma_subsampling]'.
#
#     . .tiff files: Only sub-images of multi-pages tiff files can be loaded, using the input
#        expression 'filename.tif,_first_frame,_last_frame,_step'.
#        Output expression 'filename.tiff,_datatype,_compression,_force_multipage,_use_bigtiff' can
#        be used to specify the output pixel type, as well as the compression method.
#        'datatype' can be the same as for .cimg[z] files. 'compression' can be
#        { none (default) | lzw | jpeg }. 'force_multipage can be { 0=no (default) | 1=yes }.
#        'use_bigtiff can be { 0=no | 1=yes (default) }.
#
#     . .gif files: Animated gif files can be saved, using the input expression
#        'filename.gif,fps>0,nb_loops'. Specify 'nb_loops=0' to get an infinite number of animation
#        loops (this is the default behavior).
#
#     . .jpeg files: The output quality may be specified (in %), using the output expression
#        'filename.jpg,30' (here, to get a 30% quality output). '100' is the default.
#
#     . .mnc files: The output header can set from another file, using the output expression
#        'filename.mnc,header_template.mnc'.
#
#     . .pan, .cpp, .hpp, .c and .h files: The output datatype can be selected with output expression
#        'filename[,datatype]'. 'datatype' can be the same as for .cimg[z] files.
#
#     . .gmic files: These filenames are assumed to be G'MIC custom commands files. Loading such a
#        file will add the commands it defines to the interpreter. Debug information can be
#        enabled/disabled by the input expression 'filename.gmic[,add_debug_info={ 0 | 1 }]'.
#
#     . Inserting 'ext:' on the beginning of a filename (e.g. 'jpg:filename') forces G'MIC to
#        read/write the file as it would have been done if it had the specified extension '.ext'.
#
#   - Some input/output formats and options may not be supported, depending on the configuration
#      flags that have been set during the build of the G'MIC software.
#
#  8. Substitution rules
#     ------------------
#
#   - G'MIC items containing '$' or '{}' are substituted before being interpreted. Use these
#      substituting expressions to access various data from the interpreter environment.
#
#   - '$name' and '${name}' are both substituted by the value of the specified named variable
#      (set previously by the item 'name=value'). If this variable has not been already set, the
#      expression is substituted by the highest positive indice of the named image '[name]'. If no
#      image has this name, the expression is substituted by the value of the OS environment variable
#      with same name (it may be thus an empty string).
#      The following reserved variables are predefined by the G'MIC interpreter:
#
#        . '$!': The current number of images in the list.
#        . '$>' and '$<': The increasing/decreasing indice of the latest (currently running)
#           'repeat...done' loop.
#        . '$/': The current call stack. Stack items are separated by slashes '/'.
#        . '$|': The current value (expressed in seconds) of a millisecond precision timer.
#        . '$^': The current verbosity level.
#        . '$_cpus': The number of computation cores available on your machine.
#        . '$_pid': The current process identifier, as an integer.
#        . '$_prerelease': For pre-releases only, the date of the pre-release as 'yymmdd'.
#           For stable releases, this variable is not defined.
#        . '$_version': A 3-digits number telling about the current version of the G'MIC interpreter
#           (currently '222').
#        . '$_vt100': Set to 1 (default value) if colored text output is allowed on the console.
#        . '$_path_rc': The path to the G'MIC folder used to store resources and configuration files
#          (its value is OS-dependent).
#        . '$_path_user': The path to the G'MIC user file .gmic or user.gmic (its value is
#           OS-dependent).
#
#   - '$$name' and '$${name}' are both substituted by the G'MIC script code of the specified named
#      custom command, or by an empty string if no custom command with specified name exists.
#
#   - '${"-command line"}' is substituted by the status value set by the execution of the specified
#      command line (see command 'status' to learn more about status). Expression '${}' thus stands
#      for the current status value.
#
#   - '{``string}' (starting with two backquotes) is substituted by a double-quoted version of the
#      specified string.
#
#   - '{/string}' is substituted by the escaped version of the specified string.
#
#   - '{'string'}' (between single quotes) is substituted by the sequence of ascii codes that compose
#      the specified string, separated by commas ','. For instance, item '{'foo'}' is substituted
#      by '102,111,111'.
#
#   - '{image,feature}' is substituted by a specific feature of the image [image]. 'image' can be
#      either an image number or an image name. It can be also eluded, in which case, the last image
#      '[-1]' of the list is considered for the requested feature.
#      Specified 'feature' can be one of:
#
#        . 'b': The image basename (i.e. filename without the folder path nor extension).
#        . 'f': The image folder name.
#        . 'n': The image name or filename (if the image has been read from a file).
#        . 't': The text string from the image values regarded as ascii codes.
#        . 'x': The image extension (i.e last characters after the last '.' in the image name).
#        . '^ : The sequence of all image values, separated by commas ','.
#        . '@subset': The sequence of image values corresponding to the specified subset, and
#           separated by commas ','.
#        . Any other 'feature' is considered as a mathematical expression associated to the image
#           [image] and is substituted by the result of its evaluation (float value). For instance,
#           expression '{0,w+h}' is substituted by the sum of the width and height of the first image
#           (see section 'Mathematical expressions' for more details). If a mathematical expression
#           starts with an underscore '_', the resulting value is truncated to a readable format.
#           For instance, item '{_pi}' is substituted by '3.14159' (while '{pi}' is substituted by
#           '3.141592653589793').
#        . A 'feature' delimited by backquotes is replaced by a string whose ascii codes correspond
#           to the list of values resulting from the evaluation of the specified mathematical
#           expression. For instance, item '{`[102,111,111]`}' is substituted by 'foo' and item
#           '{`vector8(65)`}' by 'AAAAAAAA'.
#
#   - '{*}' is substituted by the visibility state of the instant display window [0] (can be
#      { 0=closed | 1=visible }).
#
#   - '{*,feature}' or '{*indice,feature}' is substituted by a specific feature of the instant
#      display window #0 (or #indice, if specified). Requested 'feature' can be:
#
#        . 'w': display width (i.e. width of the display area managed by the window).
#        . 'h': display height (i.e. height of the display area managed by the window).
#        . 'wh': display width x display height.
#        . 'd': window width (i.e. width of the window widget).
#        . 'e': window height (i.e. height of the window widget).
#        . 'de': window width x window height.
#        . 'u': screen width (actually independent on the window size).
#        .' v': screen height (actually independent on the window size).
#        . 'uv': screen width x screen height.
#        . 'n': current normalization type of the instant display.
#        . 't': window title of the instant display.
#        . 'x': X-coordinate of the mouse position (or -1, if outside the display area).
#        . 'y': Y-coordinate of the mouse position (or -1, if outside the display area).
#        . 'b': state of the mouse buttons { 1=left-but. | 2=right-but. | 4=middle-but. }.
#        . 'o': state of the mouse wheel.
#        . 'k': decimal code of the pressed key if any, 0 otherwise.
#        . 'c': boolean (0 or 1) telling if the instant display has been closed recently.
#        . 'r': boolean telling if the instant display has been resized recently.
#        . 'm': boolean telling if the instant display has been moved recently.
#        . Any other 'feature' stands for a keycode name (in capital letters), and is substituted by
#           a boolean describing the current key state { 0=pressed | 1=released }.
#        . You can also prepend a hyphen '-' to a 'feature' (that supports it) to flush the
#           corresponding event immediately after reading its state (works for keys, mouse and
#           window events).
#
#   - Item substitution is never performed in items between double quotes. One must break the quotes
#     to enable substitution if needed, as in "3+8 kg = "{3+8}" kg". Using double quotes is then
#     a convenient way to disable the substitutions mechanism in items, when necessary.
#
#   - One can also disable the substitution mechanism on items outside double quotes, by escaping the
#      '{','}' or '$' characters, as in '\{3+4\}\ doesn't\ evaluate'.
#
#  9. Mathematical expressions
#     ------------------------
#
#   - G'MIC has an embedded mathematical parser. It is used to evaluate (possibly complex) expressions
#      inside braces '{}', or formulas in commands that may take one as an argument (e.g. 'fill').
#
#   - When the context allows it, a formula is evaluated for each pixel of the selected images
#      (e.g. 'fill').
#
#   - A math expression may return a scalar or vector-valued result (with a fixed number of
#      components).
#
#   - The mathematical parser understands the following set of functions, operators and variables:
#
#     _ Usual operators: || (logical or), && (logical and), | (bitwise or), & (bitwise and),
#        !=, ==, <=, >=, <, >, << (left bitwise shift), >> (right bitwise shift), -, +, *, /,
#        % (modulo), ^ (power), ! (logical not), ~ (bitwise not),
#        ++, --, +=, -=, *=, /=, %=, &=, |=, ^=, >>=, <<= (in-place operators).
#
#     _ Usual math functions: abs(), acos(), arg(), argkth(), argmax(), argmin(), asin(), atan(),
#        atan2(), avg(), bool(), cbrt(), ceil(), cos(), cosh(), cut(), exp(), fact(), fibo(), floor(), gauss(), int(),
#        isval(), isnan(), isinf(), isint(), isbool(), isfile(), isdir(), isin(), kth(), log(), log2(), log10(),
#        max(), mean(), med(), min(), narg(), prod(), rol() (left bit rotation),
#        ror() (right bit rotation), round(), sign(), sin(), sinc(), sinh(), sqrt(), std(),
#        srand(_seed), sum(), tan(), tanh(), variance(), xor().
#
#        . 'atan2(y,x)' is the version of 'atan()' with two arguments 'y' and 'x' (as in C/C++).
#        . 'permut(k,n,with_order)' computes the number of permutations of k objects from a set of
#           n objects.
#        . 'gauss(x,_sigma)' returns 'exp(-x^2/(2*s^2))/sqrt(2*pi*sigma^2)'.
#        . 'cut(value,min,max)' returns value if it is in range [min,max], or min or max otherwise.
#        . 'narg(a_1,...,a_N)' returns the number of specified arguments (here, N).
#        . 'arg(i,a_1,..,a_N)' returns the ith argument a_i.
#        . 'isval()', 'isnan()', 'isinf()', 'isint()', 'isbool()' test the type of the given
#           number or expression, and return 0 (false) or 1 (true).
#        . 'isfile()' (resp. 'isdir()') returns 0 (false) or 1 (true) whether its argument is a
#           path to an existing file (resp. to a directory) or not.
#        . 'isin(v,a_1,...,a_n)' returns 0 (false) or 1 (true) whether the first value 'v' appears
#           in the set of other values 'a_i'.
#        . 'argmin()', 'argmax()', 'kth()', 'max()', 'mean()', 'med()', 'min()', 'std()', 'sum()'
#           and 'variance()' can be called with an arbitrary number of scalar/vector arguments.
#        . 'round(value,rounding_value,direction)' returns a rounded value. 'direction' can be
#           { -1=to-lowest | 0=to-nearest | 1=to-highest }.
#
#     _ Variable names below are pre-defined. They can be overridden.
#
#        . 'l': length of the associated list of images.
#        . 'w': width of the associated image, if any (0 otherwise).
#        . 'h': height of the associated image, if any (0 otherwise).
#        . 'd': depth of the associated image, if any (0 otherwise).
#        . 's': spectrum of the associated image, if any (0 otherwise).
#        . 'r': shared state of the associated image, if any (0 otherwise).
#        . 'wh': shortcut for width x height.
#        . 'whd': shortcut for width x height x depth.
#        . 'whds': shortcut for width x height x depth x spectrum (i.e. number of image values).
#        . 'im','iM','ia','iv','is','ip','ic': Respectively the minimum, maximum, average,
#           variance, sum, product and median value of the associated image, if any (0 otherwise).
#        . 'xm','ym','zm','cm': The pixel coordinates of the minimum value in the associated
#           image, if any (0 otherwise).
#        . 'xM','yM','zM','cM': The pixel coordinates of the maximum value in the associated
#           image, if any (0 otherwise).
#        . All these variables are considered as constant values by the math parser (for optimization
#           purposes) which is indeed the case most of the time. Anyway, this might not be the case,
#           if function 'resize(#ind,..)' is used in the math expression.
#           If so, it is safer to invoke functions 'l()', 'w(_#ind)', 'h(_#ind)', ... 's(_#ind)'
#           and 'ic(_#ind)' instead of the corresponding named variables.
#        . 'i': current processed pixel value (i.e. value located at (x,y,z,c)) in the associated
#           image, if any (0 otherwise).
#        . 'iN': Nth channel value of current processed pixel (i.e. value located at (x,y,z,N)) in
#           the associated image, if any (0 otherwise). 'N' must be an integer in range [0,9].
#        . 'R','G','B' and 'A' are equivalent to 'i0', 'i1', 'i2' and 'i3' respectively.
#        . 'I': current vector-valued processed pixel in the associated image, if any (0 otherwise).
#           The number of vector components is equal to the number of image channels
#           (e.g. I = [ R,G,B ] for a RGB image).
#        . You may add '#ind' to any of the variable name above to retrieve the information for any
#           numbered image [ind] of the list (when this makes sense). For instance 'ia#0' denotes the
#           average value of the first image of the list).
#        . 'x': current processed column of the associated image, if any (0 otherwise).
#        . 'y': current processed row of the associated image, if any (0 otherwise).
#        . 'z': current processed slice of the associated image, if any (0 otherwise).
#        . 'c': current processed channel of the associated image, if any (0 otherwise).
#        . 't': thread id when an expression is evaluated with multiple threads (0 means
#           'master thread').
#        . 'e': value of e, i.e. 2.71828...
#        . 'pi': value of pi, i.e. 3.1415926...
#        . 'u': a random value between [0,1], following a uniform distribution.
#        . 'g': a random value, following a gaussian distribution of variance 1
#           (roughly in [-6,6]).
#        . 'interpolation': value of the default interpolation mode used when reading pixel values
#            with the pixel access operators (i.e. when the interpolation argument is not explicitly
#            specified, see below for more details on pixel access operators). Its initial default
#            value is 0.
#        . 'boundary': value of the default boundary conditions used when reading pixel values with
#            the pixel access operators (i.e. when the boundary condition argument is not explicitly
#            specified, see below for more details on pixel access operators). Its initial default
#            value is 0.
#
#     _ Vector calculus: Most operators are also able to work with vector-valued elements.
#
#        . '[ a0,a1,...,aN ]' defines a (N+1)-dimensional vector with scalar coefficients ak.
#        . 'vectorN(a0,a1,,...,)' does the same, with the ak being repeated periodically if only a
#           few are specified.
#        . In both previous expressions, the ak can be vectors themselves, to be concatenated into a
#           single vector.
#        . The scalar element ak of a vector X is retrieved by 'X[k]'.
#        . The sub-vector [ X[p]...X[p+q-1] ] (of size q) of a vector X is retrieved by 'X[p,q]'.
#        . Equality/inequality comparisons between two vectors is done with operators '==' and '!='.
#        . Some vector-specific functions can be used on vector values:
#          'cross(X,Y)' (cross product), 'dot(X,Y)' (dot product), 'size(X)' (vector dimension),
#          'sort(X,_is_increasing,_chunk_size)' (sorting values), 'reverse(A)' (reverse order of
#          components), 'shift(A,_length,_boundary_conditions)' and
#          'same(A,B,_nb_vals,_is_case_sensitive)' (vector equality test).
#        . Function 'normP(u1,...,un)' computes the LP-norm of the specified vector
#           (P being an unsigned integer constant or 'inf'). If P is omitted, the L2 norm is used.
#        . Function 'resize(A,size,_interpolation,_boundary_conditions)' returns a resized version of
#           a vector 'A' with specified interpolation mode. 'interpolation' can be { -1=none
#           (memory content) | 0=none | 1=nearest | 2=average | 3=linear | 4=grid | 5=bicubic |
#           6=lanczos }, and 'boundary_conditions'  can be { 0=dirichlet | 1=neumann | 2=periodic | 3=mirror }.
#        . Function 'find(A,B,_is_forward,_starting_indice)' returns the index where sub-vector B
#           appears in vector A, (or -1 if B is not found in A). Argument A can be also replaced by
#           an image indice #ind.
#        . A 2-dimensional vector may be seen as a complex number and used in those particular
#           functions/operators:
#           '**' (complex multiplication), '//' (complex division), '^^' (complex exponentiation),
#           '**=' (complex self-multiplication), '//=' (complex self-division), '^^=' (complex
#           self-exponentiation), 'cabs()' (complex modulus), 'carg()' (complex argument), 'cconj()'
#           (complex conjugate), 'cexp()' (complex exponential) and 'clog()' (complex logarithm).
#        . A MN-dimensional vector may be seen as a M x N matrix and used in those particular
#           functions/operators:
#           '*' (matrix-vector multiplication), 'det(A)' (determinant), 'diag(V)' (diagonal matrix
#           from a vector), 'eig(A)' (eigenvalues/eigenvectors), 'eye(n)' (n x n identity matrix),
#           'inv(A)' (matrix inverse), 'mul(A,B,_nb_colsB)' (matrix-matrix multiplication),
#           'pseudoinv(A,_nb_colsA)', 'rot(u,v,w,angle)' (3d rotation matrix), 'rot(angle)' (2d
#           rotation matrix), 'solve(A,B,_nb_colsB)' (least-square solver of linear system A.X = B),
#           'svd(A,_nb_colsA)' (singular value decomposition), 'trace(A)' (matrix trace) and
#           'transp(A,nb_colsA)' (matrix transpose). Argument 'nb_colsB' may be omitted if it is
#           equal to 1.
#        . Specifying a vector-valued math expression as an argument of a command that operates on
#           image values (e.g. 'fill') modifies the whole spectrum range of the processed image(s),
#           for each spatial coordinates (x,y,z). The command does not loop over the C-axis in this
#           case.
#
#     _ String manipulation: Character strings are defined and managed as vectors objects.
#        Dedicated functions and initializers to manage strings are
#
#        . [ 'string' ] and 'string' define a vector whose values are the ascii codes of the
#           specified character string (e.g. 'foo' is equal to [ 102,111,111 ]).
#        . _'character' returns the (scalar) ascii code of the specified character (e.g. _'A' is
#           equal to 65).
#        . A special case happens for empty strings: Values of both expressions [ '' ] and '' are 0.
#        . Functions 'lowercase()' and 'uppercase()' return string with all string characters
#           lowercased or uppercased.
#        . Function 'stov(str,_starting_indice,_is_strict)' parses specified string 'str' and returns the value
#           contained in it.
#        . Function 'vtos(expr,_nb_digits,_siz)' returns a vector of size 'siz' which contains
#           the ascii representation of values described by expression 'expr'.
#           'nb_digits' can be { -1=auto-reduced | 0=all | >0=max number of digits }.
#        . Function 'echo(str1,str2,...,strN)' prints the concatenation of given string arguments
#           on the console.
#        . Function 'cats(str1,str2,...,strN,siz)' returns the concatenation of given string arguments
#           as a new vector of size 'siz'.
#
#     _ Special operators can be used:
#
#        . ';': expression separator. The returned value is always the last encountered expression.
#           For instance expression '1;2;pi' is evaluated as 'pi'.
#        . '=': variable assignment. Variables in mathematical parser can only refer to numerical
#           values (vectors or scalars). Variable names are case-sensitive. Use this operator in
#           conjunction with ';' to define more complex evaluable expressions, such as
#           't=cos(x);3*t^2+2*t+1'.
#           These variables remain local to the mathematical parser and cannot be accessed outside
#            the evaluated expression.
#        . Variables defined in math parser may have a constant property, by specifying keyword const
#           before the variable name (e.g. const foo = pi/4;). The value set to such a variable must
#           be indeed a constant scalar. Constant variables allows certain types of optimizations in
#           the math JIT compiler.
#
#     _ The following specific functions are also defined:
#
#        . 'u(max)' or 'u(min,max)': return a random value between [0,max] or [min,max], following
#           a uniform distribution.
#        . 'i(_a,_b,_c,_d,_interpolation_type,_boundary_conditions)': return the value of the pixel
#           located at position (a,b,c,d) in the associated image, if any (0 otherwise).
#           'interpolation_type' can be { 0=nearest neighbor | other=linear }.
#           'boundary_conditions' can be { 0=dirichlet | 1=neumann | 2=periodic | 3=mirror }.
#           Omitted coordinates are replaced by their default values which are respectively
#           x, y, z, c, interpolation and boundary.
#           For instance command 'fill 0.5*(i(x+1)-i(x-1))' will estimate the X-derivative of an
#           image with a classical finite difference scheme.
#        . 'j(_dx,_dy,_dz,_dc,_interpolation_type,_boundary_conditions)' does the same for the pixel
#           located at position (x+dx,y+dy,z+dz,c+dc) (pixel access relative to the current
#           coordinates).
#        . 'i[offset,_boundary_conditions]' returns the value of the pixel located at specified
#           'offset' in the associated image buffer (or 0 if offset is out-of-bounds).
#        . 'j[offset,_boundary_conditions]' does the same for an offset relative to the current pixel
#           coordinates (x,y,z,c).
#        . 'i(#ind,_x,_y,_z,_c,_interpolation,_boundary_conditions)',
#           'j(#ind,_dx,_dy,_dz,_dc,_interpolation,_boundary_conditions)',
#           'i[#ind,offset,_boundary_conditions]' and 'i[offset,_boundary_conditions]' are similar expressions used to
#           access pixel values for any numbered image [ind] of the list.
#        . 'I/J[offset,_boundary_conditions]' and 'I/J(#ind,_x,_y,_z,_interpolation,_boundary_conditions)' do
#           the same as 'i/j[offset,_boundary_conditions]' and
#           'i/j(#ind,_x,_y,_z,_c,_interpolation,_boundary_conditions)' but return a vector instead of a scalar
#           (e.g. a vector [ R,G,B ] for a pixel at (a,b,c) in a color image).
#        . 'sort(#ind,_is_increasing,_axis)' sorts the values in the specified image [ind].
#        . 'crop(_#ind,_x,_y,_z,_c,_dx,_dy,_dz,_dc,_boundary_conditions)' returns a vector whose values come
#           from the cropped region of image [ind] (or from default image selected if 'ind' is not
#           specified). Cropped region starts from point (x,y,z,c) and has a size of
#           dx x dy x dz x dc. Arguments for coordinates and sizes can be omitted if they are not
#           ambiguous (e.g. 'crop(#ind,x,y,dx,dy)' is a valid invocation of this function).
#        . 'draw(_#ind,S,x,y,z,c,dx,_dy,_dz,_dc,_opacity,_M,_max_M)' draws a sprite S in image [ind]
#           (or in default image selected if 'ind' is not specified) at coordinates (x,y,z,c).
#           The size of the sprite dx x dy x dz x dc must be specified. You can also specify a
#           corresponding opacity mask M if its size matches S.
#        . 'polygon(_#ind,nb_vertices,coords,_opacity,_color)' draws a filled polygon in image [ind]
#           (or in default image selected if 'ind' is not specified) at specified coordinates.
#           It draws a single line if 'nb_vertices' is set to 2.
#        . 'ellipse(_#ind,xc,yc,radius1,_radius2,_angle,_opacity,_color)' draws a filled ellipse in image [ind]
#           (or in default image selected if 'ind' is not specified) with specified coordinates and geometry.
#        . 'resize(#ind,w,_h,_d,_s,_interp,_boundary_conditions,cx,_cy,_cz,_cc)' resizes an image of the
#           associated list with specified dimension and interpolation method. When using this,
#           function, you should consider retrieving the (non-constant) image dimensions using the
#           dynamic functions 'w(_#ind)', 'h(_#ind)', 'd(_#ind)', 's(_#ind)', 'wh(_#ind)',
#           'whd(_#ind)' and 'whds(_#ind)' instead of the corresponding constant variables.
#        . 'if(condition,expr_then,_expr_else)': return value of 'expr_then' or 'expr_else',
#           depending on the value of 'condition' (0=false, other=true). 'expr_else' can be omitted
#           in which case 0 is returned if the condition does not hold. Using the ternary operator
#           'condition?expr_then[:expr_else]' gives an equivalent expression.
#           For instance, G'MIC commands 'fill if(x%10==0,255,i)' and 'fill x%10?i:255' both draw
#           blank vertical lines on every 10th column of an image.
#        . 'dowhile(expression,_condition)' repeats the evaluation of 'expression' until 'condition'
#           vanishes (or until 'expression' vanishes if no 'condition' is specified). For instance,
#           the expression: 'if(N<2,N,n=N-1;F0=0;F1=1;dowhile(F2=F0+F1;F0=F1;F1=F2,n=n-1))' returns
#           the Nth value of the Fibonacci sequence, for N>=0 (e.g., 46368 for N=24).
#           'dowhile(expression,condition)' always evaluates the specified expression at least once,
#           then check for the loop condition. When done, it returns the last value of 'expression'.
#        . 'for(init,condition,_procedure,body)' first evaluates the expression 'init', then
#           iteratively evaluates 'body' (followed by 'procedure' if specified) while 'condition'
#           is verified (i.e. not zero). It may happen that no iteration is done, in which case the
#           function returns nan. Otherwise, it returns the last value of 'body'.
#           For instance, the expression: 'if(N<2,N,for(n=N;F0=0;F1=1,n=n-1,F2=F0+F1;F0=F1;F1=F2))'
#           returns the Nth value of the Fibonacci sequence, for N>=0 (e.g., 46368 for N=24).
#        . 'whiledo(condition,expression)' is exactly the same as 'for(init,condition,expression)'
#           without the specification of an initializing expression.
#        . 'break()' and 'continue()' respectively breaks and continues the current running bloc
#           (loop, init or main environment).
#        . 'fsize(filename)' returns the size of the specified 'filename' (or '-1' if file does not exist).
#        . 'date(attr,path)' returns the date attribute for the given 'path' (file or directory),
#           with 'attr' being { 0=year | 1=month | 2=day | 3=day of week | 4=hour | 5=minute |
#           6=second }, or a vector of those values.
#        . 'date(_attr) returns the specified attribute for the current (locale) date.
#        . 'print(expr1,expr2,...) or 'print(#ind) prints the value of the specified expressions
#           (or image information) on the console, and returns the value of the last expression
#           (or nan in case of an image). Function 'prints(expr)' also prints the string composed
#           of the ascii characters defined by the vector-valued expression (e.g. 'prints('Hello')').
#        . 'debug(expression) prints detailed debug information about the sequence of operations done
#           by the math parser to evaluate the expression (and returns its value).
#        . 'display(_X,_w,_h,_d,_s) or 'display(#ind) display the contents of the vector 'X'
#           (or specified image) and wait for user events. if no arguments are provided, a memory
#           snapshot of the math parser environment is displayed instead.
#        . 'init(expression) and 'end(expression) evaluates the specified expressions only once,
#           respectively at the beginning and end of the evaluation procedure, and this,
#           even when multiple evaluations are required (e.g. in 'fill init(foo=0);++foo').
#        . 'copy(dest,src,_nb_elts,_inc_d,_inc_s,_opacity) copies an entire memory block of 'nb_elts'
#           elements starting from a source value 'src' to a specified destination 'dest', with
#           increments defined by 'inc_d' and 'inc_s' respectively for the destination and source
#           pointers.
#        . 'stats(_#ind) returns the statistics vector of the running image '[ind]', i.e the vector
#           [ im,iM,ia,iv,xm,ym,zm,cm,xM,yM,zM,cM,is,ip ] (14 values).
#        . 'unref(a,b,...) destroys references to the named variable given as arguments.
#        . 'breakpoint() inserts a possible computation breakpoint (not supported by the cli interface).
#        . '_(expr) just ignores its arguments (mainly useful for debugging).
#        . 'ext('pipeline') executes the specified G'MIC pipeline as if it was called outside
#           the currently evaluated expression.
#
#     - User-defined macros:
#
#        . Custom macro functions can be defined in a math expression, using the assignment operator
#           '=', e.g. 'foo(x,y) = cos(x + y); result = foo(1,2) + foo(2,3)'.
#        . Trying to override a built-in function (e.g. 'abs()') has no effect.
#        . Overloading macros with different number of arguments is possible. Re-defining a
#           previously defined macro with the same number of arguments discards its previous
#           definition.
#        . Macro functions are indeed processed as macros by the mathematical evaluator. You should
#           avoid invoking them with arguments that are themselves results of assignments or
#           self-operations. For instance, 'foo(x) = x + x; z = 0; foo(++z)' returns '4' rather
#           than expected value '2'.
#        . When substituted, macro arguments are placed inside parentheses, except if a number sign
#           '#' is located just before or after the argument name. For instance, expression
#           'foo(x,y) = x*y; foo(1+2,3)' returns '9' (being substituted as '(1+2)*(3)'), while
#           expression 'foo(x,y) = x#*y#; foo(1+2,3)' returns '7' (being substituted as '1+2*3').
#        . Number signs appearing between macro arguments function actually count for 'empty'
#           separators. They may be used to force the substitution of macro arguments in unusual
#           places, e.g. as in 'str(N) = ['I like N#'];'.
#
#     - Multi-threaded and in-place evaluation:
#
#        . If your image data are large enough and you have several CPUs available, it is likely that
#           the math expression passed to a 'fill' or 'input' command is evaluated in parallel,
#           using multiple computation threads.
#        . Starting an expression with ':' or '*' forces the evaluations required for an image to be
#           run in parallel, even if the amount of data to process is small (beware, it may be slower
#           to evaluate in this case!). Specify ':' (instead of '*') to avoid possible image copy
#           done before evaluating the expression (this saves memory, but do this only if you are
#           sure this step is not required!)
#        . If the specified expression starts with '>' or '<', the pixel access operators
#           'i(), i[], j()' and 'j[]' return values of the image being currently modified,
#           in forward ('>') or backward ('<') order. The multi-threading evaluation of the
#           expression is also disabled in this case.
#        . Function 'critical(operands)' forces the execution of the given operands in a single thread at a
#           time.
#
#     _ Expressions 'i(_#ind,x,_y,_z,_c)=value', 'j(_#ind,x,_y,_z,_c)=value', 'i[_#ind,offset]=value'
#        and 'j[_#ind,offset]=value' set a pixel value at a different location than the running one
#        in the image [ind] (or in the associated image if argument '#ind' is omitted), either with
#        global coordinates/offsets (with 'i(...)' and 'i[...]'), or relatively to the current
#        position (x,y,z,c) (with 'j(...)' and 'j[...]'). These expressions always return 'value'.
#
#   - The last image of the list is always associated to the evaluations of '{expressions}',
#      e.g. G'MIC sequence '256,128 fill {w}' will create a 256x128 image filled with value 256.
#
#  10. Image and data viewers
#      ----------------------
#
# ...
#
#       Return 1 if extension of specified filename is typical from video files.
#
#     is_windows:
#
#       Return 1 if current computer OS is Windows, 0 otherwise.
#
#     math_lib:
#
#       Return string that defines a set of several useful macros for the embedded math evaluator.
#
#     mad:
#
#       Return the MAD (Maximum Absolute Deviation) of the last selected image.
#       The MAD is defined as MAD = med_i|x_i-med_j(x_j)|
#
#     max_w:
#
#       Return the maximal width between selected images.
#
#     max_h:
#
#       Return the maximal height between selected images.
#
#     max_d:
#
#       Return the maximal depth between selected images.
#
#     max_s:
#
#       Return the maximal spectrum between selected images.
#
#     max_wh:
#
#       Return the maximal wxh size of selected images.
#
#     max_whd:
#
#       Return the maximal wxhxd size of selected images.
#
#     max_whds:
#
#       Return the maximal wxhxdxs size of selected images.
#
#     med:
#
#       Return the median value of the last selected image.
#
#     median_color:
#
#       Return the median color value of the last selected image.
#
#     min_w:
#
#       Return the minimal width between selected images.
#
#     min_h:
#
#       Return the minimal height between selected images.
#
#     min_d:
#
#       Return the minimal depth between selected images.
#
#     min_s:
#
#       Return the minimal s size of selected images.
#
#     min_wh:
#
#       Return the minimal wxh size of selected images.
#
#     min_whd:
#
#       Return the minimal wxhxd size of selected images.
#
#     min_whds:
#
#       Return the minimal wxhxdxs size of selected images.
#
#     normalize_filename:
#         filename
#
#       Return a "normalized" version of the specified filename, without spaces and capital letters.
#
#     oct:
#         octal_int1,...
#
#       Print specified octal integers into their binary, decimal, hexadecimal and string
#         representations.
#
#     oct2dec:
#         octal_int1,...
#
#       Convert specified octal integers into their decimal representations.
#
#     padint:
#         number,_size>0
#
#       Return a integer with 'size' digits (eventually left-padded with '0').
#
#     path_gimp:
#
#       Return a path to store GIMP configuration files for one user (whose value is OS-dependent).
#
#     path_tmp:
#
#       Return a path to store temporary files (whose value is OS-dependent).
#
#     reset:
#
#       Reset global parameters of the interpreter environment.
#
#     RGB:
#
#       Return a random int-valued RGB color.
#
#     RGBA:
#
#       Return a random int-valued RGBA color.
#
#     std_noise:
#
#       Return the estimated noise standard deviation of the last selected image.
#
#     str:
#         string
#
#       Print specified string into its binary, octal, decimal and hexadecimal representations.
#
#     str2hex:
#         string
#
#       Convert specified string into a sequence of hexadecimal values.
#
#     stresc:
#         val1,...,valN
#
#       Return escaped string from specified ascii codes.
#
#     strcat:
#         "string1","string2",...
#
#       Return the concatenation of all strings passed as arguments.
#
#     strcmp:
#         "string1","string2",_nb_characters>=0
#
#       Return '1' if the two specified strings are equals, '0' otherwise.
#       If 'nb_characters' is specified, the comparison is done only for the 'nb_characters' first
#         characters.
#
#     strcontains:
#         string1,string2
#
#       Return 1 if the first string contains the second one.
#
#     strlen:
#         string1
#
#       Return the length of specified string argument.
#
#     strreplace:
#         string,search,replace
#
#       Search and replace substrings in an input string.
#
#     strlowercase:
#         string
#
#       Return a lower-case version of the specified string.
#
#     strvar:
#         string
#
#       Return a simplified version of the specified string, that can be used as a variable name.
#
#     strver:
#         _version
#
#       Return the specified version number of the G'MIC interpreter, as a string.
#
#       Default value: 'version=$_version'.
#
#     tic:
#
#       Initialize tic-toc timer.
#       Use it in conjunction with 'toc'.
#
#     toc:
#
#       Display elapsed time of the tic-toc timer since the last call to 'tic'.
#       This command returns the elapsed time in the status value.
#       Use it in conjunction with 'tic'.
#
#     uchar2str:
#
#       Encode the latest of the selected image as a string.
#       The string can be decoded using command 'str2uchar'.
#       Input image must have values that are integers in [0,255].
#
#     str2uchar:
#         "string"
#
#       Decode given string as a newly inserted image at the end of the list.
#       The argument string should have been generated using command 'uchar2str'.
#
#
#  **** Other interactive commands:
#
#
#     demo:
#         _run_in_parallel={ 0=no | 1=yes | 2=auto }
#
#       Show a menu to select and view all G'MIC interactive demos.
#
#     x_2048:
#
#       Launch the 2048 game.
#
#     x_blobs:
#
#       Launch the blobs editor.
#
#     x_bouncing:
#
#       Launch the bouncing balls demo.
#
#     x_color_curves:
#         _colorspace={ rgb | cmy | cmyk | hsi | hsl | hsv | lab | lch | ycbcr | last }
#
#       Apply color curves on selected RGB[A] images, using an interactive window.
#       Set 'colorspace' to 'last' to apply last defined color curves without opening interactive windows.
#
#       Default value: 'colorspace=rgb'.
#
#     x_colorize:
#         _is_lineart={ 0 | 1 },_max_resolution={ 0 | >=128 },_multichannels_output={ 0 | \
#          1 },_[palette1],_[palette2],_[grabber1]
#
#       Colorized selected B&W images, using an interactive window.
#       When >0, argument 'max_resolution' defines the maximal image resolution used in the interactive window.
#
#       Default values: 'is_lineart=1', 'max_resolution=1024' and 'multichannels_output=0'.
#
#     x_connect4:
#
#       Launch the Connect Four game.
#
#     x_fire:
#
#       Launch the fire effect demo.
#
#     x_fireworks:
#
#       Launch the fireworks demo.
#
#     x_fisheye:
#
#       Launch the fish-eye effect demo.
#
#     x_fourier:
#
#       Launch the fourier filtering demo.
#
#     x_grab_color:
#         _variable_name
#
#       Open a color grabber widget from the first selected image.
#       Argument 'variable_name' specifies the variable that contains the selected color values at any time.
#       Assigning '-1' to it forces the interactive window to close.
#
#       Default values: 'variable_name=xgc_variable'.
#
#     x_hanoi:
#
#       Launch the Tower of Hanoi game.
#
#     x_histogram:
#
#       Launch the histogram demo.
#
#     x_hough:
#
#       Launch the hough transform demo.
#
#     x_jawbreaker:
#         0<_width<20,0<_height<20,0<_balls<=8
#
#       Launch the Jawbreaker game.
#
#     x_landscape:
#
#       Launch the virtual landscape demo.
#
#     x_life:
#
#       Launch the game of life.
#
#     x_light:
#
#       Launch the light effect demo.
#
#     x_mandelbrot:
#         _julia={ 0 | 1 },_c0r,_c0i
#
#       Launch Mandelbrot/Julia explorer.
#
#     x_mask_color:
#         _colorspace={ all | rgb | lrgb | ycbcr | lab | lch | hsv | hsi | hsl | cmy | \
#          cmyk | yiq },_spatial_tolerance>=0,_color_tolerance>=0
#
#       Interactively select a color, and add an alpha channel containing the corresponding color mask.
#       Argument 'colorspace' refers to the color metric used to compute color similarities, and can be
#         basically one of { rgb | lrgb | ycbcr | lab | lch | hsv | hsi | hsl | cmy | cmyk | yiq }.
#       You can also select one one particular channel of this colorspace, by setting 'colorspace' as
#         'colorspace_channel' (e.g. 'hsv_h' for the hue).
#
#       Default values: 'colorspace=all', 'spatial_tolerance=5' and 'color_tolerance=5'.
#
#     x_metaballs3d:
#
#       Launch the 3d metaballs demo.
#
#     x_minesweeper:
#         8<=_width=<20,8<=_height<=20
#
#       Launch the Minesweeper game.
#
#     x_minimal_path:
#
#       Launch the minimal path demo.
#
#     x_pacman:
#
#       Launch pacman game.
#
#     x_paint:
#
#       Launch the interactive painter.
#
#     x_plasma:
#
#       Launch the plasma effect demo.
#
#     x_quantize_rgb:
#         _nbcolors>=2
#
#       Launch the RGB color quantization demo.
#
#     x_reflection3d:
#
#       Launch the 3d reflection demo.
#
#     x_rubber3d:
#
#       Launch the 3d rubber object demo.
#
#     x_segment:
#         _max_resolution={ 0 | >=128 }
#
#       Segment foreground from background in selected opaque RGB images, interactively.
#       Return RGBA images with binary alpha-channels.
#
#       Default value: 'max_resolution=1024'.
#
#     x_select_color:
#         _variable_name
#
#       Display a RGB or RGBA color selector.
#       Argument 'variable_name' specifies the variable that contains the selected color values (as R,G,
#         B,[A]) at any time.
#       Its value specifies the initial selected color. Assigning '-1' to it forces the interactive
#         window to close.
#
#       Default value: 'variable_name=xsc_variable'.
#
#     x_select_function1d:
#         _variable_name,_background_curve_R,_background_curve_G,_background_curve_B
#
#       Open an interactive window, where the user can defined its own 1d function.
#       If an image is selected, it is used to display additional information :
#       - The first row defines the values of a background curve displayed on the window (e.g. an
#         histogram).
#       - The 2nd, 3rd and 4th rows define the R,G,B color components displayed beside the X and Y axes.
#       Argument 'variable_name' specifies the variable that contains the selected function keypoints
#         at any time.
#       Assigning '-1' to it forces the interactive window to close.
#
#       Default values: 'variable_name=xsf_variable', 'background_curve_R=220',
#         'background_curve_G=background_curve_B=background_curve_T'.
#
#     x_select_palette:
#         _variable_name,_number_of_columns={ 0=auto | >0 }
#
#       Open a RGB or RGBA color selector widget from a palette.
#       The palette is given as a selected image.
#       Argument 'variable_name' specifies the variable that contains the selected color values (as R,G,
#         B,[A]) at any time.
#       Assigning '-1' to it forces the interactive window to close.
#
#       Default values: 'variable_name=xsp_variable' and 'number_of_columns=2'.
#
#     x_shadebobs:
#
#       Launch the shade bobs demo.
#
#     x_spline:
#
#       Launch spline curve editor.
#
#     x_starfield3d:
#
#       Launch the 3d starfield demo.
#
#     x_tetris:
#
#       Launch tetris game.
#
#     x_tictactoe:
#
#       Launch tic-tac-toe game.
#
#     x_waves:
#
#       Launch the image waves demo.
#
#     x_whirl:
#         _opacity>=0
#
#       Launch the fractal whirls demo.
#
#       Default values: 'opacity=0.2'.
#
#
#  **** Command shortcuts:
#
#
#     h : eq. to 'help'.
#     m  (+): eq. to 'command'.
#     d  (+): eq. to 'display'.
#     d0 : eq. to 'display0'.
#     d3d  (+): eq. to 'display3d'.
#     da : eq. to 'display_array'.
#     dfft : eq. to 'display_fft'.
#     dg : eq. to 'display_graph'.
#     dh : eq. to 'display_histogram'.
#     dp : eq. to 'display_parallel'.
#     dp0 : eq. to 'display_parallel0'.
#     dq : eq. to 'display_quiver'.
#     drgba : eq. to 'display_rgba'.
#     dt : eq. to 'display_tensors'.
#     dw : eq. to 'display_warp'.
#     e  (+): eq. to 'echo'.
#     i  (+): eq. to 'input'.
#     ig : eq. to 'input_glob'.
#     o  (+): eq. to 'output'.
#     on : eq. to 'outputn'.
#     op : eq. to 'outputp'.
#     ow : eq. to 'outputw'.
#     ox : eq. to 'outputx'.
#     p  (+): eq. to 'print'.
#     sh  (+): eq. to 'shared'.
#     sp : eq. to 'sample'.
#     up : eq. to 'update'.
#     v  (+): eq. to 'verbose'.
#     w  (+): eq. to 'window'.
#     k  (+): eq. to 'keep'.
#     mv  (+): eq. to 'move'.
#     nm  (+): eq. to 'name'.
#     rm  (+): eq. to 'remove'.
#     rv  (+): eq. to 'reverse'.
#     +  (+): eq. to 'add'.
#     &  (+): eq. to 'and'.
#     <<  (+): eq. to 'bsl'.
#     >>  (+): eq. to 'bsr'.
#     /  (+): eq. to 'div'.
#     ==  (+): eq. to 'eq'.
#     >=  (+): eq. to 'ge'.
#     >  (+): eq. to 'gt'.
#     <=  (+): eq. to 'le'.
#     <  (+): eq. to 'lt'.
#     m/  (+): eq. to 'mdiv'.
#     %  (+): eq. to 'mod'.
#     m*  (+): eq. to 'mmul'.
#     *  (+): eq. to 'mul'.
#     !=  (+): eq. to 'neq'.
#     |  (+): eq. to 'or'.
#     ^  (+): eq. to 'pow'.
#     -  (+): eq. to 'sub'.
#     c  (+): eq. to 'cut'.
#     f  (+): eq. to 'fill'.
#     ir : eq. to 'inrange'.
#     n  (+): eq. to 'normalize'.
#     =  (+): eq. to 'set'.
#     ac : eq. to 'apply_channels'.
#     fc : eq. to 'fill_color'.
#     a  (+): eq. to 'append'.
#     z  (+): eq. to 'crop'.
#     r  (+): eq. to 'resize'.
#     rr2d : eq. to 'resize_ratio2d'.
#     r2dx : eq. to 'resize2dx'.
#     r2dy : eq. to 'resize2dy'.
#     r3dx : eq. to 'resize3dx'.
#     r3dy : eq. to 'resize3dy'.
#     r3dz : eq. to 'resize3dz'.
#     s  (+): eq. to 'split'.
#     y  (+): eq. to 'unroll'.
#     b  (+): eq. to 'blur'.
#     g  (+): eq. to 'gradient'.
#     j  (+): eq. to 'image'.
#     j3d  (+): eq. to 'object3d'.
#     t  (+): eq. to 'text'.
#     to : eq. to 'text_outline'.
#     +3d  (+): eq. to 'add3d'.
#     c3d : eq. to 'center3d'.
#     col3d  (+): eq. to 'color3d'.
#     /3d  (+): eq. to 'div3d'.
#     db3d  (+): eq. to 'double3d'.
#     f3d  (+): eq. to 'focale3d'.
#     l3d  (+): eq. to 'light3d'.
#     m3d  (+): eq. to 'mode3d'.
#     md3d  (+): eq. to 'moded3d'.
#     *3d  (+): eq. to 'mul3d'.
#     n3d : eq. to 'normalize3d'.
#     o3d  (+): eq. to 'opacity3d'.
#     p3d  (+): eq. to 'primitives3d'.
#     rv3d  (+): eq. to 'reverse3d'.
#     r3d  (+): eq. to 'rotate3d'.
#     sl3d  (+): eq. to 'specl3d'.
#     ss3d  (+): eq. to 'specs3d'.
#     s3d  (+): eq. to 'split3d'.
#     -3d  (+): eq. to 'sub3d'.
#     t3d  (+): eq. to 'texturize3d'.
#     ap : eq. to 'apply_parallel'.
#     apc : eq. to 'apply_parallel_channels'.
#     apo : eq. to 'apply_parallel_overlap'.
#     at : eq. to 'apply_tiles'.
#     fi  (+): eq. to 'endif'.
#     endl  (+): eq. to 'endlocal'.
#     x  (+): eq. to 'exec'.
#     l  (+): eq. to 'local'.
#     q  (+): eq. to 'quit'.
#     u  (+): eq. to 'status'.
#     frame : eq. to 'frame_xy'.
#
#    [ Total number of commands: 973 ]
#
#  13. Examples of use
#      ---------------
#
#  'gmic' is a generic image processing tool which can be used in a wide variety of situations.
#  The few examples below illustrate possible uses of this tool:
#
#   - View a list of images:
#      gmic file1.bmp file2.jpeg
#
#   - Convert an image file:
#      gmic input.bmp output output.jpg
#
#   - Create a volumetric image from a movie sequence:
#      gmic input.mpg append z output output.hdr
#
#   - Compute image gradient norm:
#      gmic input.bmp gradient_norm
#
#   - Denoise a color image:
#      gmic image.jpg denoise 30,10 output denoised.jpg
#
#   - Compose two images using overlay layer blending:
#      gmic image1.jpg image2.jpg blend overlay output blended.jpg
#
#   - Evaluate a mathematical expression:
#      gmic echo "cos(pi/4)^2+sin(pi/4)^2={cos(pi/4)^2+sin(pi/4)^2}"
#
#   - Plot a 2d function:
#      gmic 1000,1,1,2 fill "X=3*(x-500)/500;X^2*sin(3*X^2)+if(c==0,u(0,-1),cos(X*10))" plot
#
#   - Plot a 3d elevated function in random colors:
#      gmic 128,128,1,3,"u(0,255)" plasma 10,3 blur 4 sharpen 10000 \
#       elevation3d[-1] "'X=(x-64)/6;Y=(y-64)/6;100*exp(-(X^2+Y^2)/30)*abs(cos(X)*sin(Y))'"
#
#   - Plot the isosurface of a 3d volume:
#      gmic mode3d 5 moded3d 5 double3d 0 isosurface3d "'x^2+y^2+abs(z)^abs(4*cos(x*y*z*3))'",3
#
#   - Render a G'MIC 3d logo:
#      gmic 0 text G\'MIC,0,0,53,1,1,1,1 expand_xy 10,0 blur 1 normalize 0,100 +plasma 0.4 add \
#       blur 1 elevation3d -0.1 moded3d 4
#
#   - Generate a 3d ring of torii:
#      gmic repeat 20 torus3d 15,2 color3d[-1] "{u(60,255)},{u(60,255)},{u(60,255)}" \
#       *3d[-1] 0.5,1 if "{$>%2}" rotate3d[-1] 0,1,0,90 endif add3d[-1] 70 add3d \
#       rotate3d 0,0,1,18 done moded3d 3 mode3d 5 double3d 0
#
#   - Create a vase from a 3d isosurface:
#      gmic moded3d 4 isosurface3d "'x^2+2*abs(y/2)*sin(2*y)^2+z^2-3',0" sphere3d 1.5 \
#       sub3d[-1] 0,5 plane3d 15,15 rotate3d[-1] 1,0,0,90 center3d[-1] add3d[-1] 0,3.2 \
#       color3d[-1] 180,150,255 color3d[-2] 128,255,0 color3d[-3] 255,128,0 add3d
#
#   - Display filtered webcam stream:
#      gmic apply_camera \"+mirror x +mirror y add div 4\"
#
#   - Launch a set of G'MIC interactive demos:
#      gmic demo
#
#  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **

# %%
# !gmic -i 640x640/171.jpg -status
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/171.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set status to ''.
# [gmic]-1./ Display image [0] = '171.jpg'.
# [0] = '640x640/171.jpg':
#   size = (640,640,1,3) [4800 Kio of floats].
#   data = (146,147,145,145,146,147,146,146,139,136,130,129,(...),254,255,255,255,254,253,252,252,253,254,255,255).
#   min = 0, max = 255, mean = 132.191, std = 77.8613, coords_min = (557,63,0,0), coords_max = (564,156,0,0).
# [gmic]-1./ End G'MIC interpreter.

# %%
# create a list in memory of a directory
from time import sleep
import os
LST = []
PATH = "640x640/"
for files in sorted(os.listdir(PATH)):
    LST.append(PATH+files)
    
    
Then it may be used with:
    
    
for line in LST:
    print line

# %%
for line in LST:
    print line
# Out:
# 640x640/003.jpg
# 640x640/003.png
# 640x640/013.jpg
# 640x640/013.png
# 640x640/015.jpg
# 640x640/015.png
# 640x640/025.jpg
# 640x640/025.png
# 640x640/026.jpg
# 640x640/026.png
# 640x640/052.jpg
# 640x640/052.png
# 640x640/054.jpg
# 640x640/054.png
# 640x640/073.jpg
# 640x640/073.png
# 640x640/082.jpg
# 640x640/082.png
# 640x640/089.jpg
# 640x640/089.png
# 640x640/092.jpg
# 640x640/092.png
# 640x640/094.jpg
# 640x640/094.png
# 640x640/101.jpg
# 640x640/101.png
# 640x640/106.jpg
# 640x640/106.png
# 640x640/121.jpg
# 640x640/121.png
# 640x640/126.jpg
# 640x640/126.png
# 640x640/127.jpg
# 640x640/127.png
# 640x640/128.jpg
# 640x640/128.png
# 640x640/136.jpg
# 640x640/136.png
# 640x640/137.jpg
# 640x640/137.png
# 640x640/138.jpg
# 640x640/138.png
# 640x640/142.jpg
# 640x640/142.png
# 640x640/150.jpg
# 640x640/150.png
# 640x640/153.jpg
# 640x640/153.png
# 640x640/162.jpg
# 640x640/162.png
# 640x640/171.jpg
# 640x640/171.png
# 640x640/172.jpg
# 640x640/172.png
# 640x640/173.jpg
# 640x640/173.png
# 640x640/174.jpg
# 640x640/174.png
# 640x640/179.jpg
# 640x640/179.png
# 640x640/181.jpg
# 640x640/181.png
# 640x640/185.jpg
# 640x640/185.png
# 640x640/188.jpg
# 640x640/188.png
# 640x640/194.jpg
# 640x640/194.png
# 640x640/195.jpg
# 640x640/195.png
# 640x640/202.jpg
# 640x640/202.png
# 640x640/211.jpg
# 640x640/211.png
# 640x640/213.jpg
# 640x640/213.png
# 640x640/220.jpg
# 640x640/220.png
# 640x640/226.jpg
# 640x640/226.png
# 640x640/241.jpg
# 640x640/241.png
# 640x640/245.jpg
# 640x640/245.png
# 640x640/260.jpg
# 640x640/260.png
# 640x640/261.jpg
# 640x640/261.png
# 640x640/262.jpg
# 640x640/262.png
# 640x640/263.jpg
# 640x640/263.png
# 640x640/P_20180411_062100.jpg
# 640x640/P_20180411_062100.png
# 640x640/P_20180411_062104.jpg
# 640x640/P_20180411_062104.png
# 640x640/P_20180411_062110.jpg
# 640x640/P_20180411_062110.png
# 640x640/P_20180411_062114.jpg
# 640x640/P_20180411_062114.png
# 640x640/P_20180411_112909.jpg
# 640x640/P_20180411_112909.png
# 640x640/P_20180411_112959_BF.jpg
# 640x640/P_20180411_112959_BF.png
# 640x640/P_20180411_113004.jpg
# 640x640/P_20180411_113004.png
# 640x640/P_20180411_113229.jpg
# 640x640/P_20180411_113229.png
# 640x640/P_20180411_113942.jpg
# 640x640/P_20180411_113942.png
# 640x640/P_20180411_114114.jpg
# 640x640/P_20180411_114114.png
# 640x640/P_20180411_114858.jpg
# 640x640/P_20180411_114858.png
# 640x640/P_20180411_114905.jpg
# 640x640/P_20180411_114905.png
# 640x640/P_20180412_090916.jpg
# 640x640/P_20180412_090916.png
# 640x640/P_20180412_165355.jpg
# 640x640/P_20180412_165355.png
# 640x640/P_20180412_165404.jpg
# 640x640/P_20180412_165404.png
# 640x640/P_20180412_165411.jpg
# 640x640/P_20180412_165411.png
# 640x640/P_20180412_165437.jpg
# 640x640/P_20180412_165437.png
# 640x640/P_20180412_173934.jpg
# 640x640/P_20180412_173934.png
# 640x640/P_20180412_173956.jpg
# 640x640/P_20180412_173956.png
# 640x640/P_20180412_173958.jpg
# 640x640/P_20180412_173958.png
# 640x640/P_20180412_175847.jpg
# 640x640/P_20180412_175847.png
# 640x640/P_20180412_181920.jpg
# 640x640/P_20180412_181920.png
# 640x640/P_20180413_130142_BF.jpg
# 640x640/P_20180413_130142_BF.png
# 640x640/P_20180413_130327_BF.jpg
# 640x640/P_20180413_130327_BF.png
# 640x640/P_20180413_130459.jpg
# 640x640/P_20180413_130459.png
# 640x640/P_20180413_162636.jpg
# 640x640/P_20180413_162636.png
# 640x640/P_20180413_170240.jpg
# 640x640/P_20180413_170240.png
# 640x640/P_20180413_170300.jpg
# 640x640/P_20180413_170300.png
# 640x640/P_20180413_170310.jpg
# 640x640/P_20180413_170310.png
# 640x640/P_20180413_170312.jpg
# 640x640/P_20180413_170312.png
# 640x640/P_20180413_170547.jpg
# 640x640/P_20180413_170547.png
# 640x640/P_20180414_181207.jpg
# 640x640/P_20180414_181207.png
# 640x640/P_20180414_181305.jpg
# 640x640/P_20180414_181305.png
# 640x640/P_20180414_181313.jpg
# 640x640/P_20180414_181313.png
# 640x640/P_20180415_162602.jpg
# 640x640/P_20180415_162602.png
# 640x640/P_20180415_162829.jpg
# 640x640/P_20180415_162829.png
# 640x640/P_20180415_162849.jpg
# 640x640/P_20180415_162849.png
# 640x640/P_20180415_163054.jpg
# 640x640/P_20180415_163054.png
# 640x640/P_20180415_163356.jpg
# 640x640/P_20180415_163356.png
# 640x640/P_20180415_163400.jpg
# 640x640/P_20180415_163400.png
# 640x640/P_20180415_163539.jpg
# 640x640/P_20180415_163539.png
# 640x640/P_20180415_163909.jpg
# 640x640/P_20180415_163909.png
# 640x640/P_20180415_164000.jpg
# 640x640/P_20180415_164000.png
# 640x640/P_20180415_164415.jpg
# 640x640/P_20180415_164415.png
# 640x640/P_20180415_164418.jpg
# 640x640/P_20180415_164418.png
# 640x640/P_20180415_164646.jpg
# 640x640/P_20180415_164646.png
# 640x640/P_20180415_164704.jpg
# 640x640/P_20180415_164704.png
# 640x640/P_20180415_164707.jpg
# 640x640/P_20180415_164707.png
# 640x640/P_20180415_164859.jpg
# 640x640/P_20180415_164859.png
# 640x640/P_20180415_165023.jpg
# 640x640/P_20180415_165023.png
# 640x640/P_20180415_165040.jpg
# 640x640/P_20180415_165040.png
# 640x640/P_20180415_165044.jpg
# 640x640/P_20180415_165044.png
# 640x640/P_20180415_165046.jpg
# 640x640/P_20180415_165046.png
# 640x640/P_20180415_165241.jpg
# 640x640/P_20180415_165241.png
# 640x640/P_20180415_165453.jpg
# 640x640/P_20180415_165453.png
# 640x640/P_20180415_170146.jpg
# 640x640/P_20180415_170146.png
# 640x640/P_20180415_170218.jpg
# 640x640/P_20180415_170218.png
# 640x640/P_20180415_170223.jpg
# 640x640/P_20180415_170223.png
# 640x640/P_20180415_170240.jpg
# 640x640/P_20180415_170240.png
# 640x640/P_20180415_170353.jpg
# 640x640/P_20180415_170353.png
# 640x640/P_20180415_170416.jpg
# 640x640/P_20180415_170416.png
# 640x640/P_20180415_170609.jpg
# 640x640/P_20180415_170609.png
# 640x640/P_20180415_172850.jpg
# 640x640/P_20180415_172850.png
# 640x640/P_20180415_175038.jpg
# 640x640/P_20180415_175038.png
# 640x640/P_20180416_163956_BF.jpg
# 640x640/P_20180416_163956_BF.png
# 640x640/P_20180416_164243.jpg
# 640x640/P_20180416_164243.png
# 640x640/b082.jpg
# 640x640/b082.png

# %%
import subprocess
import os
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    filename = time.strftime("cartoon/%Y%m%d%H%M%S.jpg")
    #com ="gmic -input "+filein+ " -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #-normalize[-0] 60,255 -output "+filename+", shell=True"
    #subprocess.call(com)
    subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    -normalize[-0] 60,255 -output "+filename, shell=True)
# Out:
# 2  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 4  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 6  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 8  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 10  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 12  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 14  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 16  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 18  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 20  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 22  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 24  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 26  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 28  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 30  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 32  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 34  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 36  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 38  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 40  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 42  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 44  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 46  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 48  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 50  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 52  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 54  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 56  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 58  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 60  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 62  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 64  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 66  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 68  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 70  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 72  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 74  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 76  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 78  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 80  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 82  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 84  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 86  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 88  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 90  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 92  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 94  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 96  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 98  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 100  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 102  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 104  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 106  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 108  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 110  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 112  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 114  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 116  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 118  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 120  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 122  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 124  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 126  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 128  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 130  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 132  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 134  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 136  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 138  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 140  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 142  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 144  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 146  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 148  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 150  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 152  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 154  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 156  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 158  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 160  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 162  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 164  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 166  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 168  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 170  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 172  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 174  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 176  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 178  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 180  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 182  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 184  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 186  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 188  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 190  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 192  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 194  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 196  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 198  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 200  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 202  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 204  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 206  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 208  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 210  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 212  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 214  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 216  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 218  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 220  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 222  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 224  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 226  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-150-a930e001c4c6> in <module>()
#       4 while True:
#       5     count = count+1
# ----> 6     filein = LST[count]
#       7     filein = filein.replace("\n","")
#       8     count = count +1
#
# IndexError: list index out of range

# %%
import subprocess
import os
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    filename = time.strftime("cartoon/RANDOM_%Y%m%d%H%M%S.jpg")

    subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    -normalize[-0] 60,255 -output "+filename, shell=True)
# Out:
# 2  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 4  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 6  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 8  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 10  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 12  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 14  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 16  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 18  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 20  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 22  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 24  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 26  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 28  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 30  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 32  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 34  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 36  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 38  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 40  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 42  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 44  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 46  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 48  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 50  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 52  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 54  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 56  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 58  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 60  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 62  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 64  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 66  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 68  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 70  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 72  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 74  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 76  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 78  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 80  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 82  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 84  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 86  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 88  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 90  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 92  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 94  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 96  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 98  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 100  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 102  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 104  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 106  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 108  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 110  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **

# %%
print (randint(1,4)*1.1)-1
# Out:
# 0.1

# %%
import subprocess
import os
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    filename = time.strftime("cartoon/RANDOM_%Y%m%d%H%M%S.jpg")

    subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    -normalize[-0] 60,255 -output "+filename, shell=True)
# Out:
# 2  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 4  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 6  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 8  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 10  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 12  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 14  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 16  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 18  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 20  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 22  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 24  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 26  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 28  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 30  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 32  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 34  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 36  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 38  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 40  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 42  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 44  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 46  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 48  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 50  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 52  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 54  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 56  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 58  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 60  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 62  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 64  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 66  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 68  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 70  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 72  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 74  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 76  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 78  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 80  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 82  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 84  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 86  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 88  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 90  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 92  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 94  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 96  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 98  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 100  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 102  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 104  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 106  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 108  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 110  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **

# %%
# !mkdir

# %%
import subprocess
import os
import time
directory = "cartoon"
if not os.path.exists(directory):
    os.makedirs(directory)
count = 0
while True:
    count = count +1
    if count==114:break
    filename = time.strftime(directory+"/TOON_%Y%m%d%H%M%S.jpg")
    filein = LST[count]
    
    
    print count,filein
# Out:
# 1 640x640/013.jpg
# 2 640x640/015.jpg
# 3 640x640/025.jpg
# 4 640x640/026.jpg
# 5 640x640/052.jpg
# 6 640x640/054.jpg
# 7 640x640/073.jpg
# 8 640x640/082.jpg
# 9 640x640/089.jpg
# 10 640x640/092.jpg
# 11 640x640/094.jpg
# 12 640x640/101.jpg
# 13 640x640/106.jpg
# 14 640x640/121.jpg
# 15 640x640/126.jpg
# 16 640x640/126.png
# 17 640x640/127.jpg
# 18 640x640/128.jpg
# 19 640x640/136.jpg
# 20 640x640/137.jpg
# 21 640x640/138.jpg
# 22 640x640/142.jpg
# 23 640x640/150.jpg
# 24 640x640/153.jpg
# 25 640x640/162.jpg
# 26 640x640/171.jpg
# 27 640x640/172.jpg
# 28 640x640/173.jpg
# 29 640x640/174.jpg
# 30 640x640/179.jpg
# 31 640x640/181.jpg
# 32 640x640/185.jpg
# 33 640x640/188.jpg
# 34 640x640/194.jpg
# 35 640x640/195.jpg
# 36 640x640/202.jpg
# 37 640x640/211.jpg
# 38 640x640/213.jpg
# 39 640x640/220.jpg
# 40 640x640/226.jpg
# 41 640x640/241.jpg
# 42 640x640/245.jpg
# 43 640x640/260.jpg
# 44 640x640/261.jpg
# 45 640x640/262.jpg
# 46 640x640/263.jpg
# 47 640x640/b082.jpg
# 48 640x640/P_20180411_062100.jpg
# 49 640x640/P_20180411_062104.jpg
# 50 640x640/P_20180411_062110.jpg
# 51 640x640/P_20180411_062114.jpg
# 52 640x640/P_20180411_112909.jpg
# 53 640x640/P_20180411_112959_BF.jpg
# 54 640x640/P_20180411_113004.jpg
# 55 640x640/P_20180411_113229.jpg
# 56 640x640/P_20180411_113942.jpg
# 57 640x640/P_20180411_114114.jpg
# 58 640x640/P_20180411_114858.jpg
# 59 640x640/P_20180411_114905.jpg
# 60 640x640/P_20180412_090916.jpg
# 61 640x640/P_20180412_165355.jpg
# 62 640x640/P_20180412_165404.jpg
# 63 640x640/P_20180412_165411.jpg
# 64 640x640/P_20180412_165437.jpg
# 65 640x640/P_20180412_173934.jpg
# 66 640x640/P_20180412_173956.jpg
# 67 640x640/P_20180412_173958.jpg
# 68 640x640/P_20180412_175847.jpg
# 69 640x640/P_20180412_181920.jpg
# 70 640x640/P_20180413_130142_BF.jpg
# 71 640x640/P_20180413_130327_BF.jpg
# 72 640x640/P_20180413_130459.jpg
# 73 640x640/P_20180413_162636.jpg
# 74 640x640/P_20180413_170240.jpg
# 75 640x640/P_20180413_170300.jpg
# 76 640x640/P_20180413_170310.jpg
# 77 640x640/P_20180413_170312.jpg
# 78 640x640/P_20180413_170547.jpg
# 79 640x640/P_20180414_181207.jpg
# 80 640x640/P_20180414_181305.jpg
# 81 640x640/P_20180414_181313.jpg
# 82 640x640/P_20180415_162602.jpg
# 83 640x640/P_20180415_162829.jpg
# 84 640x640/P_20180415_162849.jpg
# 85 640x640/P_20180415_163054.jpg
# 86 640x640/P_20180415_163356.jpg
# 87 640x640/P_20180415_163400.jpg
# 88 640x640/P_20180415_163539.jpg
# 89 640x640/P_20180415_163909.jpg
# 90 640x640/P_20180415_164000.jpg
# 91 640x640/P_20180415_164415.jpg
# 92 640x640/P_20180415_164418.jpg
# 93 640x640/P_20180415_164646.jpg
# 94 640x640/P_20180415_164704.jpg
# 95 640x640/P_20180415_164707.jpg
# 96 640x640/P_20180415_164859.jpg
# 97 640x640/P_20180415_165023.jpg
# 98 640x640/P_20180415_165040.jpg
# 99 640x640/P_20180415_165044.jpg
# 100 640x640/P_20180415_165046.jpg
# 101 640x640/P_20180415_165241.jpg
# 102 640x640/P_20180415_165453.jpg
# 103 640x640/P_20180415_170146.jpg
# 104 640x640/P_20180415_170218.jpg
# 105 640x640/P_20180415_170223.jpg
# 106 640x640/P_20180415_170240.jpg
# 107 640x640/P_20180415_170353.jpg
# 108 640x640/P_20180415_170416.jpg
# 109 640x640/P_20180415_170609.jpg
# 110 640x640/P_20180415_172850.jpg
# 111 640x640/P_20180415_175038.jpg
# 112 640x640/P_20180416_163956_BF.jpg
# 113 640x640/P_20180416_164243.jpg

# %%
#VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    sm =randint(0,5)
    sh =randint(50,250)
    thres = randint(5,50)
    thk = randint(1,5)*.1
    col = (randint(1,10)*1.1)-1
    quant = randint(3,10)
    sm = str(sm)
    quant = str(quant)
    col = str(col)
    thres = str(thres)
    thk = str(thk)
    sh = str(sh)
    filename = time.strftime("cartoon/RANDOM-sm"+sm+"-sh"+sh+"-thres"+thres+"-thk"+thk+"-col"+col+"-quant"+quant+"%Y%m%d%H%M%S.jpg")
-v -99 -fx_posterize 150,30,1,12,0,0,0,0
    subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,"+sh+","+thres+","+thk+","+col+","+quant+",0 \
    -normalize[-0] 60,255 -output "+filename, shell=True)
    sleep(1)
# Out:
# 2  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 4  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 6  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 8  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 10  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 12  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 14  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 16  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 18  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 20  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 22  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 24  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 26  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 28  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 30  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 32  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 34  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 36  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 38  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 40  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 42  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 44  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 46  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 48  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 50  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 52  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 54  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 56  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 58  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 60  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 62  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 64  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 66  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 68  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 70  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 72  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 74  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 76  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 78  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 80  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 82  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 84  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 86  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 88  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 90  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 92  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 94  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 96  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 98  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 100  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 102  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 104  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 106  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 108  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 110  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 112  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 114  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 116  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 118  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 120  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 122  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 124  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 126  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 128  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 130  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 132  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 134  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 136  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 138  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 140  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 142  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 144  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 146  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 148  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 150  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 152  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 154  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 156  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 158  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 160  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 162  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 164  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 166  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 168  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 170  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 172  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 174  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 176  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 178  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 180  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 182  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 184  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 186  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 188  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 190  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 192  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 194  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 196  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 198  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 200  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 202  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 204  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 206  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 208  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 210  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 212  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 214  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 216  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 218  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 220  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 222  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 224  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 226  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-188-0273e6c1df14> in <module>()
#       6 while True:
#       7     count = count+1
# ----> 8     filein = LST[count]
#       9     filein = filein.replace("\n","")
#      10     count = count +1
#
# IndexError: list index out of range

# %%
import os
import random
path0 = r"640x640/"
random_filename0 = random.choice([
y for y in os.listdir(path0)
if os.path.isfile(os.path.join(path0, y)) ])
RandIm = path0+random_filename0
print RandIm
# Out:
# 640x640/P_20180415_164415.jpg

# %%
-v 0 -fx_halftone -15.3846,-35.5769,-26.9231,2.88462,12,11,57,5,2.76923,0

# %%
# 'density=50', 'thickness=10', 'max_angle=75', 'opacity=0.7' and 'smoothness=0'
# !gmic -v 5 -i 640x640/101.jpg -cubism  50, 10, 75, 0.7,0 -display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Set verbosity level to 5.
# [gmic]-0./ Input file '640x640/101.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./cubism/ Check expression '50>=0 && 10>=0 && 10<=50 && 0>=0' -> true.
# [gmic]-1./cubism/ Skip argument '75,0.7'.
# [gmic]-1./ Apply cubism effect on image [0], with density 50, thickness 10, maximum angle 75 deg., opacity 0.7 and smoothness 0.
# [gmic]-1./cubism/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*if/ End 'if...endif' block.
# [gmic]-1./cubism/ Decrement verbosity level (set to 4).
# [gmic]-1./cubism/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./cubism/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./cubism/*repeat/*local/ Set local variable 'w=640'.
# [gmic]-1./cubism/*repeat/*local/ Set local variable 'h=640'.
# [gmic]-1./cubism/*repeat/*local/ Set local variable 's=3'.
# [gmic]-1./cubism/*repeat/*local/ Set local variable 'P=32'.
# [gmic]-1./cubism/*repeat/*local/ Set local variable 'N=2400'.
# [gmic]-1./cubism/*repeat/*local/ Input image at position 1, with values (67,73,109,103,51,100) (1 image 6x1x1x1).
# [gmic]-2./cubism/*repeat/*local/ Add 0.5 to image [1].
# [gmic]-2./cubism/*repeat/*local/ Input image at position 2, with values (9600;2400) (1 image 1x2x1x1).
# [gmic]-3./cubism/*repeat/*local/ Input black image at position 3 (1 image 1x2400x1x1).
# [gmic]-4./cubism/*repeat/*local/ Fill image [3] with random values, in range [32,607].
# [gmic]-4./cubism/*repeat/*local/ Fill image [3] with random values, in range [32,607].
# [gmic]-5./cubism/*repeat/*local/ Append images [3,4] along the 'x'-axis, with alignment 0.
# [gmic]-4./cubism/*repeat/*local/ Round values of image [3] by 1 and nearest rounding.
# [gmic]-4./cubism/*repeat/*local/ Add expression '-32,-32' to image [3].
# [gmic]-5./cubism/*repeat/*local/ Add expression '32,-32' to image [3].
# [gmic]-6./cubism/*repeat/*local/ Add expression '32,32' to image [3].
# [gmic]-7./cubism/*repeat/*local/ Add expression '-32,32' to image [3].
# [gmic]-8./cubism/*repeat/*local/ Append images [4,5,6,7] along the 'x'-axis, with alignment 0.
# [gmic]-5./cubism/*repeat/*local/ Input image at position 4, with values (12,0,1,2,3;12,9596,9597,9598,9599) (1 image 5x2x1x1).
# [gmic]-6./cubism/*repeat/*local/ Resize image [4] to 5x2400x1x1, with linear interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-6./cubism/*repeat/*local/ Round values of image [4] by 1 and nearest rounding.
# [gmic]-6./cubism/*repeat/*local/ Append images [4,5] along the 'x'-axis, with alignment 0.
# [gmic]-5./cubism/*repeat/*local/ Input black image at position 5 (1 image 1x2400x1x1).
# [gmic]-6./cubism/*repeat/*local/ Fill image [5] with random values, in range [150,300].
# [gmic]-6./cubism/*repeat/*local/ Multiply image [5] by 0.0174533.
# [gmic]-6./cubism/*repeat/*local/ Compute pointwise sine of image [5].
# [gmic]-7./cubism/*repeat/*local/ Compute pointwise cosine of image [5].
# [gmic]-7./cubism/*repeat/*local/ Multiply image [6] by -1.
# [gmic]-8./cubism/*repeat/*local/ Input copy of image [5] at position 8 (1 image 1x2400x1x1).
# [gmic]-9./cubism/*repeat/*local/ Append images [5,6] along the 'x'-axis, with alignment 0.
# [gmic]-8./cubism/*repeat/*local/ Append images [6,7] along the 'x'-axis, with alignment 0.
# [gmic]-7./cubism/*repeat/*local/ Crop images [3,5,6] with coordinates (0) - (2) and dirichlet boundary conditions.
# [gmic]-7./cubism/*repeat/*local/ Multiply images [5,6] by -1.
# [gmic]-9./cubism/*repeat/*local/ Append images [5,6,7,8] along the 'x'-axis, with alignment 0.
# [gmic]-6./cubism/*repeat/*local/ Multiply image [5] by 45.2548.
# [gmic]-6./cubism/*repeat/*local/ Resize image [3] to 400%x100%x1x1, with no interpolation, periodic boundary conditions and alignment (0,0,0,0).
# [gmic]-6./cubism/*repeat/*local/ Add images [3,5].
# [gmic]-5./cubism/*repeat/*local/ Input image at position 5, with values (-128;640;640;3) (1 image 1x4x1x1).
# [gmic]-6./cubism/*repeat/*local/ Blur image [0] with standard deviation 0, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-7./cubism/*repeat/*local/*if/ Start 'if...endif' block -> condition '1' holds.
# [gmic]-7./cubism/*repeat/*local/*if/ Input image at position 7, with values '-128,0,0,0' (1 image 4x2399x1x1).
# [gmic]-8./cubism/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-8./cubism/*repeat/*local/ Input image at position 8, with values '1' (1 image 1x2400x1x1).
# [gmic]-9./cubism/*repeat/*local/ Unroll images [1,2,3,(...),6,7,8] along the 'y'-axis.
# [gmic]-9./cubism/*repeat/*local/ Append images [1,2,3,(...),6,7,8] along the 'y'-axis, with alignment 0.
# [gmic]-2./cubism/*repeat/*local/ Reverse orientation of 3d object [1].
# [gmic]-2./cubism/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-2./cubism/*repeat/*local/*if/ Draw 3d object [1] at (0,0,0) on image [0], with opacity 1, flat rendering, simple-sided mode, no z-buffer, focale 700, 3d light at (0,0,-5e+08) and specular properties (0.15,0.8)
# [gmic]-3./cubism/*repeat/*local/*if/ Remove image [1] (2 images left).
# [gmic]-2./cubism/*repeat/*local/*if/blend/ Skip argument 'alpha,0.7,1,0'.
# [gmic]-2./cubism/*repeat/*local/*if/blend/ Decrement verbosity level (set to 3).
# [gmic]-2./cubism/*repeat/*local/*if/blend/*substitute/is_image_arg/ Skip argument 'alpha'.
# [gmic]-2./cubism/*repeat/*local/*if/blend/*substitute/is_image_arg/ Decrement verbosity level (set to 2).
# [gmic]-2./cubism/*repeat/*local/*if/blend/*substitute/is_image_arg/ Set status to '0'.
# [gmic]-2./cubism/*repeat/*local/*if/blend/*substitute/is_image_arg/ Increment verbosity level (set to 3).
# [gmic]-2./cubism/*repeat/*local/*if/blend/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-2./cubism/*repeat/*local/*if/blend/*if/ End 'if...endif' block.
# [gmic]-2./cubism/*repeat/*local/*if/blend/ Increment verbosity level (set to 4).
# [gmic]-2./cubism/*repeat/*local/*if/ Blend all images [0,1] together, using 'alpha' mode and opacity 0.7.
# [gmic]-2./cubism/*repeat/*local/*if/blend/ Decrement verbosity level (set to 3).
# [gmic]-2./cubism/*repeat/*local/*if/blend/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-2./cubism/*repeat/*local/*if/blend/*repeat/*local/ Start 'local...endlocal' block, with selected images [0,1].
# [gmic]-2./cubism/*repeat/*local/*if/blend/*repeat/*local/ Resize image [1] to 640x640x1x100% , with no interpolation, dirichlet boundary conditions and alignment (0.5,0.5,0,0).
# [gmic]-2./cubism/*repeat/*local/*if/blend/*repeat/*local/ Set local variable 's=3'.
# [gmic]-1./cubism/*repeat/*local/*if/blend/*repeat/*local/to_colormode/ Skip argument '3'.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Reach 'elif' block -> condition '1' holds.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Force image [0] to be in RGB mode.
# [gmic]-1./cubism/*repeat/*local/(...)/*local/to_colormode/*if/to_rgb/ Decrement verbosity level (set to 2).
# [gmic]-1./cubism/*repeat/*local/(...)/to_colormode/*if/to_rgb/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./cubism/*repeat/*local/(...)/*if/to_rgb/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./cubism/*repeat/*local/(...)/*if/to_rgb/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./cubism/*repeat/*local/(...)/to_colormode/*if/to_rgb/*repeat/ End 'repeat...done' block.
# [gmic]-1./cubism/*repeat/*local/(...)/*local/to_colormode/*if/to_rgb/ Increment verbosity level (set to 3).
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Reach 'else' block.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ End 'if...endif' block.
# [gmic]-1./cubism/*repeat/*local/*if/blend/*repeat/*local/to_colormode/ Skip argument '3'.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Reach 'elif' block -> condition '1' holds.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Force image [0] to be in RGB mode.
# [gmic]-1./cubism/*repeat/*local/(...)/*local/to_colormode/*if/to_rgb/ Decrement verbosity level (set to 2).
# [gmic]-1./cubism/*repeat/*local/(...)/to_colormode/*if/to_rgb/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./cubism/*repeat/*local/(...)/*if/to_rgb/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./cubism/*repeat/*local/(...)/to_rgb/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./cubism/*repeat/*local/(...)/*if/to_rgb/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./cubism/*repeat/*local/(...)/to_colormode/*if/to_rgb/*repeat/ End 'repeat...done' block.
# [gmic]-1./cubism/*repeat/*local/(...)/*local/to_colormode/*if/to_rgb/ Increment verbosity level (set to 3).
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ Reach 'else' block.
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/to_colormode/*if/ End 'if...endif' block.
# [gmic]-2./cubism/*repeat/*local/*if/blend/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-2./cubism/*repeat/*local/(...)/*repeat/*local/*if/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-2./cubism/*repeat/*local/(...)/*repeat/*local/*if/*if/ Draw image [1] at (0,0,0,0) on image [0], with opacity 0.7.
# [gmic]-2./cubism/*repeat/*local/(...)/*repeat/*local/*if/*if/ Remove image [1] (1 image left).
# [gmic]-1./cubism/*repeat/*local/(...)/*repeat/*local/*if/*if/ End 'if...endif' block.
# [gmic]-1./cubism/*repeat/*local/*if/blend/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./cubism/*repeat/*local/*if/blend/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./cubism/*repeat/*local/*if/blend/*repeat/ End 'repeat...done' block.
# [gmic]-1./cubism/*repeat/*local/*if/blend/ Increment verbosity level (set to 4).
# [gmic]-1./cubism/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./cubism/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./cubism/*repeat/ End 'repeat...done' block.
# [gmic]-1./cubism/ Increment verbosity level (set to 5).
# [gmic]-1./ Input file '10,' at position 1
# [gmic]-1./ *** Error *** Unknown command or filename '10,' (did you mean 'w0' ?).

# %%
# 'density=50', 'thickness=10', 'max_angle=75', 'opacity=0.7' and 'smoothness=0'
# !gmic -i 640x640/P_20180415_164415.jpg \
-v 0 -cubism  50, 10, 75, 0.7,0 \
-o cubism22A.jpg
# !showme cubism22A.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/P_20180415_164415.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set verbosity level to 0.
# [gmic]-1./ Apply cubism effect on image [0], with density density=50, thickness 10, maximum angle 75 deg., opacity 0.7 and smoothness 0.
# [gmic]-1./cubism/ *** Error *** Item substitution '{!density=50 || !10 || !75 || !0.7}': Operator '=': Invalid lvalue '!density', in expression '!density=50 || !10 || !75 || !0.7'.
#
# No image data

# %%
import os
import random
path0 = r"640x640/"
random_filename0 = random.choice([
y for y in os.listdir(path0)
if os.path.isfile(os.path.join(path0, y)) ])
RandIm = path0+random_filename0
#posterize0022A.jpg -v -99 -fx_posterize 150,30,1,12,0,0,0,0
#posterize0022c.jpg -v -99 -fx_posterize_preview 0,0,1.54472,12,8,17.0732,1,0
#posterize0022D.jpg -v -99 -fx_posterize 150,20,1.54472,12,8,15,1,0
#halftone0022E.jpg -v -99 -fx_halftone 0,0,0,0,8,6,10,5,0.5,0
#halftone0022f.jpg -v -99 -fx_halftone 0,0,0,0,5,8,8,5,0.1,0

# !gmic -i 640x640/P_20180411_062100.jpg \
-v -99 -fx_halftone 0,0,0,0,5,8,8,5,0.1,0 \
-normalize[-0] 60,255 \
-o halftone0022f.jpg
# !showme halftone0022f.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/P_20180411_062100.jpg' at position 0 (1 image 640x640x1x3).

# %% [markdown]
# # Halftone Parameters
# brightness float  -100 - 100<br />
# contrast float t -100 - 100<br />
# gama float  -100 - 100<br />
# smoothness float  1 - 10<br /><br />
#
# number 2 - 32 <br />
# size dark 2 - 256<br />
# size light 2 - 256<br />
# shape { 0=square | 1=diamond | 2=circle | 3=inv-square | 4=inv-diamond | 5=inv-circle }<br />
# smooth float 0 -32<br /><br />
#
# -v -99 -fx_halftone 0,0,0,0,8,6,10,5,0.5,0<br />
# -v -99 -fx_halftone 0,0,0,0,5,8,8,5,0.1,0<br />

# %%
# !mkdir halftone

# %% [markdown]
# # Texture Parameters
# -v 0 -texturize_canvas 27.65,5,0.6
# Add canvas texture to image [0], with amplitude 27.65, \
# fibrousness 5 and emboss_level 0.6.
#
#     amplitude = randint(2000, 5000)*.01
#     amplitude = str(amplitude)
#     fibrousness = randint(2, 10)
#     fibrousness = str(fibrousness)
#     emboss_level = randint(1, 12)*.1
#     emboss_level = str(emboss_level)
#
# -v 0 -texturize_canvas 32.3794,3,0.6<br />
# -v 0 -texturize_canvas 32.3794,3,0.6

# %% [markdown]
# # Posterize Parameters
#     smoothness 150 - ( float  0 - 800 )<br />
#     edges 30       - ( float  0 - 100 )<br />
#     paint 1        - ( float  0 -  10 )<br />
#     minimal area 9 - ( int    0 -  64 )<br />
#     outline 0      - ( int    0 - 100)<br />
#
# -v -99 -fx_posterize 150,30,1,12,0,0,0,0<br />
# -v -99 -fx_posterize_preview 0,0,1.54472,12,8,17.0732,1,0<br />

# %% [markdown]
# # Thin Edges
#     smoothness 0 4<br />
#     threshhold .2 10<br /><br />
#
#
# -v -99 -fx_thin_edges 0.64257,7.83133,0,0<br />
# -v -99 -fx_thin_edges 1.16466,6.62651,0,0<br />

# %%
#Default values: 'strength=100', 'radius_min=70' and 'radius_max=90'.

# !gmic -i 640x640/013.jpg \
-v -99 -fx_vignette 150.0,37.0,88.0,206,0,0,0  -display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '640x640/013.jpg' at position 0 (1 image 640x640x1x3).

# %%
# Good
# !gmic -i /home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg -v -99 \
-fx_lightglow_preview 20.0,0.6,8,0.80,0,0 \
-v -99 -fx_vignette 150.0,37.0,88.0,206,0,0,0  -display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg' at position 0 (1 image 640x640x1x3).

# %%
# !gmic linear.png -input_gpl palette.gpl -x_colorize[0] 1,1024,1,[-1] -k[0] -s c,{3-s} -o[1] \
-display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file 'linear.png' at position 0
# [gmic]-0./ *** Error *** Unknown command or filename 'linear.png'.

# %%
# !gmic -i /home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg -v -99 \
-to_rgba -replace_color 0,0,255,0,0,255,128,128,128,0 -display \
-o colorize.png
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg' at position 0 (1 image 640x640x1x3).

# %%
# !gmic -i /home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg -v -99 \
-x_colorize 1,1024,1 -s c,{3-s} -o[-1] -display -o colorize.png
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg' at position 0 (1 image 640x640x1x3).

# %%
# !showme colorize.png
# Out:
# No image data

# %%
# !gmic -i /home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg -v -99 \
-fx_lightglow_preview 20.4819,0.610442,8,0.795181,0,0 -display
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/013.jpg' at position 0 (1 image 640x640x1x3).

# %%
-v -99 -fx_vignette 43.4884,67.4419,88.3721,206,118,118,255

# %%
-v -99 -fx_lightglow_preview 20.4819,0.610442,8,0.795181,0,0

# %%
gmic lineart.png -x_colorize 1,1024,1 -s c,{3-s} -o[-1] colors.png
Here is another variant if you save also in this folder a palette.gpl file to get an additional palette dialog.  
gmic linear.png -input_gpl palette.gpl -x_colorize[0] 1,1024,1,[-1] -k[0] -s c,{3-s} -o[1] colors.png

# %%
# texturize_canvas
# !gmic -input /home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180412_173934.jpg \
 -v 99 old_photo \
-normalize[-1] 50,255 \
-output old-photo.jpg
# !showme old-photo.jpg
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Input file '/home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180412_173934.jpg' at position 0 (1 image 640x640x1x3).
# [gmic]-1./ Set verbosity level to 99.
# [gmic]-1./ Apply old photo effect on image [0].
# [gmic]-1./old_photo/ Decrement verbosity level (set to 98).
# [gmic]-1./old_photo/ Add gaussian noise to image [0], with standard deviation 20.
# [gmic]-1./old_photo/ Apply bilateral filter on image [0], with standard deviations (30,60) and sampling (0,0).
# [gmic]-1./old_photo/ Blur image [0] with standard deviation 2, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-1./old_photo/ Sharpen image [0] with inverse diffusion and amplitude 100.
# [gmic]-1./old_photo/frame_fuzzy/ Skip argument '8%,6,3,255,255,255,255'.
# [gmic]-1./old_photo/ Draw 8%x8% fuzzy frame on image [0], with fuzzyness 6, smoothness 3 and RGBA color (255,255,255,255).
# [gmic]-1./old_photo/frame_fuzzy/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/ Force image [0] to be in RGBA mode.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Reach 'elif' block -> condition '1' holds.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Keep channels 0...3 of image [0].
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Insert shared buffer from channel 3 of image [0].
# [gmic]-2./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Fill image [1] with 255.
# [gmic]-2./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/to_rgba/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Input image at position 1, with values '1' (1 image 640x640x1x1).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Decrement verbosity level (set to 96).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Set status to '1'.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Set local variable 'padx=25.560000000000002'.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Decrement verbosity level (set to 96).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Set status to '1'.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/*substitute/is_percent/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Set local variable 'pady=25.560000000000002'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Skip argument '1,0,0'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Skip argument '1'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Set status to '0'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*substitute/is_pattern/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Draw filled rectangle from (25.560000000000002,25.560000000000002) to (613.44000000000005,613.44000000000005) on image [1], with opacity 1 and color (0,0).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Draw 4-vertices filled polygon on image [0], with opacity 1 and color (0,0).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/rectangle/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/ Skip argument '6,6,0'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Spread pixel of image [1] randomly, with amplitudes (6,6,0).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Input black image at position 1 (1 image 640x640x1x3).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Insert shared buffer from channel 0 of image [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Fill image [2] with random values, in range [-6,6].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [2] (2 images left).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Insert shared buffer from channel 1 of image [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Fill image [2] with random values, in range [-6,6].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [2] (2 images left).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Insert shared buffer from channel 2 of image [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Fill image [2] with random values, in range [0,0].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [2] (2 images left).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Warp image [0] with backward-relative displacement field [1], linear interpolation, neumann boundary conditions.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/spread/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Blur image [1] with standard deviation 3, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/*local/ Input black image at position 2 (1 image 640x640x1x4).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/ Set global variable '_gmic_s= [2]'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ Fill image [2] with color (255,255,255,255).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Start 'repeat...done' block (4 iterations).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 0 of image [0].
# [gmic]-2./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [1] with 255.
# [gmic]-2./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 1 of image [0].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [2] with 255.
# [gmic]-3./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 2 of image [0].
# [gmic]-4./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [3] with 255.
# [gmic]-4./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Insert shared buffer from channel 3 of image [0].
# [gmic]-5./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ Fill image [4] with 255.
# [gmic]-5./old_photo/frame_fuzzy/*repeat/(...)/_fill_color/*repeat/*local/*repeat/ End 'repeat...done' block.
# [gmic]-5./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ Keep image [0] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ Set name of image [0] to '[unnamed]'.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/fc/_fill_color/ Increment verbosity level (set to 97).
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/ Draw image [2] at (0,0,0,0) on image [0], with opacity 1 and mask [1].
# [gmic]-3./old_photo/frame_fuzzy/*repeat/*local/ Keep image [0] (1 image left).
# [gmic]-1./old_photo/frame_fuzzy/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/frame_fuzzy/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/frame_fuzzy/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/ Force image [0] to be in RGB mode.
# [gmic]-1./old_photo/to_rgb/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/to_rgb/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/to_rgb/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Reach 'elif' block -> condition '1' holds.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Keep channels 0...2 of image [0].
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/to_rgb/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/to_rgb/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/to_rgb/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/shadow_patch/ Skip argument '0.75'.
# [gmic]-1./old_photo/ Apply shadow patches to image [0], with opacity 0.75.
# [gmic]-1./old_photo/shadow_patch/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/shadow_patch/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/shadow_patch/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/shadow_patch/*repeat/*local/ Input black image at position 1 (1 image 640x640x1x1).
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Shift image [1] by displacement vector (-2,-2,0,0), dirichlet boundary conditions and nearest-neighbor interpolation.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Shift image [1] by displacement vector (1,1,0,0), dirichlet boundary conditions and nearest-neighbor interpolation.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Draw plasma fractal on image [1], with alpha 3, beta 0.3 and scale 8.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Compute pointwise absolute value of image [1].
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Blur image [1] with standard deviation 1, neumann boundary conditions and quasi-gaussian kernel.
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Cut image [1] in range [3%,15%].
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Resize image [1] to 640x640x1x3, with nearest-neighbor interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Normalize image [1] in range [0.75,1].
# [gmic]-2./old_photo/shadow_patch/*repeat/*local/ Multiply images [0,1].
# [gmic]-1./old_photo/shadow_patch/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/shadow_patch/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/shadow_patch/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/ Normalize image [0] in range [0,255].
# [gmic]-1./old_photo/ Apply sepia tones effect on image [0].
# [gmic]-1./old_photo/sepia/ Decrement verbosity level (set to 97).
# [gmic]-1./old_photo/sepia/ Input image at position 1, with values (0,44,115,143,196,244^0,20,84,119,184,235^0,5,44,73,144,200) (1 image 6x1x1x3).
# [gmic]-2./old_photo/sepia/ Resize image [1] to 256x1x1x3, with linear interpolation, dirichlet boundary conditions and alignment (0,0,0,0).
# [gmic]-2./old_photo/sepia/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-2./old_photo/sepia/*repeat/*local/ Start 'local...endlocal' block, with selected images [0,1].
# [gmic]-2./old_photo/sepia/*repeat/*local/ Split color and opacity parts of images [0,1].
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/ Decrement verbosity level (set to 96).
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/ Start 'repeat...done' block (2 iterations).
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [1].
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Split image [0] along the 'c'-axis, into blocs of 3 pixels.
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ Split image [0] along the 'c'-axis, into blocs of 3 pixels.
# [gmic]-1./old_photo/sepia/*repeat/*local/split_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/*repeat/ End 'repeat...done' block.
# [gmic]-2./old_photo/sepia/*repeat/*local/split_opacity/ Increment verbosity level (set to 97).
# [gmic]-1./old_photo/sepia/*repeat/*local/ Compute luminance of image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Decrement verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Remove opacity channel of image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/ Decrement verbosity level (set to 95).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/sepia/*repeat/(...)/remove_opacity/*repeat/*local/*if/ Start 'if...endif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/sepia/*repeat/(...)/remove_opacity/*repeat/*local/*if/ Reach 'elif' block -> condition '0' does not hold.
# [gmic]-1./old_photo/sepia/*repeat/(...)/remove_opacity/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ Set name of image [0] to '/home/jack/Desktop/GRAPHICS/gmic/640x640/P_20180412_173934.jpg'.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/remove_opacity/ Increment verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Convert color representation of image [0] from sRGB to linear RGB.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/srgb2rgb/ Decrement verbosity level (set to 95).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/srgb2rgb/ Fill image [0] with expression 'sval = i/255; val = sval<=0.04045?sval(...)055)/(1.055))^2.4; cut(255*val,0,255)'.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/srgb2rgb/ Increment verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/ Start 'repeat...done' block (1 iteration).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/ Start 'local...endlocal' block, with selected image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Start 'if...endif' block -> condition '1' holds.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 0 of image [0].
# [gmic]-2./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 1 of image [0].
# [gmic]-3./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Insert shared buffer from channel 2 of image [0].
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [1] by 0.222488.
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [2] by 0.716904.
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Multiply image [3] by 0.0606079.
# [gmic]-4./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Add images [1,2,3].
# [gmic]-2./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ Reach 'else' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/*if/ End 'if...endif' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/*repeat/ End 'repeat...done' block.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Keep channel 0 of image [0].
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Convert color representation of image [0] from linear RGB to sRGB.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/rgb2srgb/ Decrement verbosity level (set to 95).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/rgb2srgb/ Fill image [0] with expression 'val = i/255; sval = val<=0.0031308?val(...)0.416667 - 0.055; cut(255*sval,0,255)'.
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/rgb2srgb/ Increment verbosity level (set to 96).
# [gmic]-1./old_photo/sepia/*repeat/*local/luminance/ Increment verbosity level (set to 97).
# [gmic]-2./old_photo/sepia/*repeat/*local/ Map LUT [1] on image [0], with dirichlet boundary conditions.
# [gmic]-2./old_photo/sepia/*repeat/*local/ Append image [0] along the 'c'-axis, with alignment 0.
# [gmic]-2./old_photo/sepia/*repeat/*local/ End 'local...endlocal' block.
# [gmic]-2./old_photo/sepia/*repeat/ End 'repeat...done' block.
# [gmic]-2./old_photo/sepia/ Remove image [1] (1 image left).
# [gmic]-1./old_photo/sepia/ Increment verbosity level (set to 98).
# [gmic]-1./old_photo/ Increment verbosity level (set to 99).
# [gmic]-1./ Normalize image [0] in range [50,255].
# [gmic]-1./ Output image [0] as jpg file 'old-photo.jpg', with quality 100% (1 image 640x640x1x3).
# [gmic]-1./ End G'MIC interpreter.

# %%
randint(2000, 4000)*.01
# Out:
# 37.61

# %%
# !mkdir old_photo

# %%
#Thin Edges VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
import time
"""
old_photo
"""
# create a list in memory of a directory
LST = []
PATH = "MaskedResults/"
for files in sorted(os.listdir(PATH)):
    LST.append(PATH+files)
    
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count

    threshhold = randint(20, 60)
    threshhold = str(threshhold)
    thresh = randint(150, 255)
    thresh = str(thresh)

    
    filename = time.strftime("old_photo/old_photo_%Y%m%d%H%M%S.jpg")
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
    subprocess.call("gmic -input "+filein+"  -v 99 old_photo -normalize[-1] "+threshhold+","+thresh+" -output "+filename, shell=True)
    #  -v 0 -texturize_canvas 32.3794,3,0.6 \
    sleep(5)
    print filename
# Out:
# 2
# old_photo/old_photo_20180502182547.jpg
# 4
# old_photo/old_photo_20180502182554.jpg
# 6
# old_photo/old_photo_20180502182600.jpg
# 8
# old_photo/old_photo_20180502182606.jpg
# 10
# old_photo/old_photo_20180502182612.jpg
# 12
# old_photo/old_photo_20180502182619.jpg
# 14
# old_photo/old_photo_20180502182625.jpg
# 16
# old_photo/old_photo_20180502182631.jpg
# 18
# old_photo/old_photo_20180502182637.jpg
# 20
# old_photo/old_photo_20180502182644.jpg
# 22
# old_photo/old_photo_20180502182650.jpg
# 24
# old_photo/old_photo_20180502182656.jpg
# 26
# old_photo/old_photo_20180502182702.jpg
# 28
# old_photo/old_photo_20180502182709.jpg
# 30
# old_photo/old_photo_20180502182715.jpg
# 32
# old_photo/old_photo_20180502182721.jpg
# 34
# old_photo/old_photo_20180502182727.jpg
# 36
# old_photo/old_photo_20180502182734.jpg
# 38
# old_photo/old_photo_20180502182740.jpg
# 40
# old_photo/old_photo_20180502182746.jpg
# 42
# old_photo/old_photo_20180502182752.jpg
# 44
# old_photo/old_photo_20180502182758.jpg
# 46
# old_photo/old_photo_20180502182805.jpg
# 48
# old_photo/old_photo_20180502182811.jpg
# 50
# old_photo/old_photo_20180502182817.jpg
# 52
# old_photo/old_photo_20180502182823.jpg
# 54
# old_photo/old_photo_20180502182829.jpg
# 56
# old_photo/old_photo_20180502182836.jpg
# 58
# old_photo/old_photo_20180502182842.jpg
# 60
# old_photo/old_photo_20180502182848.jpg
# 62
# old_photo/old_photo_20180502182854.jpg
# 64
# old_photo/old_photo_20180502182901.jpg
# 66
# old_photo/old_photo_20180502182907.jpg
# 68
# old_photo/old_photo_20180502182913.jpg
# 70
# old_photo/old_photo_20180502182919.jpg
# 72
# old_photo/old_photo_20180502182926.jpg
# 74
# old_photo/old_photo_20180502182932.jpg
# 76
# old_photo/old_photo_20180502182938.jpg
# 78
# old_photo/old_photo_20180502182944.jpg
# 80
# old_photo/old_photo_20180502182951.jpg
# 82
# old_photo/old_photo_20180502182957.jpg
# 84
# old_photo/old_photo_20180502183003.jpg
# 86
# old_photo/old_photo_20180502183009.jpg
# 88
# old_photo/old_photo_20180502183016.jpg
# 90
# old_photo/old_photo_20180502183022.jpg
# 92
# old_photo/old_photo_20180502183028.jpg
# 94
# old_photo/old_photo_20180502183034.jpg
# 96
# old_photo/old_photo_20180502183041.jpg
# 98
# old_photo/old_photo_20180502183047.jpg
# 100
# old_photo/old_photo_20180502183053.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-43c9439e50d7> in <module>()
#      17 while True:
#      18     count = count+1
# ---> 19     filein = LST[count]
#      20     filein = filein.replace("\n","")
#      21     count = count +1
#
# IndexError: list index out of range

# %%
# !gmic -update
# Out:
# [gmic]-0./ Start G'MIC interpreter.
# [gmic]-0./ Update commands from the latest definition file on the G'MIC server.
# [gmic]-0./ End G'MIC interpreter.

# %% [markdown]
# # DON'T TOUCH KEEPERS HERE DOWN -----------------------------------

# %% [markdown]
# # DON'T TOUCH KEEPERS HERE DOWN -----------------------------------

# %% [markdown]
# # DON'T TOUCH KEEPERS HERE DOWN -----------------------------------

# %%
#Thin Edges VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
"""
-v 0 -texturize_canvas 27.65,5,0.6
Add canvas texture to image [0], with amplitude 27.65, \
fibrousness 5 and emboss level 0.6.

-v 0 -texturize_canvas 32.3794,3,0.6
-v 0 -texturize_canvas 32.3794,3,0.6
"""
# create a list in memory of a directory
LST = []
PATH = "640x640/"
for files in sorted(os.listdir(PATH)):
    LST.append(PATH+files)
    
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    #-v 0 -texturize_canvas 32.3794,3,0.6 \
    smoothness = randint(2000, 5000)*.01 
    threshhold = randint(2, 10)
    thresh = randint(1, 12)*.1
    smoothness = str(smoothness)
    thresh = str(thresh)
    threshhold = str(threshhold)
    
    filename = time.strftime("texture/RANDOM-smoothness"+smoothness+"-threshhold"+threshhold+"_%Y%m%d%H%M%S.jpg")
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
    subprocess.call("gmic -input "+filein+" -v 0 -texturize_canvas "+smoothness+","+threshhold+",,"+thresh+" -output "+filename, shell=True)
    #  -v 0 -texturize_canvas 32.3794,3,0.6 \
    sleep(5)
    print filename
# Out:
# 2 640x640/b082.png
# texture/RANDOM-smoothness47.52-threshhold6_20180501204345.jpg
# 4 640x640/b082.png
# texture/RANDOM-smoothness27.62-threshhold6_20180501204351.jpg
# 6 640x640/b082.png
# texture/RANDOM-smoothness42.67-threshhold9_20180501204356.jpg
# 8 640x640/b082.png
# texture/RANDOM-smoothness21.16-threshhold10_20180501204401.jpg
# 10 640x640/b082.png
# texture/RANDOM-smoothness41.32-threshhold8_20180501204407.jpg
# 12 640x640/b082.png
# texture/RANDOM-smoothness33.46-threshhold4_20180501204412.jpg
# 14 640x640/b082.png
# texture/RANDOM-smoothness35.72-threshhold9_20180501204418.jpg
# 16 640x640/b082.png
# texture/RANDOM-smoothness48.57-threshhold8_20180501204423.jpg
# 18 640x640/b082.png
# texture/RANDOM-smoothness45.65-threshhold8_20180501204429.jpg
# 20 640x640/b082.png
# texture/RANDOM-smoothness40.96-threshhold10_20180501204434.jpg
# 22 640x640/b082.png
# texture/RANDOM-smoothness32.41-threshhold10_20180501204440.jpg
# 24 640x640/b082.png
# texture/RANDOM-smoothness39.18-threshhold5_20180501204445.jpg
# 26 640x640/b082.png
# texture/RANDOM-smoothness38.61-threshhold9_20180501204451.jpg
# 28 640x640/b082.png
# texture/RANDOM-smoothness25.76-threshhold10_20180501204456.jpg
# 30 640x640/b082.png
# texture/RANDOM-smoothness27.01-threshhold9_20180501204502.jpg
# 32 640x640/b082.png
# texture/RANDOM-smoothness34.45-threshhold2_20180501204507.jpg
# 34 640x640/b082.png
# texture/RANDOM-smoothness39.92-threshhold6_20180501204513.jpg
# 36 640x640/b082.png
# texture/RANDOM-smoothness29.52-threshhold7_20180501204518.jpg
# 38 640x640/b082.png
# texture/RANDOM-smoothness34.12-threshhold6_20180501204524.jpg
# 40 640x640/b082.png
# texture/RANDOM-smoothness32.79-threshhold9_20180501204529.jpg
# 42 640x640/b082.png
# texture/RANDOM-smoothness38.09-threshhold2_20180501204535.jpg
# 44 640x640/b082.png
# texture/RANDOM-smoothness41.88-threshhold7_20180501204540.jpg
# 46 640x640/b082.png
# texture/RANDOM-smoothness21.7-threshhold5_20180501204546.jpg
# 48 640x640/b082.png
# texture/RANDOM-smoothness28.65-threshhold8_20180501204551.jpg
# 50 640x640/b082.png
# texture/RANDOM-smoothness47.91-threshhold10_20180501204557.jpg
# 52 640x640/b082.png
# texture/RANDOM-smoothness38.31-threshhold9_20180501204602.jpg
# 54 640x640/b082.png
# texture/RANDOM-smoothness20.13-threshhold10_20180501204608.jpg
# 56 640x640/b082.png
# texture/RANDOM-smoothness44.18-threshhold2_20180501204613.jpg
# 58 640x640/b082.png
# texture/RANDOM-smoothness36.91-threshhold7_20180501204619.jpg
# 60 640x640/b082.png
# texture/RANDOM-smoothness26.99-threshhold4_20180501204624.jpg
# 62 640x640/b082.png
# texture/RANDOM-smoothness49.19-threshhold3_20180501204630.jpg
# 64 640x640/b082.png
# texture/RANDOM-smoothness41.79-threshhold6_20180501204635.jpg
# 66 640x640/b082.png
# texture/RANDOM-smoothness28.87-threshhold3_20180501204641.jpg
# 68 640x640/b082.png
# texture/RANDOM-smoothness48.31-threshhold6_20180501204646.jpg
# 70 640x640/b082.png
# texture/RANDOM-smoothness36.17-threshhold3_20180501204652.jpg
# 72 640x640/b082.png
# texture/RANDOM-smoothness43.43-threshhold6_20180501204657.jpg
# 74 640x640/b082.png
# texture/RANDOM-smoothness22.3-threshhold2_20180501204703.jpg
# 76 640x640/b082.png
# texture/RANDOM-smoothness28.98-threshhold6_20180501204708.jpg
# 78 640x640/b082.png
# texture/RANDOM-smoothness36.32-threshhold5_20180501204714.jpg
# 80 640x640/b082.png
# texture/RANDOM-smoothness49.12-threshhold5_20180501204719.jpg
# 82 640x640/b082.png
# texture/RANDOM-smoothness28.45-threshhold2_20180501204725.jpg
# 84 640x640/b082.png
# texture/RANDOM-smoothness39.79-threshhold10_20180501204730.jpg
# 86 640x640/b082.png
# texture/RANDOM-smoothness36.51-threshhold2_20180501204736.jpg
# 88 640x640/b082.png
# texture/RANDOM-smoothness49.82-threshhold7_20180501204741.jpg
# 90 640x640/b082.png
# texture/RANDOM-smoothness42.19-threshhold2_20180501204747.jpg
# 92 640x640/b082.png
# texture/RANDOM-smoothness30.15-threshhold3_20180501204752.jpg
# 94 640x640/b082.png
# texture/RANDOM-smoothness49.1-threshhold5_20180501204758.jpg
# 96 640x640/b082.png
# texture/RANDOM-smoothness20.79-threshhold10_20180501204803.jpg
# 98 640x640/b082.png
# texture/RANDOM-smoothness22.56-threshhold3_20180501204809.jpg
# 100 640x640/b082.png
# texture/RANDOM-smoothness23.82-threshhold3_20180501204814.jpg
# 102 640x640/b082.png
# texture/RANDOM-smoothness45.27-threshhold4_20180501204820.jpg
# 104 640x640/b082.png
# texture/RANDOM-smoothness42.5-threshhold2_20180501204825.jpg
# 106 640x640/b082.png
# texture/RANDOM-smoothness34.41-threshhold5_20180501204831.jpg
# 108 640x640/b082.png
# texture/RANDOM-smoothness38.84-threshhold7_20180501204836.jpg
# 110 640x640/b082.png
# texture/RANDOM-smoothness46.12-threshhold9_20180501204842.jpg
# 112 640x640/b082.png
# texture/RANDOM-smoothness25.73-threshhold10_20180501204848.jpg
# 114 640x640/b082.png
# texture/RANDOM-smoothness42.77-threshhold5_20180501204853.jpg
# 116 640x640/b082.png
# texture/RANDOM-smoothness46.97-threshhold9_20180501204859.jpg
# 118 640x640/b082.png
# texture/RANDOM-smoothness40.84-threshhold6_20180501204904.jpg
# 120 640x640/b082.png
# texture/RANDOM-smoothness31.44-threshhold5_20180501204910.jpg
# 122 640x640/b082.png
# texture/RANDOM-smoothness24.92-threshhold6_20180501204915.jpg
# 124 640x640/b082.png
# texture/RANDOM-smoothness29.13-threshhold10_20180501204921.jpg
# 126 640x640/b082.png
# texture/RANDOM-smoothness30.64-threshhold9_20180501204926.jpg
# 128 640x640/b082.png
# texture/RANDOM-smoothness26.26-threshhold4_20180501204932.jpg
# 130 640x640/b082.png
# texture/RANDOM-smoothness49.57-threshhold3_20180501204937.jpg
# 132 640x640/b082.png
# texture/RANDOM-smoothness46.39-threshhold10_20180501204943.jpg
# 134 640x640/b082.png
# texture/RANDOM-smoothness43.65-threshhold3_20180501204948.jpg
# 136 640x640/b082.png
# texture/RANDOM-smoothness47.15-threshhold2_20180501204954.jpg
# 138 640x640/b082.png
# texture/RANDOM-smoothness31.88-threshhold9_20180501204959.jpg
# 140 640x640/b082.png
# texture/RANDOM-smoothness32.39-threshhold9_20180501205005.jpg
# 142 640x640/b082.png
# texture/RANDOM-smoothness20.88-threshhold3_20180501205010.jpg
# 144 640x640/b082.png
# texture/RANDOM-smoothness47.22-threshhold10_20180501205016.jpg
# 146 640x640/b082.png
# texture/RANDOM-smoothness30.95-threshhold7_20180501205021.jpg
# 148 640x640/b082.png
# texture/RANDOM-smoothness29.63-threshhold7_20180501205027.jpg
# 150 640x640/b082.png
# texture/RANDOM-smoothness41.25-threshhold9_20180501205032.jpg
# 152 640x640/b082.png
# texture/RANDOM-smoothness36.27-threshhold4_20180501205038.jpg
# 154 640x640/b082.png
# texture/RANDOM-smoothness33.84-threshhold9_20180501205043.jpg
# 156 640x640/b082.png
# texture/RANDOM-smoothness36.61-threshhold3_20180501205049.jpg
# 158 640x640/b082.png
# texture/RANDOM-smoothness24.07-threshhold8_20180501205054.jpg
# 160 640x640/b082.png
# texture/RANDOM-smoothness44.29-threshhold8_20180501205100.jpg
# 162 640x640/b082.png
# texture/RANDOM-smoothness25.39-threshhold9_20180501205105.jpg
# 164 640x640/b082.png
# texture/RANDOM-smoothness29.23-threshhold4_20180501205111.jpg
# 166 640x640/b082.png
# texture/RANDOM-smoothness40.82-threshhold6_20180501205116.jpg
# 168 640x640/b082.png
# texture/RANDOM-smoothness44.82-threshhold9_20180501205122.jpg
# 170 640x640/b082.png
# texture/RANDOM-smoothness24.61-threshhold7_20180501205127.jpg
# 172 640x640/b082.png
# texture/RANDOM-smoothness43.72-threshhold6_20180501205133.jpg
# 174 640x640/b082.png
# texture/RANDOM-smoothness25.69-threshhold3_20180501205138.jpg
# 176 640x640/b082.png
# texture/RANDOM-smoothness38.84-threshhold5_20180501205144.jpg
# 178 640x640/b082.png
# texture/RANDOM-smoothness30.33-threshhold7_20180501205149.jpg
# 180 640x640/b082.png
# texture/RANDOM-smoothness33.04-threshhold2_20180501205155.jpg
# 182 640x640/b082.png
# texture/RANDOM-smoothness46.24-threshhold6_20180501205200.jpg
# 184 640x640/b082.png
# texture/RANDOM-smoothness45.25-threshhold4_20180501205206.jpg
# 186 640x640/b082.png
# texture/RANDOM-smoothness24.24-threshhold10_20180501205211.jpg
# 188 640x640/b082.png
# texture/RANDOM-smoothness36.56-threshhold3_20180501205217.jpg
# 190 640x640/b082.png
# texture/RANDOM-smoothness32.56-threshhold5_20180501205222.jpg
# 192 640x640/b082.png
# texture/RANDOM-smoothness28.37-threshhold4_20180501205228.jpg
# 194 640x640/b082.png
# texture/RANDOM-smoothness31.35-threshhold9_20180501205233.jpg
# 196 640x640/b082.png
# texture/RANDOM-smoothness20.32-threshhold9_20180501205239.jpg
# 198 640x640/b082.png
# texture/RANDOM-smoothness30.2-threshhold5_20180501205244.jpg
# 200 640x640/b082.png
# texture/RANDOM-smoothness34.72-threshhold3_20180501205250.jpg
# 202 640x640/b082.png
# texture/RANDOM-smoothness28.05-threshhold5_20180501205255.jpg
# 204 640x640/b082.png
# texture/RANDOM-smoothness22.48-threshhold4_20180501205301.jpg
# 206 640x640/b082.png
# texture/RANDOM-smoothness22.94-threshhold2_20180501205306.jpg
# 208 640x640/b082.png
# texture/RANDOM-smoothness48.78-threshhold3_20180501205312.jpg
# 210 640x640/b082.png
# texture/RANDOM-smoothness45.76-threshhold2_20180501205317.jpg
# 212 640x640/b082.png
# texture/RANDOM-smoothness40.18-threshhold4_20180501205323.jpg
# 214 640x640/b082.png
# texture/RANDOM-smoothness21.91-threshhold2_20180501205328.jpg
# 216 640x640/b082.png
# texture/RANDOM-smoothness25.46-threshhold10_20180501205334.jpg
# 218 640x640/b082.png
# texture/RANDOM-smoothness34.16-threshhold5_20180501205339.jpg
# 220 640x640/b082.png
# texture/RANDOM-smoothness40.35-threshhold4_20180501205345.jpg
# 222 640x640/b082.png
# texture/RANDOM-smoothness42.44-threshhold7_20180501205350.jpg
# 224 640x640/b082.png
# texture/RANDOM-smoothness27.65-threshhold5_20180501205356.jpg
# 226 640x640/b082.png
# texture/RANDOM-smoothness36.64-threshhold10_20180501205401.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-308-184dc802591b> in <module>()
#      19 while True:
#      20     count = count+1
# ---> 21     filein = LST[count]
#      22     filein = filein.replace("\n","")
#      23     count = count +1
#
# IndexError: list index out of range

# %%
#Thin Edges VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
"""
Thin Edges
smoothness 0 4 
threshhold .2 10


-v -99 -fx_thin_edges 0.64257,7.83133,0,0
-v -99 -fx_thin_edges 1.16466,6.62651,0,0
"""
# create a list in memory of a directory
LST = []
PATH = "640x640/"
for files in sorted(os.listdir(PATH)):
    LST.append(PATH+files)
    
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    
    smoothness = randint(1, 400)*.01 
    threshhold = randint(20, 600)*.01
    smoothness = str(smoothness)
    threshhold = str(threshhold)
    
    filename = time.strftime("thinedges/RANDOM-smoothness"+smoothness+"-threshhold"+threshhold+"_%Y%m%d%H%M%S.jpg")
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
    subprocess.call("gmic -input "+filein+" -v 0 -fx_thin_edges "+smoothness+","+threshhold+"0,0 -output "+filename, shell=True)
    # -v -99 -fx_thin_edges 1.16466,6.62651,0,0
    sleep(5)
    print filename
# Out:
# 2 640x640/b082.png
# thinedges/RANDOM-smoothness2.48-threshhold5.5_20180501182100.jpg
# 4 640x640/b082.png
# thinedges/RANDOM-smoothness3.41-threshhold0.73_20180501182108.jpg
# 6 640x640/b082.png
# thinedges/RANDOM-smoothness2.56-threshhold4.17_20180501182140.jpg
# 8 640x640/b082.png
# thinedges/RANDOM-smoothness1.54-threshhold5.47_20180501182151.jpg
# 10 640x640/b082.png
# thinedges/RANDOM-smoothness2.99-threshhold1.86_20180501182159.jpg
# 12 640x640/b082.png
# thinedges/RANDOM-smoothness1.17-threshhold4.36_20180501182214.jpg
# 14 640x640/b082.png
# thinedges/RANDOM-smoothness3.78-threshhold2.73_20180501182225.jpg
# 16 640x640/b082.png
# thinedges/RANDOM-smoothness0.72-threshhold5.76_20180501182246.jpg
# 18 640x640/b082.png
# thinedges/RANDOM-smoothness2.81-threshhold3.66_20180501182254.jpg
# 20 640x640/b082.png
# thinedges/RANDOM-smoothness3.43-threshhold4.99_20180501182307.jpg
# 22 640x640/b082.png
# thinedges/RANDOM-smoothness3.58-threshhold4.18_20180501182329.jpg
# 24 640x640/b082.png
# thinedges/RANDOM-smoothness1.04-threshhold0.68_20180501182346.jpg
# 26 640x640/b082.png
# thinedges/RANDOM-smoothness2.42-threshhold2.82_20180501182405.jpg
# 28 640x640/b082.png
# thinedges/RANDOM-smoothness3.72-threshhold0.84_20180501182421.jpg
# 30 640x640/b082.png
# thinedges/RANDOM-smoothness1.7-threshhold3.46_20180501182442.jpg
# 32 640x640/b082.png
# thinedges/RANDOM-smoothness0.83-threshhold3.18_20180501182452.jpg
# 34 640x640/b082.png
# thinedges/RANDOM-smoothness1.95-threshhold1.7_20180501182505.jpg
# 36 640x640/b082.png
# thinedges/RANDOM-smoothness3.12-threshhold1.51_20180501182517.jpg
# 38 640x640/b082.png
# thinedges/RANDOM-smoothness1.79-threshhold4.62_20180501182538.jpg
# 40 640x640/b082.png
# thinedges/RANDOM-smoothness2.6-threshhold1.97_20180501182547.jpg
# 42 640x640/b082.png
# thinedges/RANDOM-smoothness2.95-threshhold2.11_20180501182607.jpg
# 44 640x640/b082.png
# thinedges/RANDOM-smoothness2.56-threshhold1.69_20180501182621.jpg
# 46 640x640/b082.png
# thinedges/RANDOM-smoothness2.55-threshhold5.88_20180501182636.jpg
# 48 640x640/b082.png
# thinedges/RANDOM-smoothness0.06-threshhold1.8_20180501182645.jpg
# 50 640x640/b082.png
# thinedges/RANDOM-smoothness3.59-threshhold4.37_20180501182656.jpg
# 52 640x640/b082.png
# thinedges/RANDOM-smoothness1.55-threshhold0.24_20180501182709.jpg
# 54 640x640/b082.png
# thinedges/RANDOM-smoothness1.44-threshhold0.51_20180501182801.jpg
# 56 640x640/b082.png
# thinedges/RANDOM-smoothness0.87-threshhold0.3_20180501182828.jpg
# 58 640x640/b082.png
# thinedges/RANDOM-smoothness2.61-threshhold3.68_20180501182858.jpg
# 60 640x640/b082.png
# thinedges/RANDOM-smoothness3.8-threshhold5.27_20180501182913.jpg
# 62 640x640/b082.png
# thinedges/RANDOM-smoothness0.48-threshhold4.49_20180501182930.jpg
# 64 640x640/b082.png
# thinedges/RANDOM-smoothness1.49-threshhold2.07_20180501182939.jpg
# 66 640x640/b082.png
# thinedges/RANDOM-smoothness3.98-threshhold1.16_20180501182958.jpg
# 68 640x640/b082.png
# thinedges/RANDOM-smoothness2.04-threshhold4.93_20180501183031.jpg
# 70 640x640/b082.png
# thinedges/RANDOM-smoothness3.78-threshhold1.58_20180501183042.jpg
# 72 640x640/b082.png
# thinedges/RANDOM-smoothness3.41-threshhold1.9_20180501183108.jpg
# 74 640x640/b082.png
# thinedges/RANDOM-smoothness2.88-threshhold1.67_20180501183125.jpg
# 76 640x640/b082.png
# thinedges/RANDOM-smoothness0.51-threshhold2.83_20180501183155.jpg
# 78 640x640/b082.png
# thinedges/RANDOM-smoothness1.93-threshhold3.11_20180501183202.jpg
# 80 640x640/b082.png
# thinedges/RANDOM-smoothness1.51-threshhold4.74_20180501183213.jpg
# 82 640x640/b082.png
# thinedges/RANDOM-smoothness2.56-threshhold1.35_20180501183223.jpg
# 84 640x640/b082.png
# thinedges/RANDOM-smoothness0.38-threshhold3.37_20180501183255.jpg
# 86 640x640/b082.png
# thinedges/RANDOM-smoothness2.1-threshhold5.49_20180501183303.jpg
# 88 640x640/b082.png
# thinedges/RANDOM-smoothness2.18-threshhold3.5_20180501183314.jpg
# 90 640x640/b082.png
# thinedges/RANDOM-smoothness1.93-threshhold4.91_20180501183329.jpg
# 92 640x640/b082.png
# thinedges/RANDOM-smoothness3.05-threshhold5.44_20180501183340.jpg
# 94 640x640/b082.png
# thinedges/RANDOM-smoothness2.31-threshhold0.93_20180501183352.jpg
# 96 640x640/b082.png
# thinedges/RANDOM-smoothness2.9-threshhold1.93_20180501183420.jpg
# 98 640x640/b082.png
# thinedges/RANDOM-smoothness1.63-threshhold3.48_20180501183439.jpg
# 100 640x640/b082.png
# thinedges/RANDOM-smoothness3.2-threshhold2.34_20180501183449.jpg
# 102 640x640/b082.png
# thinedges/RANDOM-smoothness1.13-threshhold3.16_20180501183510.jpg
# 104 640x640/b082.png
# thinedges/RANDOM-smoothness1.99-threshhold3.48_20180501183518.jpg
# 106 640x640/b082.png
# thinedges/RANDOM-smoothness0.51-threshhold3.57_20180501183530.jpg
# 108 640x640/b082.png
# thinedges/RANDOM-smoothness3.25-threshhold3.91_20180501183538.jpg
# 110 640x640/b082.png
# thinedges/RANDOM-smoothness1.29-threshhold1.29_20180501183550.jpg
# 112 640x640/b082.png
# thinedges/RANDOM-smoothness3.51-threshhold5.28_20180501183603.jpg
# 114 640x640/b082.png
# thinedges/RANDOM-smoothness1.56-threshhold4.73_20180501183619.jpg
# 116 640x640/b082.png
# thinedges/RANDOM-smoothness0.09-threshhold2.66_20180501183627.jpg
# 118 640x640/b082.png
# thinedges/RANDOM-smoothness2.52-threshhold5.51_20180501183637.jpg
# 120 640x640/b082.png
# thinedges/RANDOM-smoothness1.65-threshhold1.24_20180501183652.jpg
# 122 640x640/b082.png
# thinedges/RANDOM-smoothness0.38-threshhold3.88_20180501183707.jpg
# 124 640x640/b082.png
# thinedges/RANDOM-smoothness2.72-threshhold4.43_20180501183715.jpg
# 126 640x640/b082.png
# thinedges/RANDOM-smoothness2.91-threshhold0.65_20180501183733.jpg
# 128 640x640/b082.png
# thinedges/RANDOM-smoothness2.62-threshhold1.42_20180501183808.jpg
# 130 640x640/b082.png
# thinedges/RANDOM-smoothness1.29-threshhold4.0_20180501183841.jpg
# 132 640x640/b082.png
# thinedges/RANDOM-smoothness1.34-threshhold0.53_20180501183852.jpg
# 134 640x640/b082.png
# thinedges/RANDOM-smoothness0.36-threshhold5.08_20180501183924.jpg
# 136 640x640/b082.png
# thinedges/RANDOM-smoothness1.16-threshhold1.66_20180501183931.jpg
# 138 640x640/b082.png
# thinedges/RANDOM-smoothness3.93-threshhold2.92_20180501183943.jpg
# 140 640x640/b082.png
# thinedges/RANDOM-smoothness0.87-threshhold0.35_20180501183958.jpg
# 142 640x640/b082.png
# thinedges/RANDOM-smoothness3.42-threshhold1.17_20180501184023.jpg
# 144 640x640/b082.png
# thinedges/RANDOM-smoothness2.17-threshhold5.43_20180501184056.jpg
# 146 640x640/b082.png
# thinedges/RANDOM-smoothness2.37-threshhold5.29_20180501184105.jpg
# 148 640x640/b082.png
# thinedges/RANDOM-smoothness2.77-threshhold2.36_20180501184116.jpg
# 150 640x640/b082.png
# thinedges/RANDOM-smoothness3.52-threshhold4.28_20180501184131.jpg
# 152 640x640/b082.png
# thinedges/RANDOM-smoothness1.05-threshhold4.31_20180501184147.jpg
# 154 640x640/b082.png
# thinedges/RANDOM-smoothness2.87-threshhold0.2_20180501184156.jpg
# 156 640x640/b082.png
# thinedges/RANDOM-smoothness1.95-threshhold1.87_20180501184244.jpg
# 158 640x640/b082.png
# thinedges/RANDOM-smoothness1.21-threshhold3.79_20180501184257.jpg
# 160 640x640/b082.png
# thinedges/RANDOM-smoothness2.36-threshhold5.26_20180501184308.jpg
# 162 640x640/b082.png
# thinedges/RANDOM-smoothness0.43-threshhold3.31_20180501184319.jpg
# 164 640x640/b082.png
# thinedges/RANDOM-smoothness0.99-threshhold0.55_20180501184328.jpg
# 166 640x640/b082.png
# thinedges/RANDOM-smoothness3.01-threshhold0.47_20180501184352.jpg
# 168 640x640/b082.png
# thinedges/RANDOM-smoothness0.15-threshhold1.3_20180501184433.jpg
# 170 640x640/b082.png
# thinedges/RANDOM-smoothness0.23-threshhold0.32_20180501184446.jpg
# 172 640x640/b082.png
# thinedges/RANDOM-smoothness0.62-threshhold4.1_20180501184510.jpg
# 174 640x640/b082.png
# thinedges/RANDOM-smoothness3.45-threshhold2.64_20180501184518.jpg
# 176 640x640/b082.png
# thinedges/RANDOM-smoothness2.51-threshhold4.1_20180501184539.jpg
# 178 640x640/b082.png
# thinedges/RANDOM-smoothness2.8-threshhold4.68_20180501184554.jpg
# 180 640x640/b082.png
# thinedges/RANDOM-smoothness2.92-threshhold2.33_20180501184605.jpg
# 182 640x640/b082.png
# thinedges/RANDOM-smoothness1.4-threshhold4.33_20180501184627.jpg
# 184 640x640/b082.png
# thinedges/RANDOM-smoothness1.69-threshhold2.21_20180501184636.jpg
# 186 640x640/b082.png
# thinedges/RANDOM-smoothness2.88-threshhold1.42_20180501184652.jpg
# 188 640x640/b082.png
# thinedges/RANDOM-smoothness0.32-threshhold3.7_20180501184715.jpg
# 190 640x640/b082.png
# thinedges/RANDOM-smoothness1.87-threshhold3.54_20180501184722.jpg
# 192 640x640/b082.png
# thinedges/RANDOM-smoothness3.82-threshhold2.18_20180501184737.jpg
# 194 640x640/b082.png
# thinedges/RANDOM-smoothness3.21-threshhold1.85_20180501184758.jpg
# 196 640x640/b082.png
# thinedges/RANDOM-smoothness2.93-threshhold5.7_20180501184815.jpg
# 198 640x640/b082.png
# thinedges/RANDOM-smoothness2.64-threshhold3.98_20180501184828.jpg
# 200 640x640/b082.png
# thinedges/RANDOM-smoothness0.83-threshhold4.76_20180501184840.jpg
# 202 640x640/b082.png
# thinedges/RANDOM-smoothness0.92-threshhold3.27_20180501184850.jpg
# 204 640x640/b082.png
# thinedges/RANDOM-smoothness2.12-threshhold3.85_20180501184901.jpg
# 206 640x640/b082.png
# thinedges/RANDOM-smoothness0.82-threshhold5.38_20180501184913.jpg
# 208 640x640/b082.png
# thinedges/RANDOM-smoothness3.28-threshhold1.95_20180501184923.jpg
# 210 640x640/b082.png
# thinedges/RANDOM-smoothness2.56-threshhold1.1_20180501184939.jpg
# 212 640x640/b082.png
# thinedges/RANDOM-smoothness3.64-threshhold1.84_20180501185002.jpg
# 214 640x640/b082.png
# thinedges/RANDOM-smoothness1.08-threshhold4.04_20180501185021.jpg
# 216 640x640/b082.png
# thinedges/RANDOM-smoothness0.16-threshhold2.38_20180501185030.jpg
# 218 640x640/b082.png
# thinedges/RANDOM-smoothness1.27-threshhold2.82_20180501185039.jpg
# 220 640x640/b082.png
# thinedges/RANDOM-smoothness2.54-threshhold5.41_20180501185048.jpg
# 222 640x640/b082.png
# thinedges/RANDOM-smoothness3.45-threshhold0.98_20180501185100.jpg
# 224 640x640/b082.png
# thinedges/RANDOM-smoothness1.21-threshhold2.7_20180501185139.jpg
# 226 640x640/b082.png
# thinedges/RANDOM-smoothness3.62-threshhold1.06_20180501185151.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-253-bad22b988eae> in <module>()
#      22 while True:
#      23     count = count+1
# ---> 24     filein = LST[count]
#      25     filein = filein.replace("\n","")
#      26     count = count +1
#
# IndexError: list index out of range

# %%
#Halftone VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
"""
Halftone Parameters
brightness float -100 - 100
contrast float t -100 - 100
gama float -100 - 100
smoothness float 1 - 10

number 2 - 32 
size dark 2 - 256
size light 2 - 256
shape { 0=square | 1=diamond | 2=circle | 3=inv-square | 4=inv-diamond | 5=inv-circle }
smooth float 0 -32

-v -99 -fx_halftone 0,0,0,0,8,6,10,5,0.5,0
-v -99 -fx_halftone 0,0,0,0,5,8,8,5,0.1,0
"""
# create a list in memory of a directory
LST = []
PATH = "640x640/"
for files in sorted(os.listdir(PATH)):
    LST.append(PATH+files)
    
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    
    brit = randint(-50,50)
    cont = randint(-50,50)
    gama = randint(-50,100)*.1
    smoothness = randint(1,80)*.1
    
    #number = randint(2, 32)
    number = randint(2, 10) 
    #sizedark = randint(2, 256)
    #sizelight = randint(2, 256)
    sizedark = randint(2, 15)
    sizelight = randint(2, 15)    
    shape = randint(0,5)
    smooth = randint(1, 20)*.1    
 
    brit = str(brit)
    cont = str(cont)
    gama = str(gama)
    smoothness = str(smoothness)
    number = str(number)
    sizedark =str(sizedark)
    sizelight = str(sizelight)
    shape = str(shape)
    smooth = str(smooth)
    
    filename = time.strftime("halftone/RANDOM-brit"+brit+"-cont"+cont+"-gama"+gama+"-smoothness"+smoothness+"-number"+number+"-sizedark"+sizedark+"-sizelight"+sizelight+"-shape"+shape+"-smooth"+smooth+"_%Y%m%d%H%M%S.jpg")
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
    subprocess.call("gmic -input "+filein+" -v 0 -fx_halftone "+brit+","+cont+","+gama+","+smoothness+","+number+","+sizedark+","+sizelight+","+shape+","+smooth+" -normalize[-0] 0,255 -output "+filename, shell=True)
    # -v -99 -fx_halftone 0,0,0,0,8,6,10,5,0.5,0
    sleep(5)
    print filename
# Out:
# 2 640x640/b082.png
# halftone/RANDOM-brit26-cont-2-gama-0.1-smoothness6.8-number3-sizedark11-sizelight7-shape2-smooth1.7_20180501185440.jpg
# 4 640x640/b082.png
# halftone/RANDOM-brit36-cont26-gama-4.7-smoothness4.5-number3-sizedark15-sizelight4-shape3-smooth1.0_20180501185450.jpg
# 6 640x640/b082.png
# halftone/RANDOM-brit-1-cont-36-gama-3.8-smoothness1.8-number7-sizedark5-sizelight2-shape5-smooth2.0_20180501185500.jpg
# 8 640x640/b082.png
# halftone/RANDOM-brit-25-cont-27-gama-1.7-smoothness7.6-number5-sizedark2-sizelight10-shape0-smooth0.3_20180501185517.jpg
# 10 640x640/b082.png
# halftone/RANDOM-brit47-cont4-gama7.7-smoothness7.0-number4-sizedark9-sizelight3-shape5-smooth0.7_20180501185529.jpg
# 12 640x640/b082.png
# halftone/RANDOM-brit-40-cont49-gama8.8-smoothness5.5-number6-sizedark7-sizelight12-shape0-smooth1.7_20180501185540.jpg
# 14 640x640/b082.png
# halftone/RANDOM-brit45-cont11-gama10.0-smoothness1.1-number4-sizedark9-sizelight11-shape5-smooth1.7_20180501185551.jpg
# 16 640x640/b082.png
# halftone/RANDOM-brit2-cont13-gama5.9-smoothness5.2-number7-sizedark10-sizelight8-shape4-smooth1.0_20180501185603.jpg
# 18 640x640/b082.png
# halftone/RANDOM-brit-43-cont-5-gama7.8-smoothness5.6-number8-sizedark11-sizelight2-shape3-smooth0.8_20180501185616.jpg
# 20 640x640/b082.png
# halftone/RANDOM-brit31-cont-21-gama-0.7-smoothness1.8-number4-sizedark12-sizelight5-shape3-smooth1.6_20180501185627.jpg
# 22 640x640/b082.png
# halftone/RANDOM-brit43-cont-43-gama-0.4-smoothness5.9-number9-sizedark4-sizelight3-shape1-smooth0.2_20180501185637.jpg
# 24 640x640/b082.png
# halftone/RANDOM-brit-49-cont47-gama-0.1-smoothness3.3-number9-sizedark15-sizelight6-shape0-smooth1.0_20180501185656.jpg
# 26 640x640/b082.png
# halftone/RANDOM-brit-35-cont-16-gama1.7-smoothness5.3-number6-sizedark8-sizelight10-shape2-smooth0.6_20180501185713.jpg
# 28 640x640/b082.png
# halftone/RANDOM-brit11-cont-18-gama4.4-smoothness0.4-number10-sizedark8-sizelight2-shape4-smooth1.4_20180501185722.jpg
# 30 640x640/b082.png
# halftone/RANDOM-brit-34-cont-37-gama7.9-smoothness3.9-number8-sizedark6-sizelight7-shape4-smooth1.1_20180501185740.jpg
# 32 640x640/b082.png
# halftone/RANDOM-brit-17-cont4-gama-2.1-smoothness1.7-number5-sizedark5-sizelight5-shape2-smooth1.6_20180501185753.jpg
# 34 640x640/b082.png
# halftone/RANDOM-brit-50-cont-16-gama-1.5-smoothness5.0-number2-sizedark9-sizelight5-shape5-smooth1.7_20180501185810.jpg
# 36 640x640/b082.png
# halftone/RANDOM-brit24-cont-20-gama-3.4-smoothness8.0-number7-sizedark3-sizelight9-shape3-smooth2.0_20180501185818.jpg
# 38 640x640/b082.png
# halftone/RANDOM-brit26-cont-47-gama7.2-smoothness0.1-number3-sizedark2-sizelight6-shape3-smooth1.4_20180501185832.jpg
# 40 640x640/b082.png
# halftone/RANDOM-brit-25-cont33-gama8.2-smoothness7.6-number6-sizedark7-sizelight12-shape3-smooth1.3_20180501185839.jpg
# 42 640x640/b082.png
# halftone/RANDOM-brit-21-cont-4-gama-1.9-smoothness6.7-number7-sizedark5-sizelight15-shape4-smooth0.4_20180501185854.jpg
# 44 640x640/b082.png
# halftone/RANDOM-brit-49-cont-20-gama5.6-smoothness4.2-number9-sizedark3-sizelight4-shape0-smooth0.7_20180501185908.jpg
# 46 640x640/b082.png
# halftone/RANDOM-brit-46-cont-12-gama-3.9-smoothness6.8-number8-sizedark2-sizelight13-shape3-smooth1.6_20180501185921.jpg
# 48 640x640/b082.png
# halftone/RANDOM-brit3-cont-28-gama-2.9-smoothness7.8-number8-sizedark13-sizelight15-shape2-smooth0.9_20180501185936.jpg
# 50 640x640/b082.png
# halftone/RANDOM-brit18-cont-40-gama1.7-smoothness7.2-number8-sizedark8-sizelight5-shape2-smooth0.1_20180501185949.jpg
# 52 640x640/b082.png
# halftone/RANDOM-brit28-cont-31-gama2.3-smoothness1.9-number4-sizedark9-sizelight8-shape2-smooth1.4_20180501190001.jpg
# 54 640x640/b082.png
# halftone/RANDOM-brit-31-cont-28-gama-4.5-smoothness3.8-number10-sizedark11-sizelight9-shape4-smooth0.5_20180501190013.jpg
# 56 640x640/b082.png
# halftone/RANDOM-brit-18-cont45-gama-0.8-smoothness6.3-number10-sizedark11-sizelight11-shape1-smooth1.6_20180501190033.jpg
# 58 640x640/b082.png
# halftone/RANDOM-brit25-cont-1-gama3.4-smoothness6.7-number7-sizedark2-sizelight11-shape2-smooth1.2_20180501190047.jpg
# 60 640x640/b082.png
# halftone/RANDOM-brit-45-cont-1-gama8.3-smoothness0.9-number2-sizedark4-sizelight9-shape4-smooth0.5_20180501190104.jpg
# 62 640x640/b082.png
# halftone/RANDOM-brit28-cont22-gama9.6-smoothness1.9-number6-sizedark11-sizelight9-shape4-smooth0.3_20180501190112.jpg
# 64 640x640/b082.png
# halftone/RANDOM-brit-1-cont23-gama3.1-smoothness0.4-number3-sizedark4-sizelight5-shape3-smooth1.9_20180501190128.jpg
# 66 640x640/b082.png
# halftone/RANDOM-brit31-cont-31-gama6.4-smoothness5.7-number9-sizedark14-sizelight15-shape2-smooth0.7_20180501190136.jpg
# 68 640x640/b082.png
# halftone/RANDOM-brit-19-cont-44-gama-2.3-smoothness4.1-number3-sizedark2-sizelight12-shape3-smooth0.2_20180501190204.jpg
# 70 640x640/b082.png
# halftone/RANDOM-brit1-cont-21-gama2.0-smoothness5.2-number6-sizedark9-sizelight7-shape1-smooth0.4_20180501190215.jpg
# 72 640x640/b082.png
# halftone/RANDOM-brit-17-cont27-gama-1.0-smoothness6.1-number5-sizedark5-sizelight4-shape1-smooth0.3_20180501190227.jpg
# 74 640x640/b082.png
# halftone/RANDOM-brit-13-cont-45-gama6.7-smoothness3.9-number9-sizedark6-sizelight14-shape3-smooth0.3_20180501190241.jpg
# 76 640x640/b082.png
# halftone/RANDOM-brit34-cont14-gama7.7-smoothness2.4-number5-sizedark15-sizelight3-shape4-smooth0.6_20180501190255.jpg
# 78 640x640/b082.png
# halftone/RANDOM-brit45-cont3-gama-3.5-smoothness3.9-number6-sizedark2-sizelight14-shape4-smooth1.0_20180501190307.jpg
# 80 640x640/b082.png
# halftone/RANDOM-brit-8-cont48-gama7.3-smoothness3.3-number8-sizedark3-sizelight10-shape5-smooth0.8_20180501190329.jpg
# 82 640x640/b082.png
# halftone/RANDOM-brit40-cont-49-gama-0.8-smoothness7.8-number9-sizedark7-sizelight5-shape5-smooth1.3_20180501190343.jpg
# 84 640x640/b082.png
# halftone/RANDOM-brit19-cont-50-gama-4.2-smoothness4.5-number3-sizedark3-sizelight3-shape1-smooth0.5_20180501190406.jpg
# 86 640x640/b082.png
# halftone/RANDOM-brit-6-cont43-gama4.4-smoothness5.7-number4-sizedark10-sizelight11-shape4-smooth1.3_20180501190418.jpg
# 88 640x640/b082.png
# halftone/RANDOM-brit-2-cont-29-gama5.8-smoothness3.2-number9-sizedark12-sizelight7-shape2-smooth2.0_20180501190429.jpg
# 90 640x640/b082.png
# halftone/RANDOM-brit7-cont-14-gama1.1-smoothness0.8-number5-sizedark13-sizelight11-shape3-smooth1.1_20180501190447.jpg
# 92 640x640/b082.png
# halftone/RANDOM-brit-47-cont-22-gama3.4-smoothness3.9-number6-sizedark10-sizelight14-shape1-smooth0.7_20180501190503.jpg
# 94 640x640/b082.png
# halftone/RANDOM-brit50-cont44-gama4.4-smoothness2.3-number2-sizedark14-sizelight5-shape4-smooth1.6_20180501190518.jpg
# 96 640x640/b082.png
# halftone/RANDOM-brit28-cont-38-gama-0.4-smoothness3.2-number2-sizedark2-sizelight14-shape2-smooth1.0_20180501190525.jpg
# 98 640x640/b082.png
# halftone/RANDOM-brit12-cont5-gama-3.6-smoothness3.3-number9-sizedark15-sizelight7-shape2-smooth0.2_20180501190534.jpg
# 100 640x640/b082.png
# halftone/RANDOM-brit25-cont12-gama-0.6-smoothness7.4-number9-sizedark14-sizelight15-shape0-smooth0.7_20180501190543.jpg
# 102 640x640/b082.png
# halftone/RANDOM-brit28-cont-20-gama-3.7-smoothness7.0-number4-sizedark6-sizelight3-shape4-smooth1.2_20180501190601.jpg
# 104 640x640/b082.png
# halftone/RANDOM-brit45-cont35-gama5.4-smoothness0.4-number2-sizedark6-sizelight9-shape3-smooth1.8_20180501190612.jpg
# 106 640x640/b082.png
# halftone/RANDOM-brit-44-cont-47-gama2.5-smoothness6.8-number7-sizedark11-sizelight12-shape0-smooth1.5_20180501190620.jpg
# 108 640x640/b082.png
# halftone/RANDOM-brit35-cont-19-gama7.1-smoothness6.7-number9-sizedark4-sizelight11-shape3-smooth1.9_20180501190634.jpg
# 110 640x640/b082.png
# halftone/RANDOM-brit-3-cont46-gama2.8-smoothness4.0-number10-sizedark8-sizelight2-shape1-smooth1.5_20180501190655.jpg
# 112 640x640/b082.png
# halftone/RANDOM-brit44-cont-47-gama-0.2-smoothness1.9-number3-sizedark13-sizelight12-shape5-smooth0.5_20180501190707.jpg
# 114 640x640/b082.png
# halftone/RANDOM-brit-33-cont39-gama-2.5-smoothness1.5-number4-sizedark12-sizelight5-shape1-smooth1.9_20180501190717.jpg
# 116 640x640/b082.png
# halftone/RANDOM-brit29-cont10-gama2.4-smoothness4.2-number6-sizedark15-sizelight13-shape5-smooth1.9_20180501190729.jpg
# 118 640x640/b082.png
# halftone/RANDOM-brit-18-cont-7-gama1.0-smoothness7.6-number8-sizedark12-sizelight11-shape5-smooth0.6_20180501190747.jpg
# 120 640x640/b082.png
# halftone/RANDOM-brit28-cont-32-gama4.7-smoothness7.5-number5-sizedark2-sizelight12-shape2-smooth0.5_20180501190802.jpg
# 122 640x640/b082.png
# halftone/RANDOM-brit46-cont29-gama8.1-smoothness7.2-number5-sizedark11-sizelight2-shape5-smooth1.3_20180501190815.jpg
# 124 640x640/b082.png
# halftone/RANDOM-brit-20-cont-18-gama4.7-smoothness4.3-number7-sizedark6-sizelight9-shape0-smooth0.5_20180501190831.jpg
# 126 640x640/b082.png
# halftone/RANDOM-brit48-cont-24-gama6.0-smoothness4.3-number8-sizedark11-sizelight2-shape3-smooth1.8_20180501190842.jpg
# 128 640x640/b082.png
# halftone/RANDOM-brit-16-cont20-gama9.6-smoothness3.4-number9-sizedark12-sizelight7-shape0-smooth0.1_20180501190906.jpg
# 130 640x640/b082.png
# halftone/RANDOM-brit-16-cont35-gama6.4-smoothness0.3-number5-sizedark14-sizelight7-shape0-smooth2.0_20180501190925.jpg
# 132 640x640/b082.png
# halftone/RANDOM-brit-22-cont-50-gama2.1-smoothness4.3-number3-sizedark3-sizelight4-shape2-smooth1.2_20180501190936.jpg
# 134 640x640/b082.png
# halftone/RANDOM-brit11-cont-30-gama3.5-smoothness6.3-number6-sizedark5-sizelight12-shape5-smooth1.0_20180501190947.jpg
# 136 640x640/b082.png
# halftone/RANDOM-brit-6-cont-45-gama0.5-smoothness4.3-number8-sizedark11-sizelight2-shape1-smooth1.6_20180501191003.jpg
# 138 640x640/b082.png
# halftone/RANDOM-brit-9-cont47-gama0.6-smoothness2.4-number4-sizedark10-sizelight5-shape4-smooth0.5_20180501191021.jpg
# 140 640x640/b082.png
# halftone/RANDOM-brit-18-cont-38-gama2.3-smoothness3.5-number6-sizedark12-sizelight3-shape5-smooth1.7_20180501191031.jpg
# 142 640x640/b082.png
# halftone/RANDOM-brit24-cont50-gama7.0-smoothness2.6-number10-sizedark2-sizelight3-shape4-smooth0.4_20180501191041.jpg
# 144 640x640/b082.png
# halftone/RANDOM-brit-36-cont50-gama0.2-smoothness6.5-number8-sizedark5-sizelight11-shape5-smooth1.5_20180501191051.jpg
# 146 640x640/b082.png
# halftone/RANDOM-brit-49-cont-26-gama4.6-smoothness7.9-number9-sizedark4-sizelight10-shape1-smooth1.4_20180501191107.jpg
# 148 640x640/b082.png
# halftone/RANDOM-brit14-cont11-gama-3.7-smoothness3.9-number10-sizedark3-sizelight8-shape4-smooth0.5_20180501191119.jpg
# 150 640x640/b082.png
# halftone/RANDOM-brit21-cont39-gama8.5-smoothness3.1-number5-sizedark12-sizelight9-shape5-smooth1.9_20180501191133.jpg
# 152 640x640/b082.png
# halftone/RANDOM-brit28-cont18-gama-3.2-smoothness0.3-number8-sizedark4-sizelight7-shape3-smooth0.2_20180501191144.jpg
# 154 640x640/b082.png
# halftone/RANDOM-brit41-cont-50-gama4.2-smoothness0.1-number3-sizedark14-sizelight4-shape2-smooth1.3_20180501191155.jpg
# 156 640x640/b082.png
# halftone/RANDOM-brit34-cont-7-gama3.8-smoothness7.1-number7-sizedark9-sizelight13-shape3-smooth0.6_20180501191203.jpg
# 158 640x640/b082.png
# halftone/RANDOM-brit-4-cont28-gama-1.0-smoothness5.3-number4-sizedark4-sizelight5-shape5-smooth0.6_20180501191220.jpg
# 160 640x640/b082.png
# halftone/RANDOM-brit-39-cont-29-gama-1.1-smoothness6.7-number2-sizedark6-sizelight8-shape2-smooth0.9_20180501191230.jpg
# 162 640x640/b082.png
# halftone/RANDOM-brit11-cont-23-gama4.5-smoothness3.9-number4-sizedark5-sizelight7-shape5-smooth1.0_20180501191238.jpg
# 164 640x640/b082.png
# halftone/RANDOM-brit17-cont-39-gama2.0-smoothness6.8-number6-sizedark10-sizelight9-shape5-smooth1.6_20180501191250.jpg
# 166 640x640/b082.png
# halftone/RANDOM-brit-35-cont11-gama5.3-smoothness1.2-number3-sizedark5-sizelight3-shape4-smooth0.3_20180501191304.jpg
# 168 640x640/b082.png
# halftone/RANDOM-brit-11-cont31-gama-3.5-smoothness1.3-number8-sizedark2-sizelight12-shape5-smooth2.0_20180501191314.jpg
# 170 640x640/b082.png
# halftone/RANDOM-brit18-cont-15-gama-0.9-smoothness2.2-number6-sizedark13-sizelight10-shape1-smooth1.1_20180501191328.jpg
# 172 640x640/b082.png
# halftone/RANDOM-brit-35-cont-46-gama2.9-smoothness6.3-number6-sizedark6-sizelight12-shape0-smooth1.1_20180501191340.jpg
# 174 640x640/b082.png
# halftone/RANDOM-brit12-cont-46-gama4.6-smoothness5.1-number6-sizedark6-sizelight8-shape0-smooth0.9_20180501191350.jpg
# 176 640x640/b082.png
# halftone/RANDOM-brit49-cont-28-gama-4.7-smoothness2.5-number4-sizedark12-sizelight13-shape2-smooth0.6_20180501191407.jpg
# 178 640x640/b082.png
# halftone/RANDOM-brit28-cont15-gama6.9-smoothness3.3-number9-sizedark9-sizelight5-shape4-smooth1.1_20180501191418.jpg
# 180 640x640/b082.png
# halftone/RANDOM-brit42-cont-10-gama4.2-smoothness0.6-number9-sizedark3-sizelight15-shape5-smooth1.8_20180501191430.jpg
# 182 640x640/b082.png
# halftone/RANDOM-brit-22-cont21-gama4.4-smoothness6.4-number9-sizedark3-sizelight12-shape5-smooth1.5_20180501191500.jpg
# 184 640x640/b082.png
# halftone/RANDOM-brit-2-cont43-gama7.6-smoothness0.3-number3-sizedark13-sizelight13-shape0-smooth0.9_20180501191517.jpg
# 186 640x640/b082.png
# halftone/RANDOM-brit46-cont19-gama-3.2-smoothness5.2-number5-sizedark8-sizelight12-shape3-smooth0.1_20180501191527.jpg
# 188 640x640/b082.png
# halftone/RANDOM-brit49-cont12-gama6.3-smoothness0.4-number10-sizedark13-sizelight8-shape5-smooth0.3_20180501191551.jpg
# 190 640x640/b082.png
# halftone/RANDOM-brit-20-cont13-gama8.1-smoothness0.9-number4-sizedark14-sizelight9-shape1-smooth1.4_20180501191614.jpg
# 192 640x640/b082.png
# halftone/RANDOM-brit32-cont-42-gama1.7-smoothness7.0-number4-sizedark10-sizelight12-shape5-smooth0.7_20180501191625.jpg
# 194 640x640/b082.png
# halftone/RANDOM-brit48-cont7-gama4.6-smoothness7.4-number2-sizedark13-sizelight6-shape5-smooth0.6_20180501191637.jpg
# 196 640x640/b082.png
# halftone/RANDOM-brit-13-cont14-gama6.0-smoothness5.6-number6-sizedark5-sizelight9-shape2-smooth1.6_20180501191645.jpg
# 198 640x640/b082.png
# halftone/RANDOM-brit-23-cont35-gama7.9-smoothness7.2-number8-sizedark4-sizelight13-shape0-smooth1.6_20180501191658.jpg
# 200 640x640/b082.png
# halftone/RANDOM-brit6-cont-18-gama1.9-smoothness7.3-number5-sizedark13-sizelight9-shape4-smooth1.0_20180501191710.jpg
# 202 640x640/b082.png
# halftone/RANDOM-brit30-cont-25-gama-0.6-smoothness1.3-number7-sizedark4-sizelight2-shape3-smooth0.3_20180501191723.jpg
# 204 640x640/b082.png
# halftone/RANDOM-brit-36-cont17-gama0.7-smoothness8.0-number2-sizedark11-sizelight5-shape2-smooth0.8_20180501191738.jpg
# 206 640x640/b082.png
# halftone/RANDOM-brit28-cont33-gama7.0-smoothness4.9-number6-sizedark15-sizelight6-shape3-smooth1.1_20180501191746.jpg
# 208 640x640/b082.png
# halftone/RANDOM-brit20-cont33-gama2.1-smoothness5.6-number6-sizedark9-sizelight7-shape3-smooth0.9_20180501191759.jpg
# 210 640x640/b082.png
# halftone/RANDOM-brit13-cont-18-gama3.2-smoothness6.0-number7-sizedark14-sizelight11-shape0-smooth1.0_20180501191813.jpg
# 212 640x640/b082.png
# halftone/RANDOM-brit24-cont-24-gama9.5-smoothness3.3-number8-sizedark4-sizelight15-shape2-smooth1.2_20180501191833.jpg
# 214 640x640/b082.png
# halftone/RANDOM-brit-12-cont32-gama0.6-smoothness7.4-number5-sizedark8-sizelight6-shape5-smooth1.7_20180501191848.jpg
# 216 640x640/b082.png
# halftone/RANDOM-brit-43-cont41-gama5.5-smoothness0.3-number5-sizedark3-sizelight8-shape1-smooth1.4_20180501191901.jpg
# 218 640x640/b082.png
# halftone/RANDOM-brit-37-cont36-gama-0.3-smoothness6.7-number2-sizedark7-sizelight3-shape5-smooth1.2_20180501191913.jpg
# 220 640x640/b082.png
# halftone/RANDOM-brit-23-cont-27-gama5.6-smoothness3.8-number3-sizedark7-sizelight10-shape5-smooth1.7_20180501191919.jpg
# 222 640x640/b082.png
# halftone/RANDOM-brit-10-cont42-gama4.5-smoothness2.3-number9-sizedark8-sizelight13-shape3-smooth1.7_20180501191929.jpg
# 224 640x640/b082.png
# halftone/RANDOM-brit31-cont-8-gama0.6-smoothness1.5-number5-sizedark8-sizelight14-shape4-smooth1.6_20180501191945.jpg
# 226 640x640/b082.png
# halftone/RANDOM-brit35-cont28-gama8.4-smoothness7.6-number9-sizedark2-sizelight12-shape5-smooth1.0_20180501191959.jpg
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-254-52b87efe33fb> in <module>()
#      29 while True:
#      30     count = count+1
# ---> 31     filein = LST[count]
#      32     filein = filein.replace("\n","")
#      33     count = count +1
#
# IndexError: list index out of range

# %%
#Posturize VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
"""
Posturize Parameters
smoothness 150 - ( float  0 - 800 )
edges 30       - ( float  0 - 100 )
paint 1        - ( float  0 -  10 )
minimal area 9 - ( int    0 -  64 )
outline 0      - ( int    0 - 100)

-v -99 -fx_posterize 150,30,1,12,0,0,0,0
-v -99 -fx_posterize_preview 0,0,1.54472,12,8,17.0732,1,0

"""
# create a list in memory of a directory
LST = []
PATH = "640x640/"
for files in sorted(os.listdir(PATH)):
    LST.append(PATH+files)
    
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    sm =randint(40,4000)*.1
    edge =randint(200,1000)*.1    
    paint = randint(10,100)*.1
    #paint = randint(2,10)
    #mini = randint(0,640)*.1
    mini = randint(0,96)
    minix = randint(0,100)
    outline = randint(0,20)
    linez = randint(0,80)
    sm = str(sm)
    edge = str(edge)
    paint = str(paint)
    mini = str(mini)
    minix = str(minix)
    outline =str(outline)
    linez = str(linez) 
    filename = time.strftime("posterize/RANDOM-sm"+sm+"-edge"+edge+"-paint"+paint+"-mini"+mini+"-minix"+minix+"-outline"+outline+"-linez"+linez+"_%Y%m%d%H%M%S.jpg")
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
    subprocess.call("gmic -input "+filein+" -v 0 -fx_posterize "+sm+","+edge+","+paint+","+mini+","+minix+","+outline+","+linez+",0 \
    -normalize[-0] 0,255 -output "+filename, shell=True)
    #-v -99 -fx_posterize 150,20,1.54472,12,8,15,1,0
    sleep(5)
    print filename
# Out:
# 2 640x640/b082.png
# posterize/RANDOM-sm170.7-edge75.7-paint7.4-mini63-minix4-outline13-linez49_20180501153237.jpg
# 4 640x640/b082.png
# posterize/RANDOM-sm10.4-edge32.8-paint8.7-mini67-minix81-outline16-linez42_20180501153257.jpg
# 6 640x640/b082.png
# posterize/RANDOM-sm16.6-edge71.9-paint3.0-mini15-minix39-outline5-linez15_20180501153308.jpg
# 8 640x640/b082.png
# posterize/RANDOM-sm278.2-edge36.1-paint2.8-mini70-minix100-outline1-linez70_20180501153321.jpg
# 10 640x640/b082.png
# posterize/RANDOM-sm273.2-edge89.8-paint3.4-mini47-minix68-outline8-linez46_20180501153340.jpg
# 12 640x640/b082.png
# posterize/RANDOM-sm117.6-edge43.1-paint2.7-mini31-minix57-outline17-linez19_20180501153358.jpg
# 14 640x640/b082.png
# posterize/RANDOM-sm285.0-edge76.8-paint2.9-mini87-minix96-outline9-linez78_20180501153421.jpg
# 16 640x640/b082.png
# posterize/RANDOM-sm37.1-edge90.7-paint8.0-mini44-minix39-outline7-linez52_20180501153441.jpg
# 18 640x640/b082.png
# posterize/RANDOM-sm25.2-edge75.2-paint5.9-mini54-minix18-outline3-linez15_20180501153454.jpg
# 20 640x640/b082.png
# posterize/RANDOM-sm163.6-edge38.0-paint5.5-mini21-minix82-outline20-linez46_20180501153505.jpg
# 22 640x640/b082.png
# posterize/RANDOM-sm240.0-edge36.8-paint8.6-mini91-minix89-outline8-linez10_20180501153520.jpg
# 24 640x640/b082.png
# posterize/RANDOM-sm113.6-edge49.1-paint6.0-mini74-minix20-outline6-linez59_20180501153537.jpg
# 26 640x640/b082.png
# posterize/RANDOM-sm269.3-edge34.9-paint1.7-mini78-minix8-outline2-linez50_20180501153551.jpg
# 28 640x640/b082.png
# posterize/RANDOM-sm244.6-edge79.8-paint5.9-mini20-minix39-outline0-linez43_20180501153609.jpg
# 30 640x640/b082.png
# posterize/RANDOM-sm148.3-edge82.7-paint9.6-mini35-minix21-outline17-linez53_20180501153634.jpg
# 32 640x640/b082.png
# posterize/RANDOM-sm187.3-edge45.4-paint7.6-mini49-minix88-outline14-linez43_20180501153648.jpg
# 34 640x640/b082.png
# posterize/RANDOM-sm369.4-edge61.3-paint5.6-mini57-minix3-outline16-linez63_20180501153703.jpg
# 36 640x640/b082.png
# posterize/RANDOM-sm176.0-edge99.2-paint7.7-mini73-minix48-outline15-linez43_20180501153722.jpg
# 38 640x640/b082.png
# posterize/RANDOM-sm210.9-edge59.2-paint6.8-mini94-minix95-outline7-linez8_20180501153736.jpg
# 40 640x640/b082.png
# posterize/RANDOM-sm383.5-edge41.3-paint3.3-mini81-minix94-outline4-linez73_20180501153753.jpg
# 42 640x640/b082.png
# posterize/RANDOM-sm364.0-edge55.9-paint6.6-mini18-minix81-outline16-linez73_20180501153816.jpg
# 44 640x640/b082.png
# posterize/RANDOM-sm252.1-edge49.6-paint7.9-mini65-minix79-outline18-linez0_20180501153841.jpg
# 46 640x640/b082.png
# posterize/RANDOM-sm281.3-edge58.5-paint8.9-mini24-minix28-outline20-linez1_20180501153902.jpg
# 48 640x640/b082.png
# posterize/RANDOM-sm394.1-edge80.0-paint8.9-mini33-minix44-outline16-linez13_20180501153930.jpg
# 50 640x640/b082.png
# posterize/RANDOM-sm337.7-edge45.1-paint2.3-mini22-minix69-outline13-linez20_20180501153955.jpg
# 52 640x640/b082.png
# posterize/RANDOM-sm4.5-edge58.7-paint3.5-mini83-minix39-outline20-linez64_20180501154019.jpg
# 54 640x640/b082.png
# posterize/RANDOM-sm261.9-edge81.5-paint4.9-mini69-minix85-outline7-linez42_20180501154029.jpg
# 56 640x640/b082.png
# posterize/RANDOM-sm173.3-edge60.8-paint2.3-mini64-minix89-outline10-linez48_20180501154049.jpg
# 58 640x640/b082.png
# posterize/RANDOM-sm263.9-edge87.8-paint3.7-mini67-minix69-outline0-linez27_20180501154102.jpg
# 60 640x640/b082.png
# posterize/RANDOM-sm326.6-edge26.8-paint1.7-mini41-minix68-outline2-linez74_20180501154116.jpg
# 62 640x640/b082.png
# posterize/RANDOM-sm248.4-edge60.2-paint9.4-mini29-minix73-outline17-linez57_20180501154139.jpg
# 64 640x640/b082.png
# posterize/RANDOM-sm187.6-edge67.9-paint6.7-mini29-minix5-outline9-linez66_20180501154156.jpg
# 66 640x640/b082.png
# posterize/RANDOM-sm291.2-edge44.9-paint2.0-mini36-minix61-outline5-linez61_20180501154217.jpg
# 68 640x640/b082.png
# posterize/RANDOM-sm32.7-edge58.4-paint10.0-mini71-minix20-outline19-linez16_20180501154235.jpg
# 70 640x640/b082.png
# posterize/RANDOM-sm203.7-edge94.4-paint2.2-mini41-minix13-outline13-linez53_20180501154248.jpg
# 72 640x640/b082.png
# posterize/RANDOM-sm150.6-edge98.5-paint4.9-mini56-minix38-outline3-linez15_20180501154303.jpg
# 74 640x640/b082.png
# posterize/RANDOM-sm254.2-edge54.5-paint3.9-mini25-minix98-outline5-linez77_20180501154323.jpg
# 76 640x640/b082.png
# posterize/RANDOM-sm349.3-edge44.8-paint9.4-mini16-minix5-outline12-linez37_20180501154342.jpg
# 78 640x640/b082.png
# posterize/RANDOM-sm84.9-edge64.2-paint3.0-mini65-minix32-outline1-linez63_20180501154409.jpg
# 80 640x640/b082.png
# posterize/RANDOM-sm320.9-edge20.6-paint2.1-mini14-minix75-outline12-linez43_20180501154423.jpg
# 82 640x640/b082.png
# posterize/RANDOM-sm396.6-edge22.6-paint1.7-mini16-minix49-outline14-linez33_20180501154445.jpg
# 84 640x640/b082.png
# posterize/RANDOM-sm126.2-edge49.9-paint9.3-mini68-minix0-outline9-linez38_20180501154508.jpg
# 86 640x640/b082.png
# posterize/RANDOM-sm308.1-edge70.7-paint1.9-mini56-minix19-outline0-linez73_20180501154522.jpg
# 88 640x640/b082.png
# posterize/RANDOM-sm178.6-edge61.8-paint8.3-mini78-minix38-outline1-linez70_20180501154542.jpg
# 90 640x640/b082.png
# posterize/RANDOM-sm347.6-edge49.5-paint9.9-mini31-minix96-outline3-linez36_20180501154558.jpg
# 92 640x640/b082.png
# posterize/RANDOM-sm326.1-edge66.6-paint6.7-mini14-minix54-outline15-linez40_20180501154624.jpg
# 94 640x640/b082.png
# posterize/RANDOM-sm339.0-edge24.5-paint4.5-mini77-minix25-outline1-linez17_20180501154642.jpg
# 96 640x640/b082.png
# posterize/RANDOM-sm337.7-edge23.5-paint3.8-mini17-minix13-outline19-linez45_20180501154703.jpg
# 98 640x640/b082.png
# posterize/RANDOM-sm214.7-edge47.5-paint9.5-mini19-minix11-outline6-linez53_20180501154723.jpg
# 100 640x640/b082.png
# posterize/RANDOM-sm227.5-edge26.3-paint2.3-mini87-minix77-outline4-linez28_20180501154746.jpg
# 102 640x640/b082.png
# posterize/RANDOM-sm73.8-edge40.9-paint1.3-mini85-minix1-outline17-linez48_20180501154806.jpg
# 104 640x640/b082.png
# posterize/RANDOM-sm53.4-edge60.1-paint3.4-mini45-minix16-outline3-linez69_20180501154817.jpg
# 106 640x640/b082.png
# posterize/RANDOM-sm90.3-edge52.0-paint8.6-mini77-minix96-outline7-linez43_20180501154833.jpg
# 108 640x640/b082.png
# posterize/RANDOM-sm278.9-edge82.1-paint1.6-mini42-minix35-outline10-linez36_20180501154845.jpg
# 110 640x640/b082.png
# posterize/RANDOM-sm250.8-edge69.2-paint6.3-mini2-minix23-outline18-linez63_20180501154902.jpg
# 112 640x640/b082.png
# posterize/RANDOM-sm14.6-edge83.9-paint2.8-mini75-minix51-outline19-linez18_20180501154916.jpg
# 114 640x640/b082.png
# posterize/RANDOM-sm285.2-edge89.7-paint7.4-mini25-minix8-outline12-linez40_20180501154928.jpg
# 116 640x640/b082.png
# posterize/RANDOM-sm221.7-edge58.6-paint3.2-mini30-minix75-outline12-linez20_20180501154950.jpg
# 118 640x640/b082.png
# posterize/RANDOM-sm391.8-edge60.0-paint9.6-mini41-minix83-outline19-linez71_20180501155013.jpg
# 120 640x640/b082.png
# posterize/RANDOM-sm57.7-edge98.3-paint1.1-mini52-minix55-outline19-linez51_20180501155035.jpg
# 122 640x640/b082.png
# posterize/RANDOM-sm85.4-edge53.0-paint3.5-mini77-minix39-outline13-linez80_20180501155047.jpg
# 124 640x640/b082.png
# posterize/RANDOM-sm362.4-edge47.3-paint1.0-mini13-minix82-outline17-linez1_20180501155058.jpg
# 126 640x640/b082.png
# posterize/RANDOM-sm182.4-edge97.6-paint3.9-mini90-minix100-outline8-linez13_20180501155122.jpg
# 128 640x640/b082.png
# posterize/RANDOM-sm246.1-edge25.0-paint5.9-mini29-minix21-outline20-linez77_20180501155138.jpg
# 130 640x640/b082.png
# posterize/RANDOM-sm338.4-edge20.1-paint10.0-mini33-minix60-outline12-linez28_20180501155157.jpg
# 132 640x640/b082.png
# posterize/RANDOM-sm301.3-edge43.0-paint7.0-mini25-minix5-outline3-linez40_20180501155224.jpg
# 134 640x640/b082.png
# posterize/RANDOM-sm305.5-edge84.2-paint2.1-mini45-minix73-outline17-linez68_20180501155245.jpg
# 136 640x640/b082.png
# posterize/RANDOM-sm343.0-edge48.5-paint5.1-mini66-minix53-outline19-linez34_20180501155303.jpg
# 138 640x640/b082.png
# posterize/RANDOM-sm126.7-edge94.6-paint9.6-mini17-minix92-outline11-linez14_20180501155322.jpg
# 140 640x640/b082.png
# posterize/RANDOM-sm186.4-edge35.0-paint9.5-mini62-minix13-outline19-linez66_20180501155339.jpg
# 142 640x640/b082.png
# posterize/RANDOM-sm219.5-edge32.4-paint3.7-mini67-minix85-outline14-linez39_20180501155351.jpg
# 144 640x640/b082.png
# posterize/RANDOM-sm211.1-edge39.0-paint8.4-mini61-minix47-outline6-linez16_20180501155409.jpg
# 146 640x640/b082.png
# posterize/RANDOM-sm95.0-edge77.9-paint6.7-mini44-minix84-outline4-linez21_20180501155428.jpg
# 148 640x640/b082.png
# posterize/RANDOM-sm104.6-edge75.3-paint4.3-mini13-minix37-outline10-linez25_20180501155444.jpg
# 150 640x640/b082.png
# posterize/RANDOM-sm360.0-edge50.0-paint3.9-mini43-minix78-outline17-linez30_20180501155458.jpg
# 152 640x640/b082.png
# posterize/RANDOM-sm12.8-edge98.0-paint3.9-mini24-minix34-outline7-linez64_20180501155516.jpg
# 154 640x640/b082.png
# posterize/RANDOM-sm52.9-edge62.0-paint6.1-mini30-minix84-outline20-linez70_20180501155528.jpg
# 156 640x640/b082.png
# posterize/RANDOM-sm40.6-edge39.4-paint8.4-mini2-minix20-outline0-linez22_20180501155541.jpg
# 158 640x640/b082.png
# posterize/RANDOM-sm5.8-edge56.5-paint8.0-mini41-minix97-outline1-linez28_20180501155549.jpg
# 160 640x640/b082.png
# posterize/RANDOM-sm165.4-edge72.5-paint9.5-mini68-minix3-outline2-linez11_20180501155603.jpg
# 162 640x640/b082.png
# posterize/RANDOM-sm298.4-edge25.5-paint2.4-mini81-minix73-outline15-linez79_20180501155618.jpg
# 164 640x640/b082.png
# posterize/RANDOM-sm205.4-edge27.0-paint1.7-mini9-minix56-outline2-linez75_20180501155637.jpg
# 166 640x640/b082.png
# posterize/RANDOM-sm34.0-edge87.3-paint8.1-mini86-minix96-outline17-linez42_20180501155653.jpg
# 168 640x640/b082.png
# posterize/RANDOM-sm12.9-edge74.1-paint1.6-mini72-minix48-outline15-linez21_20180501155704.jpg
# 170 640x640/b082.png
# posterize/RANDOM-sm82.1-edge38.1-paint6.3-mini60-minix82-outline3-linez40_20180501155720.jpg
# 172 640x640/b082.png
# posterize/RANDOM-sm244.1-edge39.0-paint6.7-mini77-minix13-outline12-linez12_20180501155735.jpg
# 174 640x640/b082.png
# posterize/RANDOM-sm82.3-edge97.0-paint5.2-mini88-minix73-outline4-linez45_20180501155750.jpg
# 176 640x640/b082.png
# posterize/RANDOM-sm214.9-edge73.1-paint8.6-mini84-minix80-outline16-linez37_20180501155803.jpg
# 178 640x640/b082.png
# posterize/RANDOM-sm222.1-edge90.3-paint9.1-mini95-minix73-outline10-linez50_20180501155818.jpg
# 180 640x640/b082.png
# posterize/RANDOM-sm372.2-edge44.6-paint2.5-mini2-minix62-outline11-linez77_20180501155834.jpg
# 182 640x640/b082.png
# posterize/RANDOM-sm323.3-edge84.7-paint5.4-mini8-minix30-outline12-linez21_20180501155852.jpg
# 184 640x640/b082.png
# posterize/RANDOM-sm256.7-edge27.2-paint10.0-mini87-minix25-outline2-linez41_20180501155909.jpg
# 186 640x640/b082.png
# posterize/RANDOM-sm221.9-edge44.1-paint1.4-mini19-minix57-outline1-linez66_20180501155931.jpg
# 188 640x640/b082.png
# posterize/RANDOM-sm315.1-edge87.5-paint8.1-mini40-minix43-outline11-linez54_20180501155949.jpg
# 190 640x640/b082.png
# posterize/RANDOM-sm251.0-edge35.0-paint1.4-mini39-minix21-outline10-linez37_20180501160015.jpg
# 192 640x640/b082.png
# posterize/RANDOM-sm253.7-edge95.3-paint1.2-mini96-minix74-outline20-linez7_20180501160034.jpg
# 194 640x640/b082.png
# posterize/RANDOM-sm94.2-edge65.5-paint1.8-mini3-minix22-outline0-linez73_20180501160052.jpg
# 196 640x640/b082.png
# posterize/RANDOM-sm352.3-edge36.3-paint5.0-mini13-minix88-outline8-linez66_20180501160102.jpg
# 198 640x640/b082.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-236-531c294afcac> in <module>()
#      48     #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
#      49     #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
# ---> 50     subprocess.call("gmic -input "+filein+" -v 0 -fx_posterize "+sm+","+edge+","+paint+","+mini+","+minix+","+outline+","+linez+",0     -normalize[-0] 0,255 -output "+filename, shell=True)
#      51     #-v -99 -fx_posterize 150,20,1.54472,12,8,15,1,0
#      52     sleep(5)
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in call(*popenargs, **kwargs)
#     166     retcode = call(["ls", "-l"])
#     167     """
# --> 168     return Popen(*popenargs, **kwargs).wait()
#     169
#     170
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in wait(self)
#    1075             while self.returncode is None:
#    1076                 try:
# -> 1077                     pid, sts = _eintr_retry_call(os.waitpid, self.pid, 0)
#    1078                 except OSError as e:
#    1079                     if e.errno != errno.ECHILD:
#
# /home/jack/anaconda2/lib/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     119     while True:
#     120         try:
# --> 121             return func(*args)
#     122         except (OSError, IOError) as e:
#     123             if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %%
#VERY GOOD 
import subprocess
import os
from random import randint
from time import sleep
count = 0
while True:
    count = count+1
    filein = LST[count]
    filein = filein.replace("\n","")
    count = count +1
    print count,line
    sm =randint(0,5)
    sh =randint(50,250)
    thres = randint(5,50)
    thk = randint(1,5)*.1
    col = (randint(1,10)*1.1)-1
    quant = randint(3,10)
    sm = str(sm)
    quant = str(quant)
    col = str(col)
    thres = str(thres)
    thk = str(thk)
    sh = str(sh)
    filename = time.strftime("cartoon/RANDOM-sm"+sm+"-sh"+sh+"-thres"+thres+"-thk"+thk+"-col"+col+"-quant"+quant+"%Y%m%d%H%M%S.jpg")
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,124.771,20,0.5,1.5,8,0 \
    #subprocess.call("gmic -input "+filein+" -v 0 -cartoon" +sm+" "+sh+" "+thres+" "+thk+" "+col+" "+quant+\
    subprocess.call("gmic -input "+filein+" -v 0 -cartoon 1,"+sh+","+thres+","+thk+","+col+","+quant+",0 \
    -normalize[-0] 60,255 -output "+filename, shell=True)
    sleep(1)
# Out:
# 2  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 4  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 6  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 8  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 10  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 12  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 14  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 16  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 18  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 20  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 22  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 24  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 26  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 28  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 30  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 32  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 34  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 36  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 38  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 40  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 42  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 44  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 46  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 48  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 50  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 52  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 54  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 56  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 58  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 60  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 62  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 64  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 66  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 68  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 70  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 72  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 74  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 76  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 78  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 80  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 82  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 84  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 86  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 88  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 90  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 92  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 94  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 96  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 98  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 100  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 102  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 104  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 106  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 108  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 110  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 112  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 114  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 116  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 118  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 120  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 122  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 124  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 126  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 128  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 130  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 132  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 134  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 136  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 138  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 140  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 142  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 144  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 146  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 148  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 150  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 152  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 154  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 156  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 158  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 160  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 162  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 164  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 166  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 168  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 170  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 172  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 174  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 176  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 178  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 180  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 182  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 184  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 186  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 188  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 190  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 192  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 194  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 196  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 198  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 200  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 202  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 204  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 206  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 208  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 210  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 212  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 214  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 216  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 218  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 220  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 222  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 224  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# 226  ** G'MIC comes with ABSOLUTELY NO WARRANTY; for details visit: http://gmic.eu **
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-188-0273e6c1df14> in <module>()
#       6 while True:
#       7     count = count+1
# ----> 8     filein = LST[count]
#       9     filein = filein.replace("\n","")
#      10     count = count +1
#
# IndexError: list index out of range
